# %% [markdown]
# <a href="https://www.kaggle.com/code/miradelimanr/burger-in-south-jakarta?scriptVersionId=98399322" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # **South Jakarta**
#
# This is another grand city in Jakarta besides of Central Jakarta. It's famous for being trendy among the youth. Some famous district are Blok M (which actually shopping block area), Senopati, Tebet, Kuningan (business district) and Pondok Indah (high end housing complex). Some of district here also not so far from SCBD in Central Jakarta.
#
# # Content
# * District
# * Price Range
# * Facility
# * Rating

# %%
import pandas as pd
from pandasql import sqldf
burger = pd.read_csv('../input/south-jakarta-burger/south_jakarta.csv', encoding = 'unicode_escape', sep = ";")

# %% [markdown]
# # District

# %%
district = sqldf("SELECT DISTINCT district FROM burger").transpose()
district
# Out:
#               0      1      2         3             4       5          6   \
# District  Blok M  Tebet  Karet  Kuningan  Pondok Indah  Kemang  Setiabudi
#
#                     7         8          9     10       11
# District  Pasar Minggu  Senopati  Fatmawati  SCBD  Senayan

# %% [markdown]
# Then here is the restaurant/partlors available in South Jakarta. There are total 24 vendors and rather dominated by fast food and budget section. Mostly Burger King, Blenger Burger, and Flip Burger. Least fast food available is Carl's Jr and the high end available are Lawless Burgerbar and TGI Fridays Lippo Kemang.

# %%
burger = sqldf("SELECT no, partlor_name, district, unique_menu, price FROM burger")
burger.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_87ffd_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >no</th>
#       <th class="col_heading level0 col1" >partlor_name</th>
#       <th class="col_heading level0 col2" >District</th>
#       <th class="col_heading level0 col3" >unique_menu</th>
#       <th class="col_heading level0 col4" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_87ffd_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_87ffd_row0_col1" class="data row0 col1" >Burger King</td>
#       <td id="T_87ffd_row0_col2" class="data row0 col2" >Blok M</td>
#       <td id="T_87ffd_row0_col3" class="data row0 col3" >Double Cheese Burger</td>
#       <td id="T_87ffd_row0_col4" class="data row0 col4" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_87ffd_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_87ffd_row1_col1" class="data row1 col1" >Burger King</td>
# ...

# %% [markdown]
# # Price-Range
#
# We sorted the list from the most expensive and also the cheapest, also with the price range from IDR 50000 to 100000. Here is the order from the most expensive. The most expensive here is TGI Fridays Lippo Mall Kemang which ranged 100k per menu, the cheapest is Burger Bakar Qebul which ranged 13k per menu. Mostly budgeted below 50k.

# %%
#most expensive
burger_price = sqldf("""SELECT partlor_name, district, unique_menu, price 
                        FROM burger 
                        ORDER BY price DESC""")
burger_price.head().style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_541ce_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_541ce_row0_col0" class="data row0 col0" >TGI Fridays Lippo Mall Kemang</td>
#       <td id="T_541ce_row0_col1" class="data row0 col1" >Kemang</td>
#       <td id="T_541ce_row0_col2" class="data row0 col2" >Fridays Cheeseburger</td>
#       <td id="T_541ce_row0_col3" class="data row0 col3" >129000</td>
#     </tr>
#     <tr>
#       <td id="T_541ce_row1_col0" class="data row1 col0" >Three Buns</td>
#       <td id="T_541ce_row1_col1" class="data row1 col1" >Senopati</td>
#       <td id="T_541ce_row1_col2" class="data row1 col2" >Rambo</td>
# ...

# %%
#cheapest
burger_price = sqldf("""SELECT partlor_name, district, unique_menu, price 
                        FROM burger 
                        ORDER BY price""")
burger_price.head().style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_cb570_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cb570_row0_col0" class="data row0 col0" >Burger Bakar Qebul</td>
#       <td id="T_cb570_row0_col1" class="data row0 col1" >Pasar Minggu</td>
#       <td id="T_cb570_row0_col2" class="data row0 col2" >Beef Burger</td>
#       <td id="T_cb570_row0_col3" class="data row0 col3" >13000</td>
#     </tr>
#     <tr>
#       <td id="T_cb570_row1_col0" class="data row1 col0" >Blenger Burger</td>
#       <td id="T_cb570_row1_col1" class="data row1 col1" >Fatmawati</td>
#       <td id="T_cb570_row1_col2" class="data row1 col2" >Cheese Burger</td>
# ...

# %%
#more than IDR 100000
burger_price = sqldf("""SELECT partlor_name, district, unique_menu, price
                        FROM burger 
                        WHERE price >= 100000""")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_b0a01_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b0a01_row0_col0" class="data row0 col0" >Three Buns</td>
#       <td id="T_b0a01_row0_col1" class="data row0 col1" >Senopati</td>
#       <td id="T_b0a01_row0_col2" class="data row0 col2" >Rambo</td>
#       <td id="T_b0a01_row0_col3" class="data row0 col3" >115000</td>
#     </tr>
#     <tr>
#       <td id="T_b0a01_row1_col0" class="data row1 col0" >TGI Fridays Lippo Mall Kemang</td>
#       <td id="T_b0a01_row1_col1" class="data row1 col1" >Kemang</td>
#       <td id="T_b0a01_row1_col2" class="data row1 col2" >Fridays Cheeseburger</td>
# ...

# %%
#between 50000 to 100000
burger_price = sqldf("""SELECT partlor_name, district, unique_menu, price
                        FROM burger 
                        WHERE price BETWEEN 50000 AND 100000""")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_8b037_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8b037_row0_col0" class="data row0 col0" >Goods Burger</td>
#       <td id="T_8b037_row0_col1" class="data row0 col1" >Pondok Indah</td>
#       <td id="T_8b037_row0_col2" class="data row0 col2" >Goods Coffee Rub</td>
#       <td id="T_8b037_row0_col3" class="data row0 col3" >65000</td>
#     </tr>
#     <tr>
#       <td id="T_8b037_row1_col0" class="data row1 col0" >Lawless Burgerbar</td>
#       <td id="T_8b037_row1_col1" class="data row1 col1" >Kemang</td>
#       <td id="T_8b037_row1_col2" class="data row1 col2" >Philly Anselmo</td>
# ...

# %%
#below IDR 100000
burger_price = sqldf("""SELECT partlor_name, district, unique_menu, price
                        FROM burger 
                        WHERE price <= 50000""")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_5b8f3_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5b8f3_row0_col0" class="data row0 col0" >Burger King</td>
#       <td id="T_5b8f3_row0_col1" class="data row0 col1" >Blok M</td>
#       <td id="T_5b8f3_row0_col2" class="data row0 col2" >Double Cheese Burger</td>
#       <td id="T_5b8f3_row0_col3" class="data row0 col3" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_5b8f3_row1_col0" class="data row1 col0" >Burger King</td>
#       <td id="T_5b8f3_row1_col1" class="data row1 col1" >Tebet</td>
#       <td id="T_5b8f3_row1_col2" class="data row1 col2" >Double Cheese Burger</td>
#       <td id="T_5b8f3_row1_col3" class="data row1 col3" >41818</td>
# ...

# %% [markdown]
# # Facility
#
# Last but not least, we chose the restaurant whether we could takeaway, or deliver our food. We also could find out whether these partlor has outdoor seats, smoking room, wifi, and reservation. Last but not least, we researched about poultry with some dietary restriction like alcohol and halal_menu. But this halal menu will not available in other project. We changed to other_poultry instead.
#
# Mostly they can do takeaway but for delivery there are some vendors unable to do so. Outdoor seat and smoking area also mostly available, let alone with wifi. There are only four vendor which needed/able to reserve, as for dietary restriction there are alcohol on high end restaurant like Lawless Burgerbar, Three Buns, TGI Fridays, and Byurgers, only one remaining which has pork menu.
#
# No drive thru options unfortunately.
#
# Let's take a look for all the facility.

# %%
burger = sqldf("""SELECT no, partlor_name, district, takeaway, delivery, outdoor_seat, smoking_area
                         alcohol_served, wifi, reservation, drive_thru, halal_food 
                  FROM burger""")
burger.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_d32b0_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >no</th>
#       <th class="col_heading level0 col1" >partlor_name</th>
#       <th class="col_heading level0 col2" >District</th>
#       <th class="col_heading level0 col3" >takeaway</th>
#       <th class="col_heading level0 col4" >delivery</th>
#       <th class="col_heading level0 col5" >outdoor_seat</th>
#       <th class="col_heading level0 col6" >alcohol_served</th>
#       <th class="col_heading level0 col7" >wifi</th>
#       <th class="col_heading level0 col8" >reservation</th>
#       <th class="col_heading level0 col9" >drive_thru</th>
#       <th class="col_heading level0 col10" >halal_food</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d32b0_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_d32b0_row0_col1" class="data row0 col1" >Burger King</td>
# ...

# %% [markdown]
# # Rating
#
# From the list Lawless Burgerbar Kemang is the most well known among the city (scored 4.6), followed by Burger Bakar Qebul which scored 4.4, and Byurger which scored 4,4. If the score is more than 3.5 then the partlor is worthed to try. All the facility and menu are representated by all both google and platform rating and count, so in the meantime only ratings are counted here.

# %%
burger = sqldf("""SELECT partlor_name, district, 
                         ltrim(google_rating) as google_rating, 
                         ltrim(zomato_rating) as zomato_rating, 
                         ltrim(qraved_rating) as qraved_rating, 
                         ltrim((google_rating + zomato_rating + qraved_rating)/3) as total_rating,
                    CASE
                        WHEN ltrim((google_rating + zomato_rating + qraved_rating)/3) >= 3.5 THEN "Recommended"
                        ELSE "Reconsider"
                    END AS "Recommendation"
                    FROM burger
                    ORDER BY total_rating DESC""")
burger.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_7ed72_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >google_rating</th>
#       <th class="col_heading level0 col3" >zomato_rating</th>
#       <th class="col_heading level0 col4" >qraved_rating</th>
#       <th class="col_heading level0 col5" >total_rating</th>
#       <th class="col_heading level0 col6" >Recommendation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7ed72_row0_col0" class="data row0 col0" >Lawless Burgerbar</td>
#       <td id="T_7ed72_row0_col1" class="data row0 col1" >Kemang</td>
#       <td id="T_7ed72_row0_col2" class="data row0 col2" >4.7</td>
#       <td id="T_7ed72_row0_col3" class="data row0 col3" >4.7</td>
#       <td id="T_7ed72_row0_col4" class="data row0 col4" >4.6</td>
# ...
