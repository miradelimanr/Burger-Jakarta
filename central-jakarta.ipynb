# %% [markdown]
# # **Central Jakarta**
#
# Central Jakarta is the center of life for entire Jakarta. One of the most popular district is SCBD (Sudirman Center Business District) where all the business is started. If you heard about Pacific Place then the place is there.
#
# Besides, Menteng, Thamrin (Grand Indonesia), and Cempaka Putih also famous for its high end lifestyle. So some burgers are served in proper restaurant. Even though there are also bunch of cheap burger which lower than IDR 50000.

# %% [markdown]
# # Content
#
# * [District](#District)
# * [Price-Range](#Price-Range)
# * [Facility](#Facility)

# %%
import pandas as pd
from pandasql import sqldf
burger = pd.read_csv('../input/burger-central/central_jakarta.csv', sep = ";")

# %% [markdown]
# # District

# %%
partlor_name = sqldf("SELECT DISTINCT district FROM burger").transpose()
partlor_name
# Out:
#                0            1                2         3            4      5   \
# District  Thamrin  Tanah Abang  Bendungan Hilir  Sudirman  Hayam Wuruk  Senen
#
#                      6        7     8      9           10
# District  Cempaka Putih  Menteng  SCBD  Karet  Pecenongan

# %% [markdown]
# As we can see, there are 10 districts in Central Jakarta. Bendungan Hilir, Karet, and Tanah Abang is actually one region with Thamrin as the area are not so far from each other. Meanwhile Menteng is closer to Pecenongan, the furthest is Hayam Wuruk.
#
# Then here is all the details of burger restaurant/partlors. There are some high end restaurant but the budget and fast food are also available as well.

# %%
burger = sqldf("SELECT no, partlor_name, District, unique_menu, price FROM burger")
burger.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_cbbd6_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >no</th>
#       <th class="col_heading level0 col1" >partlor_name</th>
#       <th class="col_heading level0 col2" >District</th>
#       <th class="col_heading level0 col3" >unique_menu</th>
#       <th class="col_heading level0 col4" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cbbd6_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_cbbd6_row0_col1" class="data row0 col1" >Burger King Grand Indonesia</td>
#       <td id="T_cbbd6_row0_col2" class="data row0 col2" >Thamrin</td>
#       <td id="T_cbbd6_row0_col3" class="data row0 col3" >Whooper Jr.</td>
#       <td id="T_cbbd6_row0_col4" class="data row0 col4" >37273</td>
#     </tr>
#     <tr>
#       <td id="T_cbbd6_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_cbbd6_row1_col1" class="data row1 col1" >Burger King Thamrin City</td>
#       <td id="T_cbbd6_row1_col2" class="data row1 col2" >Tanah Abang</td>
#       <td id="T_cbbd6_row1_col3" class="data row1 col3" >Whooper Jr.</td>
#       <td id="T_cbbd6_row1_col4" class="data row1 col4" >37273</td>
#     </tr>
#     <tr>
#       <td id="T_cbbd6_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_cbbd6_row2_col1" class="data row2 col1" >Burger King Bendungan Hilir</td>
#       <td id="T_cbbd6_row2_col2" class="data row2 col2" >Bendungan Hilir</td>
#       <td id="T_cbbd6_row2_col3" class="data row2 col3" >Whooper Jr.</td>
#       <td id="T_cbbd6_row2_col4" class="data row2 col4" >37273</td>
#     </tr>
#     <tr>
#       <td id="T_cbbd6_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_cbbd6_row3_col1" class="data row3 col1" >Burger King Citywalk Sudirman</td>
#       <td id="T_cbbd6_row3_col2" class="data row3 col2" >Sudirman</td>
#       <td id="T_cbbd6_row3_col3" class="data row3 col3" >Cheese Burger</td>
#       <td id="T_cbbd6_row3_col4" class="data row3 col4" >25000</td>
#     </tr>
#     <tr>
#       <td id="T_cbbd6_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_cbbd6_row4_col1" class="data row4 col1" >Burger King Hayam Wuruk</td>
#       <td id="T_cbbd6_row4_col2" class="data row4 col2" >Hayam Wuruk</td>
#       <td id="T_cbbd6_row4_col3" class="data row4 col3" >Chicken Steakhouse BBQ</td>
#       <td id="T_cbbd6_row4_col4" class="data row4 col4" >59901</td>
#     </tr>
#     <tr>
#       <td id="T_cbbd6_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_cbbd6_row5_col1" class="data row5 col1" >Burger King Atrium Plaza</td>
#       <td id="T_cbbd6_row5_col2" class="data row5 col2" >Senen</td>
#       <td id="T_cbbd6_row5_col3" class="data row5 col3" >Mushroom Swiss XL</td>
#       <td id="T_cbbd6_row5_col4" class="data row5 col4" >59901</td>
#     </tr>
#     <tr>
#       <td id="T_cbbd6_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_cbbd6_row6_col1" class="data row6 col1" >Burger King Cempaka Putih</td>
#       <td id="T_cbbd6_row6_col2" class="data row6 col2" >Cempaka Putih</td>
#       <td id="T_cbbd6_row6_col3" class="data row6 col3" >Whooper Jr.</td>
#       <td id="T_cbbd6_row6_col4" class="data row6 col4" >37273</td>
#     </tr>
#     <tr>
#       <td id="T_cbbd6_row7_col0" class="data row7 col0" >9</td>
#       <td id="T_cbbd6_row7_col1" class="data row7 col1" >Flip Burger</td>
#       <td id="T_cbbd6_row7_col2" class="data row7 col2" >Sudirman</td>
#       <td id="T_cbbd6_row7_col3" class="data row7 col3" >Cheese Burger</td>
#       <td id="T_cbbd6_row7_col4" class="data row7 col4" >40909</td>
#     </tr>
#     <tr>
#       <td id="T_cbbd6_row8_col0" class="data row8 col0" >10</td>
#       <td id="T_cbbd6_row8_col1" class="data row8 col1" >Lawless Burger</td>
#       <td id="T_cbbd6_row8_col2" class="data row8 col2" >Menteng</td>
#       <td id="T_cbbd6_row8_col3" class="data row8 col3" >The Lemmy</td>
#       <td id="T_cbbd6_row8_col4" class="data row8 col4" >105000</td>
#     </tr>
#     <tr>
#       <td id="T_cbbd6_row9_col0" class="data row9 col0" >11</td>
#       <td id="T_cbbd6_row9_col1" class="data row9 col1" >Lemoe Burger</td>
#       <td id="T_cbbd6_row9_col2" class="data row9 col2" >Cempaka Putih</td>
#       <td id="T_cbbd6_row9_col3" class="data row9 col3" >Chicken Cabe Ijo</td>
#       <td id="T_cbbd6_row9_col4" class="data row9 col4" >14000</td>
#     </tr>
#     <tr>
#       <td id="T_cbbd6_row10_col0" class="data row10 col0" >12</td>
#       <td id="T_cbbd6_row10_col1" class="data row10 col1" >Le Burger</td>
#       <td id="T_cbbd6_row10_col2" class="data row10 col2" >Sudirman</td>
#       <td id="T_cbbd6_row10_col3" class="data row10 col3" >Truffle Burger</td>
#       <td id="T_cbbd6_row10_col4" class="data row10 col4" >130000</td>
#     </tr>
#     <tr>
#       <td id="T_cbbd6_row11_col0" class="data row11 col0" >13</td>
#       <td id="T_cbbd6_row11_col1" class="data row11 col1" >Burger Bener</td>
#       <td id="T_cbbd6_row11_col2" class="data row11 col2" >Senen</td>
#       <td id="T_cbbd6_row11_col3" class="data row11 col3" >Beef Burger Spicy BBQ Sauce</td>
#       <td id="T_cbbd6_row11_col4" class="data row11 col4" >24000</td>
#     </tr>
#     <tr>
#       <td id="T_cbbd6_row12_col0" class="data row12 col0" >14</td>
#       <td id="T_cbbd6_row12_col1" class="data row12 col1" >Dope Burger</td>
#       <td id="T_cbbd6_row12_col2" class="data row12 col2" >Menteng</td>
#       <td id="T_cbbd6_row12_col3" class="data row12 col3" >All American</td>
#       <td id="T_cbbd6_row12_col4" class="data row12 col4" >75000</td>
#     </tr>
#     <tr>
#       <td id="T_cbbd6_row13_col0" class="data row13 col0" >15</td>
#       <td id="T_cbbd6_row13_col1" class="data row13 col1" >The Goods Diner</td>
#       <td id="T_cbbd6_row13_col2" class="data row13 col2" >SCBD</td>
#       <td id="T_cbbd6_row13_col3" class="data row13 col3" >Coffee Rubed Burger</td>
#       <td id="T_cbbd6_row13_col4" class="data row13 col4" >120000</td>
#     </tr>
#     <tr>
#       <td id="T_cbbd6_row14_col0" class="data row14 col0" >16</td>
#       <td id="T_cbbd6_row14_col1" class="data row14 col1" >Burgreens Menteng</td>
#       <td id="T_cbbd6_row14_col2" class="data row14 col2" >Menteng</td>
#       <td id="T_cbbd6_row14_col3" class="data row14 col3" >Mini Trio Vegan Burger</td>
#       <td id="T_cbbd6_row14_col4" class="data row14 col4" >75000</td>
#     </tr>
#     <tr>
#       <td id="T_cbbd6_row15_col0" class="data row15 col0" >17</td>
#       <td id="T_cbbd6_row15_col1" class="data row15 col1" >Burgreens Pacific Place</td>
#       <td id="T_cbbd6_row15_col2" class="data row15 col2" >SCBD</td>
#       <td id="T_cbbd6_row15_col3" class="data row15 col3" >Mini Trio Vegan Burger</td>
#       <td id="T_cbbd6_row15_col4" class="data row15 col4" >75000</td>
#     </tr>
#     <tr>
#       <td id="T_cbbd6_row16_col0" class="data row16 col0" >18</td>
#       <td id="T_cbbd6_row16_col1" class="data row16 col1" >JJ Royal Brasserie</td>
#       <td id="T_cbbd6_row16_col2" class="data row16 col2" >Karet</td>
#       <td id="T_cbbd6_row16_col3" class="data row16 col3" >Western Bacon Cheese Burger</td>
#       <td id="T_cbbd6_row16_col4" class="data row16 col4" >110000</td>
#     </tr>
#     <tr>
#       <td id="T_cbbd6_row17_col0" class="data row17 col0" >19</td>
#       <td id="T_cbbd6_row17_col1" class="data row17 col1" >Hard Rock Cafe</td>
#       <td id="T_cbbd6_row17_col2" class="data row17 col2" >SCBD</td>
#       <td id="T_cbbd6_row17_col3" class="data row17 col3" >Original Legendary Burger</td>
#       <td id="T_cbbd6_row17_col4" class="data row17 col4" >229000</td>
#     </tr>
#     <tr>
#       <td id="T_cbbd6_row18_col0" class="data row18 col0" >20</td>
#       <td id="T_cbbd6_row18_col1" class="data row18 col1" >Ask for Patty</td>
#       <td id="T_cbbd6_row18_col2" class="data row18 col2" >Menteng</td>
#       <td id="T_cbbd6_row18_col3" class="data row18 col3" >Classic Patty</td>
#       <td id="T_cbbd6_row18_col4" class="data row18 col4" >60500</td>
#     </tr>
#     <tr>
#       <td id="T_cbbd6_row19_col0" class="data row19 col0" >21</td>
#       <td id="T_cbbd6_row19_col1" class="data row19 col1" >Johny Rockets</td>
#       <td id="T_cbbd6_row19_col2" class="data row19 col2" >Karet</td>
#       <td

# %% [markdown]
# # Price-Range
#
# We sorted the list from the most expensive and also the cheapest, also with the price range from IDR 50000 to 100000. Here is the order from the most expensive.

# %%
#most expensive
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price FROM burger ORDER BY price DESC")
burger_price.head().style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_94001_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_94001_row0_col0" class="data row0 col0" >Hard Rock Cafe</td>
#       <td id="T_94001_row0_col1" class="data row0 col1" >SCBD</td>
#       <td id="T_94001_row0_col2" class="data row0 col2" >Original Legendary Burger</td>
#       <td id="T_94001_row0_col3" class="data row0 col3" >229000</td>
#     </tr>
#     <tr>
#       <td id="T_94001_row1_col0" class="data row1 col0" >Le Burger</td>
#       <td id="T_94001_row1_col1" class="data row1 col1" >Sudirman</td>
#       <td id="T_94001_row1_col2" class="data row1 col2" >Truffle Burger</td>
#       <td id="T_94001_row1_col3" class="data row1 col3" >130000</td>
#     </tr>
#     <tr>
#       <td id="T_94001_row2_col0" class="data row2 col0" >The Goods Diner</td>
#       <td id="T_94001_row2_col1" class="data row2 col1" >SCBD</td>
#       <td id="T_94001_row2_col2" class="data row2 col2" >Coffee Rubed Burger</td>
#       <td id="T_94001_row2_col3" class="data row2 col3" >120000</td>
#     </tr>
#     <tr>
#       <td id="T_94001_row3_col0" class="data row3 col0" >JJ Royal Brasserie</td>
#       <td id="T_94001_row3_col1" class="data row3 col1" >Karet</td>
#       <td id="T_94001_row3_col2" class="data row3 col2" >Western Bacon Cheese Burger</td>
#       <td id="T_94001_row3_col3" class="data row3 col3" >110000</td>
#     </tr>
#     <tr>
#       <td id="T_94001_row4_col0" class="data row4 col0" >Lawless Burger</td>
#       <td id="T_94001_row4_col1" class="data row4 col1" >Menteng</td>
#       <td id="T_94001_row4_col2" class="data row4 col2" >The Lemmy</td>
#       <td id="T_94001_row4_col3" class="data row4 col3" >105000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#cheapest
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price FROM burger ORDER BY price")
burger_price.head().style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_4ebb7_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4ebb7_row0_col0" class="data row0 col0" >Lemoe Burger</td>
#       <td id="T_4ebb7_row0_col1" class="data row0 col1" >Cempaka Putih</td>
#       <td id="T_4ebb7_row0_col2" class="data row0 col2" >Chicken Cabe Ijo</td>
#       <td id="T_4ebb7_row0_col3" class="data row0 col3" >14000</td>
#     </tr>
#     <tr>
#       <td id="T_4ebb7_row1_col0" class="data row1 col0" >BarBurger</td>
#       <td id="T_4ebb7_row1_col1" class="data row1 col1" >Cempaka Putih</td>
#       <td id="T_4ebb7_row1_col2" class="data row1 col2" >Barchiz Burger</td>
#       <td id="T_4ebb7_row1_col3" class="data row1 col3" >23000</td>
#     </tr>
#     <tr>
#       <td id="T_4ebb7_row2_col0" class="data row2 col0" >Burger Bener</td>
#       <td id="T_4ebb7_row2_col1" class="data row2 col1" >Senen</td>
#       <td id="T_4ebb7_row2_col2" class="data row2 col2" >Beef Burger Spicy BBQ Sauce</td>
#       <td id="T_4ebb7_row2_col3" class="data row2 col3" >24000</td>
#     </tr>
#     <tr>
#       <td id="T_4ebb7_row3_col0" class="data row3 col0" >Burger King Citywalk Sudirman</td>
#       <td id="T_4ebb7_row3_col1" class="data row3 col1" >Sudirman</td>
#       <td id="T_4ebb7_row3_col2" class="data row3 col2" >Cheese Burger</td>
#       <td id="T_4ebb7_row3_col3" class="data row3 col3" >25000</td>
#     </tr>
#     <tr>
#       <td id="T_4ebb7_row4_col0" class="data row4 col0" >Gode Burger</td>
#       <td id="T_4ebb7_row4_col1" class="data row4 col1" >Pecenongan</td>
#       <td id="T_4ebb7_row4_col2" class="data row4 col2" >Pretty Purple Chicken Matah</td>
#       <td id="T_4ebb7_row4_col3" class="data row4 col3" >30000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Then here is the price range I mentioned earlier.

# %%
#more than IDR 100000
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price FROM burger WHERE price >= 100000")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_258a1_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_258a1_row0_col0" class="data row0 col0" >Lawless Burger</td>
#       <td id="T_258a1_row0_col1" class="data row0 col1" >Menteng</td>
#       <td id="T_258a1_row0_col2" class="data row0 col2" >The Lemmy</td>
#       <td id="T_258a1_row0_col3" class="data row0 col3" >105000</td>
#     </tr>
#     <tr>
#       <td id="T_258a1_row1_col0" class="data row1 col0" >Le Burger</td>
#       <td id="T_258a1_row1_col1" class="data row1 col1" >Sudirman</td>
#       <td id="T_258a1_row1_col2" class="data row1 col2" >Truffle Burger</td>
#       <td id="T_258a1_row1_col3" class="data row1 col3" >130000</td>
#     </tr>
#     <tr>
#       <td id="T_258a1_row2_col0" class="data row2 col0" >The Goods Diner</td>
#       <td id="T_258a1_row2_col1" class="data row2 col1" >SCBD</td>
#       <td id="T_258a1_row2_col2" class="data row2 col2" >Coffee Rubed Burger</td>
#       <td id="T_258a1_row2_col3" class="data row2 col3" >120000</td>
#     </tr>
#     <tr>
#       <td id="T_258a1_row3_col0" class="data row3 col0" >JJ Royal Brasserie</td>
#       <td id="T_258a1_row3_col1" class="data row3 col1" >Karet</td>
#       <td id="T_258a1_row3_col2" class="data row3 col2" >Western Bacon Cheese Burger</td>
#       <td id="T_258a1_row3_col3" class="data row3 col3" >110000</td>
#     </tr>
#     <tr>
#       <td id="T_258a1_row4_col0" class="data row4 col0" >Hard Rock Cafe</td>
#       <td id="T_258a1_row4_col1" class="data row4 col1" >SCBD</td>
#       <td id="T_258a1_row4_col2" class="data row4 col2" >Original Legendary Burger</td>
#       <td id="T_258a1_row4_col3" class="data row4 col3" >229000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#between 50000 to 100000
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price FROM burger WHERE price BETWEEN 50000 AND 100000")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_e877f_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e877f_row0_col0" class="data row0 col0" >Burger King Hayam Wuruk</td>
#       <td id="T_e877f_row0_col1" class="data row0 col1" >Hayam Wuruk</td>
#       <td id="T_e877f_row0_col2" class="data row0 col2" >Chicken Steakhouse BBQ</td>
#       <td id="T_e877f_row0_col3" class="data row0 col3" >59901</td>
#     </tr>
#     <tr>
#       <td id="T_e877f_row1_col0" class="data row1 col0" >Burger King Atrium Plaza</td>
#       <td id="T_e877f_row1_col1" class="data row1 col1" >Senen</td>
#       <td id="T_e877f_row1_col2" class="data row1 col2" >Mushroom Swiss XL</td>
#       <td id="T_e877f_row1_col3" class="data row1 col3" >59901</td>
#     </tr>
#     <tr>
#       <td id="T_e877f_row2_col0" class="data row2 col0" >Dope Burger</td>
#       <td id="T_e877f_row2_col1" class="data row2 col1" >Menteng</td>
#       <td id="T_e877f_row2_col2" class="data row2 col2" >All American</td>
#       <td id="T_e877f_row2_col3" class="data row2 col3" >75000</td>
#     </tr>
#     <tr>
#       <td id="T_e877f_row3_col0" class="data row3 col0" >Burgreens Menteng</td>
#       <td id="T_e877f_row3_col1" class="data row3 col1" >Menteng</td>
#       <td id="T_e877f_row3_col2" class="data row3 col2" >Mini Trio Vegan Burger</td>
#       <td id="T_e877f_row3_col3" class="data row3 col3" >75000</td>
#     </tr>
#     <tr>
#       <td id="T_e877f_row4_col0" class="data row4 col0" >Burgreens Pacific Place</td>
#       <td id="T_e877f_row4_col1" class="data row4 col1" >SCBD</td>
#       <td id="T_e877f_row4_col2" class="data row4 col2" >Mini Trio Vegan Burger</td>
#       <td id="T_e877f_row4_col3" class="data row4 col3" >75000</td>
#     </tr>
#     <tr>
#       <td id="T_e877f_row5_col0" class="data row5 col0" >Ask for Patty</td>
#       <td id="T_e877f_row5_col1" class="data row5 col1" >Menteng</td>
#       <td id="T_e877f_row5_col2" class="data row5 col2" >Classic Patty</td>
#       <td id="T_e877f_row5_col3" class="data row5 col3" >60500</td>
#     </tr>
#     <tr>
#       <td id="T_e877f_row6_col0" class="data row6 col0" >Johny Rockets</td>
#       <td id="T_e877f_row6_col1" class="data row6 col1" >Karet</td>
#       <td id="T_e877f_row6_col2" class="data row6 col2" >Bacon Cheddar</td>
#       <td id="T_e877f_row6_col3" class="data row6 col3" >72000</td>
#     </tr>
#     <tr>
#       <td id="T_e877f_row7_col0" class="data row7 col0" >Belly Bandit To Go</td>
#       <td id="T_e877f_row7_col1" class="data row7 col1" >Menteng</td>
#       <td id="T_e877f_row7_col2" class="data row7 col2" >Bandit Tower</td>
#       <td id="T_e877f_row7_col3" class="data row7 col3" >68000</td>
#     </tr>
#     <tr>
#       <td id="T_e877f_row8_col0" class="data row8 col0" >Lucy Beer & Burger Bar</td>
#       <td id="T_e877f_row8_col1" class="data row8 col1" >Sudirman</td>
#       <td id="T_e877f_row8_col2" class="data row8 col2" >Bacon Me Crazy</td>
#       <td id="T_e877f_row8_col3" class="data row8 col3" >68000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#below IDR 100000
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price FROM burger WHERE price <= 50000")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_c0701_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c0701_row0_col0" class="data row0 col0" >Burger King Grand Indonesia</td>
#       <td id="T_c0701_row0_col1" class="data row0 col1" >Thamrin</td>
#       <td id="T_c0701_row0_col2" class="data row0 col2" >Whooper Jr.</td>
#       <td id="T_c0701_row0_col3" class="data row0 col3" >37273</td>
#     </tr>
#     <tr>
#       <td id="T_c0701_row1_col0" class="data row1 col0" >Burger King Thamrin City</td>
#       <td id="T_c0701_row1_col1" class="data row1 col1" >Tanah Abang</td>
#       <td id="T_c0701_row1_col2" class="data row1 col2" >Whooper Jr.</td>
#       <td id="T_c0701_row1_col3" class="data row1 col3" >37273</td>
#     </tr>
#     <tr>
#       <td id="T_c0701_row2_col0" class="data row2 col0" >Burger King Bendungan Hilir</td>
#       <td id="T_c0701_row2_col1" class="data row2 col1" >Bendungan Hilir</td>
#       <td id="T_c0701_row2_col2" class="data row2 col2" >Whooper Jr.</td>
#       <td id="T_c0701_row2_col3" class="data row2 col3" >37273</td>
#     </tr>
#     <tr>
#       <td id="T_c0701_row3_col0" class="data row3 col0" >Burger King Citywalk Sudirman</td>
#       <td id="T_c0701_row3_col1" class="data row3 col1" >Sudirman</td>
#       <td id="T_c0701_row3_col2" class="data row3 col2" >Cheese Burger</td>
#       <td id="T_c0701_row3_col3" class="data row3 col3" >25000</td>
#     </tr>
#     <tr>
#       <td id="T_c0701_row4_col0" class="data row4 col0" >Burger King Cempaka Putih</td>
#       <td id="T_c0701_row4_col1" class="data row4 col1" >Cempaka Putih</td>
#       <td id="T_c0701_row4_col2" class="data row4 col2" >Whooper Jr.</td>
#       <td id="T_c0701_row4_col3" class="data row4 col3" >37273</td>
#     </tr>
#     <tr>
#       <td id="T_c0701_row5_col0" class="data row5 col0" >Flip Burger</td>
#       <td id="T_c0701_row5_col1" class="data row5 col1" >Sudirman</td>
#       <td id="T_c0701_row5_col2" class="data row5 col2" >Cheese Burger</td>
#       <td id="T_c0701_row5_col3" class="data row5 col3" >40909</td>
#     </tr>
#     <tr>
#       <td id="T_c0701_row6_col0" class="data row6 col0" >Lemoe Burger</td>
#       <td id="T_c0701_row6_col1" class="data row6 col1" >Cempaka Putih</td>
#       <td id="T_c0701_row6_col2" class="data row6 col2" >Chicken Cabe Ijo</td>
#       <td id="T_c0701_row6_col3" class="data row6 col3" >14000</td>
#     </tr>
#     <tr>
#       <td id="T_c0701_row7_col0" class="data row7 col0" >Burger Bener</td>
#       <td id="T_c0701_row7_col1" class="data row7 col1" >Senen</td>
#       <td id="T_c0701_row7_col2" class="data row7 col2" >Beef Burger Spicy BBQ Sauce</td>
#       <td id="T_c0701_row7_col3" class="data row7 col3" >24000</td>
#     </tr>
#     <tr>
#       <td id="T_c0701_row8_col0" class="data row8 col0" >BarBurger</td>
#       <td id="T_c0701_row8_col1" class="data row8 col1" >Cempaka Putih</td>
#       <td id="T_c0701_row8_col2" class="data row8 col2" >Barchiz Burger</td>
#       <td id="T_c0701_row8_col3" class="data row8 col3" >23000</td>
#     </tr>
#     <tr>
#       <td id="T_c0701_row9_col0" class="data row9 col0" >Klenger Burger</td>
#       <td id="T_c0701_row9_col1" class="data row9 col1" >Senen</td>
#       <td id="T_c0701_row9_col2" class="data row9 col2" >Super Duper Klenger Burger</td>
#       <td id="T_c0701_row9_col3" class="data row9 col3" >45000</td>
#     </tr>
#     <tr>
#       <td id="T_c0701_row10_col0" class="data row10 col0" >Gode Burger</td>
#       <td id="T_c0701_row10_col1" class="data row10 col1" >Pecenongan</td>
#       <td id="T_c0701_row10_col2" class="data row10 col2" >Pretty Purple Chicken Matah</td>
#       <td id="T_c0701_row10_col3" class="data row10 col3" >30000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Facility
#
# Last but not least, we chose the restaurant whether we could takeaway, or deliver our food. We also could find out whether these partlor has outdoor seats, smoking room, wifi, and reservation. Last but not least, we researched about poultry with some dietary restriction like alcohol and halal_menu. But this halal menu will not available in other project. We changed to other_poultry instead.
#
# Let's take a look for all the facility, I counted each of them also.

# %%
burger = sqldf("SELECT no, partlor_name, district, takeaway, delivery, outdoor_seat, smoking_area, alcohol_served, wifi, reservation, drive_thru, halal_food FROM burger")
burger.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_5f312_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >no</th>
#       <th class="col_heading level0 col1" >partlor_name</th>
#       <th class="col_heading level0 col2" >District</th>
#       <th class="col_heading level0 col3" >takeaway</th>
#       <th class="col_heading level0 col4" >delivery</th>
#       <th class="col_heading level0 col5" >outdoor_seat</th>
#       <th class="col_heading level0 col6" >smoking_area</th>
#       <th class="col_heading level0 col7" >alcohol_served</th>
#       <th class="col_heading level0 col8" >wifi</th>
#       <th class="col_heading level0 col9" >reservation</th>
#       <th class="col_heading level0 col10" >drive_thru</th>
#       <th class="col_heading level0 col11" >halal_food</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5f312_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_5f312_row0_col1" class="data row0 col1" >Burger King Grand Indonesia</td>
#       <td id="T_5f312_row0_col2" class="data row0 col2" >Thamrin</td>
#       <td id="T_5f312_row0_col3" class="data row0 col3" >yes</td>
#       <td id="T_5f312_row0_col4" class="data row0 col4" >yes</td>
#       <td id="T_5f312_row0_col5" class="data row0 col5" >no</td>
#       <td id="T_5f312_row0_col6" class="data row0 col6" >no</td>
#       <td id="T_5f312_row0_col7" class="data row0 col7" >no</td>
#       <td id="T_5f312_row0_col8" class="data row0 col8" >no</td>
#       <td id="T_5f312_row0_col9" class="data row0 col9" >no</td>
#       <td id="T_5f312_row0_col10" class="data row0 col10" >no</td>
#       <td id="T_5f312_row0_col11" class="data row0 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_5f312_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_5f312_row1_col1" class="data row1 col1" >Burger King Thamrin City</td>
#       <td id="T_5f312_row1_col2" class="data row1 col2" >Tanah Abang</td>
#       <td id="T_5f312_row1_col3" class="data row1 col3" >yes</td>
#       <td id="T_5f312_row1_col4" class="data row1 col4" >yes</td>
#       <td id="T_5f312_row1_col5" class="data row1 col5" >no</td>
#       <td id="T_5f312_row1_col6" class="data row1 col6" >no</td>
#       <td id="T_5f312_row1_col7" class="data row1 col7" >no</td>
#       <td id="T_5f312_row1_col8" class="data row1 col8" >no</td>
#       <td id="T_5f312_row1_col9" class="data row1 col9" >no</td>
#       <td id="T_5f312_row1_col10" class="data row1 col10" >no</td>
#       <td id="T_5f312_row1_col11" class="data row1 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_5f312_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_5f312_row2_col1" class="data row2 col1" >Burger King Bendungan Hilir</td>
#       <td id="T_5f312_row2_col2" class="data row2 col2" >Bendungan Hilir</td>
#       <td id="T_5f312_row2_col3" class="data row2 col3" >yes</td>
#       <td id="T_5f312_row2_col4" class="data row2 col4" >yes</td>
#       <td id="T_5f312_row2_col5" class="data row2 col5" >yes</td>
#       <td id="T_5f312_row2_col6" class="data row2 col6" >yes</td>
#       <td id="T_5f312_row2_col7" class="data row2 col7" >no</td>
#       <td id="T_5f312_row2_col8" class="data row2 col8" >yes</td>
#       <td id="T_5f312_row2_col9" class="data row2 col9" >no</td>
#       <td id="T_5f312_row2_col10" class="data row2 col10" >no</td>
#       <td id="T_5f312_row2_col11" class="data row2 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_5f312_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_5f312_row3_col1" class="data row3 col1" >Burger King Citywalk Sudirman</td>
#       <td id="T_5f312_row3_col2" class="data row3 col2" >Sudirman</td>
#       <td id="T_5f312_row3_col3" class="data row3 col3" >yes</td>
#       <td id="T_5f312_row3_col4" class="data row3 col4" >yes</td>
#       <td id="T_5f312_row3_col5" class="data row3 col5" >yes</td>
#       <td id="T_5f312_row3_col6" class="data row3 col6" >yes</td>
#       <td id="T_5f312_row3_col7" class="data row3 col7" >no</td>
#       <td id="T_5f312_row3_col8" class="data row3 col8" >yes</td>
#       <td id="T_5f312_row3_col9" class="data row3 col9" >no</td>
#       <td id="T_5f312_row3_col10" class="data row3 col10" >no</td>
#       <td id="T_5f312_row3_col11" class="data row3 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_5f312_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_5f312_row4_col1" class="data row4 col1" >Burger King Hayam Wuruk</td>
#       <td id="T_5f312_row4_col2" class="data row4 col2" >Hayam Wuruk</td>
#       <td id="T_5f312_row4_col3" class="data row4 col3" >yes</td>
#       <td id="T_5f312_row4_col4" class="data row4 col4" >yes</td>
#       <td id="T_5f312_row4_col5" class="data row4 col5" >yes</td>
#       <td id="T_5f312_row4_col6" class="data row4 col6" >yes</td>
#       <td id="T_5f312_row4_col7" class="data row4 col7" >no</td>
#       <td id="T_5f312_row4_col8" class="data row4 col8" >yes</td>
#       <td id="T_5f312_row4_col9" class="data row4 col9" >no</td>
#       <td id="T_5f312_row4_col10" class="data row4 col10" >no</td>
#       <td id="T_5f312_row4_col11" class="data row4 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_5f312_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_5f312_row5_col1" class="data row5 col1" >Burger King Atrium Plaza</td>
#       <td id="T_5f312_row5_col2" class="data row5 col2" >Senen</td>
#       <td id="T_5f312_row5_col3" class="data row5 col3" >yes</td>
#       <td id="T_5f312_row5_col4" class="data row5 col4" >no</td>
#       <td id="T_5f312_row5_col5" class="data row5 col5" >no</td>
#       <td id="T_5f312_row5_col6" class="data row5 col6" >yes</td>
#       <td id="T_5f312_row5_col7" class="data row5 col7" >no</td>
#       <td id="T_5f312_row5_col8" class="data row5 col8" >yes</td>
#       <td id="T_5f312_row5_col9" class="data row5 col9" >no</td>
#       <td id="T_5f312_row5_col10" class="data row5 col10" >no</td>
#       <td id="T_5f312_row5_col11" class="data row5 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_5f312_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_5f312_row6_col1" class="data row6 col1" >Burger King Cempaka Putih</td>
#       <td id="T_5f312_row6_col2" class="data row6 col2" >Cempaka Putih</td>
#       <td id="T_5f312_row6_col3" class="data row6 col3" >yes</td>
#       <td id="T_5f312_row6_col4" class="data row6 col4" >yes</td>
#       <td id="T_5f312_row6_col5" class="data row6 col5" >yes</td>
#       <td id="T_5f312_row6_col6" class="data row6 col6" >yes</td>
#       <td id="T_5f312_row6_col7" class="data row6 col7" >no</td>
#       <td id="T_5f312_row6_col8" class="data row6 col8" >yes</td>
#       <td id="T_5f312_row6_col9" class="data row6 col9" >no</td>
#       <td id="T_5f312_row6_col10" class="data row6 col10" >yes</td>
#       <td id="T_5f312_row6_col11" class="data row6 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_5f312_row7_col0" class="data row7 col0" >9</td>
#       <td id="T_5f312_row7_col1" class="data row7 col1" >Flip Burger</td>
#       <td id="T_5f312_row7_col2" class="data row7 col2" >Sudirman</td>
#       <td id="T_5f312_row7_col3" class="data row7 col3" >yes</td>
#       <td id="T_5f312_row7_col4" class="data row7 col4" >no</td>
#       <td id="T_5f312_row7_col5" class="data row7 col5" >no</td>
#       <td id="T_5f312_row7_col6" class="data row7 col6" >no</td>
#       <td id="T_5f312_row7_col7" class="data row7 col7" >no</td>
#       <td id="T_5f312_row7_col8" class="data row7 col8" >no</td>
#       <td id="T_5f312_row7_col9" class="data row7 col9" >no</td>
#       <td id="T_5f312_row7_col10" class="data row7 col10" >no</td>
#       <td id="T_5f312_row7_col11" class="data row7 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_5f312_row8_col0" class="data row8 col0" >10</td>
#       <td id="T_5f312_row8_col1" class="data row8 col1" >Lawless Burger</td>
#       <td id="T_5f312_row8_col2" class="data row8 col2" >Menteng</td>
#       <td id="T_5f312_row8_col3" class="data row8 col3" >yes</td>
#       <td id="T_5f312_row8_col4" class="data row8 col4" >no</td>
#       <td id="T_5f312_row8_col5" class="data row8 col5" >yes</td>
#       <td id="T_5f312_row8_col6" class="data row8 col6" >yes</td>
#       <td id="T_5f312

# %% [markdown]
# Let's take a look for each one of those.

# %%
#takeaway
takeaway = sqldf("SELECT partlor_name, district, takeaway FROM burger WHERE takeaway = 'yes'")
takeaway.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_f404e_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >takeaway</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f404e_row0_col0" class="data row0 col0" >Burger King Grand Indonesia</td>
#       <td id="T_f404e_row0_col1" class="data row0 col1" >Thamrin</td>
#       <td id="T_f404e_row0_col2" class="data row0 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row1_col0" class="data row1 col0" >Burger King Thamrin City</td>
#       <td id="T_f404e_row1_col1" class="data row1 col1" >Tanah Abang</td>
#       <td id="T_f404e_row1_col2" class="data row1 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row2_col0" class="data row2 col0" >Burger King Bendungan Hilir</td>
#       <td id="T_f404e_row2_col1" class="data row2 col1" >Bendungan Hilir</td>
#       <td id="T_f404e_row2_col2" class="data row2 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row3_col0" class="data row3 col0" >Burger King Citywalk Sudirman</td>
#       <td id="T_f404e_row3_col1" class="data row3 col1" >Sudirman</td>
#       <td id="T_f404e_row3_col2" class="data row3 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row4_col0" class="data row4 col0" >Burger King Hayam Wuruk</td>
#       <td id="T_f404e_row4_col1" class="data row4 col1" >Hayam Wuruk</td>
#       <td id="T_f404e_row4_col2" class="data row4 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row5_col0" class="data row5 col0" >Burger King Atrium Plaza</td>
#       <td id="T_f404e_row5_col1" class="data row5 col1" >Senen</td>
#       <td id="T_f404e_row5_col2" class="data row5 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row6_col0" class="data row6 col0" >Burger King Cempaka Putih</td>
#       <td id="T_f404e_row6_col1" class="data row6 col1" >Cempaka Putih</td>
#       <td id="T_f404e_row6_col2" class="data row6 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row7_col0" class="data row7 col0" >Flip Burger</td>
#       <td id="T_f404e_row7_col1" class="data row7 col1" >Sudirman</td>
#       <td id="T_f404e_row7_col2" class="data row7 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row8_col0" class="data row8 col0" >Lawless Burger</td>
#       <td id="T_f404e_row8_col1" class="data row8 col1" >Menteng</td>
#       <td id="T_f404e_row8_col2" class="data row8 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row9_col0" class="data row9 col0" >Lemoe Burger</td>
#       <td id="T_f404e_row9_col1" class="data row9 col1" >Cempaka Putih</td>
#       <td id="T_f404e_row9_col2" class="data row9 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row10_col0" class="data row10 col0" >Le Burger</td>
#       <td id="T_f404e_row10_col1" class="data row10 col1" >Sudirman</td>
#       <td id="T_f404e_row10_col2" class="data row10 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row11_col0" class="data row11 col0" >Burger Bener</td>
#       <td id="T_f404e_row11_col1" class="data row11 col1" >Senen</td>
#       <td id="T_f404e_row11_col2" class="data row11 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row12_col0" class="data row12 col0" >Dope Burger</td>
#       <td id="T_f404e_row12_col1" class="data row12 col1" >Menteng</td>
#       <td id="T_f404e_row12_col2" class="data row12 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row13_col0" class="data row13 col0" >The Goods Diner</td>
#       <td id="T_f404e_row13_col1" class="data row13 col1" >SCBD</td>
#       <td id="T_f404e_row13_col2" class="data row13 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row14_col0" class="data row14 col0" >Burgreens Menteng</td>
#       <td id="T_f404e_row14_col1" class="data row14 col1" >Menteng</td>
#       <td id="T_f404e_row14_col2" class="data row14 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row15_col0" class="data row15 col0" >Burgreens Pacific Place</td>
#       <td id="T_f404e_row15_col1" class="data row15 col1" >SCBD</td>
#       <td id="T_f404e_row15_col2" class="data row15 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row16_col0" class="data row16 col0" >Hard Rock Cafe</td>
#       <td id="T_f404e_row16_col1" class="data row16 col1" >SCBD</td>
#       <td id="T_f404e_row16_col2" class="data row16 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row17_col0" class="data row17 col0" >Ask for Patty</td>
#       <td id="T_f404e_row17_col1" class="data row17 col1" >Menteng</td>
#       <td id="T_f404e_row17_col2" class="data row17 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row18_col0" class="data row18 col0" >Johny Rockets</td>
#       <td id="T_f404e_row18_col1" class="data row18 col1" >Karet</td>
#       <td id="T_f404e_row18_col2" class="data row18 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row19_col0" class="data row19 col0" >BarBurger</td>
#       <td id="T_f404e_row19_col1" class="data row19 col1" >Cempaka Putih</td>
#       <td id="T_f404e_row19_col2" class="data row19 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row20_col0" class="data row20 col0" >Belly Bandit To Go</td>
#       <td id="T_f404e_row20_col1" class="data row20 col1" >Menteng</td>
#       <td id="T_f404e_row20_col2" class="data row20 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row21_col0" class="data row21 col0" >Klenger Burger</td>
#       <td id="T_f404e_row21_col1" class="data row21 col1" >Senen</td>
#       <td id="T_f404e_row21_col2" class="data row21 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row22_col0" class="data row22 col0" >Gode Burger</td>
#       <td id="T_f404e_row22_col1" class="data row22 col1" >Pecenongan</td>
#       <td id="T_f404e_row22_col2" class="data row22 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f404e_row23_col0" class="data row23 col0" >Lucy Beer & Burger Bar</td>
#       <td id="T_f404e_row23_col1" class="data row23 col1" >Sudirman</td>
#       <td id="T_f404e_row23_col2" class="data row23 col2" >yes</td>
#     </tr>
#   </tbody>
# </table>

# %%
takeaway = sqldf("SELECT COUNT(takeaway) FROM burger GROUP BY takeaway HAVING takeaway = 'yes'")
takeaway
# Out:
#    COUNT(takeaway)
# 0               24

# %%
#delivery
delivery = sqldf("SELECT partlor_name, district, delivery FROM burger WHERE delivery = 'yes'")
delivery.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_63c08_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >delivery</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_63c08_row0_col0" class="data row0 col0" >Burger King Grand Indonesia</td>
#       <td id="T_63c08_row0_col1" class="data row0 col1" >Thamrin</td>
#       <td id="T_63c08_row0_col2" class="data row0 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63c08_row1_col0" class="data row1 col0" >Burger King Thamrin City</td>
#       <td id="T_63c08_row1_col1" class="data row1 col1" >Tanah Abang</td>
#       <td id="T_63c08_row1_col2" class="data row1 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63c08_row2_col0" class="data row2 col0" >Burger King Bendungan Hilir</td>
#       <td id="T_63c08_row2_col1" class="data row2 col1" >Bendungan Hilir</td>
#       <td id="T_63c08_row2_col2" class="data row2 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63c08_row3_col0" class="data row3 col0" >Burger King Citywalk Sudirman</td>
#       <td id="T_63c08_row3_col1" class="data row3 col1" >Sudirman</td>
#       <td id="T_63c08_row3_col2" class="data row3 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63c08_row4_col0" class="data row4 col0" >Burger King Hayam Wuruk</td>
#       <td id="T_63c08_row4_col1" class="data row4 col1" >Hayam Wuruk</td>
#       <td id="T_63c08_row4_col2" class="data row4 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63c08_row5_col0" class="data row5 col0" >Burger King Cempaka Putih</td>
#       <td id="T_63c08_row5_col1" class="data row5 col1" >Cempaka Putih</td>
#       <td id="T_63c08_row5_col2" class="data row5 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63c08_row6_col0" class="data row6 col0" >Lemoe Burger</td>
#       <td id="T_63c08_row6_col1" class="data row6 col1" >Cempaka Putih</td>
#       <td id="T_63c08_row6_col2" class="data row6 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63c08_row7_col0" class="data row7 col0" >Le Burger</td>
#       <td id="T_63c08_row7_col1" class="data row7 col1" >Sudirman</td>
#       <td id="T_63c08_row7_col2" class="data row7 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63c08_row8_col0" class="data row8 col0" >Burger Bener</td>
#       <td id="T_63c08_row8_col1" class="data row8 col1" >Senen</td>
#       <td id="T_63c08_row8_col2" class="data row8 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63c08_row9_col0" class="data row9 col0" >Dope Burger</td>
#       <td id="T_63c08_row9_col1" class="data row9 col1" >Menteng</td>
#       <td id="T_63c08_row9_col2" class="data row9 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63c08_row10_col0" class="data row10 col0" >The Goods Diner</td>
#       <td id="T_63c08_row10_col1" class="data row10 col1" >SCBD</td>
#       <td id="T_63c08_row10_col2" class="data row10 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63c08_row11_col0" class="data row11 col0" >Burgreens Pacific Place</td>
#       <td id="T_63c08_row11_col1" class="data row11 col1" >SCBD</td>
#       <td id="T_63c08_row11_col2" class="data row11 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63c08_row12_col0" class="data row12 col0" >Ask for Patty</td>
#       <td id="T_63c08_row12_col1" class="data row12 col1" >Menteng</td>
#       <td id="T_63c08_row12_col2" class="data row12 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63c08_row13_col0" class="data row13 col0" >Belly Bandit To Go</td>
#       <td id="T_63c08_row13_col1" class="data row13 col1" >Menteng</td>
#       <td id="T_63c08_row13_col2" class="data row13 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63c08_row14_col0" class="data row14 col0" >Klenger Burger</td>
#       <td id="T_63c08_row14_col1" class="data row14 col1" >Senen</td>
#       <td id="T_63c08_row14_col2" class="data row14 col2" >yes</td>
#     </tr>
#   </tbody>
# </table>

# %%
delivery = sqldf("SELECT COUNT(delivery) FROM burger GROUP BY delivery HAVING delivery = 'yes'")
delivery
# Out:
#    COUNT(delivery)
# 0               15

# %%
#outdoor_seat
outdoor_seat = sqldf("SELECT partlor_name, district, outdoor_seat FROM burger WHERE outdoor_seat = 'yes'")
outdoor_seat.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_99121_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >outdoor_seat</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_99121_row0_col0" class="data row0 col0" >Burger King Bendungan Hilir</td>
#       <td id="T_99121_row0_col1" class="data row0 col1" >Bendungan Hilir</td>
#       <td id="T_99121_row0_col2" class="data row0 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_99121_row1_col0" class="data row1 col0" >Burger King Citywalk Sudirman</td>
#       <td id="T_99121_row1_col1" class="data row1 col1" >Sudirman</td>
#       <td id="T_99121_row1_col2" class="data row1 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_99121_row2_col0" class="data row2 col0" >Burger King Hayam Wuruk</td>
#       <td id="T_99121_row2_col1" class="data row2 col1" >Hayam Wuruk</td>
#       <td id="T_99121_row2_col2" class="data row2 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_99121_row3_col0" class="data row3 col0" >Burger King Cempaka Putih</td>
#       <td id="T_99121_row3_col1" class="data row3 col1" >Cempaka Putih</td>
#       <td id="T_99121_row3_col2" class="data row3 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_99121_row4_col0" class="data row4 col0" >Lawless Burger</td>
#       <td id="T_99121_row4_col1" class="data row4 col1" >Menteng</td>
#       <td id="T_99121_row4_col2" class="data row4 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_99121_row5_col0" class="data row5 col0" >Lemoe Burger</td>
#       <td id="T_99121_row5_col1" class="data row5 col1" >Cempaka Putih</td>
#       <td id="T_99121_row5_col2" class="data row5 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_99121_row6_col0" class="data row6 col0" >Burger Bener</td>
#       <td id="T_99121_row6_col1" class="data row6 col1" >Senen</td>
#       <td id="T_99121_row6_col2" class="data row6 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_99121_row7_col0" class="data row7 col0" >JJ Royal Brasserie</td>
#       <td id="T_99121_row7_col1" class="data row7 col1" >Karet</td>
#       <td id="T_99121_row7_col2" class="data row7 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_99121_row8_col0" class="data row8 col0" >Hard Rock Cafe</td>
#       <td id="T_99121_row8_col1" class="data row8 col1" >SCBD</td>
#       <td id="T_99121_row8_col2" class="data row8 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_99121_row9_col0" class="data row9 col0" >Ask for Patty</td>
#       <td id="T_99121_row9_col1" class="data row9 col1" >Menteng</td>
#       <td id="T_99121_row9_col2" class="data row9 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_99121_row10_col0" class="data row10 col0" >Johny Rockets</td>
#       <td id="T_99121_row10_col1" class="data row10 col1" >Karet</td>
#       <td id="T_99121_row10_col2" class="data row10 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_99121_row11_col0" class="data row11 col0" >Lucy Beer & Burger Bar</td>
#       <td id="T_99121_row11_col1" class="data row11 col1" >Sudirman</td>
#       <td id="T_99121_row11_col2" class="data row11 col2" >yes</td>
#     </tr>
#   </tbody>
# </table>

# %%
outdoor_seat = sqldf("SELECT COUNT(outdoor_seat) FROM burger GROUP BY outdoor_seat HAVING outdoor_seat = 'yes'")
outdoor_seat
# Out:
#    COUNT(outdoor_seat)
# 0                   12

# %%
#smoking_area
smoking_area = sqldf("SELECT partlor_name, district, smoking_area FROM burger WHERE smoking_area = 'yes'")
smoking_area.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_d96fb_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >smoking_area</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d96fb_row0_col0" class="data row0 col0" >Burger King Bendungan Hilir</td>
#       <td id="T_d96fb_row0_col1" class="data row0 col1" >Bendungan Hilir</td>
#       <td id="T_d96fb_row0_col2" class="data row0 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d96fb_row1_col0" class="data row1 col0" >Burger King Citywalk Sudirman</td>
#       <td id="T_d96fb_row1_col1" class="data row1 col1" >Sudirman</td>
#       <td id="T_d96fb_row1_col2" class="data row1 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d96fb_row2_col0" class="data row2 col0" >Burger King Hayam Wuruk</td>
#       <td id="T_d96fb_row2_col1" class="data row2 col1" >Hayam Wuruk</td>
#       <td id="T_d96fb_row2_col2" class="data row2 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d96fb_row3_col0" class="data row3 col0" >Burger King Atrium Plaza</td>
#       <td id="T_d96fb_row3_col1" class="data row3 col1" >Senen</td>
#       <td id="T_d96fb_row3_col2" class="data row3 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d96fb_row4_col0" class="data row4 col0" >Burger King Cempaka Putih</td>
#       <td id="T_d96fb_row4_col1" class="data row4 col1" >Cempaka Putih</td>
#       <td id="T_d96fb_row4_col2" class="data row4 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d96fb_row5_col0" class="data row5 col0" >Lawless Burger</td>
#       <td id="T_d96fb_row5_col1" class="data row5 col1" >Menteng</td>
#       <td id="T_d96fb_row5_col2" class="data row5 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d96fb_row6_col0" class="data row6 col0" >Le Burger</td>
#       <td id="T_d96fb_row6_col1" class="data row6 col1" >Sudirman</td>
#       <td id="T_d96fb_row6_col2" class="data row6 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d96fb_row7_col0" class="data row7 col0" >Burger Bener</td>
#       <td id="T_d96fb_row7_col1" class="data row7 col1" >Senen</td>
#       <td id="T_d96fb_row7_col2" class="data row7 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d96fb_row8_col0" class="data row8 col0" >Dope Burger</td>
#       <td id="T_d96fb_row8_col1" class="data row8 col1" >Menteng</td>
#       <td id="T_d96fb_row8_col2" class="data row8 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d96fb_row9_col0" class="data row9 col0" >The Goods Diner</td>
#       <td id="T_d96fb_row9_col1" class="data row9 col1" >SCBD</td>
#       <td id="T_d96fb_row9_col2" class="data row9 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d96fb_row10_col0" class="data row10 col0" >Burgreens Menteng</td>
#       <td id="T_d96fb_row10_col1" class="data row10 col1" >Menteng</td>
#       <td id="T_d96fb_row10_col2" class="data row10 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d96fb_row11_col0" class="data row11 col0" >JJ Royal Brasserie</td>
#       <td id="T_d96fb_row11_col1" class="data row11 col1" >Karet</td>
#       <td id="T_d96fb_row11_col2" class="data row11 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d96fb_row12_col0" class="data row12 col0" >Hard Rock Cafe</td>
#       <td id="T_d96fb_row12_col1" class="data row12 col1" >SCBD</td>
#       <td id="T_d96fb_row12_col2" class="data row12 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d96fb_row13_col0" class="data row13 col0" >Ask for Patty</td>
#       <td id="T_d96fb_row13_col1" class="data row13 col1" >Menteng</td>
#       <td id="T_d96fb_row13_col2" class="data row13 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d96fb_row14_col0" class="data row14 col0" >Johny Rockets</td>
#       <td id="T_d96fb_row14_col1" class="data row14 col1" >Karet</td>
#       <td id="T_d96fb_row14_col2" class="data row14 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d96fb_row15_col0" class="data row15 col0" >Lucy Beer & Burger Bar</td>
#       <td id="T_d96fb_row15_col1" class="data row15 col1" >Sudirman</td>
#       <td id="T_d96fb_row15_col2" class="data row15 col2" >yes</td>
#     </tr>
#   </tbody>
# </table>

# %%
smoking_area = sqldf("SELECT COUNT(smoking_area) FROM burger GROUP BY smoking_area HAVING smoking_area = 'yes'")
smoking_area
# Out:
#    COUNT(smoking_area)
# 0                   16

# %%
#alcohol
alcohol = sqldf("SELECT partlor_name, district, alcohol_served FROM burger WHERE alcohol_served = 'yes'")
alcohol.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_815c8_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >alcohol_served</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_815c8_row0_col0" class="data row0 col0" >Lawless Burger</td>
#       <td id="T_815c8_row0_col1" class="data row0 col1" >Menteng</td>
#       <td id="T_815c8_row0_col2" class="data row0 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_815c8_row1_col0" class="data row1 col0" >Le Burger</td>
#       <td id="T_815c8_row1_col1" class="data row1 col1" >Sudirman</td>
#       <td id="T_815c8_row1_col2" class="data row1 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_815c8_row2_col0" class="data row2 col0" >The Goods Diner</td>
#       <td id="T_815c8_row2_col1" class="data row2 col1" >SCBD</td>
#       <td id="T_815c8_row2_col2" class="data row2 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_815c8_row3_col0" class="data row3 col0" >Hard Rock Cafe</td>
#       <td id="T_815c8_row3_col1" class="data row3 col1" >SCBD</td>
#       <td id="T_815c8_row3_col2" class="data row3 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_815c8_row4_col0" class="data row4 col0" >Lucy Beer & Burger Bar</td>
#       <td id="T_815c8_row4_col1" class="data row4 col1" >Sudirman</td>
#       <td id="T_815c8_row4_col2" class="data row4 col2" >yes</td>
#     </tr>
#   </tbody>
# </table>

# %%
alcohol.count()

# %%
#wifi
wifi = sqldf("SELECT partlor_name, district, wifi FROM burger WHERE wifi = 'yes'")
wifi.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_40c09_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >wifi</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_40c09_row0_col0" class="data row0 col0" >Burger King Bendungan Hilir</td>
#       <td id="T_40c09_row0_col1" class="data row0 col1" >Bendungan Hilir</td>
#       <td id="T_40c09_row0_col2" class="data row0 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_40c09_row1_col0" class="data row1 col0" >Burger King Citywalk Sudirman</td>
#       <td id="T_40c09_row1_col1" class="data row1 col1" >Sudirman</td>
#       <td id="T_40c09_row1_col2" class="data row1 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_40c09_row2_col0" class="data row2 col0" >Burger King Hayam Wuruk</td>
#       <td id="T_40c09_row2_col1" class="data row2 col1" >Hayam Wuruk</td>
#       <td id="T_40c09_row2_col2" class="data row2 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_40c09_row3_col0" class="data row3 col0" >Burger King Atrium Plaza</td>
#       <td id="T_40c09_row3_col1" class="data row3 col1" >Senen</td>
#       <td id="T_40c09_row3_col2" class="data row3 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_40c09_row4_col0" class="data row4 col0" >Burger King Cempaka Putih</td>
#       <td id="T_40c09_row4_col1" class="data row4 col1" >Cempaka Putih</td>
#       <td id="T_40c09_row4_col2" class="data row4 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_40c09_row5_col0" class="data row5 col0" >Lawless Burger</td>
#       <td id="T_40c09_row5_col1" class="data row5 col1" >Menteng</td>
#       <td id="T_40c09_row5_col2" class="data row5 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_40c09_row6_col0" class="data row6 col0" >Le Burger</td>
#       <td id="T_40c09_row6_col1" class="data row6 col1" >Sudirman</td>
#       <td id="T_40c09_row6_col2" class="data row6 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_40c09_row7_col0" class="data row7 col0" >Dope Burger</td>
#       <td id="T_40c09_row7_col1" class="data row7 col1" >Menteng</td>
#       <td id="T_40c09_row7_col2" class="data row7 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_40c09_row8_col0" class="data row8 col0" >The Goods Diner</td>
#       <td id="T_40c09_row8_col1" class="data row8 col1" >SCBD</td>
#       <td id="T_40c09_row8_col2" class="data row8 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_40c09_row9_col0" class="data row9 col0" >Burgreens Menteng</td>
#       <td id="T_40c09_row9_col1" class="data row9 col1" >Menteng</td>
#       <td id="T_40c09_row9_col2" class="data row9 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_40c09_row10_col0" class="data row10 col0" >Burgreens Pacific Place</td>
#       <td id="T_40c09_row10_col1" class="data row10 col1" >SCBD</td>
#       <td id="T_40c09_row10_col2" class="data row10 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_40c09_row11_col0" class="data row11 col0" >JJ Royal Brasserie</td>
#       <td id="T_40c09_row11_col1" class="data row11 col1" >Karet</td>
#       <td id="T_40c09_row11_col2" class="data row11 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_40c09_row12_col0" class="data row12 col0" >Hard Rock Cafe</td>
#       <td id="T_40c09_row12_col1" class="data row12 col1" >SCBD</td>
#       <td id="T_40c09_row12_col2" class="data row12 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_40c09_row13_col0" class="data row13 col0" >Johny Rockets</td>
#       <td id="T_40c09_row13_col1" class="data row13 col1" >Karet</td>
#       <td id="T_40c09_row13_col2" class="data row13 col2" >yes</td>
#     </tr>
#   </tbody>
# </table>

# %%
wifi = sqldf("SELECT COUNT(wifi) FROM burger GROUP BY wifi HAVING wifi = 'yes'")
wifi
# Out:
#    COUNT(wifi)
# 0           14

# %%
#reservation needed
reservation = sqldf("SELECT partlor_name, district, reservation FROM burger WHERE reservation = 'yes'")
reservation.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_e0fab_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >reservation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e0fab_row0_col0" class="data row0 col0" >Lawless Burger</td>
#       <td id="T_e0fab_row0_col1" class="data row0 col1" >Menteng</td>
#       <td id="T_e0fab_row0_col2" class="data row0 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_e0fab_row1_col0" class="data row1 col0" >Le Burger</td>
#       <td id="T_e0fab_row1_col1" class="data row1 col1" >Sudirman</td>
#       <td id="T_e0fab_row1_col2" class="data row1 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_e0fab_row2_col0" class="data row2 col0" >Dope Burger</td>
#       <td id="T_e0fab_row2_col1" class="data row2 col1" >Menteng</td>
#       <td id="T_e0fab_row2_col2" class="data row2 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_e0fab_row3_col0" class="data row3 col0" >The Goods Diner</td>
#       <td id="T_e0fab_row3_col1" class="data row3 col1" >SCBD</td>
#       <td id="T_e0fab_row3_col2" class="data row3 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_e0fab_row4_col0" class="data row4 col0" >JJ Royal Brasserie</td>
#       <td id="T_e0fab_row4_col1" class="data row4 col1" >Karet</td>
#       <td id="T_e0fab_row4_col2" class="data row4 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_e0fab_row5_col0" class="data row5 col0" >Hard Rock Cafe</td>
#       <td id="T_e0fab_row5_col1" class="data row5 col1" >SCBD</td>
#       <td id="T_e0fab_row5_col2" class="data row5 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_e0fab_row6_col0" class="data row6 col0" >Johny Rockets</td>
#       <td id="T_e0fab_row6_col1" class="data row6 col1" >Karet</td>
#       <td id="T_e0fab_row6_col2" class="data row6 col2" >yes</td>
#     </tr>
#   </tbody>
# </table>

# %%
reservation = sqldf("SELECT COUNT(reservation) FROM burger GROUP BY reservation HAVING reservation = 'yes'")
reservation
# Out:
#    COUNT(reservation)
# 0                   7

# %%
#drive thru
drive_thru = sqldf("SELECT partlor_name, district, drive_thru FROM burger WHERE drive_thru = 'yes'")
drive_thru.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_08e2e_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >drive_thru</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_08e2e_row0_col0" class="data row0 col0" >Burger King Cempaka Putih</td>
#       <td id="T_08e2e_row0_col1" class="data row0 col1" >Cempaka Putih</td>
#       <td id="T_08e2e_row0_col2" class="data row0 col2" >yes</td>
#     </tr>
#   </tbody>
# </table>

# %%
drive_thru = sqldf("SELECT COUNT(drive_thru) FROM burger GROUP BY drive_thru HAVING drive_thru = 'yes'")
drive_thru
# Out:
#    COUNT(drive_thru)
# 0                  1

# %%
#dietary restricted
halal_food = sqldf("SELECT partlor_name, district, halal_food FROM burger WHERE halal_food = 'no'")
halal_food.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_c5a7e_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >halal_food</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c5a7e_row0_col0" class="data row0 col0" >The Goods Diner</td>
#       <td id="T_c5a7e_row0_col1" class="data row0 col1" >SCBD</td>
#       <td id="T_c5a7e_row0_col2" class="data row0 col2" >no</td>
#     </tr>
#     <tr>
#       <td id="T_c5a7e_row1_col0" class="data row1 col0" >JJ Royal Brasserie</td>
#       <td id="T_c5a7e_row1_col1" class="data row1 col1" >Karet</td>
#       <td id="T_c5a7e_row1_col2" class="data row1 col2" >no</td>
#     </tr>
#     <tr>
#       <td id="T_c5a7e_row2_col0" class="data row2 col0" >Hard Rock Cafe</td>
#       <td id="T_c5a7e_row2_col1" class="data row2 col1" >SCBD</td>
#       <td id="T_c5a7e_row2_col2" class="data row2 col2" >no</td>
#     </tr>
#   </tbody>
# </table>

# %%
halal_food = sqldf("SELECT COUNT(halal_food) FROM burger GROUP BY halal_food HAVING halal_food = 'no'")
halal_food
# Out:
#    COUNT(halal_food)
# 0                  3

# %% [markdown]
# # Rating
#
# I'll calculate and decide which are recommended on the other file but here is the glimpse. We can see which vendor has the highest rating available. For this time I order this list by google_rating as it appeared first.

# %%
rating = sqldf("SELECT partlor_name, district, ltrim(google_rating) as google_rating, ltrim(zomato_rating) as zomato_rating, ltrim(qraved_rating) as qraved_rating, google_count, zomato_count, qraved_count FROM burger ORDER BY google_rating DESC")
rating.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_6611b_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >google_rating</th>
#       <th class="col_heading level0 col3" >zomato_rating</th>
#       <th class="col_heading level0 col4" >qraved_rating</th>
#       <th class="col_heading level0 col5" >google_count</th>
#       <th class="col_heading level0 col6" >zomato_count</th>
#       <th class="col_heading level0 col7" >qraved_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6611b_row0_col0" class="data row0 col0" >Klenger Burger</td>
#       <td id="T_6611b_row0_col1" class="data row0 col1" >Senen</td>
#       <td id="T_6611b_row0_col2" class="data row0 col2" >4.08</td>
#       <td id="T_6611b_row0_col3" class="data row0 col3" >3.06</td>
#       <td id="T_6611b_row0_col4" class="data row0 col4" >0.0</td>
#       <td id="T_6611b_row0_col5" class="data row0 col5" >9</td>
#       <td id="T_6611b_row0_col6" class="data row0 col6" >12</td>
#       <td id="T_6611b_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_6611b_row1_col0" class="data row1 col0" >Ask for Patty</td>
#       <td id="T_6611b_row1_col1" class="data row1 col1" >Menteng</td>
#       <td id="T_6611b_row1_col2" class="data row1 col2" >4.07</td>
#       <td id="T_6611b_row1_col3" class="data row1 col3" >3.08</td>
#       <td id="T_6611b_row1_col4" class="data row1 col4" >0.0</td>
#       <td id="T_6611b_row1_col5" class="data row1 col5" >127</td>
#       <td id="T_6611b_row1_col6" class="data row1 col6" >13</td>
#       <td id="T_6611b_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_6611b_row2_col0" class="data row2 col0" >Lawless Burger</td>
#       <td id="T_6611b_row2_col1" class="data row2 col1" >Menteng</td>
#       <td id="T_6611b_row2_col2" class="data row2 col2" >4.06</td>
#       <td id="T_6611b_row2_col3" class="data row2 col3" >4.01</td>
#       <td id="T_6611b_row2_col4" class="data row2 col4" >5.0</td>
#       <td id="T_6611b_row2_col5" class="data row2 col5" >1821</td>
#       <td id="T_6611b_row2_col6" class="data row2 col6" >103</td>
#       <td id="T_6611b_row2_col7" class="data row2 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_6611b_row3_col0" class="data row3 col0" >Belly Bandit To Go</td>
#       <td id="T_6611b_row3_col1" class="data row3 col1" >Menteng</td>
#       <td id="T_6611b_row3_col2" class="data row3 col2" >4.06</td>
#       <td id="T_6611b_row3_col3" class="data row3 col3" >3.06</td>
#       <td id="T_6611b_row3_col4" class="data row3 col4" >0.0</td>
#       <td id="T_6611b_row3_col5" class="data row3 col5" >100</td>
#       <td id="T_6611b_row3_col6" class="data row3 col6" >11</td>
#       <td id="T_6611b_row3_col7" class="data row3 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_6611b_row4_col0" class="data row4 col0" >Lucy Beer & Burger Bar</td>
#       <td id="T_6611b_row4_col1" class="data row4 col1" >Sudirman</td>
#       <td id="T_6611b_row4_col2" class="data row4 col2" >4.06</td>
#       <td id="T_6611b_row4_col3" class="data row4 col3" >3.05</td>
#       <td id="T_6611b_row4_col4" class="data row4 col4" >0.0</td>
#       <td id="T_6611b_row4_col5" class="data row4 col5" >31</td>
#       <td id="T_6611b_row4_col6" class="data row4 col6" >35</td>
#       <td id="T_6611b_row4_col7" class="data row4 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_6611b_row5_col0" class="data row5 col0" >Burger King Bendungan Hilir</td>
#       <td id="T_6611b_row5_col1" class="data row5 col1" >Bendungan Hilir</td>
#       <td id="T_6611b_row5_col2" class="data row5 col2" >4.05</td>
#       <td id="T_6611b_row5_col3" class="data row5 col3" >3.01</td>
#       <td id="T_6611b_row5_col4" class="data row5 col4" >5.0</td>
#       <td id="T_6611b_row5_col5" class="data row5 col5" >3656</td>
#       <td id="T_6611b_row5_col6" class="data row5 col6" >21</td>
#       <td id="T_6611b_row5_col7" class="data row5 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_6611b_row6_col0" class="data row6 col0" >Burger King Hayam Wuruk</td>
#       <td id="T_6611b_row6_col1" class="data row6 col1" >Hayam Wuruk</td>
#       <td id="T_6611b_row6_col2" class="data row6 col2" >4.05</td>
#       <td id="T_6611b_row6_col3" class="data row6 col3" >3.03</td>
#       <td id="T_6611b_row6_col4" class="data row6 col4" >4.01</td>
#       <td id="T_6611b_row6_col5" class="data row6 col5" >4085</td>
#       <td id="T_6611b_row6_col6" class="data row6 col6" >120</td>
#       <td id="T_6611b_row6_col7" class="data row6 col7" >11</td>
#     </tr>
#     <tr>
#       <td id="T_6611b_row7_col0" class="data row7 col0" >Le Burger</td>
#       <td id="T_6611b_row7_col1" class="data row7 col1" >Sudirman</td>
#       <td id="T_6611b_row7_col2" class="data row7 col2" >4.05</td>
#       <td id="T_6611b_row7_col3" class="data row7 col3" >4.03</td>
#       <td id="T_6611b_row7_col4" class="data row7 col4" >4.03</td>
#       <td id="T_6611b_row7_col5" class="data row7 col5" >778</td>
#       <td id="T_6611b_row7_col6" class="data row7 col6" >389</td>
#       <td id="T_6611b_row7_col7" class="data row7 col7" >14</td>
#     </tr>
#     <tr>
#       <td id="T_6611b_row8_col0" class="data row8 col0" >Burger Bener</td>
#       <td id="T_6611b_row8_col1" class="data row8 col1" >Senen</td>
#       <td id="T_6611b_row8_col2" class="data row8 col2" >4.05</td>
#       <td id="T_6611b_row8_col3" class="data row8 col3" >3.07</td>
#       <td id="T_6611b_row8_col4" class="data row8 col4" >4.0</td>
#       <td id="T_6611b_row8_col5" class="data row8 col5" >1171</td>
#       <td id="T_6611b_row8_col6" class="data row8 col6" >51</td>
#       <td id="T_6611b_row8_col7" class="data row8 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_6611b_row9_col0" class="data row9 col0" >Dope Burger</td>
#       <td id="T_6611b_row9_col1" class="data row9 col1" >Menteng</td>
#       <td id="T_6611b_row9_col2" class="data row9 col2" >4.05</td>
#       <td id="T_6611b_row9_col3" class="data row9 col3" >4.03</td>
#       <td id="T_6611b_row9_col4" class="data row9 col4" >3.05</td>
#       <td id="T_6611b_row9_col5" class="data row9 col5" >775</td>
#       <td id="T_6611b_row9_col6" class="data row9 col6" >774</td>
#       <td id="T_6611b_row9_col7" class="data row9 col7" >2</td>
#     </tr>
#     <tr>
#       <td id="T_6611b_row10_col0" class="data row10 col0" >Burgreens Menteng</td>
#       <td id="T_6611b_row10_col1" class="data row10 col1" >Menteng</td>
#       <td id="T_6611b_row10_col2" class="data row10 col2" >4.05</td>
#       <td id="T_6611b_row10_col3" class="data row10 col3" >4.04</td>
#       <td id="T_6611b_row10_col4" class="data row10 col4" >4.0</td>
#       <td id="T_6611b_row10_col5" class="data row10 col5" >473</td>
#       <td id="T_6611b_row10_col6" class="data row10 col6" >237</td>
#       <td id="T_6611b_row10_col7" class="data row10 col7" >2</td>
#     </tr>
#     <tr>
#       <td id="T_6611b_row11_col0" class="data row11 col0" >Burgreens Pacific Place</td>
#       <td id="T_6611b_row11_col1" class="data row11 col1" >SCBD</td>
#       <td id="T_6611b_row11_col2" class="data row11 col2" >4.05</td>
#       <td id="T_6611b_row11_col3" class="data row11 col3" >4.04</td>
#       <td id="T_6611b_row11_col4" class="data row11 col4" >4.01</td>
#       <td id="T_6611b_row11_col5" class="data row11 col5" >532</td>
#       <td id="T_6611b_row11_col6" class="data row11 col6" >323</td>
#       <td id="T_6611b_row11_col7" class="data row11 col7" >30</td>
#     </tr>
#     <tr>
#       <td id="T_6611b_row12_col0" class="data row12 col0" >JJ Royal Brasserie</td>
#       <td id="T_6611b_row12_col1" class="data row12 col1" >Karet</td>
#       <td id="T_6611b_row12_col2" class="data row12 col2" >4.05</td>
#       <td id="T_6611b_row12_col3" class="data row12 col3" >4.0</td>
#       <td id="T_6611b_row12_col4" class="data row12 col4" >4.0</td>
#       <td id="T_6611b_row12_col5" class="data row12 col5" >1252</td>
#       <td id="T_6611b_row12_col6" class="data row12 col6" >578</td>
#       <td id="T_6611b_row12_col7" class="data row12 col7" >63</td>
#     </tr>
#     <tr
