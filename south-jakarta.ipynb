# %% [markdown]
# # **South Jakarta**
#
# This is another grand city in Jakarta besides of Central Jakarta. It's famous for being trendy among the youth. Some famous district are Blok M (which actually shopping block area), Senopati, Tebet, Kuningan (business district) and Pondok Indah (high end housing complex). Some of district here also not so far from SCBD in Central Jakarta.
#
# # Content
# * District
# * Price Range
# * Facility
# * Rating

# %%
import pandas as pd
from pandasql import sqldf
burger = pd.read_csv('../input/south-jakarta-burger/south_jakarta.csv', encoding = 'unicode_escape', sep = ";")

# %% [markdown]
# # District

# %%
district = sqldf("SELECT DISTINCT district FROM burger").transpose()
district
# Out:
#               0      1      2         3             4       5          6   \
# District  Blok M  Tebet  Karet  Kuningan  Pondok Indah  Kemang  Setiabudi
#
#                     7         8          9     10       11
# District  Pasar Minggu  Senopati  Fatmawati  SCBD  Senayan

# %% [markdown]
# Then here is the restaurant/partlors available in South Jakarta. There are total 24 vendors and rather dominated by fast food and budget section. Mostly Burger King, Blenger Burger, and Flip Burger. Least fast food available is Carl's Jr and the high end available are Lawless Burgerbar and TGI Fridays Lippo Kemang.

# %%
burger = sqldf("SELECT no, partlor_name, district, unique_menu, price FROM burger")
burger.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_e83c1_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >no</th>
#       <th class="col_heading level0 col1" >partlor_name</th>
#       <th class="col_heading level0 col2" >District</th>
#       <th class="col_heading level0 col3" >unique_menu</th>
#       <th class="col_heading level0 col4" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e83c1_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e83c1_row0_col1" class="data row0 col1" >Burger King</td>
#       <td id="T_e83c1_row0_col2" class="data row0 col2" >Blok M</td>
#       <td id="T_e83c1_row0_col3" class="data row0 col3" >Double Cheese Burger</td>
#       <td id="T_e83c1_row0_col4" class="data row0 col4" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_e83c1_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_e83c1_row1_col1" class="data row1 col1" >Burger King</td>
#       <td id="T_e83c1_row1_col2" class="data row1 col2" >Tebet</td>
#       <td id="T_e83c1_row1_col3" class="data row1 col3" >Double Cheese Burger</td>
#       <td id="T_e83c1_row1_col4" class="data row1 col4" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_e83c1_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_e83c1_row2_col1" class="data row2 col1" >Burger King Lotte Avenue</td>
#       <td id="T_e83c1_row2_col2" class="data row2 col2" >Karet</td>
#       <td id="T_e83c1_row2_col3" class="data row2 col3" >Double Cheese Burger</td>
#       <td id="T_e83c1_row2_col4" class="data row2 col4" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_e83c1_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_e83c1_row3_col1" class="data row3 col1" >Burger King Bellagio</td>
#       <td id="T_e83c1_row3_col2" class="data row3 col2" >Kuningan</td>
#       <td id="T_e83c1_row3_col3" class="data row3 col3" >Double Cheese Burger</td>
#       <td id="T_e83c1_row3_col4" class="data row3 col4" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_e83c1_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_e83c1_row4_col1" class="data row4 col1" >Burger King Pondok Indah Plaza</td>
#       <td id="T_e83c1_row4_col2" class="data row4 col2" >Pondok Indah</td>
#       <td id="T_e83c1_row4_col3" class="data row4 col3" >Double Cheese Burger</td>
#       <td id="T_e83c1_row4_col4" class="data row4 col4" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_e83c1_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_e83c1_row5_col1" class="data row5 col1" >Burger King</td>
#       <td id="T_e83c1_row5_col2" class="data row5 col2" >Kemang</td>
#       <td id="T_e83c1_row5_col3" class="data row5 col3" >Double Cheese Burger</td>
#       <td id="T_e83c1_row5_col4" class="data row5 col4" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_e83c1_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_e83c1_row6_col1" class="data row6 col1" >Burger King</td>
#       <td id="T_e83c1_row6_col2" class="data row6 col2" >Setiabudi</td>
#       <td id="T_e83c1_row6_col3" class="data row6 col3" >Double Cheese Burger</td>
#       <td id="T_e83c1_row6_col4" class="data row6 col4" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_e83c1_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_e83c1_row7_col1" class="data row7 col1" >Burger Bakar Qebul</td>
#       <td id="T_e83c1_row7_col2" class="data row7 col2" >Pasar Minggu</td>
#       <td id="T_e83c1_row7_col3" class="data row7 col3" >Beef Burger</td>
#       <td id="T_e83c1_row7_col4" class="data row7 col4" >13000</td>
#     </tr>
#     <tr>
#       <td id="T_e83c1_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_e83c1_row8_col1" class="data row8 col1" >Flip Burger </td>
#       <td id="T_e83c1_row8_col2" class="data row8 col2" >Senopati</td>
#       <td id="T_e83c1_row8_col3" class="data row8 col3" >Double Cheese Burger</td>
#       <td id="T_e83c1_row8_col4" class="data row8 col4" >45000</td>
#     </tr>
#     <tr>
#       <td id="T_e83c1_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_e83c1_row9_col1" class="data row9 col1" >Blenger Burger</td>
#       <td id="T_e83c1_row9_col2" class="data row9 col2" >Blok M</td>
#       <td id="T_e83c1_row9_col3" class="data row9 col3" >Cheese Burger X2</td>
#       <td id="T_e83c1_row9_col4" class="data row9 col4" >32000</td>
#     </tr>
#     <tr>
#       <td id="T_e83c1_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_e83c1_row10_col1" class="data row10 col1" >Blenger Burger</td>
#       <td id="T_e83c1_row10_col2" class="data row10 col2" >Fatmawati</td>
#       <td id="T_e83c1_row10_col3" class="data row10 col3" >Cheese Burger</td>
#       <td id="T_e83c1_row10_col4" class="data row10 col4" >20000</td>
#     </tr>
#     <tr>
#       <td id="T_e83c1_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_e83c1_row11_col1" class="data row11 col1" >Goods Burger</td>
#       <td id="T_e83c1_row11_col2" class="data row11 col2" >Pondok Indah</td>
#       <td id="T_e83c1_row11_col3" class="data row11 col3" >Goods Coffee Rub</td>
#       <td id="T_e83c1_row11_col4" class="data row11 col4" >65000</td>
#     </tr>
#     <tr>
#       <td id="T_e83c1_row12_col0" class="data row12 col0" >13</td>
#       <td id="T_e83c1_row12_col1" class="data row12 col1" >Flip Burger Kota Kasablanka</td>
#       <td id="T_e83c1_row12_col2" class="data row12 col2" >Tebet</td>
#       <td id="T_e83c1_row12_col3" class="data row12 col3" >Brisket Cheese Burger</td>
#       <td id="T_e83c1_row12_col4" class="data row12 col4" >28182</td>
#     </tr>
#     <tr>
#       <td id="T_e83c1_row13_col0" class="data row13 col0" >14</td>
#       <td id="T_e83c1_row13_col1" class="data row13 col1" >Flip Burger Pondok Indah Plaza</td>
#       <td id="T_e83c1_row13_col2" class="data row13 col2" >Pondok Indah</td>
#       <td id="T_e83c1_row13_col3" class="data row13 col3" >Bitsy Double Cheese</td>
#       <td id="T_e83c1_row13_col4" class="data row13 col4" >45455</td>
#     </tr>
#     <tr>
#       <td id="T_e83c1_row14_col0" class="data row14 col0" >15</td>
#       <td id="T_e83c1_row14_col1" class="data row14 col1" >Lawless Burgerbar</td>
#       <td id="T_e83c1_row14_col2" class="data row14 col2" >Kemang</td>
#       <td id="T_e83c1_row14_col3" class="data row14 col3" >Philly Anselmo</td>
#       <td id="T_e83c1_row14_col4" class="data row14 col4" >75000</td>
#     </tr>
#     <tr>
#       <td id="T_e83c1_row15_col0" class="data row15 col0" >16</td>
#       <td id="T_e83c1_row15_col1" class="data row15 col1" >Three Buns</td>
#       <td id="T_e83c1_row15_col2" class="data row15 col2" >Senopati</td>
#       <td id="T_e83c1_row15_col3" class="data row15 col3" >Rambo</td>
#       <td id="T_e83c1_row15_col4" class="data row15 col4" >115000</td>
#     </tr>
#     <tr>
#       <td id="T_e83c1_row16_col0" class="data row16 col0" >17</td>
#       <td id="T_e83c1_row16_col1" class="data row16 col1" >Byurger</td>
#       <td id="T_e83c1_row16_col2" class="data row16 col2" >Fatmawati</td>
#       <td id="T_e83c1_row16_col3" class="data row16 col3" >Sexyback Rib</td>
#       <td id="T_e83c1_row16_col4" class="data row16 col4" >65000</td>
#     </tr>
#     <tr>
#       <td id="T_e83c1_row17_col0" class="data row17 col0" >18</td>
#       <td id="T_e83c1_row17_col1" class="data row17 col1" >TGI Fridays Lippo Mall Kemang</td>
#       <td id="T_e83c1_row17_col2" class="data row17 col2" >Kemang</td>
#       <td id="T_e83c1_row17_col3" class="data row17 col3" >Fridays Cheeseburger</td>
#       <td id="T_e83c1_row17_col4" class="data row17 col4" >129000</td>
#     </tr>
#     <tr>
#       <td id="T_e83c1_row18_col0" class="data row18 col0" >19</td>
#       <td id="T_e83c1_row18_col1" class="data row18 col1" >Carl's Junior</td>
#       <td id="T_e83c1_row18_col2" class="data row18 col2" >Kemang</td>
#       <td id="T_e83c1_row18_col3" class="data row18 col3" >Western Beefbac</td>
#       <td id="T_e83c1_row18_col4" class="data row18 col4" >59091</td>
#     </tr>
#     <tr>
#       <td id="T_e83c1_row19_col0" class="data row19 col0" >20</td>
#       <td id="T_e83c1_row19_col1" class="data row19 col1" >MOS Caf</td>
#       <td id="T_e83c1_row19_col2" class="data row19 col2" >SCBD</td>
#       <td id="T_e83c1_row19_col3" class

# %% [markdown]
# # Price-Range
#
# We sorted the list from the most expensive and also the cheapest, also with the price range from IDR 50000 to 100000. Here is the order from the most expensive. The most expensive here is TGI Fridays Lippo Mall Kemang which ranged 100k per menu, the cheapest is Burger Bakar Qebul which ranged 13k per menu. Mostly budgeted below 50k.

# %%
#most expensive
burger_price = sqldf("""SELECT partlor_name, district, unique_menu, price 
FROM burger 
ORDER BY price DESC""")
burger_price.head().style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_62c1b_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_62c1b_row0_col0" class="data row0 col0" >TGI Fridays Lippo Mall Kemang</td>
#       <td id="T_62c1b_row0_col1" class="data row0 col1" >Kemang</td>
#       <td id="T_62c1b_row0_col2" class="data row0 col2" >Fridays Cheeseburger</td>
#       <td id="T_62c1b_row0_col3" class="data row0 col3" >129000</td>
#     </tr>
#     <tr>
#       <td id="T_62c1b_row1_col0" class="data row1 col0" >Three Buns</td>
#       <td id="T_62c1b_row1_col1" class="data row1 col1" >Senopati</td>
#       <td id="T_62c1b_row1_col2" class="data row1 col2" >Rambo</td>
#       <td id="T_62c1b_row1_col3" class="data row1 col3" >115000</td>
#     </tr>
#     <tr>
#       <td id="T_62c1b_row2_col0" class="data row2 col0" >Lawless Burgerbar</td>
#       <td id="T_62c1b_row2_col1" class="data row2 col1" >Kemang</td>
#       <td id="T_62c1b_row2_col2" class="data row2 col2" >Philly Anselmo</td>
#       <td id="T_62c1b_row2_col3" class="data row2 col3" >75000</td>
#     </tr>
#     <tr>
#       <td id="T_62c1b_row3_col0" class="data row3 col0" >Goods Burger</td>
#       <td id="T_62c1b_row3_col1" class="data row3 col1" >Pondok Indah</td>
#       <td id="T_62c1b_row3_col2" class="data row3 col2" >Goods Coffee Rub</td>
#       <td id="T_62c1b_row3_col3" class="data row3 col3" >65000</td>
#     </tr>
#     <tr>
#       <td id="T_62c1b_row4_col0" class="data row4 col0" >Byurger</td>
#       <td id="T_62c1b_row4_col1" class="data row4 col1" >Fatmawati</td>
#       <td id="T_62c1b_row4_col2" class="data row4 col2" >Sexyback Rib</td>
#       <td id="T_62c1b_row4_col3" class="data row4 col3" >65000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#cheapest
burger_price = sqldf("""SELECT partlor_name, district, unique_menu, price 
FROM burger 
ORDER BY price""")
burger_price.head().style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_6b0c0_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6b0c0_row0_col0" class="data row0 col0" >Burger Bakar Qebul</td>
#       <td id="T_6b0c0_row0_col1" class="data row0 col1" >Pasar Minggu</td>
#       <td id="T_6b0c0_row0_col2" class="data row0 col2" >Beef Burger</td>
#       <td id="T_6b0c0_row0_col3" class="data row0 col3" >13000</td>
#     </tr>
#     <tr>
#       <td id="T_6b0c0_row1_col0" class="data row1 col0" >Blenger Burger</td>
#       <td id="T_6b0c0_row1_col1" class="data row1 col1" >Fatmawati</td>
#       <td id="T_6b0c0_row1_col2" class="data row1 col2" >Cheese Burger</td>
#       <td id="T_6b0c0_row1_col3" class="data row1 col3" >20000</td>
#     </tr>
#     <tr>
#       <td id="T_6b0c0_row2_col0" class="data row2 col0" >Flip Burger Kota Kasablanka</td>
#       <td id="T_6b0c0_row2_col1" class="data row2 col1" >Tebet</td>
#       <td id="T_6b0c0_row2_col2" class="data row2 col2" >Brisket Cheese Burger</td>
#       <td id="T_6b0c0_row2_col3" class="data row2 col3" >28182</td>
#     </tr>
#     <tr>
#       <td id="T_6b0c0_row3_col0" class="data row3 col0" >Stacksite Express</td>
#       <td id="T_6b0c0_row3_col1" class="data row3 col1" >Senayan</td>
#       <td id="T_6b0c0_row3_col2" class="data row3 col2" >Quicksand</td>
#       <td id="T_6b0c0_row3_col3" class="data row3 col3" >30000</td>
#     </tr>
#     <tr>
#       <td id="T_6b0c0_row4_col0" class="data row4 col0" >Blenger Burger</td>
#       <td id="T_6b0c0_row4_col1" class="data row4 col1" >Blok M</td>
#       <td id="T_6b0c0_row4_col2" class="data row4 col2" >Cheese Burger X2</td>
#       <td id="T_6b0c0_row4_col3" class="data row4 col3" >32000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#more than IDR 100000
burger_price = sqldf("""SELECT partlor_name, district, unique_menu, price
FROM burger 
WHERE price >= 100000""")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_67fbc_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_67fbc_row0_col0" class="data row0 col0" >Three Buns</td>
#       <td id="T_67fbc_row0_col1" class="data row0 col1" >Senopati</td>
#       <td id="T_67fbc_row0_col2" class="data row0 col2" >Rambo</td>
#       <td id="T_67fbc_row0_col3" class="data row0 col3" >115000</td>
#     </tr>
#     <tr>
#       <td id="T_67fbc_row1_col0" class="data row1 col0" >TGI Fridays Lippo Mall Kemang</td>
#       <td id="T_67fbc_row1_col1" class="data row1 col1" >Kemang</td>
#       <td id="T_67fbc_row1_col2" class="data row1 col2" >Fridays Cheeseburger</td>
#       <td id="T_67fbc_row1_col3" class="data row1 col3" >129000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#between 50000 to 100000
burger_price = sqldf("""SELECT partlor_name, district, unique_menu, price
FROM burger 
WHERE price BETWEEN 50000 AND 100000""")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_3c0a4_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3c0a4_row0_col0" class="data row0 col0" >Goods Burger</td>
#       <td id="T_3c0a4_row0_col1" class="data row0 col1" >Pondok Indah</td>
#       <td id="T_3c0a4_row0_col2" class="data row0 col2" >Goods Coffee Rub</td>
#       <td id="T_3c0a4_row0_col3" class="data row0 col3" >65000</td>
#     </tr>
#     <tr>
#       <td id="T_3c0a4_row1_col0" class="data row1 col0" >Lawless Burgerbar</td>
#       <td id="T_3c0a4_row1_col1" class="data row1 col1" >Kemang</td>
#       <td id="T_3c0a4_row1_col2" class="data row1 col2" >Philly Anselmo</td>
#       <td id="T_3c0a4_row1_col3" class="data row1 col3" >75000</td>
#     </tr>
#     <tr>
#       <td id="T_3c0a4_row2_col0" class="data row2 col0" >Byurger</td>
#       <td id="T_3c0a4_row2_col1" class="data row2 col1" >Fatmawati</td>
#       <td id="T_3c0a4_row2_col2" class="data row2 col2" >Sexyback Rib</td>
#       <td id="T_3c0a4_row2_col3" class="data row2 col3" >65000</td>
#     </tr>
#     <tr>
#       <td id="T_3c0a4_row3_col0" class="data row3 col0" >Carl's Junior</td>
#       <td id="T_3c0a4_row3_col1" class="data row3 col1" >Kemang</td>
#       <td id="T_3c0a4_row3_col2" class="data row3 col2" >Western Beefbac</td>
#       <td id="T_3c0a4_row3_col3" class="data row3 col3" >59091</td>
#     </tr>
#     <tr>
#       <td id="T_3c0a4_row4_col0" class="data row4 col0" >MOS Caf</td>
#       <td id="T_3c0a4_row4_col1" class="data row4 col1" >SCBD</td>
#       <td id="T_3c0a4_row4_col2" class="data row4 col2" >Charcoal Tobikiri Burger</td>
#       <td id="T_3c0a4_row4_col3" class="data row4 col3" >63000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#below IDR 100000
burger_price = sqldf("""SELECT partlor_name, district, unique_menu, price
FROM burger 
WHERE price <= 50000""")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_6ccc6_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6ccc6_row0_col0" class="data row0 col0" >Burger King</td>
#       <td id="T_6ccc6_row0_col1" class="data row0 col1" >Blok M</td>
#       <td id="T_6ccc6_row0_col2" class="data row0 col2" >Double Cheese Burger</td>
#       <td id="T_6ccc6_row0_col3" class="data row0 col3" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_6ccc6_row1_col0" class="data row1 col0" >Burger King</td>
#       <td id="T_6ccc6_row1_col1" class="data row1 col1" >Tebet</td>
#       <td id="T_6ccc6_row1_col2" class="data row1 col2" >Double Cheese Burger</td>
#       <td id="T_6ccc6_row1_col3" class="data row1 col3" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_6ccc6_row2_col0" class="data row2 col0" >Burger King Lotte Avenue</td>
#       <td id="T_6ccc6_row2_col1" class="data row2 col1" >Karet</td>
#       <td id="T_6ccc6_row2_col2" class="data row2 col2" >Double Cheese Burger</td>
#       <td id="T_6ccc6_row2_col3" class="data row2 col3" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_6ccc6_row3_col0" class="data row3 col0" >Burger King Bellagio</td>
#       <td id="T_6ccc6_row3_col1" class="data row3 col1" >Kuningan</td>
#       <td id="T_6ccc6_row3_col2" class="data row3 col2" >Double Cheese Burger</td>
#       <td id="T_6ccc6_row3_col3" class="data row3 col3" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_6ccc6_row4_col0" class="data row4 col0" >Burger King Pondok Indah Plaza</td>
#       <td id="T_6ccc6_row4_col1" class="data row4 col1" >Pondok Indah</td>
#       <td id="T_6ccc6_row4_col2" class="data row4 col2" >Double Cheese Burger</td>
#       <td id="T_6ccc6_row4_col3" class="data row4 col3" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_6ccc6_row5_col0" class="data row5 col0" >Burger King</td>
#       <td id="T_6ccc6_row5_col1" class="data row5 col1" >Kemang</td>
#       <td id="T_6ccc6_row5_col2" class="data row5 col2" >Double Cheese Burger</td>
#       <td id="T_6ccc6_row5_col3" class="data row5 col3" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_6ccc6_row6_col0" class="data row6 col0" >Burger King</td>
#       <td id="T_6ccc6_row6_col1" class="data row6 col1" >Setiabudi</td>
#       <td id="T_6ccc6_row6_col2" class="data row6 col2" >Double Cheese Burger</td>
#       <td id="T_6ccc6_row6_col3" class="data row6 col3" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_6ccc6_row7_col0" class="data row7 col0" >Burger Bakar Qebul</td>
#       <td id="T_6ccc6_row7_col1" class="data row7 col1" >Pasar Minggu</td>
#       <td id="T_6ccc6_row7_col2" class="data row7 col2" >Beef Burger</td>
#       <td id="T_6ccc6_row7_col3" class="data row7 col3" >13000</td>
#     </tr>
#     <tr>
#       <td id="T_6ccc6_row8_col0" class="data row8 col0" >Flip Burger </td>
#       <td id="T_6ccc6_row8_col1" class="data row8 col1" >Senopati</td>
#       <td id="T_6ccc6_row8_col2" class="data row8 col2" >Double Cheese Burger</td>
#       <td id="T_6ccc6_row8_col3" class="data row8 col3" >45000</td>
#     </tr>
#     <tr>
#       <td id="T_6ccc6_row9_col0" class="data row9 col0" >Blenger Burger</td>
#       <td id="T_6ccc6_row9_col1" class="data row9 col1" >Blok M</td>
#       <td id="T_6ccc6_row9_col2" class="data row9 col2" >Cheese Burger X2</td>
#       <td id="T_6ccc6_row9_col3" class="data row9 col3" >32000</td>
#     </tr>
#     <tr>
#       <td id="T_6ccc6_row10_col0" class="data row10 col0" >Blenger Burger</td>
#       <td id="T_6ccc6_row10_col1" class="data row10 col1" >Fatmawati</td>
#       <td id="T_6ccc6_row10_col2" class="data row10 col2" >Cheese Burger</td>
#       <td id="T_6ccc6_row10_col3" class="data row10 col3" >20000</td>
#     </tr>
#     <tr>
#       <td id="T_6ccc6_row11_col0" class="data row11 col0" >Flip Burger Kota Kasablanka</td>
#       <td id="T_6ccc6_row11_col1" class="data row11 col1" >Tebet</td>
#       <td id="T_6ccc6_row11_col2" class="data row11 col2" >Brisket Cheese Burger</td>
#       <td id="T_6ccc6_row11_col3" class="data row11 col3" >28182</td>
#     </tr>
#     <tr>
#       <td id="T_6ccc6_row12_col0" class="data row12 col0" >Flip Burger Pondok Indah Plaza</td>
#       <td id="T_6ccc6_row12_col1" class="data row12 col1" >Pondok Indah</td>
#       <td id="T_6ccc6_row12_col2" class="data row12 col2" >Bitsy Double Cheese</td>
#       <td id="T_6ccc6_row12_col3" class="data row12 col3" >45455</td>
#     </tr>
#     <tr>
#       <td id="T_6ccc6_row13_col0" class="data row13 col0" >Stacksite Express</td>
#       <td id="T_6ccc6_row13_col1" class="data row13 col1" >Senayan</td>
#       <td id="T_6ccc6_row13_col2" class="data row13 col2" >Quicksand</td>
#       <td id="T_6ccc6_row13_col3" class="data row13 col3" >30000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Facility
#
# Last but not least, we chose the restaurant whether we could takeaway, or deliver our food. We also could find out whether these partlor has outdoor seats, smoking room, wifi, and reservation. Last but not least, we researched about poultry with some dietary restriction like alcohol and halal_menu. But this halal menu will not available in other project. We changed to other_poultry instead.
#
# Mostly they can do takeaway but for delivery there are some vendors unable to do so. Outdoor seat and smoking area also mostly available, let alone with wifi. There are only four vendor which needed/able to reserve, as for dietary restriction there are alcohol on high end restaurant like Lawless Burgerbar, Three Buns, TGI Fridays, and Byurgers, only one remaining which has pork menu.
#
# No drive thru options unfortunately.
#
# Let's take a look for all the facility.

# %%
burger = sqldf("""SELECT no, partlor_name, district, takeaway, delivery, outdoor_seat, smoking_area
alcohol_served, wifi, reservation, drive_thru, halal_food FROM burger""")
burger.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_f5bae_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >no</th>
#       <th class="col_heading level0 col1" >partlor_name</th>
#       <th class="col_heading level0 col2" >District</th>
#       <th class="col_heading level0 col3" >takeaway</th>
#       <th class="col_heading level0 col4" >delivery</th>
#       <th class="col_heading level0 col5" >outdoor_seat</th>
#       <th class="col_heading level0 col6" >alcohol_served</th>
#       <th class="col_heading level0 col7" >wifi</th>
#       <th class="col_heading level0 col8" >reservation</th>
#       <th class="col_heading level0 col9" >drive_thru</th>
#       <th class="col_heading level0 col10" >halal_food</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f5bae_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_f5bae_row0_col1" class="data row0 col1" >Burger King</td>
#       <td id="T_f5bae_row0_col2" class="data row0 col2" >Blok M</td>
#       <td id="T_f5bae_row0_col3" class="data row0 col3" >yes</td>
#       <td id="T_f5bae_row0_col4" class="data row0 col4" >yes</td>
#       <td id="T_f5bae_row0_col5" class="data row0 col5" >yes</td>
#       <td id="T_f5bae_row0_col6" class="data row0 col6" >yes</td>
#       <td id="T_f5bae_row0_col7" class="data row0 col7" >yes</td>
#       <td id="T_f5bae_row0_col8" class="data row0 col8" >no</td>
#       <td id="T_f5bae_row0_col9" class="data row0 col9" >no</td>
#       <td id="T_f5bae_row0_col10" class="data row0 col10" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f5bae_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_f5bae_row1_col1" class="data row1 col1" >Burger King</td>
#       <td id="T_f5bae_row1_col2" class="data row1 col2" >Tebet</td>
#       <td id="T_f5bae_row1_col3" class="data row1 col3" >yes</td>
#       <td id="T_f5bae_row1_col4" class="data row1 col4" >yes</td>
#       <td id="T_f5bae_row1_col5" class="data row1 col5" >no</td>
#       <td id="T_f5bae_row1_col6" class="data row1 col6" >no</td>
#       <td id="T_f5bae_row1_col7" class="data row1 col7" >yes</td>
#       <td id="T_f5bae_row1_col8" class="data row1 col8" >no</td>
#       <td id="T_f5bae_row1_col9" class="data row1 col9" >no</td>
#       <td id="T_f5bae_row1_col10" class="data row1 col10" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f5bae_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_f5bae_row2_col1" class="data row2 col1" >Burger King Lotte Avenue</td>
#       <td id="T_f5bae_row2_col2" class="data row2 col2" >Karet</td>
#       <td id="T_f5bae_row2_col3" class="data row2 col3" >yes</td>
#       <td id="T_f5bae_row2_col4" class="data row2 col4" >yes</td>
#       <td id="T_f5bae_row2_col5" class="data row2 col5" >no</td>
#       <td id="T_f5bae_row2_col6" class="data row2 col6" >no</td>
#       <td id="T_f5bae_row2_col7" class="data row2 col7" >yes</td>
#       <td id="T_f5bae_row2_col8" class="data row2 col8" >no</td>
#       <td id="T_f5bae_row2_col9" class="data row2 col9" >no</td>
#       <td id="T_f5bae_row2_col10" class="data row2 col10" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f5bae_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_f5bae_row3_col1" class="data row3 col1" >Burger King Bellagio</td>
#       <td id="T_f5bae_row3_col2" class="data row3 col2" >Kuningan</td>
#       <td id="T_f5bae_row3_col3" class="data row3 col3" >yes</td>
#       <td id="T_f5bae_row3_col4" class="data row3 col4" >yes</td>
#       <td id="T_f5bae_row3_col5" class="data row3 col5" >yes</td>
#       <td id="T_f5bae_row3_col6" class="data row3 col6" >yes</td>
#       <td id="T_f5bae_row3_col7" class="data row3 col7" >yes</td>
#       <td id="T_f5bae_row3_col8" class="data row3 col8" >no</td>
#       <td id="T_f5bae_row3_col9" class="data row3 col9" >no</td>
#       <td id="T_f5bae_row3_col10" class="data row3 col10" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f5bae_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_f5bae_row4_col1" class="data row4 col1" >Burger King Pondok Indah Plaza</td>
#       <td id="T_f5bae_row4_col2" class="data row4 col2" >Pondok Indah</td>
#       <td id="T_f5bae_row4_col3" class="data row4 col3" >yes</td>
#       <td id="T_f5bae_row4_col4" class="data row4 col4" >yes</td>
#       <td id="T_f5bae_row4_col5" class="data row4 col5" >yes</td>
#       <td id="T_f5bae_row4_col6" class="data row4 col6" >yes</td>
#       <td id="T_f5bae_row4_col7" class="data row4 col7" >yes</td>
#       <td id="T_f5bae_row4_col8" class="data row4 col8" >no</td>
#       <td id="T_f5bae_row4_col9" class="data row4 col9" >no</td>
#       <td id="T_f5bae_row4_col10" class="data row4 col10" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f5bae_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_f5bae_row5_col1" class="data row5 col1" >Burger King</td>
#       <td id="T_f5bae_row5_col2" class="data row5 col2" >Kemang</td>
#       <td id="T_f5bae_row5_col3" class="data row5 col3" >yes</td>
#       <td id="T_f5bae_row5_col4" class="data row5 col4" >yes</td>
#       <td id="T_f5bae_row5_col5" class="data row5 col5" >no</td>
#       <td id="T_f5bae_row5_col6" class="data row5 col6" >no</td>
#       <td id="T_f5bae_row5_col7" class="data row5 col7" >yes</td>
#       <td id="T_f5bae_row5_col8" class="data row5 col8" >no</td>
#       <td id="T_f5bae_row5_col9" class="data row5 col9" >no</td>
#       <td id="T_f5bae_row5_col10" class="data row5 col10" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f5bae_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_f5bae_row6_col1" class="data row6 col1" >Burger King</td>
#       <td id="T_f5bae_row6_col2" class="data row6 col2" >Setiabudi</td>
#       <td id="T_f5bae_row6_col3" class="data row6 col3" >yes</td>
#       <td id="T_f5bae_row6_col4" class="data row6 col4" >no</td>
#       <td id="T_f5bae_row6_col5" class="data row6 col5" >yes</td>
#       <td id="T_f5bae_row6_col6" class="data row6 col6" >yes</td>
#       <td id="T_f5bae_row6_col7" class="data row6 col7" >yes</td>
#       <td id="T_f5bae_row6_col8" class="data row6 col8" >no</td>
#       <td id="T_f5bae_row6_col9" class="data row6 col9" >no</td>
#       <td id="T_f5bae_row6_col10" class="data row6 col10" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f5bae_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_f5bae_row7_col1" class="data row7 col1" >Burger Bakar Qebul</td>
#       <td id="T_f5bae_row7_col2" class="data row7 col2" >Pasar Minggu</td>
#       <td id="T_f5bae_row7_col3" class="data row7 col3" >yes</td>
#       <td id="T_f5bae_row7_col4" class="data row7 col4" >no</td>
#       <td id="T_f5bae_row7_col5" class="data row7 col5" >no</td>
#       <td id="T_f5bae_row7_col6" class="data row7 col6" >yes</td>
#       <td id="T_f5bae_row7_col7" class="data row7 col7" >no</td>
#       <td id="T_f5bae_row7_col8" class="data row7 col8" >no</td>
#       <td id="T_f5bae_row7_col9" class="data row7 col9" >no</td>
#       <td id="T_f5bae_row7_col10" class="data row7 col10" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f5bae_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_f5bae_row8_col1" class="data row8 col1" >Flip Burger </td>
#       <td id="T_f5bae_row8_col2" class="data row8 col2" >Senopati</td>
#       <td id="T_f5bae_row8_col3" class="data row8 col3" >yes</td>
#       <td id="T_f5bae_row8_col4" class="data row8 col4" >yes</td>
#       <td id="T_f5bae_row8_col5" class="data row8 col5" >no</td>
#       <td id="T_f5bae_row8_col6" class="data row8 col6" >no</td>
#       <td id="T_f5bae_row8_col7" class="data row8 col7" >yes</td>
#       <td id="T_f5bae_row8_col8" class="data row8 col8" >no</td>
#       <td id="T_f5bae_row8_col9" class="data row8 col9" >no</td>
#       <td id="T_f5bae_row8_col10" class="data row8 col10" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f5bae_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_f5bae_row9_col1" class="data row9 col1" >Blenger Burger</td>
#       <td id="T_f5bae_row9_col2" class="data row9 col2" >Blok M</td>
#       <td id="T_f5bae_row9_col3" class="data row9 col3" >yes</td>
#       <td id="T_f5bae_row9_col4" class="data row9 col4" >yes</td>
#       <td id="T_f5bae_row9_col5" class="data row9 col5" >yes</td

# %% [markdown]
# # Rating
#
# From the list Lawless Burgerbar Kemang is the most well known among the city (scored 4.6), followed by Burger Bakar Qebul which scored 4.4, and Byurger which scored 4,4. If the score is more than 3.5 then the partlor is worthed to try. All the facility and menu are representated by all both google and platform rating and count, so in the meantime only ratings are counted here.

# %%
burger = sqldf("""SELECT partlor_name, district, ltrim(google_rating) as google_rating, ltrim(zomato_rating) as zomato_rating, ltrim(qraved_rating) as qraved_rating, 
ltrim((google_rating + zomato_rating + qraved_rating)/3,1) as total_rating,
CASE
    WHEN ltrim((google_rating + zomato_rating + qraved_rating)/3,1) >= 3.5 THEN "Recommended"
    ELSE "Reconsider"
END AS "Recommendation"
FROM burger
ORDER BY total_rating DESC""")
burger.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_a5a02_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >google_rating</th>
#       <th class="col_heading level0 col3" >zomato_rating</th>
#       <th class="col_heading level0 col4" >qraved_rating</th>
#       <th class="col_heading level0 col5" >total_rating</th>
#       <th class="col_heading level0 col6" >Recommendation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a5a02_row0_col0" class="data row0 col0" >Lawless Burgerbar</td>
#       <td id="T_a5a02_row0_col1" class="data row0 col1" >Kemang</td>
#       <td id="T_a5a02_row0_col2" class="data row0 col2" >4.7</td>
#       <td id="T_a5a02_row0_col3" class="data row0 col3" >4.7</td>
#       <td id="T_a5a02_row0_col4" class="data row0 col4" >4.6</td>
#       <td id="T_a5a02_row0_col5" class="data row0 col5" >4.66666666666667</td>
#       <td id="T_a5a02_row0_col6" class="data row0 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a5a02_row1_col0" class="data row1 col0" >Burger Bakar Qebul</td>
#       <td id="T_a5a02_row1_col1" class="data row1 col1" >Pasar Minggu</td>
#       <td id="T_a5a02_row1_col2" class="data row1 col2" >4.7</td>
#       <td id="T_a5a02_row1_col3" class="data row1 col3" >4.3</td>
#       <td id="T_a5a02_row1_col4" class="data row1 col4" >4.3</td>
#       <td id="T_a5a02_row1_col5" class="data row1 col5" >4.43333333333333</td>
#       <td id="T_a5a02_row1_col6" class="data row1 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a5a02_row2_col0" class="data row2 col0" >Byurger</td>
#       <td id="T_a5a02_row2_col1" class="data row2 col1" >Fatmawati</td>
#       <td id="T_a5a02_row2_col2" class="data row2 col2" >4.7</td>
#       <td id="T_a5a02_row2_col3" class="data row2 col3" >4.4</td>
#       <td id="T_a5a02_row2_col4" class="data row2 col4" >4.1</td>
#       <td id="T_a5a02_row2_col5" class="data row2 col5" >4.4</td>
#       <td id="T_a5a02_row2_col6" class="data row2 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a5a02_row3_col0" class="data row3 col0" >Blenger Burger</td>
#       <td id="T_a5a02_row3_col1" class="data row3 col1" >Blok M</td>
#       <td id="T_a5a02_row3_col2" class="data row3 col2" >4.5</td>
#       <td id="T_a5a02_row3_col3" class="data row3 col3" >4.3</td>
#       <td id="T_a5a02_row3_col4" class="data row3 col4" >4.3</td>
#       <td id="T_a5a02_row3_col5" class="data row3 col5" >4.36666666666667</td>
#       <td id="T_a5a02_row3_col6" class="data row3 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a5a02_row4_col0" class="data row4 col0" >Three Buns</td>
#       <td id="T_a5a02_row4_col1" class="data row4 col1" >Senopati</td>
#       <td id="T_a5a02_row4_col2" class="data row4 col2" >4.5</td>
#       <td id="T_a5a02_row4_col3" class="data row4 col3" >4.1</td>
#       <td id="T_a5a02_row4_col4" class="data row4 col4" >4.2</td>
#       <td id="T_a5a02_row4_col5" class="data row4 col5" >4.26666666666667</td>
#       <td id="T_a5a02_row4_col6" class="data row4 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a5a02_row5_col0" class="data row5 col0" >Carl's Junior</td>
#       <td id="T_a5a02_row5_col1" class="data row5 col1" >Kemang</td>
#       <td id="T_a5a02_row5_col2" class="data row5 col2" >4.5</td>
#       <td id="T_a5a02_row5_col3" class="data row5 col3" >4.2</td>
#       <td id="T_a5a02_row5_col4" class="data row5 col4" >4.0</td>
#       <td id="T_a5a02_row5_col5" class="data row5 col5" >4.23333333333333</td>
#       <td id="T_a5a02_row5_col6" class="data row5 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a5a02_row6_col0" class="data row6 col0" >Blenger Burger</td>
#       <td id="T_a5a02_row6_col1" class="data row6 col1" >Fatmawati</td>
#       <td id="T_a5a02_row6_col2" class="data row6 col2" >4.6</td>
#       <td id="T_a5a02_row6_col3" class="data row6 col3" >4.0</td>
#       <td id="T_a5a02_row6_col4" class="data row6 col4" >4.0</td>
#       <td id="T_a5a02_row6_col5" class="data row6 col5" >4.2</td>
#       <td id="T_a5a02_row6_col6" class="data row6 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a5a02_row7_col0" class="data row7 col0" >Flip Burger </td>
#       <td id="T_a5a02_row7_col1" class="data row7 col1" >Senopati</td>
#       <td id="T_a5a02_row7_col2" class="data row7 col2" >4.4</td>
#       <td id="T_a5a02_row7_col3" class="data row7 col3" >4.2</td>
#       <td id="T_a5a02_row7_col4" class="data row7 col4" >3.9</td>
#       <td id="T_a5a02_row7_col5" class="data row7 col5" >4.16666666666667</td>
#       <td id="T_a5a02_row7_col6" class="data row7 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a5a02_row8_col0" class="data row8 col0" >Flip Burger Pondok Indah Plaza</td>
#       <td id="T_a5a02_row8_col1" class="data row8 col1" >Pondok Indah</td>
#       <td id="T_a5a02_row8_col2" class="data row8 col2" >4.5</td>
#       <td id="T_a5a02_row8_col3" class="data row8 col3" >3.7</td>
#       <td id="T_a5a02_row8_col4" class="data row8 col4" >4.0</td>
#       <td id="T_a5a02_row8_col5" class="data row8 col5" >4.06666666666667</td>
#       <td id="T_a5a02_row8_col6" class="data row8 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a5a02_row9_col0" class="data row9 col0" >Burger King</td>
#       <td id="T_a5a02_row9_col1" class="data row9 col1" >Tebet</td>
#       <td id="T_a5a02_row9_col2" class="data row9 col2" >4.4</td>
#       <td id="T_a5a02_row9_col3" class="data row9 col3" >3.7</td>
#       <td id="T_a5a02_row9_col4" class="data row9 col4" >4.0</td>
#       <td id="T_a5a02_row9_col5" class="data row9 col5" >4.03333333333333</td>
#       <td id="T_a5a02_row9_col6" class="data row9 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a5a02_row10_col0" class="data row10 col0" >Burger King Lotte Avenue</td>
#       <td id="T_a5a02_row10_col1" class="data row10 col1" >Karet</td>
#       <td id="T_a5a02_row10_col2" class="data row10 col2" >4.3</td>
#       <td id="T_a5a02_row10_col3" class="data row10 col3" >3.2</td>
#       <td id="T_a5a02_row10_col4" class="data row10 col4" >4.2</td>
#       <td id="T_a5a02_row10_col5" class="data row10 col5" >3.9</td>
#       <td id="T_a5a02_row10_col6" class="data row10 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a5a02_row11_col0" class="data row11 col0" >Burger King Pondok Indah Plaza</td>
#       <td id="T_a5a02_row11_col1" class="data row11 col1" >Pondok Indah</td>
#       <td id="T_a5a02_row11_col2" class="data row11 col2" >4.5</td>
#       <td id="T_a5a02_row11_col3" class="data row11 col3" >3.2</td>
#       <td id="T_a5a02_row11_col4" class="data row11 col4" >4.0</td>
#       <td id="T_a5a02_row11_col5" class="data row11 col5" >3.9</td>
#       <td id="T_a5a02_row11_col6" class="data row11 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a5a02_row12_col0" class="data row12 col0" >Burger King</td>
#       <td id="T_a5a02_row12_col1" class="data row12 col1" >Setiabudi</td>
#       <td id="T_a5a02_row12_col2" class="data row12 col2" >4.2</td>
#       <td id="T_a5a02_row12_col3" class="data row12 col3" >3.5</td>
#       <td id="T_a5a02_row12_col4" class="data row12 col4" >4.0</td>
#       <td id="T_a5a02_row12_col5" class="data row12 col5" >3.9</td>
#       <td id="T_a5a02_row12_col6" class="data row12 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a5a02_row13_col0" class="data row13 col0" >Burger King</td>
#       <td id="T_a5a02_row13_col1" class="data row13 col1" >Blok M</td>
#       <td id="T_a5a02_row13_col2" class="data row13 col2" >4.3</td>
#       <td id="T_a5a02_row13_col3" class="data row13 col3" >3.3</td>
#       <td id="T_a5a02_row13_col4" class="data row13 col4" >3.8</td>
#       <td id="T_a5a02_row13_col5" class="data row13 col5" >3.8</td>
#       <td id="T_a5a02_row13_col6" class="data row13 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a5a02_row14_col0" class="data row14 col0" >Burger King Bellagio</td>
#       <td id="T_a5a02_row14_col1" class="data row14 col1" >Kuningan</td>
#       <td id="T_a5a02_row14_col2" class="da
