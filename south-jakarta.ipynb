# %% [markdown]
# # **South Jakarta**
#
# This is another grand city in Jakarta besides of Central Jakarta. It's famous for being trendy among the youth. Some famous district are Blok M (which actually shopping block area), Senopati, Tebet, Kuningan (business district) and Pondok Indah (high end housing complex). Some of district here also not so far from SCBD in Central Jakarta.
#
# # Content
# * [District](#District)
# * [Price-Range](#Price-Range)
# * [Facility](#Facility)
# * [Rating](#Rating)

# %%
import pandas as pd
from pandasql import sqldf
burger = pd.read_csv('../input/south-jakarta-burger/south_jakarta.csv', encoding = 'unicode_escape', sep = ";")

# %% [markdown]
# # District

# %%
district = sqldf("SELECT DISTINCT district FROM burger").transpose()
district
# Out:
#               0      1      2         3             4       5          6   \
# District  Blok M  Tebet  Karet  Kuningan  Pondok Indah  Kemang  Setiabudi
#
#                     7         8          9     10       11
# District  Pasar Minggu  Senopati  Fatmawati  SCBD  Senayan

# %% [markdown]
# Then here is the restaurant/partlors available in South Jakarta. There are total 24 vendors and rather dominated by fast food and budget section. Mostly Burger King, Blenger Burger, and Flip Burger. Least fast food available is Carl's Jr and the high end available are Lawless Burgerbar and TGI Fridays Lippo Kemang.

# %%
burger = sqldf("SELECT no, partlor_name, District, unique_menu, price FROM burger")
burger.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_a72fa_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >no</th>
#       <th class="col_heading level0 col1" >partlor_name</th>
#       <th class="col_heading level0 col2" >District</th>
#       <th class="col_heading level0 col3" >unique_menu</th>
#       <th class="col_heading level0 col4" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a72fa_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a72fa_row0_col1" class="data row0 col1" >Burger King</td>
#       <td id="T_a72fa_row0_col2" class="data row0 col2" >Blok M</td>
#       <td id="T_a72fa_row0_col3" class="data row0 col3" >Double Cheese Burger</td>
#       <td id="T_a72fa_row0_col4" class="data row0 col4" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_a72fa_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_a72fa_row1_col1" class="data row1 col1" >Burger King</td>
#       <td id="T_a72fa_row1_col2" class="data row1 col2" >Tebet</td>
#       <td id="T_a72fa_row1_col3" class="data row1 col3" >Double Cheese Burger</td>
#       <td id="T_a72fa_row1_col4" class="data row1 col4" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_a72fa_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_a72fa_row2_col1" class="data row2 col1" >Burger King Lotte Avenue</td>
#       <td id="T_a72fa_row2_col2" class="data row2 col2" >Karet</td>
#       <td id="T_a72fa_row2_col3" class="data row2 col3" >Double Cheese Burger</td>
#       <td id="T_a72fa_row2_col4" class="data row2 col4" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_a72fa_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_a72fa_row3_col1" class="data row3 col1" >Burger King Bellagio</td>
#       <td id="T_a72fa_row3_col2" class="data row3 col2" >Kuningan</td>
#       <td id="T_a72fa_row3_col3" class="data row3 col3" >Double Cheese Burger</td>
#       <td id="T_a72fa_row3_col4" class="data row3 col4" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_a72fa_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_a72fa_row4_col1" class="data row4 col1" >Burger King Pondok Indah Plaza</td>
#       <td id="T_a72fa_row4_col2" class="data row4 col2" >Pondok Indah</td>
#       <td id="T_a72fa_row4_col3" class="data row4 col3" >Double Cheese Burger</td>
#       <td id="T_a72fa_row4_col4" class="data row4 col4" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_a72fa_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_a72fa_row5_col1" class="data row5 col1" >Burger King</td>
#       <td id="T_a72fa_row5_col2" class="data row5 col2" >Kemang</td>
#       <td id="T_a72fa_row5_col3" class="data row5 col3" >Double Cheese Burger</td>
#       <td id="T_a72fa_row5_col4" class="data row5 col4" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_a72fa_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_a72fa_row6_col1" class="data row6 col1" >Burger King</td>
#       <td id="T_a72fa_row6_col2" class="data row6 col2" >Setiabudi</td>
#       <td id="T_a72fa_row6_col3" class="data row6 col3" >Double Cheese Burger</td>
#       <td id="T_a72fa_row6_col4" class="data row6 col4" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_a72fa_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_a72fa_row7_col1" class="data row7 col1" >Burger Bakar Qebul</td>
#       <td id="T_a72fa_row7_col2" class="data row7 col2" >Pasar Minggu</td>
#       <td id="T_a72fa_row7_col3" class="data row7 col3" >Beef Burger</td>
#       <td id="T_a72fa_row7_col4" class="data row7 col4" >13000</td>
#     </tr>
#     <tr>
#       <td id="T_a72fa_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_a72fa_row8_col1" class="data row8 col1" >Flip Burger </td>
#       <td id="T_a72fa_row8_col2" class="data row8 col2" >Senopati</td>
#       <td id="T_a72fa_row8_col3" class="data row8 col3" >Double Cheese Burger</td>
#       <td id="T_a72fa_row8_col4" class="data row8 col4" >45000</td>
#     </tr>
#     <tr>
#       <td id="T_a72fa_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_a72fa_row9_col1" class="data row9 col1" >Blenger Burger</td>
#       <td id="T_a72fa_row9_col2" class="data row9 col2" >Blok M</td>
#       <td id="T_a72fa_row9_col3" class="data row9 col3" >Cheese Burger X2</td>
#       <td id="T_a72fa_row9_col4" class="data row9 col4" >32000</td>
#     </tr>
#     <tr>
#       <td id="T_a72fa_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_a72fa_row10_col1" class="data row10 col1" >Blenger Burger</td>
#       <td id="T_a72fa_row10_col2" class="data row10 col2" >Fatmawati</td>
#       <td id="T_a72fa_row10_col3" class="data row10 col3" >Cheese Burger</td>
#       <td id="T_a72fa_row10_col4" class="data row10 col4" >20000</td>
#     </tr>
#     <tr>
#       <td id="T_a72fa_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_a72fa_row11_col1" class="data row11 col1" >Goods Burger</td>
#       <td id="T_a72fa_row11_col2" class="data row11 col2" >Pondok Indah</td>
#       <td id="T_a72fa_row11_col3" class="data row11 col3" >Goods Coffee Rub</td>
#       <td id="T_a72fa_row11_col4" class="data row11 col4" >65000</td>
#     </tr>
#     <tr>
#       <td id="T_a72fa_row12_col0" class="data row12 col0" >13</td>
#       <td id="T_a72fa_row12_col1" class="data row12 col1" >Flip Burger Kota Kasablanka</td>
#       <td id="T_a72fa_row12_col2" class="data row12 col2" >Tebet</td>
#       <td id="T_a72fa_row12_col3" class="data row12 col3" >Brisket Cheese Burger</td>
#       <td id="T_a72fa_row12_col4" class="data row12 col4" >28182</td>
#     </tr>
#     <tr>
#       <td id="T_a72fa_row13_col0" class="data row13 col0" >14</td>
#       <td id="T_a72fa_row13_col1" class="data row13 col1" >Flip Burger Pondok Indah Plaza</td>
#       <td id="T_a72fa_row13_col2" class="data row13 col2" >Pondok Indah</td>
#       <td id="T_a72fa_row13_col3" class="data row13 col3" >Bitsy Double Cheese</td>
#       <td id="T_a72fa_row13_col4" class="data row13 col4" >45455</td>
#     </tr>
#     <tr>
#       <td id="T_a72fa_row14_col0" class="data row14 col0" >15</td>
#       <td id="T_a72fa_row14_col1" class="data row14 col1" >Lawless Burgerbar</td>
#       <td id="T_a72fa_row14_col2" class="data row14 col2" >Kemang</td>
#       <td id="T_a72fa_row14_col3" class="data row14 col3" >Philly Anselmo</td>
#       <td id="T_a72fa_row14_col4" class="data row14 col4" >75000</td>
#     </tr>
#     <tr>
#       <td id="T_a72fa_row15_col0" class="data row15 col0" >16</td>
#       <td id="T_a72fa_row15_col1" class="data row15 col1" >Three Buns</td>
#       <td id="T_a72fa_row15_col2" class="data row15 col2" >Senopati</td>
#       <td id="T_a72fa_row15_col3" class="data row15 col3" >Rambo</td>
#       <td id="T_a72fa_row15_col4" class="data row15 col4" >115000</td>
#     </tr>
#     <tr>
#       <td id="T_a72fa_row16_col0" class="data row16 col0" >17</td>
#       <td id="T_a72fa_row16_col1" class="data row16 col1" >Byurger</td>
#       <td id="T_a72fa_row16_col2" class="data row16 col2" >Fatmawati</td>
#       <td id="T_a72fa_row16_col3" class="data row16 col3" >Sexyback Rib</td>
#       <td id="T_a72fa_row16_col4" class="data row16 col4" >65000</td>
#     </tr>
#     <tr>
#       <td id="T_a72fa_row17_col0" class="data row17 col0" >18</td>
#       <td id="T_a72fa_row17_col1" class="data row17 col1" >TGI Fridays Lippo Mall Kemang</td>
#       <td id="T_a72fa_row17_col2" class="data row17 col2" >Kemang</td>
#       <td id="T_a72fa_row17_col3" class="data row17 col3" >Fridays Cheeseburger</td>
#       <td id="T_a72fa_row17_col4" class="data row17 col4" >129000</td>
#     </tr>
#     <tr>
#       <td id="T_a72fa_row18_col0" class="data row18 col0" >19</td>
#       <td id="T_a72fa_row18_col1" class="data row18 col1" >Carl's Junior</td>
#       <td id="T_a72fa_row18_col2" class="data row18 col2" >Kemang</td>
#       <td id="T_a72fa_row18_col3" class="data row18 col3" >Western Beefbac</td>
#       <td id="T_a72fa_row18_col4" class="data row18 col4" >59091</td>
#     </tr>
#     <tr>
#       <td id="T_a72fa_row19_col0" class="data row19 col0" >20</td>
#       <td id="T_a72fa_row19_col1" class="data row19 col1" >MOS Caf</td>
#       <td id="T_a72fa_row19_col2" class="data row19 col2" >SCBD</td>
#       <td id="T_a72fa_row19_col3" class

# %% [markdown]
# # Price-Range
#
# We sorted the list from the most expensive and also the cheapest, also with the price range from IDR 50000 to 100000. Here is the order from the most expensive.

# %%
#most expensive
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price FROM burger ORDER BY price DESC")
burger_price.head().style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_308e2_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_308e2_row0_col0" class="data row0 col0" >TGI Fridays Lippo Mall Kemang</td>
#       <td id="T_308e2_row0_col1" class="data row0 col1" >Kemang</td>
#       <td id="T_308e2_row0_col2" class="data row0 col2" >Fridays Cheeseburger</td>
#       <td id="T_308e2_row0_col3" class="data row0 col3" >129000</td>
#     </tr>
#     <tr>
#       <td id="T_308e2_row1_col0" class="data row1 col0" >Three Buns</td>
#       <td id="T_308e2_row1_col1" class="data row1 col1" >Senopati</td>
#       <td id="T_308e2_row1_col2" class="data row1 col2" >Rambo</td>
#       <td id="T_308e2_row1_col3" class="data row1 col3" >115000</td>
#     </tr>
#     <tr>
#       <td id="T_308e2_row2_col0" class="data row2 col0" >Lawless Burgerbar</td>
#       <td id="T_308e2_row2_col1" class="data row2 col1" >Kemang</td>
#       <td id="T_308e2_row2_col2" class="data row2 col2" >Philly Anselmo</td>
#       <td id="T_308e2_row2_col3" class="data row2 col3" >75000</td>
#     </tr>
#     <tr>
#       <td id="T_308e2_row3_col0" class="data row3 col0" >Goods Burger</td>
#       <td id="T_308e2_row3_col1" class="data row3 col1" >Pondok Indah</td>
#       <td id="T_308e2_row3_col2" class="data row3 col2" >Goods Coffee Rub</td>
#       <td id="T_308e2_row3_col3" class="data row3 col3" >65000</td>
#     </tr>
#     <tr>
#       <td id="T_308e2_row4_col0" class="data row4 col0" >Byurger</td>
#       <td id="T_308e2_row4_col1" class="data row4 col1" >Fatmawati</td>
#       <td id="T_308e2_row4_col2" class="data row4 col2" >Sexyback Rib</td>
#       <td id="T_308e2_row4_col3" class="data row4 col3" >65000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#cheapest
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price FROM burger ORDER BY price")
burger_price.head().style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_c7f4f_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c7f4f_row0_col0" class="data row0 col0" >Burger Bakar Qebul</td>
#       <td id="T_c7f4f_row0_col1" class="data row0 col1" >Pasar Minggu</td>
#       <td id="T_c7f4f_row0_col2" class="data row0 col2" >Beef Burger</td>
#       <td id="T_c7f4f_row0_col3" class="data row0 col3" >13000</td>
#     </tr>
#     <tr>
#       <td id="T_c7f4f_row1_col0" class="data row1 col0" >Blenger Burger</td>
#       <td id="T_c7f4f_row1_col1" class="data row1 col1" >Fatmawati</td>
#       <td id="T_c7f4f_row1_col2" class="data row1 col2" >Cheese Burger</td>
#       <td id="T_c7f4f_row1_col3" class="data row1 col3" >20000</td>
#     </tr>
#     <tr>
#       <td id="T_c7f4f_row2_col0" class="data row2 col0" >Flip Burger Kota Kasablanka</td>
#       <td id="T_c7f4f_row2_col1" class="data row2 col1" >Tebet</td>
#       <td id="T_c7f4f_row2_col2" class="data row2 col2" >Brisket Cheese Burger</td>
#       <td id="T_c7f4f_row2_col3" class="data row2 col3" >28182</td>
#     </tr>
#     <tr>
#       <td id="T_c7f4f_row3_col0" class="data row3 col0" >Stacksite Express</td>
#       <td id="T_c7f4f_row3_col1" class="data row3 col1" >Senayan</td>
#       <td id="T_c7f4f_row3_col2" class="data row3 col2" >Quicksand</td>
#       <td id="T_c7f4f_row3_col3" class="data row3 col3" >30000</td>
#     </tr>
#     <tr>
#       <td id="T_c7f4f_row4_col0" class="data row4 col0" >Blenger Burger</td>
#       <td id="T_c7f4f_row4_col1" class="data row4 col1" >Blok M</td>
#       <td id="T_c7f4f_row4_col2" class="data row4 col2" >Cheese Burger X2</td>
#       <td id="T_c7f4f_row4_col3" class="data row4 col3" >32000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#more than IDR 100000
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price FROM burger WHERE price >= 100000")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_99fe2_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_99fe2_row0_col0" class="data row0 col0" >Three Buns</td>
#       <td id="T_99fe2_row0_col1" class="data row0 col1" >Senopati</td>
#       <td id="T_99fe2_row0_col2" class="data row0 col2" >Rambo</td>
#       <td id="T_99fe2_row0_col3" class="data row0 col3" >115000</td>
#     </tr>
#     <tr>
#       <td id="T_99fe2_row1_col0" class="data row1 col0" >TGI Fridays Lippo Mall Kemang</td>
#       <td id="T_99fe2_row1_col1" class="data row1 col1" >Kemang</td>
#       <td id="T_99fe2_row1_col2" class="data row1 col2" >Fridays Cheeseburger</td>
#       <td id="T_99fe2_row1_col3" class="data row1 col3" >129000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#between 50000 to 100000
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price FROM burger WHERE price BETWEEN 50000 AND 100000")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_67024_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_67024_row0_col0" class="data row0 col0" >Goods Burger</td>
#       <td id="T_67024_row0_col1" class="data row0 col1" >Pondok Indah</td>
#       <td id="T_67024_row0_col2" class="data row0 col2" >Goods Coffee Rub</td>
#       <td id="T_67024_row0_col3" class="data row0 col3" >65000</td>
#     </tr>
#     <tr>
#       <td id="T_67024_row1_col0" class="data row1 col0" >Lawless Burgerbar</td>
#       <td id="T_67024_row1_col1" class="data row1 col1" >Kemang</td>
#       <td id="T_67024_row1_col2" class="data row1 col2" >Philly Anselmo</td>
#       <td id="T_67024_row1_col3" class="data row1 col3" >75000</td>
#     </tr>
#     <tr>
#       <td id="T_67024_row2_col0" class="data row2 col0" >Byurger</td>
#       <td id="T_67024_row2_col1" class="data row2 col1" >Fatmawati</td>
#       <td id="T_67024_row2_col2" class="data row2 col2" >Sexyback Rib</td>
#       <td id="T_67024_row2_col3" class="data row2 col3" >65000</td>
#     </tr>
#     <tr>
#       <td id="T_67024_row3_col0" class="data row3 col0" >Carl's Junior</td>
#       <td id="T_67024_row3_col1" class="data row3 col1" >Kemang</td>
#       <td id="T_67024_row3_col2" class="data row3 col2" >Western Beefbac</td>
#       <td id="T_67024_row3_col3" class="data row3 col3" >59091</td>
#     </tr>
#     <tr>
#       <td id="T_67024_row4_col0" class="data row4 col0" >MOS Caf</td>
#       <td id="T_67024_row4_col1" class="data row4 col1" >SCBD</td>
#       <td id="T_67024_row4_col2" class="data row4 col2" >Charcoal Tobikiri Burger</td>
#       <td id="T_67024_row4_col3" class="data row4 col3" >63000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#below IDR 100000
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price FROM burger WHERE price <= 50000")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_14cde_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_14cde_row0_col0" class="data row0 col0" >Burger King</td>
#       <td id="T_14cde_row0_col1" class="data row0 col1" >Blok M</td>
#       <td id="T_14cde_row0_col2" class="data row0 col2" >Double Cheese Burger</td>
#       <td id="T_14cde_row0_col3" class="data row0 col3" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_14cde_row1_col0" class="data row1 col0" >Burger King</td>
#       <td id="T_14cde_row1_col1" class="data row1 col1" >Tebet</td>
#       <td id="T_14cde_row1_col2" class="data row1 col2" >Double Cheese Burger</td>
#       <td id="T_14cde_row1_col3" class="data row1 col3" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_14cde_row2_col0" class="data row2 col0" >Burger King Lotte Avenue</td>
#       <td id="T_14cde_row2_col1" class="data row2 col1" >Karet</td>
#       <td id="T_14cde_row2_col2" class="data row2 col2" >Double Cheese Burger</td>
#       <td id="T_14cde_row2_col3" class="data row2 col3" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_14cde_row3_col0" class="data row3 col0" >Burger King Bellagio</td>
#       <td id="T_14cde_row3_col1" class="data row3 col1" >Kuningan</td>
#       <td id="T_14cde_row3_col2" class="data row3 col2" >Double Cheese Burger</td>
#       <td id="T_14cde_row3_col3" class="data row3 col3" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_14cde_row4_col0" class="data row4 col0" >Burger King Pondok Indah Plaza</td>
#       <td id="T_14cde_row4_col1" class="data row4 col1" >Pondok Indah</td>
#       <td id="T_14cde_row4_col2" class="data row4 col2" >Double Cheese Burger</td>
#       <td id="T_14cde_row4_col3" class="data row4 col3" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_14cde_row5_col0" class="data row5 col0" >Burger King</td>
#       <td id="T_14cde_row5_col1" class="data row5 col1" >Kemang</td>
#       <td id="T_14cde_row5_col2" class="data row5 col2" >Double Cheese Burger</td>
#       <td id="T_14cde_row5_col3" class="data row5 col3" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_14cde_row6_col0" class="data row6 col0" >Burger King</td>
#       <td id="T_14cde_row6_col1" class="data row6 col1" >Setiabudi</td>
#       <td id="T_14cde_row6_col2" class="data row6 col2" >Double Cheese Burger</td>
#       <td id="T_14cde_row6_col3" class="data row6 col3" >41818</td>
#     </tr>
#     <tr>
#       <td id="T_14cde_row7_col0" class="data row7 col0" >Burger Bakar Qebul</td>
#       <td id="T_14cde_row7_col1" class="data row7 col1" >Pasar Minggu</td>
#       <td id="T_14cde_row7_col2" class="data row7 col2" >Beef Burger</td>
#       <td id="T_14cde_row7_col3" class="data row7 col3" >13000</td>
#     </tr>
#     <tr>
#       <td id="T_14cde_row8_col0" class="data row8 col0" >Flip Burger </td>
#       <td id="T_14cde_row8_col1" class="data row8 col1" >Senopati</td>
#       <td id="T_14cde_row8_col2" class="data row8 col2" >Double Cheese Burger</td>
#       <td id="T_14cde_row8_col3" class="data row8 col3" >45000</td>
#     </tr>
#     <tr>
#       <td id="T_14cde_row9_col0" class="data row9 col0" >Blenger Burger</td>
#       <td id="T_14cde_row9_col1" class="data row9 col1" >Blok M</td>
#       <td id="T_14cde_row9_col2" class="data row9 col2" >Cheese Burger X2</td>
#       <td id="T_14cde_row9_col3" class="data row9 col3" >32000</td>
#     </tr>
#     <tr>
#       <td id="T_14cde_row10_col0" class="data row10 col0" >Blenger Burger</td>
#       <td id="T_14cde_row10_col1" class="data row10 col1" >Fatmawati</td>
#       <td id="T_14cde_row10_col2" class="data row10 col2" >Cheese Burger</td>
#       <td id="T_14cde_row10_col3" class="data row10 col3" >20000</td>
#     </tr>
#     <tr>
#       <td id="T_14cde_row11_col0" class="data row11 col0" >Flip Burger Kota Kasablanka</td>
#       <td id="T_14cde_row11_col1" class="data row11 col1" >Tebet</td>
#       <td id="T_14cde_row11_col2" class="data row11 col2" >Brisket Cheese Burger</td>
#       <td id="T_14cde_row11_col3" class="data row11 col3" >28182</td>
#     </tr>
#     <tr>
#       <td id="T_14cde_row12_col0" class="data row12 col0" >Flip Burger Pondok Indah Plaza</td>
#       <td id="T_14cde_row12_col1" class="data row12 col1" >Pondok Indah</td>
#       <td id="T_14cde_row12_col2" class="data row12 col2" >Bitsy Double Cheese</td>
#       <td id="T_14cde_row12_col3" class="data row12 col3" >45455</td>
#     </tr>
#     <tr>
#       <td id="T_14cde_row13_col0" class="data row13 col0" >Stacksite Express</td>
#       <td id="T_14cde_row13_col1" class="data row13 col1" >Senayan</td>
#       <td id="T_14cde_row13_col2" class="data row13 col2" >Quicksand</td>
#       <td id="T_14cde_row13_col3" class="data row13 col3" >30000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Facility
#
# Last but not least, we chose the restaurant whether we could takeaway, or deliver our food. We also could find out whether these partlor has outdoor seats, smoking room, wifi, and reservation. Last but not least, we researched about poultry with some dietary restriction like alcohol and halal_menu. But this halal menu will not available in other project. We changed to other_poultry instead.
#
# Let's take a look for all the facility.

# %%
burger = sqldf("SELECT no, partlor_name, district, takeaway, delivery, outdoor_seat, smoking_area, alcohol_served, wifi, reservation, drive_thru, halal_food FROM burger")
burger.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_0ef7c_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >no</th>
#       <th class="col_heading level0 col1" >partlor_name</th>
#       <th class="col_heading level0 col2" >District</th>
#       <th class="col_heading level0 col3" >takeaway</th>
#       <th class="col_heading level0 col4" >delivery</th>
#       <th class="col_heading level0 col5" >outdoor_seat</th>
#       <th class="col_heading level0 col6" >smoking_area</th>
#       <th class="col_heading level0 col7" >alcohol_served</th>
#       <th class="col_heading level0 col8" >wifi</th>
#       <th class="col_heading level0 col9" >reservation</th>
#       <th class="col_heading level0 col10" >drive_thru</th>
#       <th class="col_heading level0 col11" >halal_food</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0ef7c_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_0ef7c_row0_col1" class="data row0 col1" >Burger King</td>
#       <td id="T_0ef7c_row0_col2" class="data row0 col2" >Blok M</td>
#       <td id="T_0ef7c_row0_col3" class="data row0 col3" >yes</td>
#       <td id="T_0ef7c_row0_col4" class="data row0 col4" >yes</td>
#       <td id="T_0ef7c_row0_col5" class="data row0 col5" >yes</td>
#       <td id="T_0ef7c_row0_col6" class="data row0 col6" >yes</td>
#       <td id="T_0ef7c_row0_col7" class="data row0 col7" >no</td>
#       <td id="T_0ef7c_row0_col8" class="data row0 col8" >yes</td>
#       <td id="T_0ef7c_row0_col9" class="data row0 col9" >no</td>
#       <td id="T_0ef7c_row0_col10" class="data row0 col10" >no</td>
#       <td id="T_0ef7c_row0_col11" class="data row0 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_0ef7c_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_0ef7c_row1_col1" class="data row1 col1" >Burger King</td>
#       <td id="T_0ef7c_row1_col2" class="data row1 col2" >Tebet</td>
#       <td id="T_0ef7c_row1_col3" class="data row1 col3" >yes</td>
#       <td id="T_0ef7c_row1_col4" class="data row1 col4" >yes</td>
#       <td id="T_0ef7c_row1_col5" class="data row1 col5" >no</td>
#       <td id="T_0ef7c_row1_col6" class="data row1 col6" >no</td>
#       <td id="T_0ef7c_row1_col7" class="data row1 col7" >no</td>
#       <td id="T_0ef7c_row1_col8" class="data row1 col8" >yes</td>
#       <td id="T_0ef7c_row1_col9" class="data row1 col9" >no</td>
#       <td id="T_0ef7c_row1_col10" class="data row1 col10" >no</td>
#       <td id="T_0ef7c_row1_col11" class="data row1 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_0ef7c_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_0ef7c_row2_col1" class="data row2 col1" >Burger King Lotte Avenue</td>
#       <td id="T_0ef7c_row2_col2" class="data row2 col2" >Karet</td>
#       <td id="T_0ef7c_row2_col3" class="data row2 col3" >yes</td>
#       <td id="T_0ef7c_row2_col4" class="data row2 col4" >yes</td>
#       <td id="T_0ef7c_row2_col5" class="data row2 col5" >no</td>
#       <td id="T_0ef7c_row2_col6" class="data row2 col6" >no</td>
#       <td id="T_0ef7c_row2_col7" class="data row2 col7" >no</td>
#       <td id="T_0ef7c_row2_col8" class="data row2 col8" >yes</td>
#       <td id="T_0ef7c_row2_col9" class="data row2 col9" >no</td>
#       <td id="T_0ef7c_row2_col10" class="data row2 col10" >no</td>
#       <td id="T_0ef7c_row2_col11" class="data row2 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_0ef7c_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_0ef7c_row3_col1" class="data row3 col1" >Burger King Bellagio</td>
#       <td id="T_0ef7c_row3_col2" class="data row3 col2" >Kuningan</td>
#       <td id="T_0ef7c_row3_col3" class="data row3 col3" >yes</td>
#       <td id="T_0ef7c_row3_col4" class="data row3 col4" >yes</td>
#       <td id="T_0ef7c_row3_col5" class="data row3 col5" >yes</td>
#       <td id="T_0ef7c_row3_col6" class="data row3 col6" >yes</td>
#       <td id="T_0ef7c_row3_col7" class="data row3 col7" >no</td>
#       <td id="T_0ef7c_row3_col8" class="data row3 col8" >yes</td>
#       <td id="T_0ef7c_row3_col9" class="data row3 col9" >no</td>
#       <td id="T_0ef7c_row3_col10" class="data row3 col10" >no</td>
#       <td id="T_0ef7c_row3_col11" class="data row3 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_0ef7c_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_0ef7c_row4_col1" class="data row4 col1" >Burger King Pondok Indah Plaza</td>
#       <td id="T_0ef7c_row4_col2" class="data row4 col2" >Pondok Indah</td>
#       <td id="T_0ef7c_row4_col3" class="data row4 col3" >yes</td>
#       <td id="T_0ef7c_row4_col4" class="data row4 col4" >yes</td>
#       <td id="T_0ef7c_row4_col5" class="data row4 col5" >yes</td>
#       <td id="T_0ef7c_row4_col6" class="data row4 col6" >yes</td>
#       <td id="T_0ef7c_row4_col7" class="data row4 col7" >no</td>
#       <td id="T_0ef7c_row4_col8" class="data row4 col8" >yes</td>
#       <td id="T_0ef7c_row4_col9" class="data row4 col9" >no</td>
#       <td id="T_0ef7c_row4_col10" class="data row4 col10" >no</td>
#       <td id="T_0ef7c_row4_col11" class="data row4 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_0ef7c_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_0ef7c_row5_col1" class="data row5 col1" >Burger King</td>
#       <td id="T_0ef7c_row5_col2" class="data row5 col2" >Kemang</td>
#       <td id="T_0ef7c_row5_col3" class="data row5 col3" >yes</td>
#       <td id="T_0ef7c_row5_col4" class="data row5 col4" >yes</td>
#       <td id="T_0ef7c_row5_col5" class="data row5 col5" >no</td>
#       <td id="T_0ef7c_row5_col6" class="data row5 col6" >no</td>
#       <td id="T_0ef7c_row5_col7" class="data row5 col7" >no</td>
#       <td id="T_0ef7c_row5_col8" class="data row5 col8" >yes</td>
#       <td id="T_0ef7c_row5_col9" class="data row5 col9" >no</td>
#       <td id="T_0ef7c_row5_col10" class="data row5 col10" >no</td>
#       <td id="T_0ef7c_row5_col11" class="data row5 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_0ef7c_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_0ef7c_row6_col1" class="data row6 col1" >Burger King</td>
#       <td id="T_0ef7c_row6_col2" class="data row6 col2" >Setiabudi</td>
#       <td id="T_0ef7c_row6_col3" class="data row6 col3" >yes</td>
#       <td id="T_0ef7c_row6_col4" class="data row6 col4" >no</td>
#       <td id="T_0ef7c_row6_col5" class="data row6 col5" >yes</td>
#       <td id="T_0ef7c_row6_col6" class="data row6 col6" >yes</td>
#       <td id="T_0ef7c_row6_col7" class="data row6 col7" >no</td>
#       <td id="T_0ef7c_row6_col8" class="data row6 col8" >yes</td>
#       <td id="T_0ef7c_row6_col9" class="data row6 col9" >no</td>
#       <td id="T_0ef7c_row6_col10" class="data row6 col10" >no</td>
#       <td id="T_0ef7c_row6_col11" class="data row6 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_0ef7c_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_0ef7c_row7_col1" class="data row7 col1" >Burger Bakar Qebul</td>
#       <td id="T_0ef7c_row7_col2" class="data row7 col2" >Pasar Minggu</td>
#       <td id="T_0ef7c_row7_col3" class="data row7 col3" >yes</td>
#       <td id="T_0ef7c_row7_col4" class="data row7 col4" >no</td>
#       <td id="T_0ef7c_row7_col5" class="data row7 col5" >no</td>
#       <td id="T_0ef7c_row7_col6" class="data row7 col6" >yes</td>
#       <td id="T_0ef7c_row7_col7" class="data row7 col7" >no</td>
#       <td id="T_0ef7c_row7_col8" class="data row7 col8" >no</td>
#       <td id="T_0ef7c_row7_col9" class="data row7 col9" >no</td>
#       <td id="T_0ef7c_row7_col10" class="data row7 col10" >no</td>
#       <td id="T_0ef7c_row7_col11" class="data row7 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_0ef7c_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_0ef7c_row8_col1" class="data row8 col1" >Flip Burger </td>
#       <td id="T_0ef7c_row8_col2" class="data row8 col2" >Senopati</td>
#       <td id="T_0ef7c_row8_col3" class="data row8 col3" >yes</td>
#       <td id="T_0ef7c_row8_col4" class="data row8 col4" >yes</td>
#       <td id="T_0ef7c_row8_col5" class="data row8 col5" >no</td>
#       <td id="T_0ef7c_row8_col6" class="data row8 col6" >no</td>
#       <td id="T_0ef7c_row8_col7" class="data row8 col7" >no</td>
#       <td id="T_0ef7c_row8_

# %% [markdown]
# Then let's take a look for each of them, also we counted each of facility which available.

# %%
#takeaway
takeaway = sqldf("SELECT partlor_name, district, takeaway FROM burger WHERE takeaway = 'yes'")
takeaway.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_f7351_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >takeaway</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f7351_row0_col0" class="data row0 col0" >Burger King</td>
#       <td id="T_f7351_row0_col1" class="data row0 col1" >Blok M</td>
#       <td id="T_f7351_row0_col2" class="data row0 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f7351_row1_col0" class="data row1 col0" >Burger King</td>
#       <td id="T_f7351_row1_col1" class="data row1 col1" >Tebet</td>
#       <td id="T_f7351_row1_col2" class="data row1 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f7351_row2_col0" class="data row2 col0" >Burger King Lotte Avenue</td>
#       <td id="T_f7351_row2_col1" class="data row2 col1" >Karet</td>
#       <td id="T_f7351_row2_col2" class="data row2 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f7351_row3_col0" class="data row3 col0" >Burger King Bellagio</td>
#       <td id="T_f7351_row3_col1" class="data row3 col1" >Kuningan</td>
#       <td id="T_f7351_row3_col2" class="data row3 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f7351_row4_col0" class="data row4 col0" >Burger King Pondok Indah Plaza</td>
#       <td id="T_f7351_row4_col1" class="data row4 col1" >Pondok Indah</td>
#       <td id="T_f7351_row4_col2" class="data row4 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f7351_row5_col0" class="data row5 col0" >Burger King</td>
#       <td id="T_f7351_row5_col1" class="data row5 col1" >Kemang</td>
#       <td id="T_f7351_row5_col2" class="data row5 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f7351_row6_col0" class="data row6 col0" >Burger King</td>
#       <td id="T_f7351_row6_col1" class="data row6 col1" >Setiabudi</td>
#       <td id="T_f7351_row6_col2" class="data row6 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f7351_row7_col0" class="data row7 col0" >Burger Bakar Qebul</td>
#       <td id="T_f7351_row7_col1" class="data row7 col1" >Pasar Minggu</td>
#       <td id="T_f7351_row7_col2" class="data row7 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f7351_row8_col0" class="data row8 col0" >Flip Burger </td>
#       <td id="T_f7351_row8_col1" class="data row8 col1" >Senopati</td>
#       <td id="T_f7351_row8_col2" class="data row8 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f7351_row9_col0" class="data row9 col0" >Blenger Burger</td>
#       <td id="T_f7351_row9_col1" class="data row9 col1" >Blok M</td>
#       <td id="T_f7351_row9_col2" class="data row9 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f7351_row10_col0" class="data row10 col0" >Blenger Burger</td>
#       <td id="T_f7351_row10_col1" class="data row10 col1" >Fatmawati</td>
#       <td id="T_f7351_row10_col2" class="data row10 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f7351_row11_col0" class="data row11 col0" >Goods Burger</td>
#       <td id="T_f7351_row11_col1" class="data row11 col1" >Pondok Indah</td>
#       <td id="T_f7351_row11_col2" class="data row11 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f7351_row12_col0" class="data row12 col0" >Flip Burger Kota Kasablanka</td>
#       <td id="T_f7351_row12_col1" class="data row12 col1" >Tebet</td>
#       <td id="T_f7351_row12_col2" class="data row12 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f7351_row13_col0" class="data row13 col0" >Flip Burger Pondok Indah Plaza</td>
#       <td id="T_f7351_row13_col1" class="data row13 col1" >Pondok Indah</td>
#       <td id="T_f7351_row13_col2" class="data row13 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f7351_row14_col0" class="data row14 col0" >Lawless Burgerbar</td>
#       <td id="T_f7351_row14_col1" class="data row14 col1" >Kemang</td>
#       <td id="T_f7351_row14_col2" class="data row14 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f7351_row15_col0" class="data row15 col0" >Three Buns</td>
#       <td id="T_f7351_row15_col1" class="data row15 col1" >Senopati</td>
#       <td id="T_f7351_row15_col2" class="data row15 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f7351_row16_col0" class="data row16 col0" >Byurger</td>
#       <td id="T_f7351_row16_col1" class="data row16 col1" >Fatmawati</td>
#       <td id="T_f7351_row16_col2" class="data row16 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f7351_row17_col0" class="data row17 col0" >Carl's Junior</td>
#       <td id="T_f7351_row17_col1" class="data row17 col1" >Kemang</td>
#       <td id="T_f7351_row17_col2" class="data row17 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f7351_row18_col0" class="data row18 col0" >MOS Caf</td>
#       <td id="T_f7351_row18_col1" class="data row18 col1" >SCBD</td>
#       <td id="T_f7351_row18_col2" class="data row18 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_f7351_row19_col0" class="data row19 col0" >Stacksite Express</td>
#       <td id="T_f7351_row19_col1" class="data row19 col1" >Senayan</td>
#       <td id="T_f7351_row19_col2" class="data row19 col2" >yes</td>
#     </tr>
#   </tbody>
# </table>

# %%
takeaway = sqldf("SELECT COUNT(takeaway) FROM burger GROUP BY takeaway HAVING takeaway = 'yes'")
takeaway
# Out:
#    COUNT(takeaway)
# 0               20

# %%
#delivery
delivery = sqldf("SELECT partlor_name, district, delivery FROM burger WHERE delivery = 'yes'")
delivery.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_c0adb_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >delivery</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c0adb_row0_col0" class="data row0 col0" >Burger King</td>
#       <td id="T_c0adb_row0_col1" class="data row0 col1" >Blok M</td>
#       <td id="T_c0adb_row0_col2" class="data row0 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_c0adb_row1_col0" class="data row1 col0" >Burger King</td>
#       <td id="T_c0adb_row1_col1" class="data row1 col1" >Tebet</td>
#       <td id="T_c0adb_row1_col2" class="data row1 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_c0adb_row2_col0" class="data row2 col0" >Burger King Lotte Avenue</td>
#       <td id="T_c0adb_row2_col1" class="data row2 col1" >Karet</td>
#       <td id="T_c0adb_row2_col2" class="data row2 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_c0adb_row3_col0" class="data row3 col0" >Burger King Bellagio</td>
#       <td id="T_c0adb_row3_col1" class="data row3 col1" >Kuningan</td>
#       <td id="T_c0adb_row3_col2" class="data row3 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_c0adb_row4_col0" class="data row4 col0" >Burger King Pondok Indah Plaza</td>
#       <td id="T_c0adb_row4_col1" class="data row4 col1" >Pondok Indah</td>
#       <td id="T_c0adb_row4_col2" class="data row4 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_c0adb_row5_col0" class="data row5 col0" >Burger King</td>
#       <td id="T_c0adb_row5_col1" class="data row5 col1" >Kemang</td>
#       <td id="T_c0adb_row5_col2" class="data row5 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_c0adb_row6_col0" class="data row6 col0" >Flip Burger </td>
#       <td id="T_c0adb_row6_col1" class="data row6 col1" >Senopati</td>
#       <td id="T_c0adb_row6_col2" class="data row6 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_c0adb_row7_col0" class="data row7 col0" >Blenger Burger</td>
#       <td id="T_c0adb_row7_col1" class="data row7 col1" >Blok M</td>
#       <td id="T_c0adb_row7_col2" class="data row7 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_c0adb_row8_col0" class="data row8 col0" >Lawless Burgerbar</td>
#       <td id="T_c0adb_row8_col1" class="data row8 col1" >Kemang</td>
#       <td id="T_c0adb_row8_col2" class="data row8 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_c0adb_row9_col0" class="data row9 col0" >Three Buns</td>
#       <td id="T_c0adb_row9_col1" class="data row9 col1" >Senopati</td>
#       <td id="T_c0adb_row9_col2" class="data row9 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_c0adb_row10_col0" class="data row10 col0" >Byurger</td>
#       <td id="T_c0adb_row10_col1" class="data row10 col1" >Fatmawati</td>
#       <td id="T_c0adb_row10_col2" class="data row10 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_c0adb_row11_col0" class="data row11 col0" >Carl's Junior</td>
#       <td id="T_c0adb_row11_col1" class="data row11 col1" >Kemang</td>
#       <td id="T_c0adb_row11_col2" class="data row11 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_c0adb_row12_col0" class="data row12 col0" >Stacksite Express</td>
#       <td id="T_c0adb_row12_col1" class="data row12 col1" >Senayan</td>
#       <td id="T_c0adb_row12_col2" class="data row12 col2" >yes</td>
#     </tr>
#   </tbody>
# </table>

# %%
delivery = sqldf("SELECT COUNT(delivery) FROM burger GROUP BY delivery HAVING delivery = 'yes'")
delivery
# Out:
#    COUNT(delivery)
# 0               13

# %%
#outdoor_seat
outdoor_seat = sqldf("SELECT partlor_name, district, outdoor_seat FROM burger WHERE outdoor_seat = 'yes'")
outdoor_seat.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_d3fb5_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >outdoor_seat</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d3fb5_row0_col0" class="data row0 col0" >Burger King</td>
#       <td id="T_d3fb5_row0_col1" class="data row0 col1" >Blok M</td>
#       <td id="T_d3fb5_row0_col2" class="data row0 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d3fb5_row1_col0" class="data row1 col0" >Burger King Bellagio</td>
#       <td id="T_d3fb5_row1_col1" class="data row1 col1" >Kuningan</td>
#       <td id="T_d3fb5_row1_col2" class="data row1 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d3fb5_row2_col0" class="data row2 col0" >Burger King Pondok Indah Plaza</td>
#       <td id="T_d3fb5_row2_col1" class="data row2 col1" >Pondok Indah</td>
#       <td id="T_d3fb5_row2_col2" class="data row2 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d3fb5_row3_col0" class="data row3 col0" >Burger King</td>
#       <td id="T_d3fb5_row3_col1" class="data row3 col1" >Setiabudi</td>
#       <td id="T_d3fb5_row3_col2" class="data row3 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d3fb5_row4_col0" class="data row4 col0" >Blenger Burger</td>
#       <td id="T_d3fb5_row4_col1" class="data row4 col1" >Blok M</td>
#       <td id="T_d3fb5_row4_col2" class="data row4 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d3fb5_row5_col0" class="data row5 col0" >Blenger Burger</td>
#       <td id="T_d3fb5_row5_col1" class="data row5 col1" >Fatmawati</td>
#       <td id="T_d3fb5_row5_col2" class="data row5 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d3fb5_row6_col0" class="data row6 col0" >Lawless Burgerbar</td>
#       <td id="T_d3fb5_row6_col1" class="data row6 col1" >Kemang</td>
#       <td id="T_d3fb5_row6_col2" class="data row6 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d3fb5_row7_col0" class="data row7 col0" >Byurger</td>
#       <td id="T_d3fb5_row7_col1" class="data row7 col1" >Fatmawati</td>
#       <td id="T_d3fb5_row7_col2" class="data row7 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d3fb5_row8_col0" class="data row8 col0" >TGI Fridays Lippo Mall Kemang</td>
#       <td id="T_d3fb5_row8_col1" class="data row8 col1" >Kemang</td>
#       <td id="T_d3fb5_row8_col2" class="data row8 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d3fb5_row9_col0" class="data row9 col0" >Carl's Junior</td>
#       <td id="T_d3fb5_row9_col1" class="data row9 col1" >Kemang</td>
#       <td id="T_d3fb5_row9_col2" class="data row9 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_d3fb5_row10_col0" class="data row10 col0" >Stacksite Express</td>
#       <td id="T_d3fb5_row10_col1" class="data row10 col1" >Senayan</td>
#       <td id="T_d3fb5_row10_col2" class="data row10 col2" >yes</td>
#     </tr>
#   </tbody>
# </table>

# %%
outdoor_seat = sqldf("SELECT COUNT(outdoor_seat) FROM burger GROUP BY outdoor_seat HAVING outdoor_seat = 'yes'")
outdoor_seat
# Out:
#    COUNT(outdoor_seat)
# 0                   11

# %%
#smoking_area
smoking_area = sqldf("SELECT partlor_name, district, smoking_area FROM burger WHERE smoking_area = 'yes'")
smoking_area.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_9b034_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >smoking_area</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9b034_row0_col0" class="data row0 col0" >Burger King</td>
#       <td id="T_9b034_row0_col1" class="data row0 col1" >Blok M</td>
#       <td id="T_9b034_row0_col2" class="data row0 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_9b034_row1_col0" class="data row1 col0" >Burger King Bellagio</td>
#       <td id="T_9b034_row1_col1" class="data row1 col1" >Kuningan</td>
#       <td id="T_9b034_row1_col2" class="data row1 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_9b034_row2_col0" class="data row2 col0" >Burger King Pondok Indah Plaza</td>
#       <td id="T_9b034_row2_col1" class="data row2 col1" >Pondok Indah</td>
#       <td id="T_9b034_row2_col2" class="data row2 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_9b034_row3_col0" class="data row3 col0" >Burger King</td>
#       <td id="T_9b034_row3_col1" class="data row3 col1" >Setiabudi</td>
#       <td id="T_9b034_row3_col2" class="data row3 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_9b034_row4_col0" class="data row4 col0" >Burger Bakar Qebul</td>
#       <td id="T_9b034_row4_col1" class="data row4 col1" >Pasar Minggu</td>
#       <td id="T_9b034_row4_col2" class="data row4 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_9b034_row5_col0" class="data row5 col0" >Blenger Burger</td>
#       <td id="T_9b034_row5_col1" class="data row5 col1" >Blok M</td>
#       <td id="T_9b034_row5_col2" class="data row5 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_9b034_row6_col0" class="data row6 col0" >Blenger Burger</td>
#       <td id="T_9b034_row6_col1" class="data row6 col1" >Fatmawati</td>
#       <td id="T_9b034_row6_col2" class="data row6 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_9b034_row7_col0" class="data row7 col0" >Lawless Burgerbar</td>
#       <td id="T_9b034_row7_col1" class="data row7 col1" >Kemang</td>
#       <td id="T_9b034_row7_col2" class="data row7 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_9b034_row8_col0" class="data row8 col0" >Three Buns</td>
#       <td id="T_9b034_row8_col1" class="data row8 col1" >Senopati</td>
#       <td id="T_9b034_row8_col2" class="data row8 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_9b034_row9_col0" class="data row9 col0" >Byurger</td>
#       <td id="T_9b034_row9_col1" class="data row9 col1" >Fatmawati</td>
#       <td id="T_9b034_row9_col2" class="data row9 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_9b034_row10_col0" class="data row10 col0" >TGI Fridays Lippo Mall Kemang</td>
#       <td id="T_9b034_row10_col1" class="data row10 col1" >Kemang</td>
#       <td id="T_9b034_row10_col2" class="data row10 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_9b034_row11_col0" class="data row11 col0" >MOS Caf</td>
#       <td id="T_9b034_row11_col1" class="data row11 col1" >SCBD</td>
#       <td id="T_9b034_row11_col2" class="data row11 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_9b034_row12_col0" class="data row12 col0" >Stacksite Express</td>
#       <td id="T_9b034_row12_col1" class="data row12 col1" >Senayan</td>
#       <td id="T_9b034_row12_col2" class="data row12 col2" >yes</td>
#     </tr>
#   </tbody>
# </table>

# %%
smoking_area = sqldf("SELECT COUNT(smoking_area) FROM burger GROUP BY smoking_area HAVING smoking_area = 'yes'")
smoking_area
# Out:
#    COUNT(smoking_area)
# 0                   13

# %%
#alcohol
alcohol = sqldf("SELECT partlor_name, district, alcohol_served FROM burger WHERE alcohol_served = 'yes'")
alcohol.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_3f2f6_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >alcohol_served</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3f2f6_row0_col0" class="data row0 col0" >Lawless Burgerbar</td>
#       <td id="T_3f2f6_row0_col1" class="data row0 col1" >Kemang</td>
#       <td id="T_3f2f6_row0_col2" class="data row0 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_3f2f6_row1_col0" class="data row1 col0" >Three Buns</td>
#       <td id="T_3f2f6_row1_col1" class="data row1 col1" >Senopati</td>
#       <td id="T_3f2f6_row1_col2" class="data row1 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_3f2f6_row2_col0" class="data row2 col0" >Byurger</td>
#       <td id="T_3f2f6_row2_col1" class="data row2 col1" >Fatmawati</td>
#       <td id="T_3f2f6_row2_col2" class="data row2 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_3f2f6_row3_col0" class="data row3 col0" >TGI Fridays Lippo Mall Kemang</td>
#       <td id="T_3f2f6_row3_col1" class="data row3 col1" >Kemang</td>
#       <td id="T_3f2f6_row3_col2" class="data row3 col2" >yes</td>
#     </tr>
#   </tbody>
# </table>

# %%
alcohol = sqldf("SELECT COUNT(alcohol_served) FROM burger GROUP BY alcohol_served HAVING alcohol_served = 'yes'")
alcohol
# Out:
#    COUNT(alcohol_served)
# 0                      4

# %%
#wifi
wifi = sqldf("SELECT partlor_name, district, wifi FROM burger WHERE wifi = 'yes'")
wifi.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_03d0b_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >wifi</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_03d0b_row0_col0" class="data row0 col0" >Burger King</td>
#       <td id="T_03d0b_row0_col1" class="data row0 col1" >Blok M</td>
#       <td id="T_03d0b_row0_col2" class="data row0 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_03d0b_row1_col0" class="data row1 col0" >Burger King</td>
#       <td id="T_03d0b_row1_col1" class="data row1 col1" >Tebet</td>
#       <td id="T_03d0b_row1_col2" class="data row1 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_03d0b_row2_col0" class="data row2 col0" >Burger King Lotte Avenue</td>
#       <td id="T_03d0b_row2_col1" class="data row2 col1" >Karet</td>
#       <td id="T_03d0b_row2_col2" class="data row2 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_03d0b_row3_col0" class="data row3 col0" >Burger King Bellagio</td>
#       <td id="T_03d0b_row3_col1" class="data row3 col1" >Kuningan</td>
#       <td id="T_03d0b_row3_col2" class="data row3 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_03d0b_row4_col0" class="data row4 col0" >Burger King Pondok Indah Plaza</td>
#       <td id="T_03d0b_row4_col1" class="data row4 col1" >Pondok Indah</td>
#       <td id="T_03d0b_row4_col2" class="data row4 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_03d0b_row5_col0" class="data row5 col0" >Burger King</td>
#       <td id="T_03d0b_row5_col1" class="data row5 col1" >Kemang</td>
#       <td id="T_03d0b_row5_col2" class="data row5 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_03d0b_row6_col0" class="data row6 col0" >Burger King</td>
#       <td id="T_03d0b_row6_col1" class="data row6 col1" >Setiabudi</td>
#       <td id="T_03d0b_row6_col2" class="data row6 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_03d0b_row7_col0" class="data row7 col0" >Flip Burger </td>
#       <td id="T_03d0b_row7_col1" class="data row7 col1" >Senopati</td>
#       <td id="T_03d0b_row7_col2" class="data row7 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_03d0b_row8_col0" class="data row8 col0" >Lawless Burgerbar</td>
#       <td id="T_03d0b_row8_col1" class="data row8 col1" >Kemang</td>
#       <td id="T_03d0b_row8_col2" class="data row8 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_03d0b_row9_col0" class="data row9 col0" >Byurger</td>
#       <td id="T_03d0b_row9_col1" class="data row9 col1" >Fatmawati</td>
#       <td id="T_03d0b_row9_col2" class="data row9 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_03d0b_row10_col0" class="data row10 col0" >TGI Fridays Lippo Mall Kemang</td>
#       <td id="T_03d0b_row10_col1" class="data row10 col1" >Kemang</td>
#       <td id="T_03d0b_row10_col2" class="data row10 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_03d0b_row11_col0" class="data row11 col0" >Carl's Junior</td>
#       <td id="T_03d0b_row11_col1" class="data row11 col1" >Kemang</td>
#       <td id="T_03d0b_row11_col2" class="data row11 col2" >yes</td>
#     </tr>
#   </tbody>
# </table>

# %%
wifi = sqldf("SELECT COUNT(wifi) FROM burger GROUP BY wifi HAVING wifi = 'yes'")
wifi
# Out:
#    COUNT(wifi)
# 0           12

# %%
#reservation needed
reservation = sqldf("SELECT partlor_name, district, reservation FROM burger WHERE reservation = 'yes'")
reservation.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_33fb1_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >reservation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_33fb1_row0_col0" class="data row0 col0" >Lawless Burgerbar</td>
#       <td id="T_33fb1_row0_col1" class="data row0 col1" >Kemang</td>
#       <td id="T_33fb1_row0_col2" class="data row0 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_33fb1_row1_col0" class="data row1 col0" >Three Buns</td>
#       <td id="T_33fb1_row1_col1" class="data row1 col1" >Senopati</td>
#       <td id="T_33fb1_row1_col2" class="data row1 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_33fb1_row2_col0" class="data row2 col0" >TGI Fridays Lippo Mall Kemang</td>
#       <td id="T_33fb1_row2_col1" class="data row2 col1" >Kemang</td>
#       <td id="T_33fb1_row2_col2" class="data row2 col2" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_33fb1_row3_col0" class="data row3 col0" >MOS Caf</td>
#       <td id="T_33fb1_row3_col1" class="data row3 col1" >SCBD</td>
#       <td id="T_33fb1_row3_col2" class="data row3 col2" >yes</td>
#     </tr>
#   </tbody>
# </table>

# %%
reservation = sqldf("SELECT COUNT(reservation) FROM burger GROUP BY reservation HAVING reservation = 'yes'")
reservation
# Out:
#    COUNT(reservation)
# 0                   4

# %%
#drive thru
drive_thru = sqldf("SELECT partlor_name, district, drive_thru FROM burger WHERE drive_thru = 'yes'")
drive_thru.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_bd3b6_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >drive_thru</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
#dietary restricted
halal_food = sqldf("SELECT partlor_name, district, halal_food FROM burger WHERE halal_food = 'no'")
halal_food.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_8772d_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >halal_food</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8772d_row0_col0" class="data row0 col0" >Three Buns</td>
#       <td id="T_8772d_row0_col1" class="data row0 col1" >Senopati</td>
#       <td id="T_8772d_row0_col2" class="data row0 col2" >no</td>
#     </tr>
#   </tbody>
# </table>

# %%
halal_food = sqldf("SELECT COUNT(halal_food) FROM burger GROUP BY halal_food HAVING halal_food = 'yes'")
halal_food
# Out:
#    COUNT(halal_food)
# 0                 20

# %% [markdown]
# # Rating
#
# I'll calculate and decide which are recommended on the other file but here is the glimpse. We can see which vendor has the highest rating available. For this time I order this list by google_rating as it appeared first.

# %%
rating = sqldf("SELECT partlor_name, district, ltrim(google_rating) as google_rating, ltrim(zomato_rating) as zomato_rating, ltrim(qraved_rating) as qraved_rating, google_count, zomato_count, qraved_count FROM burger ORDER BY google_rating DESC")
rating.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_865ed_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >google_rating</th>
#       <th class="col_heading level0 col3" >zomato_rating</th>
#       <th class="col_heading level0 col4" >qraved_rating</th>
#       <th class="col_heading level0 col5" >google_count</th>
#       <th class="col_heading level0 col6" >zomato_count</th>
#       <th class="col_heading level0 col7" >qraved_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_865ed_row0_col0" class="data row0 col0" >Burger Bakar Qebul</td>
#       <td id="T_865ed_row0_col1" class="data row0 col1" >Pasar Minggu</td>
#       <td id="T_865ed_row0_col2" class="data row0 col2" >4.07</td>
#       <td id="T_865ed_row0_col3" class="data row0 col3" >4.03</td>
#       <td id="T_865ed_row0_col4" class="data row0 col4" >4.03</td>
#       <td id="T_865ed_row0_col5" class="data row0 col5" >2098</td>
#       <td id="T_865ed_row0_col6" class="data row0 col6" >273</td>
#       <td id="T_865ed_row0_col7" class="data row0 col7" >10</td>
#     </tr>
#     <tr>
#       <td id="T_865ed_row1_col0" class="data row1 col0" >Lawless Burgerbar</td>
#       <td id="T_865ed_row1_col1" class="data row1 col1" >Kemang</td>
#       <td id="T_865ed_row1_col2" class="data row1 col2" >4.07</td>
#       <td id="T_865ed_row1_col3" class="data row1 col3" >4.07</td>
#       <td id="T_865ed_row1_col4" class="data row1 col4" >4.06</td>
#       <td id="T_865ed_row1_col5" class="data row1 col5" >7026</td>
#       <td id="T_865ed_row1_col6" class="data row1 col6" >1902</td>
#       <td id="T_865ed_row1_col7" class="data row1 col7" >20</td>
#     </tr>
#     <tr>
#       <td id="T_865ed_row2_col0" class="data row2 col0" >Byurger</td>
#       <td id="T_865ed_row2_col1" class="data row2 col1" >Fatmawati</td>
#       <td id="T_865ed_row2_col2" class="data row2 col2" >4.07</td>
#       <td id="T_865ed_row2_col3" class="data row2 col3" >4.04</td>
#       <td id="T_865ed_row2_col4" class="data row2 col4" >4.01</td>
#       <td id="T_865ed_row2_col5" class="data row2 col5" >1839</td>
#       <td id="T_865ed_row2_col6" class="data row2 col6" >640</td>
#       <td id="T_865ed_row2_col7" class="data row2 col7" >7</td>
#     </tr>
#     <tr>
#       <td id="T_865ed_row3_col0" class="data row3 col0" >Blenger Burger</td>
#       <td id="T_865ed_row3_col1" class="data row3 col1" >Fatmawati</td>
#       <td id="T_865ed_row3_col2" class="data row3 col2" >4.06</td>
#       <td id="T_865ed_row3_col3" class="data row3 col3" >4.0</td>
#       <td id="T_865ed_row3_col4" class="data row3 col4" >4.0</td>
#       <td id="T_865ed_row3_col5" class="data row3 col5" >2486</td>
#       <td id="T_865ed_row3_col6" class="data row3 col6" >114</td>
#       <td id="T_865ed_row3_col7" class="data row3 col7" >27</td>
#     </tr>
#     <tr>
#       <td id="T_865ed_row4_col0" class="data row4 col0" >Burger King Pondok Indah Plaza</td>
#       <td id="T_865ed_row4_col1" class="data row4 col1" >Pondok Indah</td>
#       <td id="T_865ed_row4_col2" class="data row4 col2" >4.05</td>
#       <td id="T_865ed_row4_col3" class="data row4 col3" >3.02</td>
#       <td id="T_865ed_row4_col4" class="data row4 col4" >4.0</td>
#       <td id="T_865ed_row4_col5" class="data row4 col5" >1244</td>
#       <td id="T_865ed_row4_col6" class="data row4 col6" >33</td>
#       <td id="T_865ed_row4_col7" class="data row4 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_865ed_row5_col0" class="data row5 col0" >Blenger Burger</td>
#       <td id="T_865ed_row5_col1" class="data row5 col1" >Blok M</td>
#       <td id="T_865ed_row5_col2" class="data row5 col2" >4.05</td>
#       <td id="T_865ed_row5_col3" class="data row5 col3" >4.03</td>
#       <td id="T_865ed_row5_col4" class="data row5 col4" >4.03</td>
#       <td id="T_865ed_row5_col5" class="data row5 col5" >4726</td>
#       <td id="T_865ed_row5_col6" class="data row5 col6" >581</td>
#       <td id="T_865ed_row5_col7" class="data row5 col7" >12</td>
#     </tr>
#     <tr>
#       <td id="T_865ed_row6_col0" class="data row6 col0" >Goods Burger</td>
#       <td id="T_865ed_row6_col1" class="data row6 col1" >Pondok Indah</td>
#       <td id="T_865ed_row6_col2" class="data row6 col2" >4.05</td>
#       <td id="T_865ed_row6_col3" class="data row6 col3" >2.06</td>
#       <td id="T_865ed_row6_col4" class="data row6 col4" >4.0</td>
#       <td id="T_865ed_row6_col5" class="data row6 col5" >4</td>
#       <td id="T_865ed_row6_col6" class="data row6 col6" >27</td>
#       <td id="T_865ed_row6_col7" class="data row6 col7" >2</td>
#     </tr>
#     <tr>
#       <td id="T_865ed_row7_col0" class="data row7 col0" >Flip Burger Pondok Indah Plaza</td>
#       <td id="T_865ed_row7_col1" class="data row7 col1" >Pondok Indah</td>
#       <td id="T_865ed_row7_col2" class="data row7 col2" >4.05</td>
#       <td id="T_865ed_row7_col3" class="data row7 col3" >3.07</td>
#       <td id="T_865ed_row7_col4" class="data row7 col4" >4.0</td>
#       <td id="T_865ed_row7_col5" class="data row7 col5" >940</td>
#       <td id="T_865ed_row7_col6" class="data row7 col6" >168</td>
#       <td id="T_865ed_row7_col7" class="data row7 col7" >6</td>
#     </tr>
#     <tr>
#       <td id="T_865ed_row8_col0" class="data row8 col0" >Three Buns</td>
#       <td id="T_865ed_row8_col1" class="data row8 col1" >Senopati</td>
#       <td id="T_865ed_row8_col2" class="data row8 col2" >4.05</td>
#       <td id="T_865ed_row8_col3" class="data row8 col3" >4.01</td>
#       <td id="T_865ed_row8_col4" class="data row8 col4" >4.02</td>
#       <td id="T_865ed_row8_col5" class="data row8 col5" >1597</td>
#       <td id="T_865ed_row8_col6" class="data row8 col6" >1292</td>
#       <td id="T_865ed_row8_col7" class="data row8 col7" >59</td>
#     </tr>
#     <tr>
#       <td id="T_865ed_row9_col0" class="data row9 col0" >Carl's Junior</td>
#       <td id="T_865ed_row9_col1" class="data row9 col1" >Kemang</td>
#       <td id="T_865ed_row9_col2" class="data row9 col2" >4.05</td>
#       <td id="T_865ed_row9_col3" class="data row9 col3" >4.02</td>
#       <td id="T_865ed_row9_col4" class="data row9 col4" >4.0</td>
#       <td id="T_865ed_row9_col5" class="data row9 col5" >2338</td>
#       <td id="T_865ed_row9_col6" class="data row9 col6" >193</td>
#       <td id="T_865ed_row9_col7" class="data row9 col7" >2</td>
#     </tr>
#     <tr>
#       <td id="T_865ed_row10_col0" class="data row10 col0" >Burger King</td>
#       <td id="T_865ed_row10_col1" class="data row10 col1" >Tebet</td>
#       <td id="T_865ed_row10_col2" class="data row10 col2" >4.04</td>
#       <td id="T_865ed_row10_col3" class="data row10 col3" >3.07</td>
#       <td id="T_865ed_row10_col4" class="data row10 col4" >4.0</td>
#       <td id="T_865ed_row10_col5" class="data row10 col5" >5497</td>
#       <td id="T_865ed_row10_col6" class="data row10 col6" >94</td>
#       <td id="T_865ed_row10_col7" class="data row10 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_865ed_row11_col0" class="data row11 col0" >Burger King Bellagio</td>
#       <td id="T_865ed_row11_col1" class="data row11 col1" >Kuningan</td>
#       <td id="T_865ed_row11_col2" class="data row11 col2" >4.04</td>
#       <td id="T_865ed_row11_col3" class="data row11 col3" >2.08</td>
#       <td id="T_865ed_row11_col4" class="data row11 col4" >3.09</td>
#       <td id="T_865ed_row11_col5" class="data row11 col5" >255</td>
#       <td id="T_865ed_row11_col6" class="data row11 col6" >30</td>
#       <td id="T_865ed_row11_col7" class="data row11 col7" >10</td>
#     </tr>
#     <tr>
#       <td id="T_865ed_row12_col0" class="data row12 col0" >Flip Burger </td>
#       <td id="T_865ed_row12_col1" class="data row12 col1" >Senopati</td>
#       <td id="T_865ed_row12_col2" class="data row12 col2" >4.04</td>
#       <td id="T_865ed_row12_col3" class="data row12 col3" >4.02</td>
#       <td id="T_865ed_row12_col4" class="data row12 col4" >3.09</td>
#       <td id="T_865ed_row12_col5" class="data row12 col5" >2791</td>
#       <td id="T_865ed_row12_col6" class="data row12 col6" >1133</td>
#       <td id="T_865ed_row12_col7" class="data row12 col7" >88</
