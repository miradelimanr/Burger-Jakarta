# %% [markdown]
# # **North Jakarta**
#
# This is the marine city as it closed to Ancol Beach area (but unfortunately, no specific burger partlor in this area except for McDonald and KFC). Consisting only three district on this sample, which are Pantai Indah Kapuk (which is high end housing complex), Kelapa Gading, and Sunter. Dominated by fast food and high end restaurant, there are still budgeted vendor available in small number.
#
# # Content
# * District
# * Price Range
# * Facility
# * Rating

# %%
import pandas as pd
from pandasql import sqldf
burger = pd.read_csv('../input/north-jakarta-burger/north_jakarta.csv', sep = ";")

# %% [markdown]
# # District

# %%
partlor_name = sqldf("SELECT DISTINCT district FROM burger").transpose()
partlor_name
# Out:
#                            0              1       2
# District  Pantai Indah Kapuk  Kelapa Gading  Sunter

# %%
burger = sqldf("SELECT no, partlor_name, District, unique_menu, price FROM burger")
burger.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_5fa39_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >no</th>
#       <th class="col_heading level0 col1" >partlor_name</th>
#       <th class="col_heading level0 col2" >District</th>
#       <th class="col_heading level0 col3" >unique_menu</th>
#       <th class="col_heading level0 col4" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5fa39_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_5fa39_row0_col1" class="data row0 col1" >Burger King Pantai Indah Kapuk</td>
#       <td id="T_5fa39_row0_col2" class="data row0 col2" >Pantai Indah Kapuk</td>
#       <td id="T_5fa39_row0_col3" class="data row0 col3" >Cheese Burger</td>
#       <td id="T_5fa39_row0_col4" class="data row0 col4" >25000</td>
#     </tr>
#     <tr>
#       <td id="T_5fa39_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_5fa39_row1_col1" class="data row1 col1" >Burger King Mall Kelapa Gading</td>
#       <td id="T_5fa39_row1_col2" class="data row1 col2" >Kelapa Gading</td>
#       <td id="T_5fa39_row1_col3" class="data row1 col3" >Cheese Burger</td>
#       <td id="T_5fa39_row1_col4" class="data row1 col4" >25000</td>
#     </tr>
#     <tr>
#       <td id="T_5fa39_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_5fa39_row2_col1" class="data row2 col1" >Burger King Mall Artha Gading</td>
#       <td id="T_5fa39_row2_col2" class="data row2 col2" >Kelapa Gading</td>
#       <td id="T_5fa39_row2_col3" class="data row2 col3" >Cheese Burger</td>
#       <td id="T_5fa39_row2_col4" class="data row2 col4" >25000</td>
#     </tr>
#     <tr>
#       <td id="T_5fa39_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_5fa39_row3_col1" class="data row3 col1" >Burger King Sunter Mall</td>
#       <td id="T_5fa39_row3_col2" class="data row3 col2" >Sunter</td>
#       <td id="T_5fa39_row3_col3" class="data row3 col3" >Chicken Steakhouse BBQ</td>
#       <td id="T_5fa39_row3_col4" class="data row3 col4" >59091</td>
#     </tr>
#     <tr>
#       <td id="T_5fa39_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_5fa39_row4_col1" class="data row4 col1" >Burger +</td>
#       <td id="T_5fa39_row4_col2" class="data row4 col2" >Sunter</td>
#       <td id="T_5fa39_row4_col3" class="data row4 col3" >Special Bacon & Egg Burger</td>
#       <td id="T_5fa39_row4_col4" class="data row4 col4" >58000</td>
#     </tr>
#     <tr>
#       <td id="T_5fa39_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_5fa39_row5_col1" class="data row5 col1" >Lemoe Burger</td>
#       <td id="T_5fa39_row5_col2" class="data row5 col2" >Kelapa Gading</td>
#       <td id="T_5fa39_row5_col3" class="data row5 col3" >Beef Cabe Ijo</td>
#       <td id="T_5fa39_row5_col4" class="data row5 col4" >17000</td>
#     </tr>
#     <tr>
#       <td id="T_5fa39_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_5fa39_row6_col1" class="data row6 col1" >Flip Burger Kelapa Gading</td>
#       <td id="T_5fa39_row6_col2" class="data row6 col2" >Kelapa Gading</td>
#       <td id="T_5fa39_row6_col3" class="data row6 col3" >Brisket Cheese Burger</td>
#       <td id="T_5fa39_row6_col4" class="data row6 col4" >28182</td>
#     </tr>
#     <tr>
#       <td id="T_5fa39_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_5fa39_row7_col1" class="data row7 col1" >Burger Bener</td>
#       <td id="T_5fa39_row7_col2" class="data row7 col2" >Kelapa Gading</td>
#       <td id="T_5fa39_row7_col3" class="data row7 col3" >Bener 1</td>
#       <td id="T_5fa39_row7_col4" class="data row7 col4" >13000</td>
#     </tr>
#     <tr>
#       <td id="T_5fa39_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_5fa39_row8_col1" class="data row8 col1" >Five Monkeys </td>
#       <td id="T_5fa39_row8_col2" class="data row8 col2" >Sunter</td>
#       <td id="T_5fa39_row8_col3" class="data row8 col3" >BBQ Bacon Cheeseburger</td>
#       <td id="T_5fa39_row8_col4" class="data row8 col4" >48182</td>
#     </tr>
#     <tr>
#       <td id="T_5fa39_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_5fa39_row9_col1" class="data row9 col1" >Six Ounces Coffee</td>
#       <td id="T_5fa39_row9_col2" class="data row9 col2" >Kelapa Gading</td>
#       <td id="T_5fa39_row9_col3" class="data row9 col3" >Aussie Burger</td>
#       <td id="T_5fa39_row9_col4" class="data row9 col4" >75000</td>
#     </tr>
#     <tr>
#       <td id="T_5fa39_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_5fa39_row10_col1" class="data row10 col1" >Pig Hunter</td>
#       <td id="T_5fa39_row10_col2" class="data row10 col2" >Sunter</td>
#       <td id="T_5fa39_row10_col3" class="data row10 col3" >American Pork Burger</td>
#       <td id="T_5fa39_row10_col4" class="data row10 col4" >55000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Price-Range
#
# We sorted the list from the most expensive and also the cheapest, also with the price range from IDR 50000 to 100000. Here is the order from the most expensive. The most expensive here is Six Ounces Coffee for at least 70k per menu. The cheapest here is Burger Bener which priced at least 13k per menu. There is no price more than 100k. Most range available are below 50k.

# %%
#most expensive
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price FROM burger ORDER BY price DESC")
burger_price.head().style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_a4644_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a4644_row0_col0" class="data row0 col0" >Six Ounces Coffee</td>
#       <td id="T_a4644_row0_col1" class="data row0 col1" >Kelapa Gading</td>
#       <td id="T_a4644_row0_col2" class="data row0 col2" >Aussie Burger</td>
#       <td id="T_a4644_row0_col3" class="data row0 col3" >75000</td>
#     </tr>
#     <tr>
#       <td id="T_a4644_row1_col0" class="data row1 col0" >Burger King Sunter Mall</td>
#       <td id="T_a4644_row1_col1" class="data row1 col1" >Sunter</td>
#       <td id="T_a4644_row1_col2" class="data row1 col2" >Chicken Steakhouse BBQ</td>
#       <td id="T_a4644_row1_col3" class="data row1 col3" >59091</td>
#     </tr>
#     <tr>
#       <td id="T_a4644_row2_col0" class="data row2 col0" >Burger +</td>
#       <td id="T_a4644_row2_col1" class="data row2 col1" >Sunter</td>
#       <td id="T_a4644_row2_col2" class="data row2 col2" >Special Bacon & Egg Burger</td>
#       <td id="T_a4644_row2_col3" class="data row2 col3" >58000</td>
#     </tr>
#     <tr>
#       <td id="T_a4644_row3_col0" class="data row3 col0" >Pig Hunter</td>
#       <td id="T_a4644_row3_col1" class="data row3 col1" >Sunter</td>
#       <td id="T_a4644_row3_col2" class="data row3 col2" >American Pork Burger</td>
#       <td id="T_a4644_row3_col3" class="data row3 col3" >55000</td>
#     </tr>
#     <tr>
#       <td id="T_a4644_row4_col0" class="data row4 col0" >Five Monkeys </td>
#       <td id="T_a4644_row4_col1" class="data row4 col1" >Sunter</td>
#       <td id="T_a4644_row4_col2" class="data row4 col2" >BBQ Bacon Cheeseburger</td>
#       <td id="T_a4644_row4_col3" class="data row4 col3" >48182</td>
#     </tr>
#   </tbody>
# </table>

# %%
#cheapest
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price FROM burger ORDER BY price")
burger_price.head().style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_41de8_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_41de8_row0_col0" class="data row0 col0" >Burger Bener</td>
#       <td id="T_41de8_row0_col1" class="data row0 col1" >Kelapa Gading</td>
#       <td id="T_41de8_row0_col2" class="data row0 col2" >Bener 1</td>
#       <td id="T_41de8_row0_col3" class="data row0 col3" >13000</td>
#     </tr>
#     <tr>
#       <td id="T_41de8_row1_col0" class="data row1 col0" >Lemoe Burger</td>
#       <td id="T_41de8_row1_col1" class="data row1 col1" >Kelapa Gading</td>
#       <td id="T_41de8_row1_col2" class="data row1 col2" >Beef Cabe Ijo</td>
#       <td id="T_41de8_row1_col3" class="data row1 col3" >17000</td>
#     </tr>
#     <tr>
#       <td id="T_41de8_row2_col0" class="data row2 col0" >Burger King Pantai Indah Kapuk</td>
#       <td id="T_41de8_row2_col1" class="data row2 col1" >Pantai Indah Kapuk</td>
#       <td id="T_41de8_row2_col2" class="data row2 col2" >Cheese Burger</td>
#       <td id="T_41de8_row2_col3" class="data row2 col3" >25000</td>
#     </tr>
#     <tr>
#       <td id="T_41de8_row3_col0" class="data row3 col0" >Burger King Mall Kelapa Gading</td>
#       <td id="T_41de8_row3_col1" class="data row3 col1" >Kelapa Gading</td>
#       <td id="T_41de8_row3_col2" class="data row3 col2" >Cheese Burger</td>
#       <td id="T_41de8_row3_col3" class="data row3 col3" >25000</td>
#     </tr>
#     <tr>
#       <td id="T_41de8_row4_col0" class="data row4 col0" >Burger King Mall Artha Gading</td>
#       <td id="T_41de8_row4_col1" class="data row4 col1" >Kelapa Gading</td>
#       <td id="T_41de8_row4_col2" class="data row4 col2" >Cheese Burger</td>
#       <td id="T_41de8_row4_col3" class="data row4 col3" >25000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#more than IDR 100000
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price FROM burger WHERE price >= 100000")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_72ba9_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
#between 50000 to 100000
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price FROM burger WHERE price BETWEEN 50000 AND 100000")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_c0e82_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c0e82_row0_col0" class="data row0 col0" >Burger King Sunter Mall</td>
#       <td id="T_c0e82_row0_col1" class="data row0 col1" >Sunter</td>
#       <td id="T_c0e82_row0_col2" class="data row0 col2" >Chicken Steakhouse BBQ</td>
#       <td id="T_c0e82_row0_col3" class="data row0 col3" >59091</td>
#     </tr>
#     <tr>
#       <td id="T_c0e82_row1_col0" class="data row1 col0" >Burger +</td>
#       <td id="T_c0e82_row1_col1" class="data row1 col1" >Sunter</td>
#       <td id="T_c0e82_row1_col2" class="data row1 col2" >Special Bacon & Egg Burger</td>
#       <td id="T_c0e82_row1_col3" class="data row1 col3" >58000</td>
#     </tr>
#     <tr>
#       <td id="T_c0e82_row2_col0" class="data row2 col0" >Six Ounces Coffee</td>
#       <td id="T_c0e82_row2_col1" class="data row2 col1" >Kelapa Gading</td>
#       <td id="T_c0e82_row2_col2" class="data row2 col2" >Aussie Burger</td>
#       <td id="T_c0e82_row2_col3" class="data row2 col3" >75000</td>
#     </tr>
#     <tr>
#       <td id="T_c0e82_row3_col0" class="data row3 col0" >Pig Hunter</td>
#       <td id="T_c0e82_row3_col1" class="data row3 col1" >Sunter</td>
#       <td id="T_c0e82_row3_col2" class="data row3 col2" >American Pork Burger</td>
#       <td id="T_c0e82_row3_col3" class="data row3 col3" >55000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#below IDR 50000
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price FROM burger WHERE price <= 50000")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_47e9a_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_47e9a_row0_col0" class="data row0 col0" >Burger King Pantai Indah Kapuk</td>
#       <td id="T_47e9a_row0_col1" class="data row0 col1" >Pantai Indah Kapuk</td>
#       <td id="T_47e9a_row0_col2" class="data row0 col2" >Cheese Burger</td>
#       <td id="T_47e9a_row0_col3" class="data row0 col3" >25000</td>
#     </tr>
#     <tr>
#       <td id="T_47e9a_row1_col0" class="data row1 col0" >Burger King Mall Kelapa Gading</td>
#       <td id="T_47e9a_row1_col1" class="data row1 col1" >Kelapa Gading</td>
#       <td id="T_47e9a_row1_col2" class="data row1 col2" >Cheese Burger</td>
#       <td id="T_47e9a_row1_col3" class="data row1 col3" >25000</td>
#     </tr>
#     <tr>
#       <td id="T_47e9a_row2_col0" class="data row2 col0" >Burger King Mall Artha Gading</td>
#       <td id="T_47e9a_row2_col1" class="data row2 col1" >Kelapa Gading</td>
#       <td id="T_47e9a_row2_col2" class="data row2 col2" >Cheese Burger</td>
#       <td id="T_47e9a_row2_col3" class="data row2 col3" >25000</td>
#     </tr>
#     <tr>
#       <td id="T_47e9a_row3_col0" class="data row3 col0" >Lemoe Burger</td>
#       <td id="T_47e9a_row3_col1" class="data row3 col1" >Kelapa Gading</td>
#       <td id="T_47e9a_row3_col2" class="data row3 col2" >Beef Cabe Ijo</td>
#       <td id="T_47e9a_row3_col3" class="data row3 col3" >17000</td>
#     </tr>
#     <tr>
#       <td id="T_47e9a_row4_col0" class="data row4 col0" >Flip Burger Kelapa Gading</td>
#       <td id="T_47e9a_row4_col1" class="data row4 col1" >Kelapa Gading</td>
#       <td id="T_47e9a_row4_col2" class="data row4 col2" >Brisket Cheese Burger</td>
#       <td id="T_47e9a_row4_col3" class="data row4 col3" >28182</td>
#     </tr>
#     <tr>
#       <td id="T_47e9a_row5_col0" class="data row5 col0" >Burger Bener</td>
#       <td id="T_47e9a_row5_col1" class="data row5 col1" >Kelapa Gading</td>
#       <td id="T_47e9a_row5_col2" class="data row5 col2" >Bener 1</td>
#       <td id="T_47e9a_row5_col3" class="data row5 col3" >13000</td>
#     </tr>
#     <tr>
#       <td id="T_47e9a_row6_col0" class="data row6 col0" >Five Monkeys </td>
#       <td id="T_47e9a_row6_col1" class="data row6 col1" >Sunter</td>
#       <td id="T_47e9a_row6_col2" class="data row6 col2" >BBQ Bacon Cheeseburger</td>
#       <td id="T_47e9a_row6_col3" class="data row6 col3" >48182</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Facility
#
# Last but not least, we chose the restaurant whether we could takeaway, or deliver our food. We also could find out whether these partlor has outdoor seats, smoking room, wifi, and reservation. Last but not least, we researched about poultry with some dietary restriction like alcohol and halal_menu. But this halal menu will not available in other project. We changed to other_poultry instead.
#
# Like other city in Jakarta, almost all of them has takeaway and delivery options except for Burger+, Flip Burger Kelapa Gading, Six Ounces Coffee, and Pig Hunter which only got their takeaway. Almost none of them got their outdoor seat but Lemoe Burger and Six Ounces Coffee, but for smoking area almost all of them has those except for Burger King, Lemoe Burger, and Burger+. Only Burger King Pantai Indah Kapuk which has both of them.
#
# For dietary restriction, there are two vendors provided alcohol which are Five Monkeys and Pig Hunter. Also for halality only Six Ounces Coffee and Pig Hunter which has pork menu.
#
# No reservation needed (except Six Ounces Coffee and Pig Hunter), also no drive thru options available.
#
# Let's take a look for all the facility.

# %%
burger = sqldf("""SELECT no, partlor_name, district, takeaway, delivery, outdoor_seat, smoking_area,
alcohol_served, wifi, reservation, drive_thru, halal_food FROM burger""")
burger.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_63ab5_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >no</th>
#       <th class="col_heading level0 col1" >partlor_name</th>
#       <th class="col_heading level0 col2" >District</th>
#       <th class="col_heading level0 col3" >takeaway</th>
#       <th class="col_heading level0 col4" >delivery</th>
#       <th class="col_heading level0 col5" >outdoor_seat</th>
#       <th class="col_heading level0 col6" >smoking_area</th>
#       <th class="col_heading level0 col7" >alcohol_served</th>
#       <th class="col_heading level0 col8" >wifi</th>
#       <th class="col_heading level0 col9" >reservation</th>
#       <th class="col_heading level0 col10" >drive_thru</th>
#       <th class="col_heading level0 col11" >halal_food</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_63ab5_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_63ab5_row0_col1" class="data row0 col1" >Burger King Pantai Indah Kapuk</td>
#       <td id="T_63ab5_row0_col2" class="data row0 col2" >Pantai Indah Kapuk</td>
#       <td id="T_63ab5_row0_col3" class="data row0 col3" >yes</td>
#       <td id="T_63ab5_row0_col4" class="data row0 col4" >yes</td>
#       <td id="T_63ab5_row0_col5" class="data row0 col5" >yes</td>
#       <td id="T_63ab5_row0_col6" class="data row0 col6" >yes</td>
#       <td id="T_63ab5_row0_col7" class="data row0 col7" >no</td>
#       <td id="T_63ab5_row0_col8" class="data row0 col8" >yes</td>
#       <td id="T_63ab5_row0_col9" class="data row0 col9" >no</td>
#       <td id="T_63ab5_row0_col10" class="data row0 col10" >no</td>
#       <td id="T_63ab5_row0_col11" class="data row0 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63ab5_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_63ab5_row1_col1" class="data row1 col1" >Burger King Mall Kelapa Gading</td>
#       <td id="T_63ab5_row1_col2" class="data row1 col2" >Kelapa Gading</td>
#       <td id="T_63ab5_row1_col3" class="data row1 col3" >yes</td>
#       <td id="T_63ab5_row1_col4" class="data row1 col4" >yes</td>
#       <td id="T_63ab5_row1_col5" class="data row1 col5" >no</td>
#       <td id="T_63ab5_row1_col6" class="data row1 col6" >no</td>
#       <td id="T_63ab5_row1_col7" class="data row1 col7" >no</td>
#       <td id="T_63ab5_row1_col8" class="data row1 col8" >yes</td>
#       <td id="T_63ab5_row1_col9" class="data row1 col9" >no</td>
#       <td id="T_63ab5_row1_col10" class="data row1 col10" >no</td>
#       <td id="T_63ab5_row1_col11" class="data row1 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63ab5_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_63ab5_row2_col1" class="data row2 col1" >Burger King Mall Artha Gading</td>
#       <td id="T_63ab5_row2_col2" class="data row2 col2" >Kelapa Gading</td>
#       <td id="T_63ab5_row2_col3" class="data row2 col3" >yes</td>
#       <td id="T_63ab5_row2_col4" class="data row2 col4" >yes</td>
#       <td id="T_63ab5_row2_col5" class="data row2 col5" >no</td>
#       <td id="T_63ab5_row2_col6" class="data row2 col6" >no</td>
#       <td id="T_63ab5_row2_col7" class="data row2 col7" >no</td>
#       <td id="T_63ab5_row2_col8" class="data row2 col8" >no</td>
#       <td id="T_63ab5_row2_col9" class="data row2 col9" >no</td>
#       <td id="T_63ab5_row2_col10" class="data row2 col10" >no</td>
#       <td id="T_63ab5_row2_col11" class="data row2 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63ab5_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_63ab5_row3_col1" class="data row3 col1" >Burger King Sunter Mall</td>
#       <td id="T_63ab5_row3_col2" class="data row3 col2" >Sunter</td>
#       <td id="T_63ab5_row3_col3" class="data row3 col3" >yes</td>
#       <td id="T_63ab5_row3_col4" class="data row3 col4" >yes</td>
#       <td id="T_63ab5_row3_col5" class="data row3 col5" >no</td>
#       <td id="T_63ab5_row3_col6" class="data row3 col6" >no</td>
#       <td id="T_63ab5_row3_col7" class="data row3 col7" >no</td>
#       <td id="T_63ab5_row3_col8" class="data row3 col8" >yes</td>
#       <td id="T_63ab5_row3_col9" class="data row3 col9" >no</td>
#       <td id="T_63ab5_row3_col10" class="data row3 col10" >no</td>
#       <td id="T_63ab5_row3_col11" class="data row3 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63ab5_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_63ab5_row4_col1" class="data row4 col1" >Burger +</td>
#       <td id="T_63ab5_row4_col2" class="data row4 col2" >Sunter</td>
#       <td id="T_63ab5_row4_col3" class="data row4 col3" >yes</td>
#       <td id="T_63ab5_row4_col4" class="data row4 col4" >no</td>
#       <td id="T_63ab5_row4_col5" class="data row4 col5" >no</td>
#       <td id="T_63ab5_row4_col6" class="data row4 col6" >no</td>
#       <td id="T_63ab5_row4_col7" class="data row4 col7" >no</td>
#       <td id="T_63ab5_row4_col8" class="data row4 col8" >no</td>
#       <td id="T_63ab5_row4_col9" class="data row4 col9" >no</td>
#       <td id="T_63ab5_row4_col10" class="data row4 col10" >no</td>
#       <td id="T_63ab5_row4_col11" class="data row4 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63ab5_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_63ab5_row5_col1" class="data row5 col1" >Lemoe Burger</td>
#       <td id="T_63ab5_row5_col2" class="data row5 col2" >Kelapa Gading</td>
#       <td id="T_63ab5_row5_col3" class="data row5 col3" >yes</td>
#       <td id="T_63ab5_row5_col4" class="data row5 col4" >yes</td>
#       <td id="T_63ab5_row5_col5" class="data row5 col5" >yes</td>
#       <td id="T_63ab5_row5_col6" class="data row5 col6" >no</td>
#       <td id="T_63ab5_row5_col7" class="data row5 col7" >no</td>
#       <td id="T_63ab5_row5_col8" class="data row5 col8" >no</td>
#       <td id="T_63ab5_row5_col9" class="data row5 col9" >no</td>
#       <td id="T_63ab5_row5_col10" class="data row5 col10" >no</td>
#       <td id="T_63ab5_row5_col11" class="data row5 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63ab5_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_63ab5_row6_col1" class="data row6 col1" >Flip Burger Kelapa Gading</td>
#       <td id="T_63ab5_row6_col2" class="data row6 col2" >Kelapa Gading</td>
#       <td id="T_63ab5_row6_col3" class="data row6 col3" >yes</td>
#       <td id="T_63ab5_row6_col4" class="data row6 col4" >no</td>
#       <td id="T_63ab5_row6_col5" class="data row6 col5" >no</td>
#       <td id="T_63ab5_row6_col6" class="data row6 col6" >yes</td>
#       <td id="T_63ab5_row6_col7" class="data row6 col7" >no</td>
#       <td id="T_63ab5_row6_col8" class="data row6 col8" >yes</td>
#       <td id="T_63ab5_row6_col9" class="data row6 col9" >no</td>
#       <td id="T_63ab5_row6_col10" class="data row6 col10" >no</td>
#       <td id="T_63ab5_row6_col11" class="data row6 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63ab5_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_63ab5_row7_col1" class="data row7 col1" >Burger Bener</td>
#       <td id="T_63ab5_row7_col2" class="data row7 col2" >Kelapa Gading</td>
#       <td id="T_63ab5_row7_col3" class="data row7 col3" >yes</td>
#       <td id="T_63ab5_row7_col4" class="data row7 col4" >yes</td>
#       <td id="T_63ab5_row7_col5" class="data row7 col5" >no</td>
#       <td id="T_63ab5_row7_col6" class="data row7 col6" >yes</td>
#       <td id="T_63ab5_row7_col7" class="data row7 col7" >no</td>
#       <td id="T_63ab5_row7_col8" class="data row7 col8" >no</td>
#       <td id="T_63ab5_row7_col9" class="data row7 col9" >no</td>
#       <td id="T_63ab5_row7_col10" class="data row7 col10" >no</td>
#       <td id="T_63ab5_row7_col11" class="data row7 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_63ab5_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_63ab5_row8_col1" class="data row8 col1" >Five Monkeys </td>
#       <td id="T_63ab5_row8_col2" class="data row8 col2" >Sunter</td>
#       <td id="T_63ab5_row8_col3" class="data row8 col3" >yes</td>
#       <td id="T_63ab5_row8_col4" class="data row8 col4" >yes</td>
#       <td id="T_63ab5_row8_col5" class="data row8 col5" >no</td>
#       <td id="T_63ab5_row8_col6" class="data row8 col6" >yes</td>
#       <td id="T_63ab5_row8_col7" c

# %% [markdown]
# # Rating
#
# I'll calculate and decide separately which are recommended on the other file but here is the glimpse. We can see which vendor has the highest rating available. For this time I order this list by google_rating as it appeared first.

# %%
burger = sqldf("""SELECT partlor_name, district, ltrim(google_rating) as google_rating, ltrim(zomato_rating) as zomato_rating, ltrim(qraved_rating) as qraved_rating, 
ltrim((google_rating + zomato_rating + qraved_rating)/3, 1) as total_rating,
CASE
    WHEN ltrim((google_rating + zomato_rating + qraved_rating)/3,1) >= 3.5 THEN "Recommended"
    ELSE "Reconsider"
END AS "Recommendation"
FROM burger
ORDER BY total_rating DESC""")
burger.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_a22b4_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >google_rating</th>
#       <th class="col_heading level0 col3" >zomato_rating</th>
#       <th class="col_heading level0 col4" >qraved_rating</th>
#       <th class="col_heading level0 col5" >total_rating</th>
#       <th class="col_heading level0 col6" >Recommendation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a22b4_row0_col0" class="data row0 col0" >Five Monkeys </td>
#       <td id="T_a22b4_row0_col1" class="data row0 col1" >Sunter</td>
#       <td id="T_a22b4_row0_col2" class="data row0 col2" >4.6</td>
#       <td id="T_a22b4_row0_col3" class="data row0 col3" >4.0</td>
#       <td id="T_a22b4_row0_col4" class="data row0 col4" >4.4</td>
#       <td id="T_a22b4_row0_col5" class="data row0 col5" >4.33333333333333</td>
#       <td id="T_a22b4_row0_col6" class="data row0 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a22b4_row1_col0" class="data row1 col0" >Six Ounces Coffee</td>
#       <td id="T_a22b4_row1_col1" class="data row1 col1" >Kelapa Gading</td>
#       <td id="T_a22b4_row1_col2" class="data row1 col2" >4.6</td>
#       <td id="T_a22b4_row1_col3" class="data row1 col3" >4.2</td>
#       <td id="T_a22b4_row1_col4" class="data row1 col4" >4.0</td>
#       <td id="T_a22b4_row1_col5" class="data row1 col5" >4.26666666666667</td>
#       <td id="T_a22b4_row1_col6" class="data row1 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a22b4_row2_col0" class="data row2 col0" >Pig Hunter</td>
#       <td id="T_a22b4_row2_col1" class="data row2 col1" >Sunter</td>
#       <td id="T_a22b4_row2_col2" class="data row2 col2" >4.4</td>
#       <td id="T_a22b4_row2_col3" class="data row2 col3" >4.0</td>
#       <td id="T_a22b4_row2_col4" class="data row2 col4" >4.2</td>
#       <td id="T_a22b4_row2_col5" class="data row2 col5" >4.2</td>
#       <td id="T_a22b4_row2_col6" class="data row2 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a22b4_row3_col0" class="data row3 col0" >Flip Burger Kelapa Gading</td>
#       <td id="T_a22b4_row3_col1" class="data row3 col1" >Kelapa Gading</td>
#       <td id="T_a22b4_row3_col2" class="data row3 col2" >4.4</td>
#       <td id="T_a22b4_row3_col3" class="data row3 col3" >3.9</td>
#       <td id="T_a22b4_row3_col4" class="data row3 col4" >4.0</td>
#       <td id="T_a22b4_row3_col5" class="data row3 col5" >4.1</td>
#       <td id="T_a22b4_row3_col6" class="data row3 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a22b4_row4_col0" class="data row4 col0" >Burger King Pantai Indah Kapuk</td>
#       <td id="T_a22b4_row4_col1" class="data row4 col1" >Pantai Indah Kapuk</td>
#       <td id="T_a22b4_row4_col2" class="data row4 col2" >4.4</td>
#       <td id="T_a22b4_row4_col3" class="data row4 col3" >3.0</td>
#       <td id="T_a22b4_row4_col4" class="data row4 col4" >4.0</td>
#       <td id="T_a22b4_row4_col5" class="data row4 col5" >3.8</td>
#       <td id="T_a22b4_row4_col6" class="data row4 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a22b4_row5_col0" class="data row5 col0" >Burger King Sunter Mall</td>
#       <td id="T_a22b4_row5_col1" class="data row5 col1" >Sunter</td>
#       <td id="T_a22b4_row5_col2" class="data row5 col2" >3.4</td>
#       <td id="T_a22b4_row5_col3" class="data row5 col3" >2.9</td>
#       <td id="T_a22b4_row5_col4" class="data row5 col4" >3.0</td>
#       <td id="T_a22b4_row5_col5" class="data row5 col5" >3.1</td>
#       <td id="T_a22b4_row5_col6" class="data row5 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a22b4_row6_col0" class="data row6 col0" >Burger +</td>
#       <td id="T_a22b4_row6_col1" class="data row6 col1" >Sunter</td>
#       <td id="T_a22b4_row6_col2" class="data row6 col2" >4.8</td>
#       <td id="T_a22b4_row6_col3" class="data row6 col3" >3.8</td>
#       <td id="T_a22b4_row6_col4" class="data row6 col4" >0.0</td>
#       <td id="T_a22b4_row6_col5" class="data row6 col5" >2.86666666666667</td>
#       <td id="T_a22b4_row6_col6" class="data row6 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a22b4_row7_col0" class="data row7 col0" >Burger King Mall Artha Gading</td>
#       <td id="T_a22b4_row7_col1" class="data row7 col1" >Kelapa Gading</td>
#       <td id="T_a22b4_row7_col2" class="data row7 col2" >4.5</td>
#       <td id="T_a22b4_row7_col3" class="data row7 col3" >3.1</td>
#       <td id="T_a22b4_row7_col4" class="data row7 col4" >0.0</td>
#       <td id="T_a22b4_row7_col5" class="data row7 col5" >2.53333333333333</td>
#       <td id="T_a22b4_row7_col6" class="data row7 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a22b4_row8_col0" class="data row8 col0" >Burger King Mall Kelapa Gading</td>
#       <td id="T_a22b4_row8_col1" class="data row8 col1" >Kelapa Gading</td>
#       <td id="T_a22b4_row8_col2" class="data row8 col2" >4.0</td>
#       <td id="T_a22b4_row8_col3" class="data row8 col3" >3.5</td>
#       <td id="T_a22b4_row8_col4" class="data row8 col4" >0.0</td>
#       <td id="T_a22b4_row8_col5" class="data row8 col5" >2.5</td>
#       <td id="T_a22b4_row8_col6" class="data row8 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a22b4_row9_col0" class="data row9 col0" >Burger Bener</td>
#       <td id="T_a22b4_row9_col1" class="data row9 col1" >Kelapa Gading</td>
#       <td id="T_a22b4_row9_col2" class="data row9 col2" >4.4</td>
#       <td id="T_a22b4_row9_col3" class="data row9 col3" >3.0</td>
#       <td id="T_a22b4_row9_col4" class="data row9 col4" >0.0</td>
#       <td id="T_a22b4_row9_col5" class="data row9 col5" >2.46666666666667</td>
#       <td id="T_a22b4_row9_col6" class="data row9 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_a22b4_row10_col0" class="data row10 col0" >Lemoe Burger</td>
#       <td id="T_a22b4_row10_col1" class="data row10 col1" >Kelapa Gading</td>
#       <td id="T_a22b4_row10_col2" class="data row10 col2" >0.0</td>
#       <td id="T_a22b4_row10_col3" class="data row10 col3" >0.0</td>
#       <td id="T_a22b4_row10_col4" class="data row10 col4" >0.0</td>
#       <td id="T_a22b4_row10_col5" class="data row10 col5" >0.0</td>
#       <td id="T_a22b4_row10_col6" class="data row10 col6" >Recommended</td>
#     </tr>
#   </tbody>
# </table>
