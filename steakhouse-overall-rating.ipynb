# %% [markdown]
# # Stekhouse Overall Rating
#
# Here is the counting rate from various platform website, this time I'll be using Google Maps and Zomato. The sections will be divided based on genre : Western, Western Specialized, Fushioned, and Local. As we can see, Local Steakhouse are the most available in this Jakarta area, whereas Western Specialized and Fushioned are the least.

# %%
import pandas as pd
from pandasql import sqldf
steak = pd.read_csv('../input/steakhouse-jakarta/Steakhouse.csv', sep = ";")

# %% [markdown]
# # Western Section
#
# Based on total rating, the highest is **Cut & Grill (Tebet, South Jakarta)** which scored 4.6 from 3086 votes, also the best among South Jakarta's Western Steakhouse.
#
# If being divided for city representative, **Tony Roma's (Thamrin)** is the best western steak from Central Jakarta, scored 4.55 from 1047 votes. **B'Steak Grill & Pancake Green Ville** has the highest rating among West Jakarta's Western style steakhouse, scored 4.55 from 2618 votes. Rest of them is **Street Steak (Kelapa Gading)** from North Jakarta scored 4.5 from 1919 votes.

# %%
steak = sqldf("""SELECT restaurant_name, city, district, ltrim(google_rating) as google_rating, 
ltrim(platform_rating) as platform_rating,
ltrim((google_rating + platform_rating)/2) as total_rating,
ltrim(google_count + platform_count) as total_count,
CASE
    WHEN (google_rating + platform_rating)/2 >= 3.5 THEN "Recommended"
    ELSE "Reconsidered"
    END AS "Recommendation"
FROM steak WHERE specialized = "Western"
ORDER BY total_rating DESC;""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_e1c34_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >city</th>
#       <th class="col_heading level0 col2" >district</th>
#       <th class="col_heading level0 col3" >google_rating</th>
#       <th class="col_heading level0 col4" >platform_rating</th>
#       <th class="col_heading level0 col5" >total_rating</th>
#       <th class="col_heading level0 col6" >total_count</th>
#       <th class="col_heading level0 col7" >Recommendation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e1c34_row0_col0" class="data row0 col0" >Cut & Grill</td>
#       <td id="T_e1c34_row0_col1" class="data row0 col1" >South Jakarta</td>
#       <td id="T_e1c34_row0_col2" class="data row0 col2" >Tebet</td>
#       <td id="T_e1c34_row0_col3" class="data row0 col3" >4.6</td>
#       <td id="T_e1c34_row0_col4" class="data row0 col4" >4.6</td>
#       <td id="T_e1c34_row0_col5" class="data row0 col5" >4.6</td>
#       <td id="T_e1c34_row0_col6" class="data row0 col6" >3086.0</td>
#       <td id="T_e1c34_row0_col7" class="data row0 col7" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_e1c34_row1_col0" class="data row1 col0" >Ruth's Chris Steakhouse</td>
#       <td id="T_e1c34_row1_col1" class="data row1 col1" >South Jakarta</td>
#       <td id="T_e1c34_row1_col2" class="data row1 col2" >Karet</td>
#       <td id="T_e1c34_row1_col3" class="data row1 col3" >4.6</td>
#       <td id="T_e1c34_row1_col4" class="data row1 col4" >4.6</td>
#       <td id="T_e1c34_row1_col5" class="data row1 col5" >4.6</td>
#       <td id="T_e1c34_row1_col6" class="data row1 col6" >1559.0</td>
#       <td id="T_e1c34_row1_col7" class="data row1 col7" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_e1c34_row2_col0" class="data row2 col0" >Tony Roma's</td>
#       <td id="T_e1c34_row2_col1" class="data row2 col1" >Central Jakarta</td>
#       <td id="T_e1c34_row2_col2" class="data row2 col2" >Thamrin</td>
#       <td id="T_e1c34_row2_col3" class="data row2 col3" >4.5</td>
#       <td id="T_e1c34_row2_col4" class="data row2 col4" >4.6</td>
#       <td id="T_e1c34_row2_col5" class="data row2 col5" >4.55</td>
#       <td id="T_e1c34_row2_col6" class="data row2 col6" >1047.0</td>
#       <td id="T_e1c34_row2_col7" class="data row2 col7" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_e1c34_row3_col0" class="data row3 col0" >B'Steak Grill & Pancake</td>
#       <td id="T_e1c34_row3_col1" class="data row3 col1" >West Jakarta</td>
#       <td id="T_e1c34_row3_col2" class="data row3 col2" >Green Ville</td>
#       <td id="T_e1c34_row3_col3" class="data row3 col3" >4.6</td>
#       <td id="T_e1c34_row3_col4" class="data row3 col4" >4.5</td>
#       <td id="T_e1c34_row3_col5" class="data row3 col5" >4.55</td>
#       <td id="T_e1c34_row3_col6" class="data row3 col6" >2618.0</td>
#       <td id="T_e1c34_row3_col7" class="data row3 col7" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_e1c34_row4_col0" class="data row4 col0" >Street Steak</td>
#       <td id="T_e1c34_row4_col1" class="data row4 col1" >North Jakarta</td>
#       <td id="T_e1c34_row4_col2" class="data row4 col2" >Kelapa Gading</td>
#       <td id="T_e1c34_row4_col3" class="data row4 col3" >4.5</td>
#       <td id="T_e1c34_row4_col4" class="data row4 col4" >4.5</td>
#       <td id="T_e1c34_row4_col5" class="data row4 col5" >4.5</td>
#       <td id="T_e1c34_row4_col6" class="data row4 col6" >1919.0</td>
#       <td id="T_e1c34_row4_col7" class="data row4 col7" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_e1c34_row5_col0" class="data row5 col0" >SKYE</td>
#       <td id="T_e1c34_row5_col1" class="data row5 col1" >Central Jakarta</td>
#       <td id="T_e1c34_row5_col2" class="data row5 col2" >Thamrin</td>
#       <td id="T_e1c34_row5_col3" class="data row5 col3" >4.6</td>
#       <td id="T_e1c34_row5_col4" class="data row5 col4" >4.3</td>
#       <td id="T_e1c34_row5_col5" class="data row5 col5" >4.45</td>
#       <td id="T_e1c34_row5_col6" class="data row5 col6" >6903.0</td>
#       <td id="T_e1c34_row5_col7" class="data row5 col7" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_e1c34_row6_col0" class="data row6 col0" >Holy Smokes</td>
#       <td id="T_e1c34_row6_col1" class="data row6 col1" >South Jakarta</td>
#       <td id="T_e1c34_row6_col2" class="data row6 col2" >Senopati</td>
#       <td id="T_e1c34_row6_col3" class="data row6 col3" >4.5</td>
#       <td id="T_e1c34_row6_col4" class="data row6 col4" >4.4</td>
#       <td id="T_e1c34_row6_col5" class="data row6 col5" >4.45</td>
#       <td id="T_e1c34_row6_col6" class="data row6 col6" >2961.0</td>
#       <td id="T_e1c34_row6_col7" class="data row6 col7" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_e1c34_row7_col0" class="data row7 col0" >Bistecca</td>
#       <td id="T_e1c34_row7_col1" class="data row7 col1" >South Jakarta</td>
#       <td id="T_e1c34_row7_col2" class="data row7 col2" >SCBD</td>
#       <td id="T_e1c34_row7_col3" class="data row7 col3" >4.5</td>
#       <td id="T_e1c34_row7_col4" class="data row7 col4" >4.4</td>
#       <td id="T_e1c34_row7_col5" class="data row7 col5" >4.45</td>
#       <td id="T_e1c34_row7_col6" class="data row7 col6" >1555.0</td>
#       <td id="T_e1c34_row7_col7" class="data row7 col7" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_e1c34_row8_col0" class="data row8 col0" >Animale Restaurant</td>
#       <td id="T_e1c34_row8_col1" class="data row8 col1" >South Jakarta</td>
#       <td id="T_e1c34_row8_col2" class="data row8 col2" >Setiabudi</td>
#       <td id="T_e1c34_row8_col3" class="data row8 col3" >4.6</td>
#       <td id="T_e1c34_row8_col4" class="data row8 col4" >4.3</td>
#       <td id="T_e1c34_row8_col5" class="data row8 col5" >4.45</td>
#       <td id="T_e1c34_row8_col6" class="data row8 col6" >499.0</td>
#       <td id="T_e1c34_row8_col7" class="data row8 col7" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_e1c34_row9_col0" class="data row9 col0" >Cork & Screw</td>
#       <td id="T_e1c34_row9_col1" class="data row9 col1" >South Jakarta</td>
#       <td id="T_e1c34_row9_col2" class="data row9 col2" >SCBD</td>
#       <td id="T_e1c34_row9_col3" class="data row9 col3" >4.5</td>
#       <td id="T_e1c34_row9_col4" class="data row9 col4" >4.4</td>
#       <td id="T_e1c34_row9_col5" class="data row9 col5" >4.45</td>
#       <td id="T_e1c34_row9_col6" class="data row9 col6" >1874.0</td>
#       <td id="T_e1c34_row9_col7" class="data row9 col7" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_e1c34_row10_col0" class="data row10 col0" >B'Steak Grill & Pancake</td>
#       <td id="T_e1c34_row10_col1" class="data row10 col1" >North Jakarta</td>
#       <td id="T_e1c34_row10_col2" class="data row10 col2" >Kelapa Gading</td>
#       <td id="T_e1c34_row10_col3" class="data row10 col3" >4.6</td>
#       <td id="T_e1c34_row10_col4" class="data row10 col4" >4.3</td>
#       <td id="T_e1c34_row10_col5" class="data row10 col5" >4.45</td>
#       <td id="T_e1c34_row10_col6" class="data row10 col6" >1411.0</td>
#       <td id="T_e1c34_row10_col7" class="data row10 col7" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_e1c34_row11_col0" class="data row11 col0" >Holy Smokes</td>
#       <td id="T_e1c34_row11_col1" class="data row11 col1" >North Jakarta</td>
#       <td id="T_e1c34_row11_col2" class="data row11 col2" >Pantai Indah Kapuk</td>
#       <td id="T_e1c34_row11_col3" class="data row11 col3" >4.5</td>
#       <td id="T_e1c34_row11_col4" class="data row11 col4" >4.4</td>
#       <td id="T_e1c34_row11_col5" class="data row11 col5" >4.45</td>
#       <td id="T_e1c34_row11_col6" class="data row11 col6" >684.0</td>
#       <td id="T_e1c34_row11_col7" class="data row11 col7" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_e1c34_row12_col0" class="data row12 col0" >Gandy Steak House</td>
#       <td id="T_e1c34_row12_col1" class="data row12 col1" >Central Jakarta</td>
#       <td id="T_e1c34_row12_col2" class="data row12 col2" >Menteng</td>
#       <td id="T_e1c34_row12_col3" class="data row12 col3" >4.5</td>
#       <td id="T_e1c34_row12_col4" class="da

# %% [markdown]
# # Western Specialized Section
#
# As for Western Specialized Section, **Tucano's Churrascaria Sudirman**, whom serving Brazilian-style steak buffet is the best among list (scored 4.7 from 1107 votes), also best among Central Jakarta on this section. **Carbon**, which serving Mexican food got 4.5 from 165 votes within South Jakarta area.
#
# For other genre, best Italian restaurant is **Caffe Milano** (Thamrin, scored 4.45 from 1869 votes), meanwhile for French restaurant **Cafe de Paris (Kebayoran Lama)** is the most worth to try (scored 3.6 from 37 votes).

# %%
steak = sqldf("""SELECT restaurant_name, specialized, city, district, ltrim(google_rating) as google_rating, 
ltrim(platform_rating) as platform_rating,
ltrim((google_rating + platform_rating)/2) as total_rating,
ltrim(google_count + platform_count) as total_count,
CASE
    WHEN (google_rating + platform_rating)/2 >= 3.5 THEN "Recommended"
    ELSE "Reconsidered"
    END AS "Recommendation"
FROM steak 
WHERE specialized = 'Brazilian' OR specialized = 'Mexican' OR specialized = 'Argentinian' 
OR specialized = 'Italian' OR specialized = 'French'
ORDER BY total_rating DESC;""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_c2c9b_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >specialized</th>
#       <th class="col_heading level0 col2" >city</th>
#       <th class="col_heading level0 col3" >district</th>
#       <th class="col_heading level0 col4" >google_rating</th>
#       <th class="col_heading level0 col5" >platform_rating</th>
#       <th class="col_heading level0 col6" >total_rating</th>
#       <th class="col_heading level0 col7" >total_count</th>
#       <th class="col_heading level0 col8" >Recommendation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c2c9b_row0_col0" class="data row0 col0" >Tucano's Churrascaria</td>
#       <td id="T_c2c9b_row0_col1" class="data row0 col1" >Brazilian</td>
#       <td id="T_c2c9b_row0_col2" class="data row0 col2" >Central Jakarta</td>
#       <td id="T_c2c9b_row0_col3" class="data row0 col3" >Sudirman</td>
#       <td id="T_c2c9b_row0_col4" class="data row0 col4" >4.7</td>
#       <td id="T_c2c9b_row0_col5" class="data row0 col5" >4.7</td>
#       <td id="T_c2c9b_row0_col6" class="data row0 col6" >4.7</td>
#       <td id="T_c2c9b_row0_col7" class="data row0 col7" >1107.0</td>
#       <td id="T_c2c9b_row0_col8" class="data row0 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_c2c9b_row1_col0" class="data row1 col0" >La Posta</td>
#       <td id="T_c2c9b_row1_col1" class="data row1 col1" >Argentinian</td>
#       <td id="T_c2c9b_row1_col2" class="data row1 col2" >Central Jakarta</td>
#       <td id="T_c2c9b_row1_col3" class="data row1 col3" >Sudirman</td>
#       <td id="T_c2c9b_row1_col4" class="data row1 col4" >4.6</td>
#       <td id="T_c2c9b_row1_col5" class="data row1 col5" >4.5</td>
#       <td id="T_c2c9b_row1_col6" class="data row1 col6" >4.55</td>
#       <td id="T_c2c9b_row1_col7" class="data row1 col7" >950.0</td>
#       <td id="T_c2c9b_row1_col8" class="data row1 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_c2c9b_row2_col0" class="data row2 col0" >Carbon</td>
#       <td id="T_c2c9b_row2_col1" class="data row2 col1" >Mexican</td>
#       <td id="T_c2c9b_row2_col2" class="data row2 col2" >South Jakarta</td>
#       <td id="T_c2c9b_row2_col3" class="data row2 col3" >Setiabudi</td>
#       <td id="T_c2c9b_row2_col4" class="data row2 col4" >4.7</td>
#       <td id="T_c2c9b_row2_col5" class="data row2 col5" >4.3</td>
#       <td id="T_c2c9b_row2_col6" class="data row2 col6" >4.5</td>
#       <td id="T_c2c9b_row2_col7" class="data row2 col7" >165.0</td>
#       <td id="T_c2c9b_row2_col8" class="data row2 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_c2c9b_row3_col0" class="data row3 col0" >Caffe Milano</td>
#       <td id="T_c2c9b_row3_col1" class="data row3 col1" >Italian</td>
#       <td id="T_c2c9b_row3_col2" class="data row3 col2" >Central Jakarta</td>
#       <td id="T_c2c9b_row3_col3" class="data row3 col3" >Thamrin</td>
#       <td id="T_c2c9b_row3_col4" class="data row3 col4" >4.5</td>
#       <td id="T_c2c9b_row3_col5" class="data row3 col5" >4.4</td>
#       <td id="T_c2c9b_row3_col6" class="data row3 col6" >4.45</td>
#       <td id="T_c2c9b_row3_col7" class="data row3 col7" >1869.0</td>
#       <td id="T_c2c9b_row3_col8" class="data row3 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_c2c9b_row4_col0" class="data row4 col0" >Rosso</td>
#       <td id="T_c2c9b_row4_col1" class="data row4 col1" >Italian</td>
#       <td id="T_c2c9b_row4_col2" class="data row4 col2" >Central Jakarta</td>
#       <td id="T_c2c9b_row4_col3" class="data row4 col3" >Sudirman</td>
#       <td id="T_c2c9b_row4_col4" class="data row4 col4" >4.5</td>
#       <td id="T_c2c9b_row4_col5" class="data row4 col5" >4.3</td>
#       <td id="T_c2c9b_row4_col6" class="data row4 col6" >4.4</td>
#       <td id="T_c2c9b_row4_col7" class="data row4 col7" >306.0</td>
#       <td id="T_c2c9b_row4_col8" class="data row4 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_c2c9b_row5_col0" class="data row5 col0" >Chilis Grill & Bar</td>
#       <td id="T_c2c9b_row5_col1" class="data row5 col1" >Mexican</td>
#       <td id="T_c2c9b_row5_col2" class="data row5 col2" >Central Jakarta</td>
#       <td id="T_c2c9b_row5_col3" class="data row5 col3" >Thamrin</td>
#       <td id="T_c2c9b_row5_col4" class="data row5 col4" >4.3</td>
#       <td id="T_c2c9b_row5_col5" class="data row5 col5" >4.5</td>
#       <td id="T_c2c9b_row5_col6" class="data row5 col6" >4.4</td>
#       <td id="T_c2c9b_row5_col7" class="data row5 col7" >1156.0</td>
#       <td id="T_c2c9b_row5_col8" class="data row5 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_c2c9b_row6_col0" class="data row6 col0" >El Asador</td>
#       <td id="T_c2c9b_row6_col1" class="data row6 col1" >Mexican</td>
#       <td id="T_c2c9b_row6_col2" class="data row6 col2" >South Jakarta</td>
#       <td id="T_c2c9b_row6_col3" class="data row6 col3" >Kemang</td>
#       <td id="T_c2c9b_row6_col4" class="data row6 col4" >4.5</td>
#       <td id="T_c2c9b_row6_col5" class="data row6 col5" >4.3</td>
#       <td id="T_c2c9b_row6_col6" class="data row6 col6" >4.4</td>
#       <td id="T_c2c9b_row6_col7" class="data row6 col7" >1402.0</td>
#       <td id="T_c2c9b_row6_col8" class="data row6 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_c2c9b_row7_col0" class="data row7 col0" >Tucano's Churrascaria</td>
#       <td id="T_c2c9b_row7_col1" class="data row7 col1" >Brazilian</td>
#       <td id="T_c2c9b_row7_col2" class="data row7 col2" >South Jakarta</td>
#       <td id="T_c2c9b_row7_col3" class="data row7 col3" >Senayan</td>
#       <td id="T_c2c9b_row7_col4" class="data row7 col4" >4.7</td>
#       <td id="T_c2c9b_row7_col5" class="data row7 col5" >3.8</td>
#       <td id="T_c2c9b_row7_col6" class="data row7 col6" >4.25</td>
#       <td id="T_c2c9b_row7_col7" class="data row7 col7" >380.0</td>
#       <td id="T_c2c9b_row7_col8" class="data row7 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_c2c9b_row8_col0" class="data row8 col0" >Liberte</td>
#       <td id="T_c2c9b_row8_col1" class="data row8 col1" >Italian</td>
#       <td id="T_c2c9b_row8_col2" class="data row8 col2" >South Jakarta</td>
#       <td id="T_c2c9b_row8_col3" class="data row8 col3" >SCBD</td>
#       <td id="T_c2c9b_row8_col4" class="data row8 col4" >4.6</td>
#       <td id="T_c2c9b_row8_col5" class="data row8 col5" >3.9</td>
#       <td id="T_c2c9b_row8_col6" class="data row8 col6" >4.25</td>
#       <td id="T_c2c9b_row8_col7" class="data row8 col7" >572.0</td>
#       <td id="T_c2c9b_row8_col8" class="data row8 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_c2c9b_row9_col0" class="data row9 col0" >Volare</td>
#       <td id="T_c2c9b_row9_col1" class="data row9 col1" >Italian</td>
#       <td id="T_c2c9b_row9_col2" class="data row9 col2" >South Jakarta</td>
#       <td id="T_c2c9b_row9_col3" class="data row9 col3" >Fatmawati</td>
#       <td id="T_c2c9b_row9_col4" class="data row9 col4" >4.0</td>
#       <td id="T_c2c9b_row9_col5" class="data row9 col5" >3.9</td>
#       <td id="T_c2c9b_row9_col6" class="data row9 col6" >3.95</td>
#       <td id="T_c2c9b_row9_col7" class="data row9 col7" >125.0</td>
#       <td id="T_c2c9b_row9_col8" class="data row9 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_c2c9b_row10_col0" class="data row10 col0" >Cafe de Paris</td>
#       <td id="T_c2c9b_row10_col1" class="data row10 col1" >French</td>
#       <td id="T_c2c9b_row10_col2" class="data row10 col2" >South Jakarta</td>
#       <td id="T_c2c9b_row10_col3" class="data row10 col3" >Kebayoran Lama</td>
#       <td id="T_c2c9b_row10_col4" class="data row10 col4" >4.0</td>
#       <td id="T_c2c9b_row10_col5" class="data row10 col5" >3.2</td>
#       <td id="T_c2c9b_row10_col6" class="data row10 col6" >3.6</td>
#       <td id="T_c2c9b_row10_col7" class="data row10 col7" >37.0</td>
#       <td id="T_c2c9b_row10_col8" class="data row10 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_c2c9b_row11_col0" class="data row11 col0" >Alto Restaurant & Bar</td>
#       <td id="T_c2c9b_row11_col1" class="data row11 col1" >

# %% [markdown]
# # Fushioned
#
# In this section, **Sumibi (Gandaria)** won the best restaurant among fushioned restaurant, scored 4.65 from 1655 votes, also the best for Japanese restaurant and South Jakarta area. **Benihana Japanese Steakhouse (Thamrin)** scored 4.45 from 410 votes, made them the highest rangking thorough Central Jakarta. As for North Jakarta, they have **Pepperloin Steakhouse** which scored 4.35 from 1015 votes.
#
# For other genre, **VIN+ Wine & Beyond (Kemang)** won the most for Indonesian fushion, scored 4.4 from 1724 votes. **Ninety Nine (Thamrin, Grand Indonesia)** won for fushioned Indonesian and Singaporean, scored 4.3 from 655 votes. **Greyhond Cafe (Thamrin, Grand Indonesia)** is the only one Thailand fushioned restaurant among this list (scored 4.3 from 1576 votes).

# %%
steak = sqldf("""SELECT restaurant_name, fushioned, city, district, ltrim(google_rating) as google_rating, 
ltrim(platform_rating) as platform_rating,
ltrim((google_rating + platform_rating)/2) as total_rating,
ltrim(google_count + platform_count) as total_count,
CASE
    WHEN (google_rating + platform_rating)/2 >= 3.5 THEN "Recommended"
    ELSE "Reconsidered"
    END AS "Recommendation"
FROM steak 
WHERE fushioned NOT LIKE '%no'
ORDER BY total_rating DESC;""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_31bbb_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >fushioned</th>
#       <th class="col_heading level0 col2" >city</th>
#       <th class="col_heading level0 col3" >district</th>
#       <th class="col_heading level0 col4" >google_rating</th>
#       <th class="col_heading level0 col5" >platform_rating</th>
#       <th class="col_heading level0 col6" >total_rating</th>
#       <th class="col_heading level0 col7" >total_count</th>
#       <th class="col_heading level0 col8" >Recommendation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_31bbb_row0_col0" class="data row0 col0" >Sumibi</td>
#       <td id="T_31bbb_row0_col1" class="data row0 col1" >Japanese (Authentic)</td>
#       <td id="T_31bbb_row0_col2" class="data row0 col2" >South Jakarta</td>
#       <td id="T_31bbb_row0_col3" class="data row0 col3" >Gandaria</td>
#       <td id="T_31bbb_row0_col4" class="data row0 col4" >4.7</td>
#       <td id="T_31bbb_row0_col5" class="data row0 col5" >4.6</td>
#       <td id="T_31bbb_row0_col6" class="data row0 col6" >4.65</td>
#       <td id="T_31bbb_row0_col7" class="data row0 col7" >1655.0</td>
#       <td id="T_31bbb_row0_col8" class="data row0 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_31bbb_row1_col0" class="data row1 col0" >Tokyo Skipjack</td>
#       <td id="T_31bbb_row1_col1" class="data row1 col1" >Japanese</td>
#       <td id="T_31bbb_row1_col2" class="data row1 col2" >South Jakarta</td>
#       <td id="T_31bbb_row1_col3" class="data row1 col3" >Blok M</td>
#       <td id="T_31bbb_row1_col4" class="data row1 col4" >4.6</td>
#       <td id="T_31bbb_row1_col5" class="data row1 col5" >4.5</td>
#       <td id="T_31bbb_row1_col6" class="data row1 col6" >4.55</td>
#       <td id="T_31bbb_row1_col7" class="data row1 col7" >4944.0</td>
#       <td id="T_31bbb_row1_col8" class="data row1 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_31bbb_row2_col0" class="data row2 col0" >Benihana Japanese Steakhouse</td>
#       <td id="T_31bbb_row2_col1" class="data row2 col1" >Japanese</td>
#       <td id="T_31bbb_row2_col2" class="data row2 col2" >Central Jakarta</td>
#       <td id="T_31bbb_row2_col3" class="data row2 col3" >Thamrin</td>
#       <td id="T_31bbb_row2_col4" class="data row2 col4" >4.6</td>
#       <td id="T_31bbb_row2_col5" class="data row2 col5" >4.3</td>
#       <td id="T_31bbb_row2_col6" class="data row2 col6" >4.45</td>
#       <td id="T_31bbb_row2_col7" class="data row2 col7" >410.0</td>
#       <td id="T_31bbb_row2_col8" class="data row2 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_31bbb_row3_col0" class="data row3 col0" >VIN+ Wine & Beyond</td>
#       <td id="T_31bbb_row3_col1" class="data row3 col1" >Indonesian</td>
#       <td id="T_31bbb_row3_col2" class="data row3 col2" >South Jakarta</td>
#       <td id="T_31bbb_row3_col3" class="data row3 col3" >Kemang</td>
#       <td id="T_31bbb_row3_col4" class="data row3 col4" >4.6</td>
#       <td id="T_31bbb_row3_col5" class="data row3 col5" >4.2</td>
#       <td id="T_31bbb_row3_col6" class="data row3 col6" >4.4</td>
#       <td id="T_31bbb_row3_col7" class="data row3 col7" >1724.0</td>
#       <td id="T_31bbb_row3_col8" class="data row3 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_31bbb_row4_col0" class="data row4 col0" >Ebeya Steakhouse</td>
#       <td id="T_31bbb_row4_col1" class="data row4 col1" >Japanese (Authentic)</td>
#       <td id="T_31bbb_row4_col2" class="data row4 col2" >South Jakarta</td>
#       <td id="T_31bbb_row4_col3" class="data row4 col3" >SCBD</td>
#       <td id="T_31bbb_row4_col4" class="data row4 col4" >4.6</td>
#       <td id="T_31bbb_row4_col5" class="data row4 col5" >4.2</td>
#       <td id="T_31bbb_row4_col6" class="data row4 col6" >4.4</td>
#       <td id="T_31bbb_row4_col7" class="data row4 col7" >253.0</td>
#       <td id="T_31bbb_row4_col8" class="data row4 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_31bbb_row5_col0" class="data row5 col0" >Yawara</td>
#       <td id="T_31bbb_row5_col1" class="data row5 col1" >Japanese (Authentic)</td>
#       <td id="T_31bbb_row5_col2" class="data row5 col2" >South Jakarta</td>
#       <td id="T_31bbb_row5_col3" class="data row5 col3" >Senopati</td>
#       <td id="T_31bbb_row5_col4" class="data row5 col4" >4.6</td>
#       <td id="T_31bbb_row5_col5" class="data row5 col5" >4.2</td>
#       <td id="T_31bbb_row5_col6" class="data row5 col6" >4.4</td>
#       <td id="T_31bbb_row5_col7" class="data row5 col7" >641.0</td>
#       <td id="T_31bbb_row5_col8" class="data row5 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_31bbb_row6_col0" class="data row6 col0" >Signatures Restaurant</td>
#       <td id="T_31bbb_row6_col1" class="data row6 col1" >Indonesian</td>
#       <td id="T_31bbb_row6_col2" class="data row6 col2" >Central Jakarta</td>
#       <td id="T_31bbb_row6_col3" class="data row6 col3" >Thamrin</td>
#       <td id="T_31bbb_row6_col4" class="data row6 col4" >4.5</td>
#       <td id="T_31bbb_row6_col5" class="data row6 col5" >4.2</td>
#       <td id="T_31bbb_row6_col6" class="data row6 col6" >4.35</td>
#       <td id="T_31bbb_row6_col7" class="data row6 col7" >1006.0</td>
#       <td id="T_31bbb_row6_col8" class="data row6 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_31bbb_row7_col0" class="data row7 col0" >AGED+ Butchered Steakhouse</td>
#       <td id="T_31bbb_row7_col1" class="data row7 col1" >Japanese</td>
#       <td id="T_31bbb_row7_col2" class="data row7 col2" >South Jakarta</td>
#       <td id="T_31bbb_row7_col3" class="data row7 col3" >Setiabudi</td>
#       <td id="T_31bbb_row7_col4" class="data row7 col4" >4.8</td>
#       <td id="T_31bbb_row7_col5" class="data row7 col5" >3.9</td>
#       <td id="T_31bbb_row7_col6" class="data row7 col6" >4.35</td>
#       <td id="T_31bbb_row7_col7" class="data row7 col7" >1015.0</td>
#       <td id="T_31bbb_row7_col8" class="data row7 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_31bbb_row8_col0" class="data row8 col0" >Pepperloin Steakhouse</td>
#       <td id="T_31bbb_row8_col1" class="data row8 col1" >Japanese</td>
#       <td id="T_31bbb_row8_col2" class="data row8 col2" >North Jakarta</td>
#       <td id="T_31bbb_row8_col3" class="data row8 col3" >Pantai Indah Kapuk</td>
#       <td id="T_31bbb_row8_col4" class="data row8 col4" >4.5</td>
#       <td id="T_31bbb_row8_col5" class="data row8 col5" >4.2</td>
#       <td id="T_31bbb_row8_col6" class="data row8 col6" >4.35</td>
#       <td id="T_31bbb_row8_col7" class="data row8 col7" >813.0</td>
#       <td id="T_31bbb_row8_col8" class="data row8 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_31bbb_row9_col0" class="data row9 col0" >Greyhound Cafe</td>
#       <td id="T_31bbb_row9_col1" class="data row9 col1" >Thailand</td>
#       <td id="T_31bbb_row9_col2" class="data row9 col2" >Central Jakarta</td>
#       <td id="T_31bbb_row9_col3" class="data row9 col3" >Thamrin</td>
#       <td id="T_31bbb_row9_col4" class="data row9 col4" >4.5</td>
#       <td id="T_31bbb_row9_col5" class="data row9 col5" >4.1</td>
#       <td id="T_31bbb_row9_col6" class="data row9 col6" >4.3</td>
#       <td id="T_31bbb_row9_col7" class="data row9 col7" >1576.0</td>
#       <td id="T_31bbb_row9_col8" class="data row9 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_31bbb_row10_col0" class="data row10 col0" >Ninety Nine</td>
#       <td id="T_31bbb_row10_col1" class="data row10 col1" >Indonesian, Singaporean</td>
#       <td id="T_31bbb_row10_col2" class="data row10 col2" >Central Jakarta</td>
#       <td id="T_31bbb_row10_col3" class="data row10 col3" >Thamrin</td>
#       <td id="T_31bbb_row10_col4" class="data row10 col4" >4.4</td>
#       <td id="T_31bbb_row10_col5" class="data row10 col5" >4.2</td>
#       <td id="T_31bbb_row10_col6" class="data row10 col6" >4.3</td>
#       <td id="T_31bbb_row10_col7" class="data row10 col7" >655.0</td>
#       <td id="T_31bbb_row10_col8" class="data row10 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_31bbb_row11_col

# %% [markdown]
# # Local Section
#
# This is the most interesting section, which is the most restaurant available thorough Jakarta area. In this section, **Holycow! Kebon Jeruk** won the most which scored 4.55 from 4601 votes, also the best among Local Western and West Jakarta area. For local section, **Joni Steak (Gajah Mada)** won the section with score 4.3 from 5638 votes, also the best local steak in Central Jakarta and thorough Jakarta area.
#
# **Holycow! Kalimalang** (scored 4.4 from 2562 votes) and **Waroeng Steak & Shake Kalimalang** (scored 3.95 from 3532 votes) is the best for both local westerned and local restaurant among East Jakarta area. **The Real Holysteak** (scored 4.35 from 471 votes) and **Andakar** (scored 4.3 from 2661 votes) also the best among South Jakarta area for both local westerned and local restaurant.
#
# Last but not least, **The Garden** (scored 4.45 from 3268 votes) and **Meaters Steak & Ribs** (scored 4.2 from 744 votes) are the best for both local westerned and local restaurant in North Jakarta area.

# %%
steak = sqldf("""SELECT restaurant_name, specialized, city, district, ltrim(google_rating) as google_rating, 
ltrim(platform_rating) as platform_rating,
ltrim((google_rating + platform_rating)/2) as total_rating,
ltrim(google_count + platform_count) as total_count,
CASE
    WHEN (google_rating + platform_rating)/2 >= 3.5 THEN "Recommended"
    ELSE "Reconsidered"
    END AS "Recommendation"
FROM steak 
WHERE specialized = 'Local' OR specialized = 'Local Westerned'
ORDER BY total_rating DESC;""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_3466f_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >specialized</th>
#       <th class="col_heading level0 col2" >city</th>
#       <th class="col_heading level0 col3" >district</th>
#       <th class="col_heading level0 col4" >google_rating</th>
#       <th class="col_heading level0 col5" >platform_rating</th>
#       <th class="col_heading level0 col6" >total_rating</th>
#       <th class="col_heading level0 col7" >total_count</th>
#       <th class="col_heading level0 col8" >Recommendation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3466f_row0_col0" class="data row0 col0" >Holycow! Kebon Jeruk</td>
#       <td id="T_3466f_row0_col1" class="data row0 col1" >Local Westerned</td>
#       <td id="T_3466f_row0_col2" class="data row0 col2" >West Jakarta</td>
#       <td id="T_3466f_row0_col3" class="data row0 col3" >Kebon Jeruk</td>
#       <td id="T_3466f_row0_col4" class="data row0 col4" >4.6</td>
#       <td id="T_3466f_row0_col5" class="data row0 col5" >4.5</td>
#       <td id="T_3466f_row0_col6" class="data row0 col6" >4.55</td>
#       <td id="T_3466f_row0_col7" class="data row0 col7" >4601.0</td>
#       <td id="T_3466f_row0_col8" class="data row0 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_3466f_row1_col0" class="data row1 col0" >Steak 21</td>
#       <td id="T_3466f_row1_col1" class="data row1 col1" >Local Westerned</td>
#       <td id="T_3466f_row1_col2" class="data row1 col2" >West Jakarta</td>
#       <td id="T_3466f_row1_col3" class="data row1 col3" >Tanjung Duren</td>
#       <td id="T_3466f_row1_col4" class="data row1 col4" >4.6</td>
#       <td id="T_3466f_row1_col5" class="data row1 col5" >4.4</td>
#       <td id="T_3466f_row1_col6" class="data row1 col6" >4.5</td>
#       <td id="T_3466f_row1_col7" class="data row1 col7" >1360.0</td>
#       <td id="T_3466f_row1_col8" class="data row1 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_3466f_row2_col0" class="data row2 col0" >The Garden</td>
#       <td id="T_3466f_row2_col1" class="data row2 col1" >Local Westerned</td>
#       <td id="T_3466f_row2_col2" class="data row2 col2" >North Jakarta</td>
#       <td id="T_3466f_row2_col3" class="data row2 col3" >Pantai Indah Kapuk</td>
#       <td id="T_3466f_row2_col4" class="data row2 col4" >4.5</td>
#       <td id="T_3466f_row2_col5" class="data row2 col5" >4.4</td>
#       <td id="T_3466f_row2_col6" class="data row2 col6" >4.45</td>
#       <td id="T_3466f_row2_col7" class="data row2 col7" >3268.0</td>
#       <td id="T_3466f_row2_col8" class="data row2 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_3466f_row3_col0" class="data row3 col0" >Holycow! Kalimalang</td>
#       <td id="T_3466f_row3_col1" class="data row3 col1" >Local Westerned</td>
#       <td id="T_3466f_row3_col2" class="data row3 col2" >East Jakarta</td>
#       <td id="T_3466f_row3_col3" class="data row3 col3" >Kalimalang</td>
#       <td id="T_3466f_row3_col4" class="data row3 col4" >4.6</td>
#       <td id="T_3466f_row3_col5" class="data row3 col5" >4.2</td>
#       <td id="T_3466f_row3_col6" class="data row3 col6" >4.4</td>
#       <td id="T_3466f_row3_col7" class="data row3 col7" >2562.0</td>
#       <td id="T_3466f_row3_col8" class="data row3 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_3466f_row4_col0" class="data row4 col0" >The Real Holysteak!</td>
#       <td id="T_3466f_row4_col1" class="data row4 col1" >Local Westerned</td>
#       <td id="T_3466f_row4_col2" class="data row4 col2" >South Jakarta</td>
#       <td id="T_3466f_row4_col3" class="data row4 col3" >Blok M</td>
#       <td id="T_3466f_row4_col4" class="data row4 col4" >4.4</td>
#       <td id="T_3466f_row4_col5" class="data row4 col5" >4.3</td>
#       <td id="T_3466f_row4_col6" class="data row4 col6" >4.35</td>
#       <td id="T_3466f_row4_col7" class="data row4 col7" >471.0</td>
#       <td id="T_3466f_row4_col8" class="data row4 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_3466f_row5_col0" class="data row5 col0" >Holycow! Pantai Indah Kapuk</td>
#       <td id="T_3466f_row5_col1" class="data row5 col1" >Local Westerned</td>
#       <td id="T_3466f_row5_col2" class="data row5 col2" >North Jakarta</td>
#       <td id="T_3466f_row5_col3" class="data row5 col3" >Pantai Indah Kapuk</td>
#       <td id="T_3466f_row5_col4" class="data row5 col4" >4.5</td>
#       <td id="T_3466f_row5_col5" class="data row5 col5" >4.2</td>
#       <td id="T_3466f_row5_col6" class="data row5 col6" >4.35</td>
#       <td id="T_3466f_row5_col7" class="data row5 col7" >1279.0</td>
#       <td id="T_3466f_row5_col8" class="data row5 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_3466f_row6_col0" class="data row6 col0" >Joni Steak</td>
#       <td id="T_3466f_row6_col1" class="data row6 col1" >Local</td>
#       <td id="T_3466f_row6_col2" class="data row6 col2" >Central Jakarta</td>
#       <td id="T_3466f_row6_col3" class="data row6 col3" >Gajah Mada</td>
#       <td id="T_3466f_row6_col4" class="data row6 col4" >4.5</td>
#       <td id="T_3466f_row6_col5" class="data row6 col5" >4.1</td>
#       <td id="T_3466f_row6_col6" class="data row6 col6" >4.3</td>
#       <td id="T_3466f_row6_col7" class="data row6 col7" >5638.0</td>
#       <td id="T_3466f_row6_col8" class="data row6 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_3466f_row7_col0" class="data row7 col0" >Andakar</td>
#       <td id="T_3466f_row7_col1" class="data row7 col1" >Local</td>
#       <td id="T_3466f_row7_col2" class="data row7 col2" >South Jakarta</td>
#       <td id="T_3466f_row7_col3" class="data row7 col3" >Pasar Minggu</td>
#       <td id="T_3466f_row7_col4" class="data row7 col4" >4.5</td>
#       <td id="T_3466f_row7_col5" class="data row7 col5" >4.1</td>
#       <td id="T_3466f_row7_col6" class="data row7 col6" >4.3</td>
#       <td id="T_3466f_row7_col7" class="data row7 col7" >2661.0</td>
#       <td id="T_3466f_row7_col8" class="data row7 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_3466f_row8_col0" class="data row8 col0" >Abuba Steak</td>
#       <td id="T_3466f_row8_col1" class="data row8 col1" >Local Westerned</td>
#       <td id="T_3466f_row8_col2" class="data row8 col2" >South Jakarta</td>
#       <td id="T_3466f_row8_col3" class="data row8 col3" >Fatmawati</td>
#       <td id="T_3466f_row8_col4" class="data row8 col4" >4.5</td>
#       <td id="T_3466f_row8_col5" class="data row8 col5" >4.1</td>
#       <td id="T_3466f_row8_col6" class="data row8 col6" >4.3</td>
#       <td id="T_3466f_row8_col7" class="data row8 col7" >7006.0</td>
#       <td id="T_3466f_row8_col8" class="data row8 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_3466f_row9_col0" class="data row9 col0" >Blue Fire Steakhouse</td>
#       <td id="T_3466f_row9_col1" class="data row9 col1" >Local Westerned</td>
#       <td id="T_3466f_row9_col2" class="data row9 col2" >East Jakarta</td>
#       <td id="T_3466f_row9_col3" class="data row9 col3" >Duren Sawit</td>
#       <td id="T_3466f_row9_col4" class="data row9 col4" >4.6</td>
#       <td id="T_3466f_row9_col5" class="data row9 col5" >4.0</td>
#       <td id="T_3466f_row9_col6" class="data row9 col6" >4.3</td>
#       <td id="T_3466f_row9_col7" class="data row9 col7" >434.0</td>
#       <td id="T_3466f_row9_col8" class="data row9 col8" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_3466f_row10_col0" class="data row10 col0" >Holycow! Pecenongan</td>
#       <td id="T_3466f_row10_col1" class="data row10 col1" >Local Westerned</td>
#       <td id="T_3466f_row10_col2" class="data row10 col2" >Central Jakarta</td>
#       <td id="T_3466f_row10_col3" class="data row10 col3" >Pecenongan</td>
#       <td id="T_3466f_row10_col4" class="data row10 col4" >4.5</td>
#       <td id="T_3466f_row10_col5" class="data row10 col5" >4.0</td>
#       <td id="T_3466f_row10_col6" class="data row10 col6" >4.25</td>
#       <td id="T_3466f_row10_col7" class="data row10 col7" >2471.0</td>
#       <td id="T_3466f_row10_col8" class="data row10 col8" >Recommended</td>
#     </tr>
#     <tr>
