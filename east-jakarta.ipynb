# %% [markdown]
# # East Jakarta
#
# The most humble city in Jakarta, some of its famous districts are Klender, Pulo Gadung, and Kramat Jati. Some of restaurant here are fast food and in affordable prices.
#
# # Content
# * District
# * Price Range
# * Facility
# * Rating

# %%
import pandas as pd
from pandasql import sqldf
burger = pd.read_csv('../input/east-jakarta-burger/east_jakarta.csv', sep = ";")

# %% [markdown]
# # District

# %%
partlor_name = sqldf("SELECT DISTINCT district FROM burger").transpose()
partlor_name
# Out:
#                 0        1          2         3            4            5
# District  Klender  Cibubur  Cililitan  Matraman  Kramat Jati  Pulo Gadung

# %% [markdown]
# Here is the list of the restaurant. Consists of 9 restaurant/partlors available.

# %%
burger = sqldf("SELECT no, partlor_name, District, unique_menu, price FROM burger")
burger.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_38440_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >no</th>
#       <th class="col_heading level0 col1" >partlor_name</th>
#       <th class="col_heading level0 col2" >District</th>
#       <th class="col_heading level0 col3" >unique_menu</th>
#       <th class="col_heading level0 col4" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_38440_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_38440_row0_col1" class="data row0 col1" >Burger King Klender</td>
#       <td id="T_38440_row0_col2" class="data row0 col2" >Klender</td>
#       <td id="T_38440_row0_col3" class="data row0 col3" >Chicken Tendercrisp</td>
#       <td id="T_38440_row0_col4" class="data row0 col4" >42727</td>
#     </tr>
#     <tr>
#       <td id="T_38440_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_38440_row1_col1" class="data row1 col1" >Burger King Cibubur Junction</td>
#       <td id="T_38440_row1_col2" class="data row1 col2" >Cibubur</td>
#       <td id="T_38440_row1_col3" class="data row1 col3" >Cheese Burger</td>
#       <td id="T_38440_row1_col4" class="data row1 col4" >25000</td>
#     </tr>
#     <tr>
#       <td id="T_38440_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_38440_row2_col1" class="data row2 col1" >Dons Burger Pusat Grosir Cililitan</td>
#       <td id="T_38440_row2_col2" class="data row2 col2" >Cililitan</td>
#       <td id="T_38440_row2_col3" class="data row2 col3" >Spesial Burger</td>
#       <td id="T_38440_row2_col4" class="data row2 col4" >13000</td>
#     </tr>
#     <tr>
#       <td id="T_38440_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_38440_row3_col1" class="data row3 col1" >Lemoe Burger Matraman</td>
#       <td id="T_38440_row3_col2" class="data row3 col2" >Matraman</td>
#       <td id="T_38440_row3_col3" class="data row3 col3" >Chicken Cabe Ijo</td>
#       <td id="T_38440_row3_col4" class="data row3 col4" >14000</td>
#     </tr>
#     <tr>
#       <td id="T_38440_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_38440_row4_col1" class="data row4 col1" >Resto Burger Takkatak</td>
#       <td id="T_38440_row4_col2" class="data row4 col2" >Kramat Jati</td>
#       <td id="T_38440_row4_col3" class="data row4 col3" >Extra Double Beef & Cheese Burger</td>
#       <td id="T_38440_row4_col4" class="data row4 col4" >30000</td>
#     </tr>
#     <tr>
#       <td id="T_38440_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_38440_row5_col1" class="data row5 col1" >Carl's Jr. Klender</td>
#       <td id="T_38440_row5_col2" class="data row5 col2" >Klender</td>
#       <td id="T_38440_row5_col3" class="data row5 col3" >Double Western Beefbac</td>
#       <td id="T_38440_row5_col4" class="data row5 col4" >82727</td>
#     </tr>
#     <tr>
#       <td id="T_38440_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_38440_row6_col1" class="data row6 col1" >Lemoe Burger Pulo Gadung</td>
#       <td id="T_38440_row6_col2" class="data row6 col2" >Pulo Gadung</td>
#       <td id="T_38440_row6_col3" class="data row6 col3" >Chicken Special Cheese</td>
#       <td id="T_38440_row6_col4" class="data row6 col4" >20000</td>
#     </tr>
#     <tr>
#       <td id="T_38440_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_38440_row7_col1" class="data row7 col1" >The Lime Roaster & Burger</td>
#       <td id="T_38440_row7_col2" class="data row7 col2" >Pulo Gadung</td>
#       <td id="T_38440_row7_col3" class="data row7 col3" >Chicken Burger</td>
#       <td id="T_38440_row7_col4" class="data row7 col4" >25000</td>
#     </tr>
#     <tr>
#       <td id="T_38440_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_38440_row8_col1" class="data row8 col1" >Papito's Burger</td>
#       <td id="T_38440_row8_col2" class="data row8 col2" >Kramat Jati</td>
#       <td id="T_38440_row8_col3" class="data row8 col3" >Mozarella Burger</td>
#       <td id="T_38440_row8_col4" class="data row8 col4" >14000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Price-Range
#
# We sorted the list from the most expensive and also the cheapest, also with the price range from IDR 50000 to 100000. Here is the order from the most expensive. The most expensive here is Carl's Jr. Klender which their premium menu is priced about 80k, the cheapest menu is Dons Burger Pusat Grosir Cililitan for at least 13k per menu.
#
# No prices more than 100k, mostly below 50k per menu.

# %%
#most expensive
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price\ 
                     FROM burger ORDER BY price DESC")
burger_price.head().style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_69f45_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_69f45_row0_col0" class="data row0 col0" >Carl's Jr. Klender</td>
#       <td id="T_69f45_row0_col1" class="data row0 col1" >Klender</td>
#       <td id="T_69f45_row0_col2" class="data row0 col2" >Double Western Beefbac</td>
#       <td id="T_69f45_row0_col3" class="data row0 col3" >82727</td>
#     </tr>
#     <tr>
#       <td id="T_69f45_row1_col0" class="data row1 col0" >Burger King Klender</td>
#       <td id="T_69f45_row1_col1" class="data row1 col1" >Klender</td>
#       <td id="T_69f45_row1_col2" class="data row1 col2" >Chicken Tendercrisp</td>
#       <td id="T_69f45_row1_col3" class="data row1 col3" >42727</td>
#     </tr>
#     <tr>
#       <td id="T_69f45_row2_col0" class="data row2 col0" >Resto Burger Takkatak</td>
#       <td id="T_69f45_row2_col1" class="data row2 col1" >Kramat Jati</td>
#       <td id="T_69f45_row2_col2" class="data row2 col2" >Extra Double Beef & Cheese Burger</td>
#       <td id="T_69f45_row2_col3" class="data row2 col3" >30000</td>
#     </tr>
#     <tr>
#       <td id="T_69f45_row3_col0" class="data row3 col0" >Burger King Cibubur Junction</td>
#       <td id="T_69f45_row3_col1" class="data row3 col1" >Cibubur</td>
#       <td id="T_69f45_row3_col2" class="data row3 col2" >Cheese Burger</td>
#       <td id="T_69f45_row3_col3" class="data row3 col3" >25000</td>
#     </tr>
#     <tr>
#       <td id="T_69f45_row4_col0" class="data row4 col0" >The Lime Roaster & Burger</td>
#       <td id="T_69f45_row4_col1" class="data row4 col1" >Pulo Gadung</td>
#       <td id="T_69f45_row4_col2" class="data row4 col2" >Chicken Burger</td>
#       <td id="T_69f45_row4_col3" class="data row4 col3" >25000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#cheapest
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price\ 
                     FROM burger ORDER BY price")
burger_price.head().style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_fd9e6_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fd9e6_row0_col0" class="data row0 col0" >Dons Burger Pusat Grosir Cililitan</td>
#       <td id="T_fd9e6_row0_col1" class="data row0 col1" >Cililitan</td>
#       <td id="T_fd9e6_row0_col2" class="data row0 col2" >Spesial Burger</td>
#       <td id="T_fd9e6_row0_col3" class="data row0 col3" >13000</td>
#     </tr>
#     <tr>
#       <td id="T_fd9e6_row1_col0" class="data row1 col0" >Lemoe Burger Matraman</td>
#       <td id="T_fd9e6_row1_col1" class="data row1 col1" >Matraman</td>
#       <td id="T_fd9e6_row1_col2" class="data row1 col2" >Chicken Cabe Ijo</td>
#       <td id="T_fd9e6_row1_col3" class="data row1 col3" >14000</td>
#     </tr>
#     <tr>
#       <td id="T_fd9e6_row2_col0" class="data row2 col0" >Papito's Burger</td>
#       <td id="T_fd9e6_row2_col1" class="data row2 col1" >Kramat Jati</td>
#       <td id="T_fd9e6_row2_col2" class="data row2 col2" >Mozarella Burger</td>
#       <td id="T_fd9e6_row2_col3" class="data row2 col3" >14000</td>
#     </tr>
#     <tr>
#       <td id="T_fd9e6_row3_col0" class="data row3 col0" >Lemoe Burger Pulo Gadung</td>
#       <td id="T_fd9e6_row3_col1" class="data row3 col1" >Pulo Gadung</td>
#       <td id="T_fd9e6_row3_col2" class="data row3 col2" >Chicken Special Cheese</td>
#       <td id="T_fd9e6_row3_col3" class="data row3 col3" >20000</td>
#     </tr>
#     <tr>
#       <td id="T_fd9e6_row4_col0" class="data row4 col0" >Burger King Cibubur Junction</td>
#       <td id="T_fd9e6_row4_col1" class="data row4 col1" >Cibubur</td>
#       <td id="T_fd9e6_row4_col2" class="data row4 col2" >Cheese Burger</td>
#       <td id="T_fd9e6_row4_col3" class="data row4 col3" >25000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#more than IDR 100000
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price\ 
                     FROM burger WHERE price >= 100000")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_ee6c6_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
#between 50000 to 100000
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price\ 
                     FROM burger WHERE price BETWEEN 50000 AND 100000")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_83c65_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_83c65_row0_col0" class="data row0 col0" >Carl's Jr. Klender</td>
#       <td id="T_83c65_row0_col1" class="data row0 col1" >Klender</td>
#       <td id="T_83c65_row0_col2" class="data row0 col2" >Double Western Beefbac</td>
#       <td id="T_83c65_row0_col3" class="data row0 col3" >82727</td>
#     </tr>
#   </tbody>
# </table>

# %%
#below IDR 50000
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price\ 
                      FROM burger WHERE price <= 50000")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_2b9da_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2b9da_row0_col0" class="data row0 col0" >Burger King Klender</td>
#       <td id="T_2b9da_row0_col1" class="data row0 col1" >Klender</td>
#       <td id="T_2b9da_row0_col2" class="data row0 col2" >Chicken Tendercrisp</td>
#       <td id="T_2b9da_row0_col3" class="data row0 col3" >42727</td>
#     </tr>
#     <tr>
#       <td id="T_2b9da_row1_col0" class="data row1 col0" >Burger King Cibubur Junction</td>
#       <td id="T_2b9da_row1_col1" class="data row1 col1" >Cibubur</td>
#       <td id="T_2b9da_row1_col2" class="data row1 col2" >Cheese Burger</td>
#       <td id="T_2b9da_row1_col3" class="data row1 col3" >25000</td>
#     </tr>
#     <tr>
#       <td id="T_2b9da_row2_col0" class="data row2 col0" >Dons Burger Pusat Grosir Cililitan</td>
#       <td id="T_2b9da_row2_col1" class="data row2 col1" >Cililitan</td>
#       <td id="T_2b9da_row2_col2" class="data row2 col2" >Spesial Burger</td>
#       <td id="T_2b9da_row2_col3" class="data row2 col3" >13000</td>
#     </tr>
#     <tr>
#       <td id="T_2b9da_row3_col0" class="data row3 col0" >Lemoe Burger Matraman</td>
#       <td id="T_2b9da_row3_col1" class="data row3 col1" >Matraman</td>
#       <td id="T_2b9da_row3_col2" class="data row3 col2" >Chicken Cabe Ijo</td>
#       <td id="T_2b9da_row3_col3" class="data row3 col3" >14000</td>
#     </tr>
#     <tr>
#       <td id="T_2b9da_row4_col0" class="data row4 col0" >Resto Burger Takkatak</td>
#       <td id="T_2b9da_row4_col1" class="data row4 col1" >Kramat Jati</td>
#       <td id="T_2b9da_row4_col2" class="data row4 col2" >Extra Double Beef & Cheese Burger</td>
#       <td id="T_2b9da_row4_col3" class="data row4 col3" >30000</td>
#     </tr>
#     <tr>
#       <td id="T_2b9da_row5_col0" class="data row5 col0" >Lemoe Burger Pulo Gadung</td>
#       <td id="T_2b9da_row5_col1" class="data row5 col1" >Pulo Gadung</td>
#       <td id="T_2b9da_row5_col2" class="data row5 col2" >Chicken Special Cheese</td>
#       <td id="T_2b9da_row5_col3" class="data row5 col3" >20000</td>
#     </tr>
#     <tr>
#       <td id="T_2b9da_row6_col0" class="data row6 col0" >The Lime Roaster & Burger</td>
#       <td id="T_2b9da_row6_col1" class="data row6 col1" >Pulo Gadung</td>
#       <td id="T_2b9da_row6_col2" class="data row6 col2" >Chicken Burger</td>
#       <td id="T_2b9da_row6_col3" class="data row6 col3" >25000</td>
#     </tr>
#     <tr>
#       <td id="T_2b9da_row7_col0" class="data row7 col0" >Papito's Burger</td>
#       <td id="T_2b9da_row7_col1" class="data row7 col1" >Kramat Jati</td>
#       <td id="T_2b9da_row7_col2" class="data row7 col2" >Mozarella Burger</td>
#       <td id="T_2b9da_row7_col3" class="data row7 col3" >14000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Facility
# Last but not least, we chose the restaurant whether we could takeaway, or deliver our food. We also could find out whether these partlor has outdoor seats, smoking room, wifi, and reservation. Last but not least, we researched about poultry with some dietary restriction like alcohol and halal_menu. But this halal menu will not available in other project. We changed to other_poultry instead.
#
# From the list I have, all of them doesn't have any alcohol drink and the food is halal. Also there are very few facilities available on outdoor seat, smoking area, and especially wifi. But you don't need to book for having burger in this area.
#
# Let's take a look for all the facility, I counted each of them also.

# %%
burger = sqldf("SELECT no, partlor_name, district, takeaway, delivery, outdoor_seat,\ 
         smoking_area, alcohol_served, wifi, reservation, drive_thru, halal_food FROM burger")
burger.head().style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_ca45a_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >no</th>
#       <th class="col_heading level0 col1" >partlor_name</th>
#       <th class="col_heading level0 col2" >District</th>
#       <th class="col_heading level0 col3" >takeaway</th>
#       <th class="col_heading level0 col4" >delivery</th>
#       <th class="col_heading level0 col5" >outdoor_seat</th>
#       <th class="col_heading level0 col6" >smoking_area</th>
#       <th class="col_heading level0 col7" >alcohol_served</th>
#       <th class="col_heading level0 col8" >wifi</th>
#       <th class="col_heading level0 col9" >reservation</th>
#       <th class="col_heading level0 col10" >drive_thru</th>
#       <th class="col_heading level0 col11" >halal_food</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ca45a_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ca45a_row0_col1" class="data row0 col1" >Burger King Klender</td>
#       <td id="T_ca45a_row0_col2" class="data row0 col2" >Klender</td>
#       <td id="T_ca45a_row0_col3" class="data row0 col3" >yes</td>
#       <td id="T_ca45a_row0_col4" class="data row0 col4" >yes</td>
#       <td id="T_ca45a_row0_col5" class="data row0 col5" >yes</td>
#       <td id="T_ca45a_row0_col6" class="data row0 col6" >no</td>
#       <td id="T_ca45a_row0_col7" class="data row0 col7" >no</td>
#       <td id="T_ca45a_row0_col8" class="data row0 col8" >yes</td>
#       <td id="T_ca45a_row0_col9" class="data row0 col9" >no</td>
#       <td id="T_ca45a_row0_col10" class="data row0 col10" >no</td>
#       <td id="T_ca45a_row0_col11" class="data row0 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_ca45a_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_ca45a_row1_col1" class="data row1 col1" >Burger King Cibubur Junction</td>
#       <td id="T_ca45a_row1_col2" class="data row1 col2" >Cibubur</td>
#       <td id="T_ca45a_row1_col3" class="data row1 col3" >yes</td>
#       <td id="T_ca45a_row1_col4" class="data row1 col4" >yes</td>
#       <td id="T_ca45a_row1_col5" class="data row1 col5" >no</td>
#       <td id="T_ca45a_row1_col6" class="data row1 col6" >no</td>
#       <td id="T_ca45a_row1_col7" class="data row1 col7" >no</td>
#       <td id="T_ca45a_row1_col8" class="data row1 col8" >yes</td>
#       <td id="T_ca45a_row1_col9" class="data row1 col9" >no</td>
#       <td id="T_ca45a_row1_col10" class="data row1 col10" >no</td>
#       <td id="T_ca45a_row1_col11" class="data row1 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_ca45a_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_ca45a_row2_col1" class="data row2 col1" >Dons Burger Pusat Grosir Cililitan</td>
#       <td id="T_ca45a_row2_col2" class="data row2 col2" >Cililitan</td>
#       <td id="T_ca45a_row2_col3" class="data row2 col3" >yes</td>
#       <td id="T_ca45a_row2_col4" class="data row2 col4" >no</td>
#       <td id="T_ca45a_row2_col5" class="data row2 col5" >no</td>
#       <td id="T_ca45a_row2_col6" class="data row2 col6" >yes</td>
#       <td id="T_ca45a_row2_col7" class="data row2 col7" >no</td>
#       <td id="T_ca45a_row2_col8" class="data row2 col8" >no</td>
#       <td id="T_ca45a_row2_col9" class="data row2 col9" >no</td>
#       <td id="T_ca45a_row2_col10" class="data row2 col10" >no</td>
#       <td id="T_ca45a_row2_col11" class="data row2 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_ca45a_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_ca45a_row3_col1" class="data row3 col1" >Lemoe Burger Matraman</td>
#       <td id="T_ca45a_row3_col2" class="data row3 col2" >Matraman</td>
#       <td id="T_ca45a_row3_col3" class="data row3 col3" >yes</td>
#       <td id="T_ca45a_row3_col4" class="data row3 col4" >yes</td>
#       <td id="T_ca45a_row3_col5" class="data row3 col5" >yes</td>
#       <td id="T_ca45a_row3_col6" class="data row3 col6" >no</td>
#       <td id="T_ca45a_row3_col7" class="data row3 col7" >no</td>
#       <td id="T_ca45a_row3_col8" class="data row3 col8" >no</td>
#       <td id="T_ca45a_row3_col9" class="data row3 col9" >no</td>
#       <td id="T_ca45a_row3_col10" class="data row3 col10" >no</td>
#       <td id="T_ca45a_row3_col11" class="data row3 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_ca45a_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_ca45a_row4_col1" class="data row4 col1" >Resto Burger Takkatak</td>
#       <td id="T_ca45a_row4_col2" class="data row4 col2" >Kramat Jati</td>
#       <td id="T_ca45a_row4_col3" class="data row4 col3" >yes</td>
#       <td id="T_ca45a_row4_col4" class="data row4 col4" >no</td>
#       <td id="T_ca45a_row4_col5" class="data row4 col5" >no</td>
#       <td id="T_ca45a_row4_col6" class="data row4 col6" >yes</td>
#       <td id="T_ca45a_row4_col7" class="data row4 col7" >no</td>
#       <td id="T_ca45a_row4_col8" class="data row4 col8" >no</td>
#       <td id="T_ca45a_row4_col9" class="data row4 col9" >no</td>
#       <td id="T_ca45a_row4_col10" class="data row4 col10" >no</td>
#       <td id="T_ca45a_row4_col11" class="data row4 col11" >yes</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Rating
# I'll calculate and decide which are recommended on the other file but here is the glimpse. We can see which vendor has the highest rating available. For this time I order this list by google_rating as it appeared first.

# %%
rating = sqldf("SELECT partlor_name, district, ltrim(google_rating) as google_rating,\
               ltrim(zomato_rating) as zomato_rating, ltrim(qraved_rating) as qraved_rating,\
               zomato_count, qraved_count FROM burger ORDER BY google_rating DESC")
rating.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_5ecec_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >google_rating</th>
#       <th class="col_heading level0 col3" >zomato_rating</th>
#       <th class="col_heading level0 col4" >qraved_rating</th>
#       <th class="col_heading level0 col5" >zomato_count</th>
#       <th class="col_heading level0 col6" >qraved_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5ecec_row0_col0" class="data row0 col0" >Carl's Jr. Klender</td>
#       <td id="T_5ecec_row0_col1" class="data row0 col1" >Klender</td>
#       <td id="T_5ecec_row0_col2" class="data row0 col2" >4.06</td>
#       <td id="T_5ecec_row0_col3" class="data row0 col3" >4.03</td>
#       <td id="T_5ecec_row0_col4" class="data row0 col4" >3.08</td>
#       <td id="T_5ecec_row0_col5" class="data row0 col5" >178</td>
#       <td id="T_5ecec_row0_col6" class="data row0 col6" >5</td>
#     </tr>
#     <tr>
#       <td id="T_5ecec_row1_col0" class="data row1 col0" >Burger King Klender</td>
#       <td id="T_5ecec_row1_col1" class="data row1 col1" >Klender</td>
#       <td id="T_5ecec_row1_col2" class="data row1 col2" >4.05</td>
#       <td id="T_5ecec_row1_col3" class="data row1 col3" >3.07</td>
#       <td id="T_5ecec_row1_col4" class="data row1 col4" >3.0</td>
#       <td id="T_5ecec_row1_col5" class="data row1 col5" >86</td>
#       <td id="T_5ecec_row1_col6" class="data row1 col6" >1</td>
#     </tr>
#     <tr>
#       <td id="T_5ecec_row2_col0" class="data row2 col0" >Lemoe Burger Pulo Gadung</td>
#       <td id="T_5ecec_row2_col1" class="data row2 col1" >Pulo Gadung</td>
#       <td id="T_5ecec_row2_col2" class="data row2 col2" >4.05</td>
#       <td id="T_5ecec_row2_col3" class="data row2 col3" >3.05</td>
#       <td id="T_5ecec_row2_col4" class="data row2 col4" >0.0</td>
#       <td id="T_5ecec_row2_col5" class="data row2 col5" >6</td>
#       <td id="T_5ecec_row2_col6" class="data row2 col6" >0</td>
#     </tr>
#     <tr>
#       <td id="T_5ecec_row3_col0" class="data row3 col0" >Burger King Cibubur Junction</td>
#       <td id="T_5ecec_row3_col1" class="data row3 col1" >Cibubur</td>
#       <td id="T_5ecec_row3_col2" class="data row3 col2" >4.04</td>
#       <td id="T_5ecec_row3_col3" class="data row3 col3" >3.06</td>
#       <td id="T_5ecec_row3_col4" class="data row3 col4" >5.0</td>
#       <td id="T_5ecec_row3_col5" class="data row3 col5" >20</td>
#       <td id="T_5ecec_row3_col6" class="data row3 col6" >1</td>
#     </tr>
#     <tr>
#       <td id="T_5ecec_row4_col0" class="data row4 col0" >Dons Burger Pusat Grosir Cililitan</td>
#       <td id="T_5ecec_row4_col1" class="data row4 col1" >Cililitan</td>
#       <td id="T_5ecec_row4_col2" class="data row4 col2" >4.04</td>
#       <td id="T_5ecec_row4_col3" class="data row4 col3" >4.0</td>
#       <td id="T_5ecec_row4_col4" class="data row4 col4" >5.0</td>
#       <td id="T_5ecec_row4_col5" class="data row4 col5" >99</td>
#       <td id="T_5ecec_row4_col6" class="data row4 col6" >1</td>
#     </tr>
#     <tr>
#       <td id="T_5ecec_row5_col0" class="data row5 col0" >The Lime Roaster & Burger</td>
#       <td id="T_5ecec_row5_col1" class="data row5 col1" >Pulo Gadung</td>
#       <td id="T_5ecec_row5_col2" class="data row5 col2" >4.04</td>
#       <td id="T_5ecec_row5_col3" class="data row5 col3" >3.03</td>
#       <td id="T_5ecec_row5_col4" class="data row5 col4" >0.0</td>
#       <td id="T_5ecec_row5_col5" class="data row5 col5" >5</td>
#       <td id="T_5ecec_row5_col6" class="data row5 col6" >0</td>
#     </tr>
#     <tr>
#       <td id="T_5ecec_row6_col0" class="data row6 col0" >Resto Burger Takkatak</td>
#       <td id="T_5ecec_row6_col1" class="data row6 col1" >Kramat Jati</td>
#       <td id="T_5ecec_row6_col2" class="data row6 col2" >4.02</td>
#       <td id="T_5ecec_row6_col3" class="data row6 col3" >3.08</td>
#       <td id="T_5ecec_row6_col4" class="data row6 col4" >4.03</td>
#       <td id="T_5ecec_row6_col5" class="data row6 col5" >37</td>
#       <td id="T_5ecec_row6_col6" class="data row6 col6" >4</td>
#     </tr>
#     <tr>
#       <td id="T_5ecec_row7_col0" class="data row7 col0" >Lemoe Burger Matraman</td>
#       <td id="T_5ecec_row7_col1" class="data row7 col1" >Matraman</td>
#       <td id="T_5ecec_row7_col2" class="data row7 col2" >0.0</td>
#       <td id="T_5ecec_row7_col3" class="data row7 col3" >0.0</td>
#       <td id="T_5ecec_row7_col4" class="data row7 col4" >3.07</td>
#       <td id="T_5ecec_row7_col5" class="data row7 col5" >0</td>
#       <td id="T_5ecec_row7_col6" class="data row7 col6" >3</td>
#     </tr>
#     <tr>
#       <td id="T_5ecec_row8_col0" class="data row8 col0" >Papito's Burger</td>
#       <td id="T_5ecec_row8_col1" class="data row8 col1" >Kramat Jati</td>
#       <td id="T_5ecec_row8_col2" class="data row8 col2" >0.0</td>
#       <td id="T_5ecec_row8_col3" class="data row8 col3" >3.05</td>
#       <td id="T_5ecec_row8_col4" class="data row8 col4" >0.0</td>
#       <td id="T_5ecec_row8_col5" class="data row8 col5" >4</td>
#       <td id="T_5ecec_row8_col6" class="data row8 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
