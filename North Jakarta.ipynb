# %% [markdown]
# <a href="https://www.kaggle.com/code/miradelimanr/burger-in-north-jakarta?scriptVersionId=98398199" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # **North Jakarta**
#
# This is the marine city as it closed to Ancol Beach area (but unfortunately, no specific burger partlor in this area except for McDonald and KFC). Consisting only three district on this sample, which are Pantai Indah Kapuk (which is high end housing complex), Kelapa Gading, and Sunter. Dominated by fast food and high end restaurant, there are still budgeted vendor available in small number.
#
# # Content
# * District
# * Price Range
# * Facility
# * Rating

# %%
import pandas as pd
from pandasql import sqldf
burger = pd.read_csv('../input/north-jakarta-burger/north_jakarta.csv', sep = ";")

# %% [markdown]
# # District

# %%
partlor_name = sqldf("SELECT DISTINCT district FROM burger").transpose()
partlor_name
# Out:
#                            0              1       2
# District  Pantai Indah Kapuk  Kelapa Gading  Sunter

# %%
burger = sqldf("SELECT no, partlor_name, District, unique_menu, price FROM burger")
burger.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_bb97f_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >no</th>
#       <th class="col_heading level0 col1" >partlor_name</th>
#       <th class="col_heading level0 col2" >District</th>
#       <th class="col_heading level0 col3" >unique_menu</th>
#       <th class="col_heading level0 col4" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bb97f_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_bb97f_row0_col1" class="data row0 col1" >Burger King Pantai Indah Kapuk</td>
#       <td id="T_bb97f_row0_col2" class="data row0 col2" >Pantai Indah Kapuk</td>
#       <td id="T_bb97f_row0_col3" class="data row0 col3" >Cheese Burger</td>
#       <td id="T_bb97f_row0_col4" class="data row0 col4" >25000</td>
#     </tr>
#     <tr>
#       <td id="T_bb97f_row1_col0" class="data row1 col0" >2</td>
# ...

# %% [markdown]
# # Price-Range
#
# We sorted the list from the most expensive and also the cheapest, also with the price range from IDR 50000 to 100000. Here is the order from the most expensive. The most expensive here is Six Ounces Coffee for at least 70k per menu. The cheapest here is Burger Bener which priced at least 13k per menu. There is no price more than 100k. Most range available are below 50k.

# %%
#most expensive
burger_price = sqldf("""SELECT partlor_name, district, unique_menu, price 
                        FROM burger 
                        ORDER BY price DESC""")
burger_price.head().style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_7cc4a_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7cc4a_row0_col0" class="data row0 col0" >Six Ounces Coffee</td>
#       <td id="T_7cc4a_row0_col1" class="data row0 col1" >Kelapa Gading</td>
#       <td id="T_7cc4a_row0_col2" class="data row0 col2" >Aussie Burger</td>
#       <td id="T_7cc4a_row0_col3" class="data row0 col3" >75000</td>
#     </tr>
#     <tr>
#       <td id="T_7cc4a_row1_col0" class="data row1 col0" >Burger King Sunter Mall</td>
#       <td id="T_7cc4a_row1_col1" class="data row1 col1" >Sunter</td>
#       <td id="T_7cc4a_row1_col2" class="data row1 col2" >Chicken Steakhouse BBQ</td>
# ...

# %%
#cheapest
burger_price = sqldf("""SELECT partlor_name, district, unique_menu, price 
                        FROM burger 
                        ORDER BY price""")
burger_price.head().style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_81e52_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_81e52_row0_col0" class="data row0 col0" >Burger Bener</td>
#       <td id="T_81e52_row0_col1" class="data row0 col1" >Kelapa Gading</td>
#       <td id="T_81e52_row0_col2" class="data row0 col2" >Bener 1</td>
#       <td id="T_81e52_row0_col3" class="data row0 col3" >13000</td>
#     </tr>
#     <tr>
#       <td id="T_81e52_row1_col0" class="data row1 col0" >Lemoe Burger</td>
#       <td id="T_81e52_row1_col1" class="data row1 col1" >Kelapa Gading</td>
#       <td id="T_81e52_row1_col2" class="data row1 col2" >Beef Cabe Ijo</td>
#       <td id="T_81e52_row1_col3" class="data row1 col3" >17000</td>
# ...

# %%
#more than IDR 100000
burger_price = sqldf("""SELECT partlor_name, district, unique_menu, price 
                        FROM burger 
                        WHERE price >= 100000""")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_f01dd_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
#between 50000 to 100000
burger_price = sqldf("""SELECT partlor_name, district, unique_menu, price 
                        FROM burger 
                        WHERE price BETWEEN 50000 AND 100000""")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_d2ec1_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d2ec1_row0_col0" class="data row0 col0" >Burger King Sunter Mall</td>
#       <td id="T_d2ec1_row0_col1" class="data row0 col1" >Sunter</td>
#       <td id="T_d2ec1_row0_col2" class="data row0 col2" >Chicken Steakhouse BBQ</td>
#       <td id="T_d2ec1_row0_col3" class="data row0 col3" >59091</td>
#     </tr>
#     <tr>
#       <td id="T_d2ec1_row1_col0" class="data row1 col0" >Burger +</td>
#       <td id="T_d2ec1_row1_col1" class="data row1 col1" >Sunter</td>
#       <td id="T_d2ec1_row1_col2" class="data row1 col2" >Special Bacon & Egg Burger</td>
# ...

# %%
#below IDR 50000
burger_price = sqldf("""SELECT partlor_name, district, unique_menu, price 
                        FROM burger 
                        WHERE price <= 50000""")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_bc5cf_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bc5cf_row0_col0" class="data row0 col0" >Burger King Pantai Indah Kapuk</td>
#       <td id="T_bc5cf_row0_col1" class="data row0 col1" >Pantai Indah Kapuk</td>
#       <td id="T_bc5cf_row0_col2" class="data row0 col2" >Cheese Burger</td>
#       <td id="T_bc5cf_row0_col3" class="data row0 col3" >25000</td>
#     </tr>
#     <tr>
#       <td id="T_bc5cf_row1_col0" class="data row1 col0" >Burger King Mall Kelapa Gading</td>
#       <td id="T_bc5cf_row1_col1" class="data row1 col1" >Kelapa Gading</td>
#       <td id="T_bc5cf_row1_col2" class="data row1 col2" >Cheese Burger</td>
# ...

# %% [markdown]
# # Facility
#
# Last but not least, we chose the restaurant whether we could takeaway, or deliver our food. We also could find out whether these partlor has outdoor seats, smoking room, wifi, and reservation. Last but not least, we researched about poultry with some dietary restriction like alcohol and halal_menu. But this halal menu will not available in other project. We changed to other_poultry instead.
#
# Like other city in Jakarta, almost all of them has takeaway and delivery options except for Burger+, Flip Burger Kelapa Gading, Six Ounces Coffee, and Pig Hunter which only got their takeaway. Almost none of them got their outdoor seat but Lemoe Burger and Six Ounces Coffee, but for smoking area almost all of them has those except for Burger King, Lemoe Burger, and Burger+. Only Burger King Pantai Indah Kapuk which has both of them.
#
# For dietary restriction, there are two vendors provided alcohol which are Five Monkeys and Pig Hunter. Also for halality only Six Ounces Coffee and Pig Hunter which has pork menu.
#
# No reservation needed (except Six Ounces Coffee and Pig Hunter), also no drive thru options available.
#
# Let's take a look for all the facility.

# %%
burger = sqldf("""SELECT no, partlor_name, district, takeaway, delivery, outdoor_seat, smoking_area,
                         alcohol_served, wifi, reservation, drive_thru, halal_food FROM burger""")
burger.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_09a42_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >no</th>
#       <th class="col_heading level0 col1" >partlor_name</th>
#       <th class="col_heading level0 col2" >District</th>
#       <th class="col_heading level0 col3" >takeaway</th>
#       <th class="col_heading level0 col4" >delivery</th>
#       <th class="col_heading level0 col5" >outdoor_seat</th>
#       <th class="col_heading level0 col6" >smoking_area</th>
#       <th class="col_heading level0 col7" >alcohol_served</th>
#       <th class="col_heading level0 col8" >wifi</th>
#       <th class="col_heading level0 col9" >reservation</th>
#       <th class="col_heading level0 col10" >drive_thru</th>
#       <th class="col_heading level0 col11" >halal_food</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_09a42_row0_col0" class="data row0 col0" >1</td>
# ...

# %% [markdown]
# # Rating
#
# Here is the highest rating available in the list, Five Monkeys is the top which scored 4.3, followed by Six Ounces Coffee scored 4.2 and Pig Hunter scored 4.2. If the score is more than 3.5 then the partlor is worthed to try. All the facility and menu are representated by all both google and platform rating and count, so in the meantime only ratings are counted here.

# %%
burger = sqldf("""SELECT partlor_name, district, 
                         ltrim(google_rating) as google_rating, 
                         ltrim(zomato_rating) as zomato_rating, 
                         ltrim(qraved_rating) as qraved_rating, 
                         ltrim((google_rating + zomato_rating + qraved_rating)/3) as total_rating,
                    CASE
                        WHEN ltrim((google_rating + zomato_rating + qraved_rating)/3) >= 3.5 THEN "Recommended"
                        ELSE "Reconsider"
                    END AS "Recommendation"
                    FROM burger
                    ORDER BY total_rating DESC""")
burger.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_aeb5c_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >google_rating</th>
#       <th class="col_heading level0 col3" >zomato_rating</th>
#       <th class="col_heading level0 col4" >qraved_rating</th>
#       <th class="col_heading level0 col5" >total_rating</th>
#       <th class="col_heading level0 col6" >Recommendation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_aeb5c_row0_col0" class="data row0 col0" >Five Monkeys </td>
#       <td id="T_aeb5c_row0_col1" class="data row0 col1" >Sunter</td>
#       <td id="T_aeb5c_row0_col2" class="data row0 col2" >4.6</td>
#       <td id="T_aeb5c_row0_col3" class="data row0 col3" >4.0</td>
#       <td id="T_aeb5c_row0_col4" class="data row0 col4" >4.4</td>
# ...
