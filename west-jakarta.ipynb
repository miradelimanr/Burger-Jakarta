# %% [markdown]
# # **West Jakarta**
#
# West Jakarta is the modest city with the mix of culture and history. Despite this, the burger here is also worth to try and almost the same with East Jakarta area, dominated by fast food. Most known districts is Tanjung Duren where Central Park, one of the famous shopping center is located. Other districts available are Cengkareng, Grogol, Meruya and Puri Indah.
#
# # Content
# * District
# * Price Range
# * Facility
# * Rating

# %%
import pandas as pd
from pandasql import sqldf
burger = pd.read_csv('../input/west-jakarta-burger/west_jakarta.csv', sep = ";")

# %% [markdown]
# # District

# %%
partlor_name = sqldf("SELECT DISTINCT district FROM burger").transpose()
partlor_name
# Out:
#                    0              1       2       3            4           5
# District  Cengkareng  Tanjung Duren  Grogol  Meruya  Kebon Jeruk  Puri Indah

# %%
burger = sqldf("SELECT no, partlor_name, District, unique_menu, price FROM burger")
burger.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_12e73_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >no</th>
#       <th class="col_heading level0 col1" >partlor_name</th>
#       <th class="col_heading level0 col2" >District</th>
#       <th class="col_heading level0 col3" >unique_menu</th>
#       <th class="col_heading level0 col4" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_12e73_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_12e73_row0_col1" class="data row0 col1" >Burger King Cengkareng</td>
#       <td id="T_12e73_row0_col2" class="data row0 col2" >Cengkareng</td>
#       <td id="T_12e73_row0_col3" class="data row0 col3" >Extra King 1</td>
#       <td id="T_12e73_row0_col4" class="data row0 col4" >52000</td>
#     </tr>
#     <tr>
#       <td id="T_12e73_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_12e73_row1_col1" class="data row1 col1" >Burger King Green Sedayu Mall</td>
#       <td id="T_12e73_row1_col2" class="data row1 col2" >Cengkareng</td>
#       <td id="T_12e73_row1_col3" class="data row1 col3" >Extra King 1</td>
#       <td id="T_12e73_row1_col4" class="data row1 col4" >52000</td>
#     </tr>
#     <tr>
#       <td id="T_12e73_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_12e73_row2_col1" class="data row2 col1" >Burger King Central Park</td>
#       <td id="T_12e73_row2_col2" class="data row2 col2" >Tanjung Duren</td>
#       <td id="T_12e73_row2_col3" class="data row2 col3" >Chicken Steakhouse BBQ</td>
#       <td id="T_12e73_row2_col4" class="data row2 col4" >59091</td>
#     </tr>
#     <tr>
#       <td id="T_12e73_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_12e73_row3_col1" class="data row3 col1" >Burger King Mall Ciputra</td>
#       <td id="T_12e73_row3_col2" class="data row3 col2" >Grogol</td>
#       <td id="T_12e73_row3_col3" class="data row3 col3" >Double Whooper</td>
#       <td id="T_12e73_row3_col4" class="data row3 col4" >69091</td>
#     </tr>
#     <tr>
#       <td id="T_12e73_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_12e73_row4_col1" class="data row4 col1" >Burger King Mall Taman Anggrek</td>
#       <td id="T_12e73_row4_col2" class="data row4 col2" >Tanjung Duren</td>
#       <td id="T_12e73_row4_col3" class="data row4 col3" >Chicken Tenderstrip</td>
#       <td id="T_12e73_row4_col4" class="data row4 col4" >42727</td>
#     </tr>
#     <tr>
#       <td id="T_12e73_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_12e73_row5_col1" class="data row5 col1" >Flip Burger Meruya</td>
#       <td id="T_12e73_row5_col2" class="data row5 col2" >Meruya</td>
#       <td id="T_12e73_row5_col3" class="data row5 col3" >Cheese Burger</td>
#       <td id="T_12e73_row5_col4" class="data row5 col4" >30000</td>
#     </tr>
#     <tr>
#       <td id="T_12e73_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_12e73_row6_col1" class="data row6 col1" >Flip Burger Kebon Jeruk</td>
#       <td id="T_12e73_row6_col2" class="data row6 col2" >Kebon Jeruk</td>
#       <td id="T_12e73_row6_col3" class="data row6 col3" >Brisket Cheese Burger</td>
#       <td id="T_12e73_row6_col4" class="data row6 col4" >28182</td>
#     </tr>
#     <tr>
#       <td id="T_12e73_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_12e73_row7_col1" class="data row7 col1" >Carl's Jr. Lippo Mall Puri</td>
#       <td id="T_12e73_row7_col2" class="data row7 col2" >Puri Indah</td>
#       <td id="T_12e73_row7_col3" class="data row7 col3" >Western Beefbac Cheeseburger</td>
#       <td id="T_12e73_row7_col4" class="data row7 col4" >69901</td>
#     </tr>
#     <tr>
#       <td id="T_12e73_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_12e73_row8_col1" class="data row8 col1" >TGI Fridays Central Park</td>
#       <td id="T_12e73_row8_col2" class="data row8 col2" >Tanjung Duren</td>
#       <td id="T_12e73_row8_col3" class="data row8 col3" >Fridays Cheeseburgers</td>
#       <td id="T_12e73_row8_col4" class="data row8 col4" >129000</td>
#     </tr>
#     <tr>
#       <td id="T_12e73_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_12e73_row9_col1" class="data row9 col1" >Carl's Jr. Central Park</td>
#       <td id="T_12e73_row9_col2" class="data row9 col2" >Tanjung Duren</td>
#       <td id="T_12e73_row9_col3" class="data row9 col3" >Super Star Cheese</td>
#       <td id="T_12e73_row9_col4" class="data row9 col4" >79900</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Price-Range
#
# We sorted the list from the most expensive and also the cheapest, also with the price range from IDR 50000 to 100000. Here is the order from the most expensive.
#
# The most expensive one is TGI Fridays Central Park which priced for at least 120K. Most fast food available are Burger King and Carl's Jr.

# %%
#most expensive
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price FROM burger ORDER BY price DESC")
burger_price.head().style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_02441_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_02441_row0_col0" class="data row0 col0" >TGI Fridays Central Park</td>
#       <td id="T_02441_row0_col1" class="data row0 col1" >Tanjung Duren</td>
#       <td id="T_02441_row0_col2" class="data row0 col2" >Fridays Cheeseburgers</td>
#       <td id="T_02441_row0_col3" class="data row0 col3" >129000</td>
#     </tr>
#     <tr>
#       <td id="T_02441_row1_col0" class="data row1 col0" >Carl's Jr. Central Park</td>
#       <td id="T_02441_row1_col1" class="data row1 col1" >Tanjung Duren</td>
#       <td id="T_02441_row1_col2" class="data row1 col2" >Super Star Cheese</td>
#       <td id="T_02441_row1_col3" class="data row1 col3" >79900</td>
#     </tr>
#     <tr>
#       <td id="T_02441_row2_col0" class="data row2 col0" >Carl's Jr. Lippo Mall Puri</td>
#       <td id="T_02441_row2_col1" class="data row2 col1" >Puri Indah</td>
#       <td id="T_02441_row2_col2" class="data row2 col2" >Western Beefbac Cheeseburger</td>
#       <td id="T_02441_row2_col3" class="data row2 col3" >69901</td>
#     </tr>
#     <tr>
#       <td id="T_02441_row3_col0" class="data row3 col0" >Burger King Mall Ciputra</td>
#       <td id="T_02441_row3_col1" class="data row3 col1" >Grogol</td>
#       <td id="T_02441_row3_col2" class="data row3 col2" >Double Whooper</td>
#       <td id="T_02441_row3_col3" class="data row3 col3" >69091</td>
#     </tr>
#     <tr>
#       <td id="T_02441_row4_col0" class="data row4 col0" >Burger King Central Park</td>
#       <td id="T_02441_row4_col1" class="data row4 col1" >Tanjung Duren</td>
#       <td id="T_02441_row4_col2" class="data row4 col2" >Chicken Steakhouse BBQ</td>
#       <td id="T_02441_row4_col3" class="data row4 col3" >59091</td>
#     </tr>
#   </tbody>
# </table>

# %%
#cheapest
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price FROM burger ORDER BY price")
burger_price.head().style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_f2bb5_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f2bb5_row0_col0" class="data row0 col0" >Flip Burger Kebon Jeruk</td>
#       <td id="T_f2bb5_row0_col1" class="data row0 col1" >Kebon Jeruk</td>
#       <td id="T_f2bb5_row0_col2" class="data row0 col2" >Brisket Cheese Burger</td>
#       <td id="T_f2bb5_row0_col3" class="data row0 col3" >28182</td>
#     </tr>
#     <tr>
#       <td id="T_f2bb5_row1_col0" class="data row1 col0" >Flip Burger Meruya</td>
#       <td id="T_f2bb5_row1_col1" class="data row1 col1" >Meruya</td>
#       <td id="T_f2bb5_row1_col2" class="data row1 col2" >Cheese Burger</td>
#       <td id="T_f2bb5_row1_col3" class="data row1 col3" >30000</td>
#     </tr>
#     <tr>
#       <td id="T_f2bb5_row2_col0" class="data row2 col0" >Burger King Mall Taman Anggrek</td>
#       <td id="T_f2bb5_row2_col1" class="data row2 col1" >Tanjung Duren</td>
#       <td id="T_f2bb5_row2_col2" class="data row2 col2" >Chicken Tenderstrip</td>
#       <td id="T_f2bb5_row2_col3" class="data row2 col3" >42727</td>
#     </tr>
#     <tr>
#       <td id="T_f2bb5_row3_col0" class="data row3 col0" >Burger King Cengkareng</td>
#       <td id="T_f2bb5_row3_col1" class="data row3 col1" >Cengkareng</td>
#       <td id="T_f2bb5_row3_col2" class="data row3 col2" >Extra King 1</td>
#       <td id="T_f2bb5_row3_col3" class="data row3 col3" >52000</td>
#     </tr>
#     <tr>
#       <td id="T_f2bb5_row4_col0" class="data row4 col0" >Burger King Green Sedayu Mall</td>
#       <td id="T_f2bb5_row4_col1" class="data row4 col1" >Cengkareng</td>
#       <td id="T_f2bb5_row4_col2" class="data row4 col2" >Extra King 1</td>
#       <td id="T_f2bb5_row4_col3" class="data row4 col3" >52000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#more than IDR 100000
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price FROM burger WHERE price >= 100000")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_2eaa6_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2eaa6_row0_col0" class="data row0 col0" >TGI Fridays Central Park</td>
#       <td id="T_2eaa6_row0_col1" class="data row0 col1" >Tanjung Duren</td>
#       <td id="T_2eaa6_row0_col2" class="data row0 col2" >Fridays Cheeseburgers</td>
#       <td id="T_2eaa6_row0_col3" class="data row0 col3" >129000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#between 50000 to 100000
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price FROM burger WHERE price BETWEEN 50000 AND 100000")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_0c6f6_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0c6f6_row0_col0" class="data row0 col0" >Burger King Cengkareng</td>
#       <td id="T_0c6f6_row0_col1" class="data row0 col1" >Cengkareng</td>
#       <td id="T_0c6f6_row0_col2" class="data row0 col2" >Extra King 1</td>
#       <td id="T_0c6f6_row0_col3" class="data row0 col3" >52000</td>
#     </tr>
#     <tr>
#       <td id="T_0c6f6_row1_col0" class="data row1 col0" >Burger King Green Sedayu Mall</td>
#       <td id="T_0c6f6_row1_col1" class="data row1 col1" >Cengkareng</td>
#       <td id="T_0c6f6_row1_col2" class="data row1 col2" >Extra King 1</td>
#       <td id="T_0c6f6_row1_col3" class="data row1 col3" >52000</td>
#     </tr>
#     <tr>
#       <td id="T_0c6f6_row2_col0" class="data row2 col0" >Burger King Central Park</td>
#       <td id="T_0c6f6_row2_col1" class="data row2 col1" >Tanjung Duren</td>
#       <td id="T_0c6f6_row2_col2" class="data row2 col2" >Chicken Steakhouse BBQ</td>
#       <td id="T_0c6f6_row2_col3" class="data row2 col3" >59091</td>
#     </tr>
#     <tr>
#       <td id="T_0c6f6_row3_col0" class="data row3 col0" >Burger King Mall Ciputra</td>
#       <td id="T_0c6f6_row3_col1" class="data row3 col1" >Grogol</td>
#       <td id="T_0c6f6_row3_col2" class="data row3 col2" >Double Whooper</td>
#       <td id="T_0c6f6_row3_col3" class="data row3 col3" >69091</td>
#     </tr>
#     <tr>
#       <td id="T_0c6f6_row4_col0" class="data row4 col0" >Carl's Jr. Lippo Mall Puri</td>
#       <td id="T_0c6f6_row4_col1" class="data row4 col1" >Puri Indah</td>
#       <td id="T_0c6f6_row4_col2" class="data row4 col2" >Western Beefbac Cheeseburger</td>
#       <td id="T_0c6f6_row4_col3" class="data row4 col3" >69901</td>
#     </tr>
#     <tr>
#       <td id="T_0c6f6_row5_col0" class="data row5 col0" >Carl's Jr. Central Park</td>
#       <td id="T_0c6f6_row5_col1" class="data row5 col1" >Tanjung Duren</td>
#       <td id="T_0c6f6_row5_col2" class="data row5 col2" >Super Star Cheese</td>
#       <td id="T_0c6f6_row5_col3" class="data row5 col3" >79900</td>
#     </tr>
#   </tbody>
# </table>

# %%
#below IDR 100000
burger_price = sqldf("SELECT partlor_name, district, unique_menu, price FROM burger WHERE price <= 50000")
burger_price.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_3334f_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3334f_row0_col0" class="data row0 col0" >Burger King Mall Taman Anggrek</td>
#       <td id="T_3334f_row0_col1" class="data row0 col1" >Tanjung Duren</td>
#       <td id="T_3334f_row0_col2" class="data row0 col2" >Chicken Tenderstrip</td>
#       <td id="T_3334f_row0_col3" class="data row0 col3" >42727</td>
#     </tr>
#     <tr>
#       <td id="T_3334f_row1_col0" class="data row1 col0" >Flip Burger Meruya</td>
#       <td id="T_3334f_row1_col1" class="data row1 col1" >Meruya</td>
#       <td id="T_3334f_row1_col2" class="data row1 col2" >Cheese Burger</td>
#       <td id="T_3334f_row1_col3" class="data row1 col3" >30000</td>
#     </tr>
#     <tr>
#       <td id="T_3334f_row2_col0" class="data row2 col0" >Flip Burger Kebon Jeruk</td>
#       <td id="T_3334f_row2_col1" class="data row2 col1" >Kebon Jeruk</td>
#       <td id="T_3334f_row2_col2" class="data row2 col2" >Brisket Cheese Burger</td>
#       <td id="T_3334f_row2_col3" class="data row2 col3" >28182</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Facility
#
# Last but not least, we chose the restaurant whether we could takeaway, or deliver our food. We also could find out whether these partlor has outdoor seats, smoking room, wifi, and reservation. Last but not least, we researched about poultry with some dietary restriction like alcohol and halal_menu. But this halal menu will not available in other project. We changed to other_poultry instead.
#
# All can do takeaway and delivery except for TGI Fridays which has takeaway options only. Most of them doesn't have outdoor seat and smoking area except for Burger King Mall Taman Anggrek which got their smoking area. TGI Fridays got both their outdoor seat and smoking area.
#
# For wifi options, almost all restaurant/partlors here got their wifi except all Flip Burger outlet and Carl's Jr. Central Park area. And more importantly, almost all vendor has not got their restrictions dietary as they got no alcohol menu (except for TGI Fridays) and the food is allowed to eat.
#
# No reservation needed except for TGI Fridays, again.
#
# Let's take a look for all of these facility.

# %%
burger = sqldf("""SELECT no, partlor_name, district, takeaway, delivery, outdoor_seat, smoking_area,
alcohol_served, wifi, reservation, drive_thru, halal_food FROM burger""")
burger.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_42cd5_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >no</th>
#       <th class="col_heading level0 col1" >partlor_name</th>
#       <th class="col_heading level0 col2" >District</th>
#       <th class="col_heading level0 col3" >takeaway</th>
#       <th class="col_heading level0 col4" >delivery</th>
#       <th class="col_heading level0 col5" >outdoor_seat</th>
#       <th class="col_heading level0 col6" >smoking_area</th>
#       <th class="col_heading level0 col7" >alcohol_served</th>
#       <th class="col_heading level0 col8" >wifi</th>
#       <th class="col_heading level0 col9" >reservation</th>
#       <th class="col_heading level0 col10" >drive_thru</th>
#       <th class="col_heading level0 col11" >halal_food</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_42cd5_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_42cd5_row0_col1" class="data row0 col1" >Burger King Cengkareng</td>
#       <td id="T_42cd5_row0_col2" class="data row0 col2" >Cengkareng</td>
#       <td id="T_42cd5_row0_col3" class="data row0 col3" >yes</td>
#       <td id="T_42cd5_row0_col4" class="data row0 col4" >yes</td>
#       <td id="T_42cd5_row0_col5" class="data row0 col5" >no</td>
#       <td id="T_42cd5_row0_col6" class="data row0 col6" >no</td>
#       <td id="T_42cd5_row0_col7" class="data row0 col7" >no</td>
#       <td id="T_42cd5_row0_col8" class="data row0 col8" >yes</td>
#       <td id="T_42cd5_row0_col9" class="data row0 col9" >no</td>
#       <td id="T_42cd5_row0_col10" class="data row0 col10" >no</td>
#       <td id="T_42cd5_row0_col11" class="data row0 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_42cd5_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_42cd5_row1_col1" class="data row1 col1" >Burger King Green Sedayu Mall</td>
#       <td id="T_42cd5_row1_col2" class="data row1 col2" >Cengkareng</td>
#       <td id="T_42cd5_row1_col3" class="data row1 col3" >yes</td>
#       <td id="T_42cd5_row1_col4" class="data row1 col4" >yes</td>
#       <td id="T_42cd5_row1_col5" class="data row1 col5" >no</td>
#       <td id="T_42cd5_row1_col6" class="data row1 col6" >no</td>
#       <td id="T_42cd5_row1_col7" class="data row1 col7" >no</td>
#       <td id="T_42cd5_row1_col8" class="data row1 col8" >yes</td>
#       <td id="T_42cd5_row1_col9" class="data row1 col9" >no</td>
#       <td id="T_42cd5_row1_col10" class="data row1 col10" >no</td>
#       <td id="T_42cd5_row1_col11" class="data row1 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_42cd5_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_42cd5_row2_col1" class="data row2 col1" >Burger King Central Park</td>
#       <td id="T_42cd5_row2_col2" class="data row2 col2" >Tanjung Duren</td>
#       <td id="T_42cd5_row2_col3" class="data row2 col3" >yes</td>
#       <td id="T_42cd5_row2_col4" class="data row2 col4" >yes</td>
#       <td id="T_42cd5_row2_col5" class="data row2 col5" >no</td>
#       <td id="T_42cd5_row2_col6" class="data row2 col6" >no</td>
#       <td id="T_42cd5_row2_col7" class="data row2 col7" >no</td>
#       <td id="T_42cd5_row2_col8" class="data row2 col8" >yes</td>
#       <td id="T_42cd5_row2_col9" class="data row2 col9" >no</td>
#       <td id="T_42cd5_row2_col10" class="data row2 col10" >no</td>
#       <td id="T_42cd5_row2_col11" class="data row2 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_42cd5_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_42cd5_row3_col1" class="data row3 col1" >Burger King Mall Ciputra</td>
#       <td id="T_42cd5_row3_col2" class="data row3 col2" >Grogol</td>
#       <td id="T_42cd5_row3_col3" class="data row3 col3" >yes</td>
#       <td id="T_42cd5_row3_col4" class="data row3 col4" >yes</td>
#       <td id="T_42cd5_row3_col5" class="data row3 col5" >no</td>
#       <td id="T_42cd5_row3_col6" class="data row3 col6" >no</td>
#       <td id="T_42cd5_row3_col7" class="data row3 col7" >no</td>
#       <td id="T_42cd5_row3_col8" class="data row3 col8" >yes</td>
#       <td id="T_42cd5_row3_col9" class="data row3 col9" >no</td>
#       <td id="T_42cd5_row3_col10" class="data row3 col10" >no</td>
#       <td id="T_42cd5_row3_col11" class="data row3 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_42cd5_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_42cd5_row4_col1" class="data row4 col1" >Burger King Mall Taman Anggrek</td>
#       <td id="T_42cd5_row4_col2" class="data row4 col2" >Tanjung Duren</td>
#       <td id="T_42cd5_row4_col3" class="data row4 col3" >yes</td>
#       <td id="T_42cd5_row4_col4" class="data row4 col4" >yes</td>
#       <td id="T_42cd5_row4_col5" class="data row4 col5" >no</td>
#       <td id="T_42cd5_row4_col6" class="data row4 col6" >yes</td>
#       <td id="T_42cd5_row4_col7" class="data row4 col7" >no</td>
#       <td id="T_42cd5_row4_col8" class="data row4 col8" >yes</td>
#       <td id="T_42cd5_row4_col9" class="data row4 col9" >no</td>
#       <td id="T_42cd5_row4_col10" class="data row4 col10" >no</td>
#       <td id="T_42cd5_row4_col11" class="data row4 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_42cd5_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_42cd5_row5_col1" class="data row5 col1" >Flip Burger Meruya</td>
#       <td id="T_42cd5_row5_col2" class="data row5 col2" >Meruya</td>
#       <td id="T_42cd5_row5_col3" class="data row5 col3" >yes</td>
#       <td id="T_42cd5_row5_col4" class="data row5 col4" >yes</td>
#       <td id="T_42cd5_row5_col5" class="data row5 col5" >no</td>
#       <td id="T_42cd5_row5_col6" class="data row5 col6" >no</td>
#       <td id="T_42cd5_row5_col7" class="data row5 col7" >no</td>
#       <td id="T_42cd5_row5_col8" class="data row5 col8" >no</td>
#       <td id="T_42cd5_row5_col9" class="data row5 col9" >no</td>
#       <td id="T_42cd5_row5_col10" class="data row5 col10" >no</td>
#       <td id="T_42cd5_row5_col11" class="data row5 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_42cd5_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_42cd5_row6_col1" class="data row6 col1" >Flip Burger Kebon Jeruk</td>
#       <td id="T_42cd5_row6_col2" class="data row6 col2" >Kebon Jeruk</td>
#       <td id="T_42cd5_row6_col3" class="data row6 col3" >yes</td>
#       <td id="T_42cd5_row6_col4" class="data row6 col4" >yes</td>
#       <td id="T_42cd5_row6_col5" class="data row6 col5" >no</td>
#       <td id="T_42cd5_row6_col6" class="data row6 col6" >no</td>
#       <td id="T_42cd5_row6_col7" class="data row6 col7" >no</td>
#       <td id="T_42cd5_row6_col8" class="data row6 col8" >no</td>
#       <td id="T_42cd5_row6_col9" class="data row6 col9" >no</td>
#       <td id="T_42cd5_row6_col10" class="data row6 col10" >no</td>
#       <td id="T_42cd5_row6_col11" class="data row6 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_42cd5_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_42cd5_row7_col1" class="data row7 col1" >Carl's Jr. Lippo Mall Puri</td>
#       <td id="T_42cd5_row7_col2" class="data row7 col2" >Puri Indah</td>
#       <td id="T_42cd5_row7_col3" class="data row7 col3" >yes</td>
#       <td id="T_42cd5_row7_col4" class="data row7 col4" >yes</td>
#       <td id="T_42cd5_row7_col5" class="data row7 col5" >no</td>
#       <td id="T_42cd5_row7_col6" class="data row7 col6" >no</td>
#       <td id="T_42cd5_row7_col7" class="data row7 col7" >no</td>
#       <td id="T_42cd5_row7_col8" class="data row7 col8" >yes</td>
#       <td id="T_42cd5_row7_col9" class="data row7 col9" >no</td>
#       <td id="T_42cd5_row7_col10" class="data row7 col10" >no</td>
#       <td id="T_42cd5_row7_col11" class="data row7 col11" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_42cd5_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_42cd5_row8_col1" class="data row8 col1" >TGI Fridays Central Park</td>
#       <td id="T_42cd5_row8_col2" class="data row8 col2" >Tanjung Duren</td>
#       <td id="T_42cd5_row8_col3" class="data row8 col3" >yes</td>
#       <td id="T_42cd5_row8_col4" class="data row8 col4" >no</td>
#       <td id="T_42cd5_row8_col5" class="data row8 col5" >yes</td>
#       <td id="T_42cd5_row8_col6" class="data row8 col6" >yes</td>

# %% [markdown]
# # Rating
#
# I'll calculate and decide separately which are recommended on the other file but here is the glimpse. We can see which vendor has the highest rating available. For this time I order this list by google_rating as it appeared first.

# %%
burger = sqldf("""SELECT partlor_name, district, ltrim(google_rating) as google_rating, ltrim(zomato_rating) as zomato_rating, ltrim(qraved_rating) as qraved_rating, 
ltrim((google_rating + zomato_rating + qraved_rating)/3, 1) as total_rating,
CASE
    WHEN ltrim((google_rating + zomato_rating + qraved_rating)/3,1) >= 3.5 THEN "Recommended"
    ELSE "Reconsider"
END AS "Recommendation"
FROM burger
ORDER BY total_rating DESC""")
burger.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_f9408_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >partlor_name</th>
#       <th class="col_heading level0 col1" >District</th>
#       <th class="col_heading level0 col2" >google_rating</th>
#       <th class="col_heading level0 col3" >zomato_rating</th>
#       <th class="col_heading level0 col4" >qraved_rating</th>
#       <th class="col_heading level0 col5" >total_rating</th>
#       <th class="col_heading level0 col6" >Recommendation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f9408_row0_col0" class="data row0 col0" >Carl's Jr. Central Park</td>
#       <td id="T_f9408_row0_col1" class="data row0 col1" >Tanjung Duren</td>
#       <td id="T_f9408_row0_col2" class="data row0 col2" >4.4</td>
#       <td id="T_f9408_row0_col3" class="data row0 col3" >4.3</td>
#       <td id="T_f9408_row0_col4" class="data row0 col4" >4.3</td>
#       <td id="T_f9408_row0_col5" class="data row0 col5" >4.33333333333333</td>
#       <td id="T_f9408_row0_col6" class="data row0 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f9408_row1_col0" class="data row1 col0" >Carl's Jr. Lippo Mall Puri</td>
#       <td id="T_f9408_row1_col1" class="data row1 col1" >Puri Indah</td>
#       <td id="T_f9408_row1_col2" class="data row1 col2" >4.5</td>
#       <td id="T_f9408_row1_col3" class="data row1 col3" >4.0</td>
#       <td id="T_f9408_row1_col4" class="data row1 col4" >4.4</td>
#       <td id="T_f9408_row1_col5" class="data row1 col5" >4.3</td>
#       <td id="T_f9408_row1_col6" class="data row1 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f9408_row2_col0" class="data row2 col0" >Flip Burger Kebon Jeruk</td>
#       <td id="T_f9408_row2_col1" class="data row2 col1" >Kebon Jeruk</td>
#       <td id="T_f9408_row2_col2" class="data row2 col2" >4.3</td>
#       <td id="T_f9408_row2_col3" class="data row2 col3" >4.0</td>
#       <td id="T_f9408_row2_col4" class="data row2 col4" >4.0</td>
#       <td id="T_f9408_row2_col5" class="data row2 col5" >4.1</td>
#       <td id="T_f9408_row2_col6" class="data row2 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f9408_row3_col0" class="data row3 col0" >TGI Fridays Central Park</td>
#       <td id="T_f9408_row3_col1" class="data row3 col1" >Tanjung Duren</td>
#       <td id="T_f9408_row3_col2" class="data row3 col2" >4.3</td>
#       <td id="T_f9408_row3_col3" class="data row3 col3" >4.0</td>
#       <td id="T_f9408_row3_col4" class="data row3 col4" >3.9</td>
#       <td id="T_f9408_row3_col5" class="data row3 col5" >4.06666666666667</td>
#       <td id="T_f9408_row3_col6" class="data row3 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f9408_row4_col0" class="data row4 col0" >Burger King Mall Ciputra</td>
#       <td id="T_f9408_row4_col1" class="data row4 col1" >Grogol</td>
#       <td id="T_f9408_row4_col2" class="data row4 col2" >4.5</td>
#       <td id="T_f9408_row4_col3" class="data row4 col3" >3.5</td>
#       <td id="T_f9408_row4_col4" class="data row4 col4" >4.0</td>
#       <td id="T_f9408_row4_col5" class="data row4 col5" >4.0</td>
#       <td id="T_f9408_row4_col6" class="data row4 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f9408_row5_col0" class="data row5 col0" >Burger King Central Park</td>
#       <td id="T_f9408_row5_col1" class="data row5 col1" >Tanjung Duren</td>
#       <td id="T_f9408_row5_col2" class="data row5 col2" >4.4</td>
#       <td id="T_f9408_row5_col3" class="data row5 col3" >3.6</td>
#       <td id="T_f9408_row5_col4" class="data row5 col4" >3.5</td>
#       <td id="T_f9408_row5_col5" class="data row5 col5" >3.83333333333333</td>
#       <td id="T_f9408_row5_col6" class="data row5 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f9408_row6_col0" class="data row6 col0" >Burger King Cengkareng</td>
#       <td id="T_f9408_row6_col1" class="data row6 col1" >Cengkareng</td>
#       <td id="T_f9408_row6_col2" class="data row6 col2" >4.5</td>
#       <td id="T_f9408_row6_col3" class="data row6 col3" >2.9</td>
#       <td id="T_f9408_row6_col4" class="data row6 col4" >4.0</td>
#       <td id="T_f9408_row6_col5" class="data row6 col5" >3.8</td>
#       <td id="T_f9408_row6_col6" class="data row6 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f9408_row7_col0" class="data row7 col0" >Burger King Green Sedayu Mall</td>
#       <td id="T_f9408_row7_col1" class="data row7 col1" >Cengkareng</td>
#       <td id="T_f9408_row7_col2" class="data row7 col2" >4.2</td>
#       <td id="T_f9408_row7_col3" class="data row7 col3" >0.0</td>
#       <td id="T_f9408_row7_col4" class="data row7 col4" >4.0</td>
#       <td id="T_f9408_row7_col5" class="data row7 col5" >2.73333333333333</td>
#       <td id="T_f9408_row7_col6" class="data row7 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f9408_row8_col0" class="data row8 col0" >Flip Burger Meruya</td>
#       <td id="T_f9408_row8_col1" class="data row8 col1" >Meruya</td>
#       <td id="T_f9408_row8_col2" class="data row8 col2" >0.0</td>
#       <td id="T_f9408_row8_col3" class="data row8 col3" >0.0</td>
#       <td id="T_f9408_row8_col4" class="data row8 col4" >4.0</td>
#       <td id="T_f9408_row8_col5" class="data row8 col5" >.33333333333333</td>
#       <td id="T_f9408_row8_col6" class="data row8 col6" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f9408_row9_col0" class="data row9 col0" >Burger King Mall Taman Anggrek</td>
#       <td id="T_f9408_row9_col1" class="data row9 col1" >Tanjung Duren</td>
#       <td id="T_f9408_row9_col2" class="data row9 col2" >0.0</td>
#       <td id="T_f9408_row9_col3" class="data row9 col3" >3.2</td>
#       <td id="T_f9408_row9_col4" class="data row9 col4" >0.0</td>
#       <td id="T_f9408_row9_col5" class="data row9 col5" >.06666666666667</td>
#       <td id="T_f9408_row9_col6" class="data row9 col6" >Recommended</td>
#     </tr>
#   </tbody>
# </table>
