# %% [markdown]
# <a href="https://www.kaggle.com/code/miradelimanr/singaporean-food-in-indonesia-i-sql-version?scriptVersionId=98395209" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Singaporean Food in Indonesia Phrase I : Greater Jakarta Area
#
# Singaporean Food in Indonesia is a project inspired by a Singaporean content creator whom looking for Singaporean restaurant in Indonesia. For this notebook I'll show you list of Singaporean restaurant in Jakarta, located in various city like Jakarta itself, Tangerang, Bogor, and Bekasi. Here is the list curated from Google Maps and various platform website. This time I'll be using Zomato for the source.
#
# Originally there are 101 restaurants selected all around Indonesia, which 39 of them are located in Jakarta. Note that the list here is not always the authentic one. There are coffee shop named Kopitiam and Chinese restaurant which has Singaporean food but never claimed themselves as Singaporean restaurant. At least they got kaya toast, hainanse rice, laksa, chili crab and etc, will explain more on menu.
#
# # Content
# * Overview
# * Menu
# * Facility
# * Rating

# %% [markdown]
# ![Tanpa Judul-1-min.png](attachment:2c0210e5-08dd-497f-961e-44f6e6319b53.png)

# %%
from pandasql import sqldf
import pandas as pd
singapore = pd.read_csv("../input/singapore-food/singapore_id.csv", sep = ";")

# %% [markdown]
# # Overview
#
# Here is the list of all restaurants sorted by region and city, there are also their unique menu, price, and ratings. Mostly ranged from 40k until 50k rupiah and ratings mostly more than 4.5. Unique menu selected randomly by myself which represented the restaurant.

# %%
singapore = sqldf("""SELECT no, restaurant_name, region, city, unique_menu, price, 
                            ltrim(google_rating) as google_rating, 
                            ltrim(platform_rating) as platform_rating 
                     FROM singapore 
                     WHERE region = 'DKI Jakarta' OR 
                           city = 'Bekasi' OR 
                           city = 'Tangerang' OR 
                           city = 'Bogor'""")
singapore.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_9c430_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >no</th>
#       <th class="col_heading level0 col1" >restaurant_name</th>
#       <th class="col_heading level0 col2" >region</th>
#       <th class="col_heading level0 col3" >city</th>
#       <th class="col_heading level0 col4" >unique_menu</th>
#       <th class="col_heading level0 col5" >price</th>
#       <th class="col_heading level0 col6" >google_rating</th>
#       <th class="col_heading level0 col7" >platform_rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9c430_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_9c430_row0_col1" class="data row0 col1" >Penang Bistro</td>
#       <td id="T_9c430_row0_col2" class="data row0 col2" >DKI Jakarta</td>
#       <td id="T_9c430_row0_col3" class="data row0 col3" >Central Jakarta</td>
#       <td id="T_9c430_row0_col4" class="data row0 col4" >Singapore Chili Sauce</td>
#       <td id="T_9c430_row0_col5" class="data row0 col5" >55000</td>
#       <td id="T_9c430_row0_col6" class="data row0 col6" >4.5</td>
#       <td id="T_9c430_row0_col7" class="data row0 col7" >4.5</td>
#     </tr>
#     <tr>
#       <td id="T_9c430_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_9c430_row1_col1" class="data row1 col1" >Lau Lim Mee Pok</td>
#       <td id="T_9c430_row1_col2" class="data row1 col2" >DKI Jakarta</td>
#       <td id="T_9c430_row1_col3" class="data row1 col3" >North Jakarta</td>
#       <td id="T_9c430_row1_col4" class="data row1 col4" >Mee Pok Dry Small</td>
#       <td id="T_9c430_row1_col5" class="data row1 col5" >45000</td>
#       <td id="T_9c430_row1_col6" class="data row1 col6" >4.4</td>
#       <td id="T_9c430_row1_col7" class="data row1 col7" >4.0</td>
#     </tr>
#     <tr>
#       <td id="T_9c430_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_9c430_row2_col1" class="data row2 col1" >Wancan Golden Plaza</td>
#       <td id="T_9c430_row2_col2" class="data row2 col2" >DKI Jakarta</td>
#       <td id="T_9c430_row2_col3" class="data row2 col3" >South Jakarta</td>
#       <td id="T_9c430_row2_col4" class="data row2 col4" >Poached Chicken Rice Set</td>
#       <td id="T_9c430_row2_col5" class="data row2 col5" >38000</td>
#       <td id="T_9c430_row2_col6" class="data row2 col6" >4.5</td>
#       <td id="T_9c430_row2_col7" class="data row2 col7" >3.8</td>
#     </tr>
#     <tr>
#       <td id="T_9c430_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_9c430_row3_col1" class="data row3 col1" >Salty Sam Mall of Indonesia</td>
#       <td id="T_9c430_row3_col2" class="data row3 col2" >DKI Jakarta</td>
#       <td id="T_9c430_row3_col3" class="data row3 col3" >North Jakarta</td>
#       <td id="T_9c430_row3_col4" class="data row3 col4" >Salted Egg Buttermilk Chicken</td>
#       <td id="T_9c430_row3_col5" class="data row3 col5" >46000</td>
#       <td id="T_9c430_row3_col6" class="data row3 col6" >4.4</td>
#       <td id="T_9c430_row3_col7" class="data row3 col7" >4.2</td>
#     </tr>
#     <tr>
#       <td id="T_9c430_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_9c430_row4_col1" class="data row4 col1" >Singapore Koo Kee Restaurant</td>
#       <td id="T_9c430_row4_col2" class="data row4 col2" >DKI Jakarta</td>
#       <td id="T_9c430_row4_col3" class="data row4 col3" >North Jakarta</td>
#       <td id="T_9c430_row4_col4" class="data row4 col4" >Hotpot Laksa</td>
#       <td id="T_9c430_row4_col5" class="data row4 col5" >65000</td>
#       <td id="T_9c430_row4_col6" class="data row4 col6" >4.3</td>
#       <td id="T_9c430_row4_col7" class="data row4 col7" >4.0</td>
#     </tr>
#     <tr>
#       <td id="T_9c430_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_9c430_row5_col1" class="data row5 col1" >Walao Eh</td>
#       <td id="T_9c430_row5_col2" class="data row5 col2" >Banten</td>
#       <td id="T_9c430_row5_col3" class="data row5 col3" >Tangerang</td>
#       <td id="T_9c430_row5_col4" class="data row5 col4" >Hongkong Duck Noodle</td>
#       <td id="T_9c430_row5_col5" class="data row5 col5" >63500</td>
#       <td id="T_9c430_row5_col6" class="data row5 col6" >4.2</td>
#       <td id="T_9c430_row5_col7" class="data row5 col7" >3.5</td>
#     </tr>
#     <tr>
#       <td id="T_9c430_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_9c430_row6_col1" class="data row6 col1" >Old Chang Kee Gandaria City</td>
#       <td id="T_9c430_row6_col2" class="data row6 col2" >DKI Jakarta</td>
#       <td id="T_9c430_row6_col3" class="data row6 col3" >Central Jakarta</td>
#       <td id="T_9c430_row6_col4" class="data row6 col4" >Singaporean Meatball Selection</td>
#       <td id="T_9c430_row6_col5" class="data row6 col5" >40000</td>
#       <td id="T_9c430_row6_col6" class="data row6 col6" >4.1</td>
#       <td id="T_9c430_row6_col7" class="data row6 col7" >3.8</td>
#     </tr>
#     <tr>
#       <td id="T_9c430_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_9c430_row7_col1" class="data row7 col1" >Ming Fa</td>
#       <td id="T_9c430_row7_col2" class="data row7 col2" >DKI Jakarta</td>
#       <td id="T_9c430_row7_col3" class="data row7 col3" >Central Jakarta</td>
#       <td id="T_9c430_row7_col4" class="data row7 col4" >Regular Bak Chor Mee</td>
#       <td id="T_9c430_row7_col5" class="data row7 col5" >43000</td>
#       <td id="T_9c430_row7_col6" class="data row7 col6" >0.0</td>
#       <td id="T_9c430_row7_col7" class="data row7 col7" >3.9</td>
#     </tr>
#     <tr>
#       <td id="T_9c430_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_9c430_row8_col1" class="data row8 col1" >Ya Kun Kaya Toast Menteng</td>
#       <td id="T_9c430_row8_col2" class="data row8 col2" >DKI Jakarta</td>
#       <td id="T_9c430_row8_col3" class="data row8 col3" >Central Jakarta</td>
#       <td id="T_9c430_row8_col4" class="data row8 col4" >French Thick Toast Kaya Set</td>
#       <td id="T_9c430_row8_col5" class="data row8 col5" >68182</td>
#       <td id="T_9c430_row8_col6" class="data row8 col6" >4.3</td>
#       <td id="T_9c430_row8_col7" class="data row8 col7" >3.6</td>
#     </tr>
#     <tr>
#       <td id="T_9c430_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_9c430_row9_col1" class="data row9 col1" >Toast Box</td>
#       <td id="T_9c430_row9_col2" class="data row9 col2" >DKI Jakarta</td>
#       <td id="T_9c430_row9_col3" class="data row9 col3" >South Jakarta</td>
#       <td id="T_9c430_row9_col4" class="data row9 col4" >Traditional Kaya Butter Multigrain Toast</td>
#       <td id="T_9c430_row9_col5" class="data row9 col5" >32000</td>
#       <td id="T_9c430_row9_col6" class="data row9 col6" >4.4</td>
#       <td id="T_9c430_row9_col7" class="data row9 col7" >3.2</td>
#     </tr>
#     <tr>
#       <td id="T_9c430_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_9c430_row10_col1" class="data row10 col1" >Lotus Mie Udang Singapore</td>
#       <td id="T_9c430_row10_col2" class="data row10 col2" >DKI Jakarta</td>
#       <td id="T_9c430_row10_col3" class="data row10 col3" >North Jakarta</td>
#       <td id="T_9c430_row10_col4" class="data row10 col4" >Mie Udang Singapore Spesial</td>
#       <td id="T_9c430_row10_col5" class="data row10 col5" >None</td>
#       <td id="T_9c430_row10_col6" class="data row10 col6" >4.6</td>
#       <td id="T_9c430_row10_col7" class="data row10 col7" >3.7</td>
#     </tr>
#     <tr>
#       <td id="T_9c430_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_9c430_row11_col1" class="data row11 col1" >Jia Jia Grand Indonesia</td>
#       <td id="T_9c430_row11_col2" class="data row11 col2" >DKI Jakarta</td>
#       <td id="T_9c430_row11_col3" class="data row11 col3" >Central Jakarta</td>
#       <td id="T_9c430_row11_col4" class="data row11 col4" >Chasio Chicken Rice</td>
#       <td id="T_9c430_row11_col5" class="data row11 col5" >36564</td>
#       <td id="T_9c430_row11_col6" class="data row11 col6" >3.5</td>
#       <td id="T_9c430_row11_col7" class="data row11 col7" >3.3</td>
#     </tr>
#     <tr>
#       <td id="T_9c430_row12_col0" class="data row12 col0" >13</td>
#       <td id="T_9c430_row12_col1" class="data row12 col1" >Lay Lay Singapore</td>
#       <td id="T_9c4

# %% [markdown]
# # Menu
#
# Singapore is famous for their Laksa as also most mentioned here in this list. Besides, they are also famous for their toast-- kaya toast especially, and hainanse rice. Their noodles are their most mainstream here as their food is kind of fusion with Chinese cuisine, like mee goreng, wonton noodle, and kway teow. Curry noodle and bakuteh are underrated but that's the real signature here. Not to mention their seafood is also well known-- chili crab for example.
#
# I'll divide those menu on three category, which is Rice & Noodle Menu, Poultry Menu, and Toast & Snack Menu.
#
# **Rice & Noodle**
#
# Here is their rice and noodle menu. For the rice they mostly have hainanse rice, fried rice, and nasi lemak. Plate rice is rice with side dish on a plate-- it could be anything. They also have porridge as well. For noodle they mostly have laksa, mee goreng, curry noodle, and wonton noodle. There are also mee shua, mee siam, ifumie (crispy noodle), chop noodle, hokkien mee, and noodle soup. All the list are representative for each city so for the complete list you need to check the issue.
#
# **Bangi Kopitiam Restaurants** are the most serving rice and noodle menu. **Penang Bistro (Central Jakarta) and Tjap Toean (Tangerang)** has the most various noodle menu, meanwhile **Singaporean Hainanse Chicken Restaurants** and **Jia Jia Grand Indonesia (Central Jakarta)** has the most various rice menu. **Wee Nam Kee Pacific Place (Central Jakarta)** has their fragance rice.
#
# There are several places doesn't serve rice, which are **Old Chang Kee Gandaria City**--only Singaporean style meatball street food, **Xi De Li**-- dessert streetfood only, and **Warung Mie Laksa 828**-- only Laksa noodle for takeaway**. Also there are some places doesn't have noodle on their menu, which are **Wancan Golden Plaza (South Jakarta), Salty Sam Mall of Indonesia (North Jakarta)**--chicken egg ricebowl only, **Old Chang Kee Gandaria City, Xi De Li,** and **Ngohiang Khas Bogor.**
#
# For disambiguation (next time you look for the menu), mee is mie/noodle, fried rice is nasi goreng, kway teow is kwetiaw, beehoon is bihun, and hainanse rice is nasi hainam. Bakmi ayam is quite similar with wonton noodle but it's different after all.

# %%
singapore  = sqldf("""SELECT restaurant_name, city, rice_menu, noodle, noodle_specific
                      FROM singapore
                      WHERE region = 'DKI Jakarta' OR 
                            city = 'Bekasi' OR 
                            city = 'Tangerang' OR 
                            city = 'Bogor'
                      GROUP BY city""")
singapore.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_246d4_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >city</th>
#       <th class="col_heading level0 col2" >rice_menu</th>
#       <th class="col_heading level0 col3" >noodle</th>
#       <th class="col_heading level0 col4" >noodle_specific</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_246d4_row0_col0" class="data row0 col0" >Bubur Singapore</td>
#       <td id="T_246d4_row0_col1" class="data row0 col1" >Bekasi</td>
#       <td id="T_246d4_row0_col2" class="data row0 col2" >fried rice, porridge, rice plate</td>
#       <td id="T_246d4_row0_col3" class="data row0 col3" >no</td>
#       <td id="T_246d4_row0_col4" class="data row0 col4" >no</td>
#     </tr>
#     <tr>
#       <td id="T_246d4_row1_col0" class="data row1 col0" >Warung Mie Laksa 828 Khas Singapore</td>
#       <td id="T_246d4_row1_col1" class="data row1 col1" >Bogor</td>
#       <td id="T_246d4_row1_col2" class="data row1 col2" >no</td>
#       <td id="T_246d4_row1_col3" class="data row1 col3" >noodle</td>
#       <td id="T_246d4_row1_col4" class="data row1 col4" >laksa</td>
#     </tr>
#     <tr>
#       <td id="T_246d4_row2_col0" class="data row2 col0" >Penang Bistro</td>
#       <td id="T_246d4_row2_col1" class="data row2 col1" >Central Jakarta</td>
#       <td id="T_246d4_row2_col2" class="data row2 col2" >hainanse rice, fried rice, lemak</td>
#       <td id="T_246d4_row2_col3" class="data row2 col3" >beehoon, kway teow, noodle</td>
#       <td id="T_246d4_row2_col4" class="data row2 col4" >mee goreng, prawn mee, mee shua, laksa, hokkien mee</td>
#     </tr>
#     <tr>
#       <td id="T_246d4_row3_col0" class="data row3 col0" >Uncle K Cijantung Mall</td>
#       <td id="T_246d4_row3_col1" class="data row3 col1" >East Jakarta</td>
#       <td id="T_246d4_row3_col2" class="data row3 col2" >nasi lemak, fried rice, hainanse rice</td>
#       <td id="T_246d4_row3_col3" class="data row3 col3" >noodle, kway teow, pasta</td>
#       <td id="T_246d4_row3_col4" class="data row3 col4" >laksa, hokkien mie, prawn noodle, mee goreng, mee chor, mie setan, wonton noodle</td>
#     </tr>
#     <tr>
#       <td id="T_246d4_row4_col0" class="data row4 col0" >Lau Lim Mee Pok</td>
#       <td id="T_246d4_row4_col1" class="data row4 col1" >North Jakarta</td>
#       <td id="T_246d4_row4_col2" class="data row4 col2" >fried rice</td>
#       <td id="T_246d4_row4_col3" class="data row4 col3" >kway teow, noodle</td>
#       <td id="T_246d4_row4_col4" class="data row4 col4" >mee goreng, mee pok</td>
#     </tr>
#     <tr>
#       <td id="T_246d4_row5_col0" class="data row5 col0" >Wancan Golden Plaza</td>
#       <td id="T_246d4_row5_col1" class="data row5 col1" >South Jakarta</td>
#       <td id="T_246d4_row5_col2" class="data row5 col2" >hainanse rice, fried rice</td>
#       <td id="T_246d4_row5_col3" class="data row5 col3" >no</td>
#       <td id="T_246d4_row5_col4" class="data row5 col4" >no</td>
#     </tr>
#     <tr>
#       <td id="T_246d4_row6_col0" class="data row6 col0" >Walao Eh</td>
#       <td id="T_246d4_row6_col1" class="data row6 col1" >Tangerang</td>
#       <td id="T_246d4_row6_col2" class="data row6 col2" >porridge, nasi lemak, hainanse chicken, fried rice, rice plate</td>
#       <td id="T_246d4_row6_col3" class="data row6 col3" >noodle, kway teow</td>
#       <td id="T_246d4_row6_col4" class="data row6 col4" >laksa</td>
#     </tr>
#     <tr>
#       <td id="T_246d4_row7_col0" class="data row7 col0" >Singapore Hainanse Chicken Neo SOHO</td>
#       <td id="T_246d4_row7_col1" class="data row7 col1" >West Jakarta</td>
#       <td id="T_246d4_row7_col2" class="data row7 col2" >fried rice, hainanse rice, porridge, rice plate</td>
#       <td id="T_246d4_row7_col3" class="data row7 col3" >noodle, kway teow</td>
#       <td id="T_246d4_row7_col4" class="data row7 col4" >mee goreng, wonton noodle, roast chicken noodle</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Poultry Menu**
#
# Here is all the meat menu, mostly chicken. I wrote the cooking method and sauce for chicken, mostly fried and the sauce is mainly dominated by sweet sour and kungpau, longed with blackpapper and teriyaki.
#
# The seafood are usually on high end or family restaurant, mostly crab, prawn, and fish. There are several places which serving pork and duck menu. For plant based they also have tofu and vegatables menu. Output labeled 'yes' means that they have those menu but just as a topping/out of the menu, except pork for dietary restrictions.
#
# Speaking about pork, there is a menu named bakuteh, one of the Singaporean delicates. Restaurant serving this is **Legend Kitchen (Muara Karang, North Jakarta City)**. For the chili crab you can find it at **Penang Bistro (Central Jakarta) and PUTIEN PIK (North Jakarta).**

# %%
singapore  = sqldf("""SELECT restaurant_name, city, chicken, seafood, poultry_other
                      FROM singapore
                      WHERE region = 'DKI Jakarta' OR 
                            city = 'Bekasi' OR 
                            city = 'Tangerang' OR 
                            city = 'Bogor'
                      GROUP BY city""")
singapore.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_1761a_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >city</th>
#       <th class="col_heading level0 col2" >chicken</th>
#       <th class="col_heading level0 col3" >seafood</th>
#       <th class="col_heading level0 col4" >poultry_other</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1761a_row0_col0" class="data row0 col0" >Bubur Singapore</td>
#       <td id="T_1761a_row0_col1" class="data row0 col1" >Bekasi</td>
#       <td id="T_1761a_row0_col2" class="data row0 col2" >yes</td>
#       <td id="T_1761a_row0_col3" class="data row0 col3" >yes</td>
#       <td id="T_1761a_row0_col4" class="data row0 col4" >no</td>
#     </tr>
#     <tr>
#       <td id="T_1761a_row1_col0" class="data row1 col0" >Warung Mie Laksa 828 Khas Singapore</td>
#       <td id="T_1761a_row1_col1" class="data row1 col1" >Bogor</td>
#       <td id="T_1761a_row1_col2" class="data row1 col2" >yes</td>
#       <td id="T_1761a_row1_col3" class="data row1 col3" >no</td>
#       <td id="T_1761a_row1_col4" class="data row1 col4" >tofu</td>
#     </tr>
#     <tr>
#       <td id="T_1761a_row2_col0" class="data row2 col0" >Penang Bistro</td>
#       <td id="T_1761a_row2_col1" class="data row2 col1" >Central Jakarta</td>
#       <td id="T_1761a_row2_col2" class="data row2 col2" >mango, fried, kungpao, curry, sweet and sour</td>
#       <td id="T_1761a_row2_col3" class="data row2 col3" >crab, fish,  prawn, squid, sotong, oyster</td>
#       <td id="T_1761a_row2_col4" class="data row2 col4" >beef, duck, tofu, vegetables, mushroom</td>
#     </tr>
#     <tr>
#       <td id="T_1761a_row3_col0" class="data row3 col0" >Uncle K Cijantung Mall</td>
#       <td id="T_1761a_row3_col1" class="data row3 col1" >East Jakarta</td>
#       <td id="T_1761a_row3_col2" class="data row3 col2" >katsudon, curry, roasted, fried</td>
#       <td id="T_1761a_row3_col3" class="data row3 col3" >yes</td>
#       <td id="T_1761a_row3_col4" class="data row3 col4" >no</td>
#     </tr>
#     <tr>
#       <td id="T_1761a_row4_col0" class="data row4 col0" >Lau Lim Mee Pok</td>
#       <td id="T_1761a_row4_col1" class="data row4 col1" >North Jakarta</td>
#       <td id="T_1761a_row4_col2" class="data row4 col2" >no</td>
#       <td id="T_1761a_row4_col3" class="data row4 col3" >string ray</td>
#       <td id="T_1761a_row4_col4" class="data row4 col4" >pork</td>
#     </tr>
#     <tr>
#       <td id="T_1761a_row5_col0" class="data row5 col0" >Wancan Golden Plaza</td>
#       <td id="T_1761a_row5_col1" class="data row5 col1" >South Jakarta</td>
#       <td id="T_1761a_row5_col2" class="data row5 col2" >yes</td>
#       <td id="T_1761a_row5_col3" class="data row5 col3" >no</td>
#       <td id="T_1761a_row5_col4" class="data row5 col4" >tofu, vegetables</td>
#     </tr>
#     <tr>
#       <td id="T_1761a_row6_col0" class="data row6 col0" >Walao Eh</td>
#       <td id="T_1761a_row6_col1" class="data row6 col1" >Tangerang</td>
#       <td id="T_1761a_row6_col2" class="data row6 col2" >roasted, kungpao, teriyaki, salted egg</td>
#       <td id="T_1761a_row6_col3" class="data row6 col3" >dory, oyster, prawn</td>
#       <td id="T_1761a_row6_col4" class="data row6 col4" >beef, duck, vegetables</td>
#     </tr>
#     <tr>
#       <td id="T_1761a_row7_col0" class="data row7 col0" >Singapore Hainanse Chicken Neo SOHO</td>
#       <td id="T_1761a_row7_col1" class="data row7 col1" >West Jakarta</td>
#       <td id="T_1761a_row7_col2" class="data row7 col2" >fried butter, sweet and sour, lemon, spicy, curry</td>
#       <td id="T_1761a_row7_col3" class="data row7 col3" >yes</td>
#       <td id="T_1761a_row7_col4" class="data row7 col4" >duck, beef, tofu, vegetables, egg</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Toast & Snack Menu**
#
# Toast is also one of Singaporean delicacy --for exact is kaya which most mentioned here. The other popular toast menu are peanut, butter, chocolate, and cheese. If you visit **Bangi Kopitiam Restaurants**, there is a distinct menu which is melaka portugese toast, the toast is kind of chocolatey things. Like this one.
#
# Snack dish is the other light (or could be appetizer) menu on the list available. There are dimsum (shumai, hakau, mantau, cakwe etc), spring roll, banana fritter, fries (french fries, cassava) and many more. **Bubur Singapore** in Bekasi has complete singaporean meatball and tempura. **Lau Liem Mee Pok (North Jakarta)** has the most snack dishes including dimsum and curry puff. **Lemongrass Resto (Bogor)** also has various selection of snack including dimsum, chee chong fun, and onde keju.
#
# In this section, toast and snack are listed separately.

# %%
singapore  = sqldf("""SELECT restaurant_name, city, toast
                      FROM singapore
                      WHERE (region = 'DKI Jakarta' OR 
                             city = 'Bekasi' OR 
                             city = 'Tangerang' OR 
                             city = 'Bogor') 
                        AND (toast NOT LIKE '%no')""")
singapore.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_469a2_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >city</th>
#       <th class="col_heading level0 col2" >toast</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_469a2_row0_col0" class="data row0 col0" >Lau Lim Mee Pok</td>
#       <td id="T_469a2_row0_col1" class="data row0 col1" >North Jakarta</td>
#       <td id="T_469a2_row0_col2" class="data row0 col2" >kaya, peanut, butter sugar, french </td>
#     </tr>
#     <tr>
#       <td id="T_469a2_row1_col0" class="data row1 col0" >Ya Kun Kaya Toast Menteng</td>
#       <td id="T_469a2_row1_col1" class="data row1 col1" >Central Jakarta</td>
#       <td id="T_469a2_row1_col2" class="data row1 col2" >kaya, butter sugar, french, cheese, peanut</td>
#     </tr>
#     <tr>
#       <td id="T_469a2_row2_col0" class="data row2 col0" >Toast Box</td>
#       <td id="T_469a2_row2_col1" class="data row2 col1" >South Jakarta</td>
#       <td id="T_469a2_row2_col2" class="data row2 col2" >kaya, cheese, beef, floss, peanut, milo</td>
#     </tr>
#     <tr>
#       <td id="T_469a2_row3_col0" class="data row3 col0" >Ya Kun Kaya Toast Plaza Indonesia</td>
#       <td id="T_469a2_row3_col1" class="data row3 col1" >Central Jakarta</td>
#       <td id="T_469a2_row3_col2" class="data row3 col2" >kaya, butter sugar, french, cheese, peanut</td>
#     </tr>
#     <tr>
#       <td id="T_469a2_row4_col0" class="data row4 col0" >Lau Mok Kopitiam</td>
#       <td id="T_469a2_row4_col1" class="data row4 col1" >West Jakarta</td>
#       <td id="T_469a2_row4_col2" class="data row4 col2" >kaya, peanut, butter sugar, chocolate, cheese, pineapple, strawberry</td>
#     </tr>
#     <tr>
#       <td id="T_469a2_row5_col0" class="data row5 col0" >Tjap Toean Soekarno Hatta Airport</td>
#       <td id="T_469a2_row5_col1" class="data row5 col1" >Tangerang</td>
#       <td id="T_469a2_row5_col2" class="data row5 col2" >kaya, pandan, butter sugar, meses, cheese, durian, brown sugar, french</td>
#     </tr>
#     <tr>
#       <td id="T_469a2_row6_col0" class="data row6 col0" >Legend Kitchen</td>
#       <td id="T_469a2_row6_col1" class="data row6 col1" >North Jakarta</td>
#       <td id="T_469a2_row6_col2" class="data row6 col2" >kaya, butter sugar, chocolate, milk, milo</td>
#     </tr>
#     <tr>
#       <td id="T_469a2_row7_col0" class="data row7 col0" >Bangi Kopitiam Kemang Pratama</td>
#       <td id="T_469a2_row7_col1" class="data row7 col1" >Bekasi</td>
#       <td id="T_469a2_row7_col2" class="data row7 col2" >peanut, butter, milo, kaya, ice cream, egg, portugese, nutella, french etc,</td>
#     </tr>
#     <tr>
#       <td id="T_469a2_row8_col0" class="data row8 col0" >Bangi Kopitiam Pasar Minggu</td>
#       <td id="T_469a2_row8_col1" class="data row8 col1" >South Jakarta</td>
#       <td id="T_469a2_row8_col2" class="data row8 col2" >peanut, butter, milo, kaya, ice cream, egg, portugese, nutella, french etc,</td>
#     </tr>
#     <tr>
#       <td id="T_469a2_row9_col0" class="data row9 col0" >Bangi Kopitiam Kelapa Gading</td>
#       <td id="T_469a2_row9_col1" class="data row9 col1" >North Jakarta</td>
#       <td id="T_469a2_row9_col2" class="data row9 col2" >peanut, butter, milo, kaya, ice cream, egg, portugese, nutella, french etc,</td>
#     </tr>
#     <tr>
#       <td id="T_469a2_row10_col0" class="data row10 col0" >Uncle K Cijantung Mall</td>
#       <td id="T_469a2_row10_col1" class="data row10 col1" >East Jakarta</td>
#       <td id="T_469a2_row10_col2" class="data row10 col2" >kaya, curry chicken, peanut butter, ice cream etc,</td>
#     </tr>
#     <tr>
#       <td id="T_469a2_row11_col0" class="data row11 col0" >Lemongrass Resto</td>
#       <td id="T_469a2_row11_col1" class="data row11 col1" >Bogor</td>
#       <td id="T_469a2_row11_col2" class="data row11 col2" >original, kaya, nutella, butter sugar, chocolate, cheese, banana, strawberry</td>
#     </tr>
#   </tbody>
# </table>

# %%
singapore  = sqldf("""SELECT restaurant_name, city, snack_dish
                      FROM singapore
                      WHERE (region = 'DKI Jakarta' OR 
                             city = 'Bekasi' OR 
                             city = 'Tangerang' OR 
                             city = 'Bogor') 
                        AND (snack_dish NOT LIKE '%no')""")
singapore.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_e334e_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >city</th>
#       <th class="col_heading level0 col2" >snack_dish</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e334e_row0_col0" class="data row0 col0" >Penang Bistro</td>
#       <td id="T_e334e_row0_col1" class="data row0 col1" >Central Jakarta</td>
#       <td id="T_e334e_row0_col2" class="data row0 col2" >spring roll, mantao, canai bread, apple crumble</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row1_col0" class="data row1 col0" >Lau Lim Mee Pok</td>
#       <td id="T_e334e_row1_col1" class="data row1 col1" >North Jakarta</td>
#       <td id="T_e334e_row1_col2" class="data row1 col2" >kuotie, dimsum, curry puff, cakwe, ngohiang, popiah, wonton etc,</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row2_col0" class="data row2 col0" >Wancan Golden Plaza</td>
#       <td id="T_e334e_row2_col1" class="data row2 col1" >South Jakarta</td>
#       <td id="T_e334e_row2_col2" class="data row2 col2" >shumai, mantao, nastar, bok choy</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row3_col0" class="data row3 col0" >Singapore Koo Kee Restaurant</td>
#       <td id="T_e334e_row3_col1" class="data row3 col1" >North Jakarta</td>
#       <td id="T_e334e_row3_col2" class="data row3 col2" >chee chong fun, dumpling, banana fritter, bakcang, chicken feet</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row4_col0" class="data row4 col0" >Walao Eh</td>
#       <td id="T_e334e_row4_col1" class="data row4 col1" >Tangerang</td>
#       <td id="T_e334e_row4_col2" class="data row4 col2" >shumai, mantao, cakwe, gyoza, fries etc,</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row5_col0" class="data row5 col0" >Ming Fa</td>
#       <td id="T_e334e_row5_col1" class="data row5 col1" >Central Jakarta</td>
#       <td id="T_e334e_row5_col2" class="data row5 col2" >dumpling, cakwe</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row6_col0" class="data row6 col0" >Ya Kun Kaya Toast Menteng</td>
#       <td id="T_e334e_row6_col1" class="data row6 col1" >Central Jakarta</td>
#       <td id="T_e334e_row6_col2" class="data row6 col2" >sandwich, cassava, banana fritter</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row7_col0" class="data row7 col0" >Jia Jia Grand Indonesia</td>
#       <td id="T_e334e_row7_col1" class="data row7 col1" >Central Jakarta</td>
#       <td id="T_e334e_row7_col2" class="data row7 col2" >bok choy, cakwe, egg</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row8_col0" class="data row8 col0" >Ya Kun Kaya Toast Plaza Indonesia</td>
#       <td id="T_e334e_row8_col1" class="data row8 col1" >Central Jakarta</td>
#       <td id="T_e334e_row8_col2" class="data row8 col2" >sandwich, cassava, banana fritter</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row9_col0" class="data row9 col0" >Xi De Li</td>
#       <td id="T_e334e_row9_col1" class="data row9 col1" >Tangerang</td>
#       <td id="T_e334e_row9_col2" class="data row9 col2" >cakwe, hum chin pang, butterfly bread, onde onde, redbean bun</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row10_col0" class="data row10 col0" >SEI EAT by Saltedegg,Ind</td>
#       <td id="T_e334e_row10_col1" class="data row10 col1" >Tangerang</td>
#       <td id="T_e334e_row10_col2" class="data row10 col2" >french fries, onion ring, potato chip</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row11_col0" class="data row11 col0" >Bubur Singapore</td>
#       <td id="T_e334e_row11_col1" class="data row11 col1" >Bekasi</td>
#       <td id="T_e334e_row11_col2" class="data row11 col2" >shumai, fries (tempura etc,), sausage, fish cake, fish ball</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row12_col0" class="data row12 col0" >Tjap Toean Soekarno Hatta Airport</td>
#       <td id="T_e334e_row12_col1" class="data row12 col1" >Tangerang</td>
#       <td id="T_e334e_row12_col2" class="data row12 col2" >cakwe, thaoke, fish rice, roti canai, chicken wings, banana fritter etc,</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row13_col0" class="data row13 col0" >Legend Kitchen</td>
#       <td id="T_e334e_row13_col1" class="data row13 col1" >North Jakarta</td>
#       <td id="T_e334e_row13_col2" class="data row13 col2" >spring roll, fish cake, wonton, ngohiong, samchan, fish ball, cakwe</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row14_col0" class="data row14 col0" >Bubur Hopeng</td>
#       <td id="T_e334e_row14_col1" class="data row14 col1" >Tangerang</td>
#       <td id="T_e334e_row14_col2" class="data row14 col2" >cakwe, spring roll</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row15_col0" class="data row15 col0" >Wee Nam Kee Pacific Place</td>
#       <td id="T_e334e_row15_col1" class="data row15 col1" >Central Jakarta</td>
#       <td id="T_e334e_row15_col2" class="data row15 col2" >dumpling, spring roll, prawn rolls, chicken wings, mantao, cakwe etc,</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row16_col0" class="data row16 col0" >Bangi Kopitiam Kemang Pratama</td>
#       <td id="T_e334e_row16_col1" class="data row16 col1" >Bekasi</td>
#       <td id="T_e334e_row16_col2" class="data row16 col2" >shumai, wonton, hakau, steamed bun, french fries, cassava, prata</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row17_col0" class="data row17 col0" >Bangi Kopitiam Pasar Minggu</td>
#       <td id="T_e334e_row17_col1" class="data row17 col1" >South Jakarta</td>
#       <td id="T_e334e_row17_col2" class="data row17 col2" >shumai, wonton, hakau, steamed bun, french fries, cassava, prata</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row18_col0" class="data row18 col0" >Bangi Kopitiam Kelapa Gading</td>
#       <td id="T_e334e_row18_col1" class="data row18 col1" >North Jakarta</td>
#       <td id="T_e334e_row18_col2" class="data row18 col2" >shumai, wonton, hakau, steamed bun, french fries, cassava, prata</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row19_col0" class="data row19 col0" >Singapore Koo Kee Restaurant Kelapa Gading</td>
#       <td id="T_e334e_row19_col1" class="data row19 col1" >North Jakarta</td>
#       <td id="T_e334e_row19_col2" class="data row19 col2" >chee chong fun, sweet noodle, banana fritter</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row20_col0" class="data row20 col0" >Uncle K Cijantung Mall</td>
#       <td id="T_e334e_row20_col1" class="data row20 col1" >East Jakarta</td>
#       <td id="T_e334e_row20_col2" class="data row20 col2" >martabak, roti tissue, prata bread, chinese dougnuts etc,</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row21_col0" class="data row21 col0" >Warung Mie Laksa 828 Khas Singapore</td>
#       <td id="T_e334e_row21_col1" class="data row21 col1" >Bogor</td>
#       <td id="T_e334e_row21_col2" class="data row21 col2" >egg, kekian, wontong</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row22_col0" class="data row22 col0" >Ngohiang Khas Bogor Asli Gang Aut</td>
#       <td id="T_e334e_row22_col1" class="data row22 col1" >Bogor</td>
#       <td id="T_e334e_row22_col2" class="data row22 col2" >wonton, shumai, meatball, bakut</td>
#     </tr>
#     <tr>
#       <td id="T_e334e_row23_col0" class="data row23 col0" >Lemongrass Resto</td>
#       <td id="T_e334e_row23_col1" class="data row23 col1" >Bogor</td>
#       <td id="T_e334e_row23_col2" class="data row23 col2" >spring roll, wonton, onde, dimsum, chee chong fun etc,</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Facility
#
# All restaurants are providing their takeaway options, meanwhile only half of them has delivery options. Outdoor and smoking area are almost rare, only **Bangi Kopitiam Pasar Minggu** has both of them. Beer is the most available options eventhough alcohol drinks are rarely served in this area. And wifi is ravedly available.
#
# Grouped by city.

# %%
singapore  = sqldf("""SELECT restaurant_name, city, takeaway, delivery, outdoor_seat, 
                             smoking_area, alcohol_served, wifi
                      FROM singapore
                      WHERE region = 'DKI Jakarta' OR 
                              city = 'Bekasi' OR 
                              city = 'Tangerang' OR 
                              city = 'Bogor'
                      GROUP BY city""")
singapore.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_6c301_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >city</th>
#       <th class="col_heading level0 col2" >takeaway</th>
#       <th class="col_heading level0 col3" >delivery</th>
#       <th class="col_heading level0 col4" >outdoor_seat</th>
#       <th class="col_heading level0 col5" >smoking_area</th>
#       <th class="col_heading level0 col6" >alcohol_served</th>
#       <th class="col_heading level0 col7" >wifi</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6c301_row0_col0" class="data row0 col0" >Bubur Singapore</td>
#       <td id="T_6c301_row0_col1" class="data row0 col1" >Bekasi</td>
#       <td id="T_6c301_row0_col2" class="data row0 col2" >yes</td>
#       <td id="T_6c301_row0_col3" class="data row0 col3" >no</td>
#       <td id="T_6c301_row0_col4" class="data row0 col4" >no</td>
#       <td id="T_6c301_row0_col5" class="data row0 col5" >no</td>
#       <td id="T_6c301_row0_col6" class="data row0 col6" >no</td>
#       <td id="T_6c301_row0_col7" class="data row0 col7" >no</td>
#     </tr>
#     <tr>
#       <td id="T_6c301_row1_col0" class="data row1 col0" >Warung Mie Laksa 828 Khas Singapore</td>
#       <td id="T_6c301_row1_col1" class="data row1 col1" >Bogor</td>
#       <td id="T_6c301_row1_col2" class="data row1 col2" >yes</td>
#       <td id="T_6c301_row1_col3" class="data row1 col3" >yes</td>
#       <td id="T_6c301_row1_col4" class="data row1 col4" >yes</td>
#       <td id="T_6c301_row1_col5" class="data row1 col5" >no</td>
#       <td id="T_6c301_row1_col6" class="data row1 col6" >no</td>
#       <td id="T_6c301_row1_col7" class="data row1 col7" >no</td>
#     </tr>
#     <tr>
#       <td id="T_6c301_row2_col0" class="data row2 col0" >Penang Bistro</td>
#       <td id="T_6c301_row2_col1" class="data row2 col1" >Central Jakarta</td>
#       <td id="T_6c301_row2_col2" class="data row2 col2" >yes</td>
#       <td id="T_6c301_row2_col3" class="data row2 col3" >yes</td>
#       <td id="T_6c301_row2_col4" class="data row2 col4" >no</td>
#       <td id="T_6c301_row2_col5" class="data row2 col5" >no</td>
#       <td id="T_6c301_row2_col6" class="data row2 col6" >beer</td>
#       <td id="T_6c301_row2_col7" class="data row2 col7" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_6c301_row3_col0" class="data row3 col0" >Uncle K Cijantung Mall</td>
#       <td id="T_6c301_row3_col1" class="data row3 col1" >East Jakarta</td>
#       <td id="T_6c301_row3_col2" class="data row3 col2" >yes</td>
#       <td id="T_6c301_row3_col3" class="data row3 col3" >yes</td>
#       <td id="T_6c301_row3_col4" class="data row3 col4" >no</td>
#       <td id="T_6c301_row3_col5" class="data row3 col5" >no</td>
#       <td id="T_6c301_row3_col6" class="data row3 col6" >no</td>
#       <td id="T_6c301_row3_col7" class="data row3 col7" >no</td>
#     </tr>
#     <tr>
#       <td id="T_6c301_row4_col0" class="data row4 col0" >Lau Lim Mee Pok</td>
#       <td id="T_6c301_row4_col1" class="data row4 col1" >North Jakarta</td>
#       <td id="T_6c301_row4_col2" class="data row4 col2" >yes</td>
#       <td id="T_6c301_row4_col3" class="data row4 col3" >no</td>
#       <td id="T_6c301_row4_col4" class="data row4 col4" >yes</td>
#       <td id="T_6c301_row4_col5" class="data row4 col5" >no</td>
#       <td id="T_6c301_row4_col6" class="data row4 col6" >no</td>
#       <td id="T_6c301_row4_col7" class="data row4 col7" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_6c301_row5_col0" class="data row5 col0" >Wancan Golden Plaza</td>
#       <td id="T_6c301_row5_col1" class="data row5 col1" >South Jakarta</td>
#       <td id="T_6c301_row5_col2" class="data row5 col2" >yes</td>
#       <td id="T_6c301_row5_col3" class="data row5 col3" >no</td>
#       <td id="T_6c301_row5_col4" class="data row5 col4" >no</td>
#       <td id="T_6c301_row5_col5" class="data row5 col5" >no</td>
#       <td id="T_6c301_row5_col6" class="data row5 col6" >no</td>
#       <td id="T_6c301_row5_col7" class="data row5 col7" >yes</td>
#     </tr>
#     <tr>
#       <td id="T_6c301_row6_col0" class="data row6 col0" >Walao Eh</td>
#       <td id="T_6c301_row6_col1" class="data row6 col1" >Tangerang</td>
#       <td id="T_6c301_row6_col2" class="data row6 col2" >yes</td>
#       <td id="T_6c301_row6_col3" class="data row6 col3" >no</td>
#       <td id="T_6c301_row6_col4" class="data row6 col4" >no</td>
#       <td id="T_6c301_row6_col5" class="data row6 col5" >no</td>
#       <td id="T_6c301_row6_col6" class="data row6 col6" >no</td>
#       <td id="T_6c301_row6_col7" class="data row6 col7" >no</td>
#     </tr>
#     <tr>
#       <td id="T_6c301_row7_col0" class="data row7 col0" >Singapore Hainanse Chicken Neo SOHO</td>
#       <td id="T_6c301_row7_col1" class="data row7 col1" >West Jakarta</td>
#       <td id="T_6c301_row7_col2" class="data row7 col2" >yes</td>
#       <td id="T_6c301_row7_col3" class="data row7 col3" >no</td>
#       <td id="T_6c301_row7_col4" class="data row7 col4" >no</td>
#       <td id="T_6c301_row7_col5" class="data row7 col5" >no</td>
#       <td id="T_6c301_row7_col6" class="data row7 col6" >no</td>
#       <td id="T_6c301_row7_col7" class="data row7 col7" >no</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Rating
#
# These ratings are ordered by highest total rating, should they have more than 3.5 then the restaurant is worth to try. All the facility and menu are representated by all both google and platform rating and count, so in the meantime only ratings are counted here. Based on the results, **Warung Laksa 828 (Bogor), Penang Bistro (Central Jakarta)**, and **Legend Kitchen (North Jakarta)** are the top 3.
#
# Breaking based on the area, here is the best restaurant among Jakarta, which are **Penang Bistro (Central Jakarta, scored 4,5), Legend Kitchen (North Jakarta, scored 4,45), Lau Mok Kopitiam (West Jakarta-- apparently the only one, scored 3,05), and Uncle K Cijantung Mall (East Jakarta, the only one, scored 3,35)**.
#
# For Bekasi and Tangerang they have representatively Bangi Kopitiam Kemang Pratama (scored 3,65 from 835 vote) and Walao Eh (3,85). Warung Laksa 828 has the highest rating in this list as long as in Bogor, eventhough it's kind of takeaway-only places (scored 4.9).
#
# NA labeled here are the restaurant who doesn't have another ratings besides of google/platform ratings.

# %%
singapore  = sqldf("""SELECT restaurant_name, city, 
                             ltrim(google_rating) as google_rating, 
                             ltrim(platform_rating) as platform_rating, 
                             ltrim((google_rating + platform_rating)/2) as total_rating,
                        CASE
                            WHEN (google_rating + platform_rating)/2 >= 3.5 THEN "Recommended"
                            ELSE "Reconsider"
                            END AS "Recommendation"
                        FROM singapore 
                        WHERE region = 'DKI Jakarta' OR 
                                city = 'Bekasi' OR 
                                city = 'Tangerang' OR 
                                city = 'Bogor'
                        ORDER BY total_rating DESC;""")
singapore.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_f4b13_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >city</th>
#       <th class="col_heading level0 col2" >google_rating</th>
#       <th class="col_heading level0 col3" >platform_rating</th>
#       <th class="col_heading level0 col4" >total_rating</th>
#       <th class="col_heading level0 col5" >Recommendation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f4b13_row0_col0" class="data row0 col0" >Warung Mie Laksa 828 Khas Singapore</td>
#       <td id="T_f4b13_row0_col1" class="data row0 col1" >Bogor</td>
#       <td id="T_f4b13_row0_col2" class="data row0 col2" >4.9</td>
#       <td id="T_f4b13_row0_col3" class="data row0 col3" >4.9</td>
#       <td id="T_f4b13_row0_col4" class="data row0 col4" >4.9</td>
#       <td id="T_f4b13_row0_col5" class="data row0 col5" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f4b13_row1_col0" class="data row1 col0" >Penang Bistro</td>
#       <td id="T_f4b13_row1_col1" class="data row1 col1" >Central Jakarta</td>
#       <td id="T_f4b13_row1_col2" class="data row1 col2" >4.5</td>
#       <td id="T_f4b13_row1_col3" class="data row1 col3" >4.5</td>
#       <td id="T_f4b13_row1_col4" class="data row1 col4" >4.5</td>
#       <td id="T_f4b13_row1_col5" class="data row1 col5" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f4b13_row2_col0" class="data row2 col0" >Legend Kitchen</td>
#       <td id="T_f4b13_row2_col1" class="data row2 col1" >North Jakarta</td>
#       <td id="T_f4b13_row2_col2" class="data row2 col2" >4.5</td>
#       <td id="T_f4b13_row2_col3" class="data row2 col3" >4.4</td>
#       <td id="T_f4b13_row2_col4" class="data row2 col4" >4.45</td>
#       <td id="T_f4b13_row2_col5" class="data row2 col5" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f4b13_row3_col0" class="data row3 col0" >PUTIEN PIK Avenue Mall</td>
#       <td id="T_f4b13_row3_col1" class="data row3 col1" >North Jakarta</td>
#       <td id="T_f4b13_row3_col2" class="data row3 col2" >4.4</td>
#       <td id="T_f4b13_row3_col3" class="data row3 col3" >4.3</td>
#       <td id="T_f4b13_row3_col4" class="data row3 col4" >4.35</td>
#       <td id="T_f4b13_row3_col5" class="data row3 col5" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f4b13_row4_col0" class="data row4 col0" >Salty Sam Mall of Indonesia</td>
#       <td id="T_f4b13_row4_col1" class="data row4 col1" >North Jakarta</td>
#       <td id="T_f4b13_row4_col2" class="data row4 col2" >4.4</td>
#       <td id="T_f4b13_row4_col3" class="data row4 col3" >4.2</td>
#       <td id="T_f4b13_row4_col4" class="data row4 col4" >4.3</td>
#       <td id="T_f4b13_row4_col5" class="data row4 col5" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f4b13_row5_col0" class="data row5 col0" >Lemongrass Resto</td>
#       <td id="T_f4b13_row5_col1" class="data row5 col1" >Bogor</td>
#       <td id="T_f4b13_row5_col2" class="data row5 col2" >4.4</td>
#       <td id="T_f4b13_row5_col3" class="data row5 col3" >4.1</td>
#       <td id="T_f4b13_row5_col4" class="data row5 col4" >4.25</td>
#       <td id="T_f4b13_row5_col5" class="data row5 col5" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f4b13_row6_col0" class="data row6 col0" >Lau Lim Mee Pok</td>
#       <td id="T_f4b13_row6_col1" class="data row6 col1" >North Jakarta</td>
#       <td id="T_f4b13_row6_col2" class="data row6 col2" >4.4</td>
#       <td id="T_f4b13_row6_col3" class="data row6 col3" >4.0</td>
#       <td id="T_f4b13_row6_col4" class="data row6 col4" >4.2</td>
#       <td id="T_f4b13_row6_col5" class="data row6 col5" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f4b13_row7_col0" class="data row7 col0" >Singapore Kwetiaw Kerang & Seafood</td>
#       <td id="T_f4b13_row7_col1" class="data row7 col1" >North Jakarta</td>
#       <td id="T_f4b13_row7_col2" class="data row7 col2" >4.5</td>
#       <td id="T_f4b13_row7_col3" class="data row7 col3" >3.9</td>
#       <td id="T_f4b13_row7_col4" class="data row7 col4" >4.2</td>
#       <td id="T_f4b13_row7_col5" class="data row7 col5" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f4b13_row8_col0" class="data row8 col0" >Wee Nam Kee Pacific Place</td>
#       <td id="T_f4b13_row8_col1" class="data row8 col1" >Central Jakarta</td>
#       <td id="T_f4b13_row8_col2" class="data row8 col2" >4.2</td>
#       <td id="T_f4b13_row8_col3" class="data row8 col3" >4.2</td>
#       <td id="T_f4b13_row8_col4" class="data row8 col4" >4.2</td>
#       <td id="T_f4b13_row8_col5" class="data row8 col5" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f4b13_row9_col0" class="data row9 col0" >Wancan Golden Plaza</td>
#       <td id="T_f4b13_row9_col1" class="data row9 col1" >South Jakarta</td>
#       <td id="T_f4b13_row9_col2" class="data row9 col2" >4.5</td>
#       <td id="T_f4b13_row9_col3" class="data row9 col3" >3.8</td>
#       <td id="T_f4b13_row9_col4" class="data row9 col4" >4.15</td>
#       <td id="T_f4b13_row9_col5" class="data row9 col5" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f4b13_row10_col0" class="data row10 col0" >Singapore Koo Kee Restaurant</td>
#       <td id="T_f4b13_row10_col1" class="data row10 col1" >North Jakarta</td>
#       <td id="T_f4b13_row10_col2" class="data row10 col2" >4.3</td>
#       <td id="T_f4b13_row10_col3" class="data row10 col3" >4.0</td>
#       <td id="T_f4b13_row10_col4" class="data row10 col4" >4.15</td>
#       <td id="T_f4b13_row10_col5" class="data row10 col5" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f4b13_row11_col0" class="data row11 col0" >Lotus Mie Udang Singapore</td>
#       <td id="T_f4b13_row11_col1" class="data row11 col1" >North Jakarta</td>
#       <td id="T_f4b13_row11_col2" class="data row11 col2" >4.6</td>
#       <td id="T_f4b13_row11_col3" class="data row11 col3" >3.7</td>
#       <td id="T_f4b13_row11_col4" class="data row11 col4" >4.15</td>
#       <td id="T_f4b13_row11_col5" class="data row11 col5" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f4b13_row12_col0" class="data row12 col0" >Lay Lay Singapore</td>
#       <td id="T_f4b13_row12_col1" class="data row12 col1" >Central Jakarta</td>
#       <td id="T_f4b13_row12_col2" class="data row12 col2" >4.5</td>
#       <td id="T_f4b13_row12_col3" class="data row12 col3" >3.6</td>
#       <td id="T_f4b13_row12_col4" class="data row12 col4" >4.05</td>
#       <td id="T_f4b13_row12_col5" class="data row12 col5" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f4b13_row13_col0" class="data row13 col0" >Old Chang Kee Gandaria City</td>
#       <td id="T_f4b13_row13_col1" class="data row13 col1" >Central Jakarta</td>
#       <td id="T_f4b13_row13_col2" class="data row13 col2" >4.1</td>
#       <td id="T_f4b13_row13_col3" class="data row13 col3" >3.8</td>
#       <td id="T_f4b13_row13_col4" class="data row13 col4" >3.95</td>
#       <td id="T_f4b13_row13_col5" class="data row13 col5" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f4b13_row14_col0" class="data row14 col0" >Ya Kun Kaya Toast Menteng</td>
#       <td id="T_f4b13_row14_col1" class="data row14 col1" >Central Jakarta</td>
#       <td id="T_f4b13_row14_col2" class="data row14 col2" >4.3</td>
#       <td id="T_f4b13_row14_col3" class="data row14 col3" >3.6</td>
#       <td id="T_f4b13_row14_col4" class="data row14 col4" >3.95</td>
#       <td id="T_f4b13_row14_col5" class="data row14 col5" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f4b13_row15_col0" class="data row15 col0" >Bangi Kopitiam Pasar Minggu</td>
#       <td id="T_f4b13_row15_col1" class="data row15 col1" >South Jakarta</td>
#       <td id="T_f4b13_row15_col2" class="data row15 col2" >4.4</td>
#       <td id="T_f4b13_row15_col3" class="data row15 col3" >3.5</td>
#       <td id="T_f4b13_row15_col4" class="data row15 col4" >3.95</td>
#       <td id="T_f4b13_row15_col5" class="data row15 col5" >Recommended</td>
#     </tr>
#     <tr>
#       <td id="T_f4b13_row16_col0" class="data row16 col0" >Ngohiang Khas Bogor Asli Gang Aut</td>
#       <td id="T_f4b13_row16_col1" class="data row16 col1" >Bogor</td>
#       <td id="T_f4b13_row1
