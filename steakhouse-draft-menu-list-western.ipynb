# %% [markdown]
# # Steakhouse Draft Menu List : Western
#
# Western is a common genre in steak area as its 'originated', where the price range are above IDR 200k. They have the most complete course from appetizer, main course, and dessert.
#
# The poultry also the most vary especially for the beef choices. Which are striploin, chateaubriand, mignon, t-bone, and tomahawk (other than ordinary sirloin-tenderloin-rib eye). Even they have lamb and foie grass as well. For seafood section there are one or two places served barramundi-- all are in South Jakarta.
#
# There are 44 western restaurants in Jakarta, special for this section I divide based on city, but unfortunately East Jakarta can't be displayed as they don't have any western like those restaurant, mostly available on other sections especially Local and Local Westerned. Each section contained of glimpse menu and price, poultry, and courses. There are also facility at the bottom, providing options like takeaway, delivery, outdoor/smoking area, alcohol, wifi, reservation, and other special features.

# %% [markdown]
# ![Steakhouse-1.png](attachment:1e45fae9-c563-48cf-82eb-203ed850ba4d.png)

# %%
import pandas as pd
from pandasql import sqldf
steak = pd.read_csv('../input/steakhouse-jakarta/Steakhouse.csv', sep = ";")

# %%
steak = sqldf("""SELECT COUNT(specialized) 
FROM steak 
WHERE specialized = 'Western'""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_e9141_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >COUNT(specialized)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e9141_row0_col0" class="data row0 col0" >44</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Central Jakarta
#
# In this area, the steakhouse mostly located in Thamrin and Sudirman (office building and shopping mall), least in Menteng and Cikini (owned place). Most choices for beef are rib eye, sirloin, and tenderloin. **SKYE Thamrin** has the most beef available including tomahawk and t-bone. **MUCCA Steak** has the most expensive menu which is Tomahawk Bone in Rib Eye Steak, priced for IDR 9.400k.
#
# As for chicken they are mostly either grilled or roasted. They also have mostly salmon on their seafood menu. Despite this, **Tony Roma's (Thamrin)** and **Gandy Steak House (Menteng)** both have chicken menu like steak and schnitzel, also much more seafood, some platters, and other dish. For other meat they have pork on Tony Roma's and SKYE, lamb on Gandy Steak House, and foie gras for OSCAR (Thamrin) and SKYE.
#
# For appetizer they mostly have salad, pasta, and soup. Also wraps and quesadilla. They also have burger, fries, and pizza. They mostly have ice cream and cake for calling the session. Watch for Tony Roma's and SKYE which has special dessert menu, **OSCAR** for the most sweet menu.

# %%
steak = sqldf("""SELECT restaurant_name, district, place, unique_menu, price
FROM steak
WHERE city = 'Central Jakarta' AND specialized = 'Western' 
ORDER BY price DESC""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_56052_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >district</th>
#       <th class="col_heading level0 col2" >place</th>
#       <th class="col_heading level0 col3" >unique_menu</th>
#       <th class="col_heading level0 col4" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_56052_row0_col0" class="data row0 col0" >MUCCA Steak</td>
#       <td id="T_56052_row0_col1" class="data row0 col1" >Sudirman</td>
#       <td id="T_56052_row0_col2" class="data row0 col2" >Citywalk Sudirman</td>
#       <td id="T_56052_row0_col3" class="data row0 col3" >Tomahawk Bone In Rib Eye Steak</td>
#       <td id="T_56052_row0_col4" class="data row0 col4" >940000</td>
#     </tr>
#     <tr>
#       <td id="T_56052_row1_col0" class="data row1 col0" >OSCAR</td>
#       <td id="T_56052_row1_col1" class="data row1 col1" >Thamrin</td>
# ...

# %%
steak = sqldf("""SELECT restaurant_name, district, place, beef, chicken, seafood, other_poultry
FROM steak
WHERE city = 'Central Jakarta' AND specialized = 'Western'""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_5315c_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >district</th>
#       <th class="col_heading level0 col2" >place</th>
#       <th class="col_heading level0 col3" >beef</th>
#       <th class="col_heading level0 col4" >chicken</th>
#       <th class="col_heading level0 col5" >seafood</th>
#       <th class="col_heading level0 col6" >other_poultry</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5315c_row0_col0" class="data row0 col0" >Tony Roma's</td>
#       <td id="T_5315c_row0_col1" class="data row0 col1" >Thamrin</td>
#       <td id="T_5315c_row0_col2" class="data row0 col2" >UOB Plaza</td>
#       <td id="T_5315c_row0_col3" class="data row0 col3" >ribs, striploin, rib eye</td>
#       <td id="T_5315c_row0_col4" class="data row0 col4" >crispy tenderloins, steak, barbeque</td>
# ...

# %%
steak = sqldf("""SELECT restaurant_name, district, place, appetizer, other_dish, dessert
FROM steak
WHERE city = 'Central Jakarta' AND specialized = 'Western'""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_5eea2_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >district</th>
#       <th class="col_heading level0 col2" >place</th>
#       <th class="col_heading level0 col3" >appetizer</th>
#       <th class="col_heading level0 col4" >other_dish</th>
#       <th class="col_heading level0 col5" >dessert</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5eea2_row0_col0" class="data row0 col0" >Tony Roma's</td>
#       <td id="T_5eea2_row0_col1" class="data row0 col1" >Thamrin</td>
#       <td id="T_5eea2_row0_col2" class="data row0 col2" >UOB Plaza</td>
#       <td id="T_5eea2_row0_col3" class="data row0 col3" >soup, salad, quesadilas, fries etc</td>
#       <td id="T_5eea2_row0_col4" class="data row0 col4" >artichoke dip, mozarella stick, burger etc</td>
# ...

# %% [markdown]
# # South Jakarta
#
# South Jakarta has the most western steak restaurant in region, mostly located on their own place as the city also have some high end household. Senayan and SCBD has the most, least are in Senopati, Kemang, and Dharmawangsa. Most expensive is Australian Wagyu Tomahawk from **The Brotherhood (Senopati)** for IDR 880k, but **Cut & Grill (Tebet)** prices based on market, apparently. Look at those unique menu as they are really unique and worth to try, they also have chateaubriand at **Cork & Stew (SCBD)**.
#
# For beef selection, they have sirloin, rib eye, and tenderloin, but they also have some distinct beef like striploin, t-bone, mignon, and tomahawk. Chicken are not too much but **Tony Roma's Gandaria and Gandy Steak House Pondok Indah** are vary. Fish and chips are common as it's so many on this area, but **Animale Restaurant (Setiabudi)** and **Odysseia (SCBD)** has the most seafood available. The seafood also distinct of black cod, barramundi, calamari, sea bass, and oyster. Mostly dominated by seafood for other poultry but pork, lamb, and duck also available as well.
#
# The appetizers mostly by soup, salad, quesadilas, and fries. Cut & Grill has bruschetta and **Hurricane's Grill (Senopati)** has most distinct appetizer menu. Burger, sandwich, and rice menu also available and cake, pannacotta, and ice cream for the dessert, but Bakerzin has the their most distinct.

# %%
steak = sqldf("""SELECT restaurant_name, district, place, unique_menu, price
FROM steak
WHERE city = 'South Jakarta' AND specialized = 'Western'
ORDER BY price DESC""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_96ac5_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >district</th>
#       <th class="col_heading level0 col2" >place</th>
#       <th class="col_heading level0 col3" >unique_menu</th>
#       <th class="col_heading level0 col4" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_96ac5_row0_col0" class="data row0 col0" >Cut & Grill</td>
#       <td id="T_96ac5_row0_col1" class="data row0 col1" >Tebet</td>
#       <td id="T_96ac5_row0_col2" class="data row0 col2" >Owned place</td>
#       <td id="T_96ac5_row0_col3" class="data row0 col3" >Australian Wagyu Tomahawk</td>
#       <td id="T_96ac5_row0_col4" class="data row0 col4" >market price</td>
#     </tr>
#     <tr>
#       <td id="T_96ac5_row1_col0" class="data row1 col0" >The Brotherhood</td>
#       <td id="T_96ac5_row1_col1" class="data row1 col1" >Senopati</td>
# ...

# %%
steak = sqldf("""SELECT restaurant_name, district, beef, chicken, seafood, other_poultry
FROM steak
WHERE city = 'South Jakarta' AND specialized = 'Western'""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_20e38_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >district</th>
#       <th class="col_heading level0 col2" >beef</th>
#       <th class="col_heading level0 col3" >chicken</th>
#       <th class="col_heading level0 col4" >seafood</th>
#       <th class="col_heading level0 col5" >other_poultry</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_20e38_row0_col0" class="data row0 col0" >Indoguna Meat Shop</td>
#       <td id="T_20e38_row0_col1" class="data row0 col1" >Senopati</td>
#       <td id="T_20e38_row0_col2" class="data row0 col2" >unspecific</td>
#       <td id="T_20e38_row0_col3" class="data row0 col3" >grilled, roasted</td>
#       <td id="T_20e38_row0_col4" class="data row0 col4" >calamari, dory</td>
#       <td id="T_20e38_row0_col5" class="data row0 col5" >seafood</td>
#     </tr>
#     <tr>
# ...

# %%
steak = sqldf("""SELECT restaurant_name, district, appetizer, other_dish, dessert
FROM steak
WHERE city = 'South Jakarta' AND specialized = 'Western'""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_60ef0_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >district</th>
#       <th class="col_heading level0 col2" >appetizer</th>
#       <th class="col_heading level0 col3" >other_dish</th>
#       <th class="col_heading level0 col4" >dessert</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_60ef0_row0_col0" class="data row0 col0" >Indoguna Meat Shop</td>
#       <td id="T_60ef0_row0_col1" class="data row0 col1" >Senopati</td>
#       <td id="T_60ef0_row0_col2" class="data row0 col2" >quesadila, nachos, soup, salad, pasta etc</td>
#       <td id="T_60ef0_row0_col3" class="data row0 col3" >burger, pizza</td>
#       <td id="T_60ef0_row0_col4" class="data row0 col4" >cake, toast</td>
#     </tr>
#     <tr>
#       <td id="T_60ef0_row1_col0" class="data row1 col0" >Cut & Grill</td>
# ...

# %% [markdown]
# # West Jakarta
#
# West Jakarta's western steak restaurant placed on their own place respectively on Green Ville, Roxy, and Cengkareng. **SOULSPIN (Cengkareng)** has their most expensive menu which is Full Rack BBQ Baby Back Ribs for IDR 389k. But Wagyu Brisket from **B'Steak Grill & Pancake (Green Ville)** is also worth to try.
#
# They have various beef steak but B'Steak has the most vary options. For chicken menu they mostly have chicken steak, but other western menu also there like schnitzel and cordon bleu. SOULSPIN has pork menu, B'Steak and **Gandy Steak House(Green Ville)** has lamb menu and rest of them are seafood. Salmon and fish and chips are most common here.
#
# Gandi Steak House has the most vary appetizer, garlic bread and quesadilas are two of them. Burger, fries, and pasta also available in this area, but seafood steak is available at **American Grill (Roxy)**. For closing the course they have ice cream/gelato, B'steak has the most vary available. But SOULSPIN has many waffle and sweet drinks.

# %%
steak = sqldf("""SELECT restaurant_name, district, place, unique_menu, price
FROM steak
WHERE city = 'West Jakarta' AND specialized = 'Western' 
ORDER BY price DESC""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_2b3dd_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >district</th>
#       <th class="col_heading level0 col2" >place</th>
#       <th class="col_heading level0 col3" >unique_menu</th>
#       <th class="col_heading level0 col4" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2b3dd_row0_col0" class="data row0 col0" >SOULSPIN</td>
#       <td id="T_2b3dd_row0_col1" class="data row0 col1" >Cengkareng</td>
#       <td id="T_2b3dd_row0_col2" class="data row0 col2" >Owned place</td>
#       <td id="T_2b3dd_row0_col3" class="data row0 col3" >Full Rack BBQ Baby Back Ribs</td>
#       <td id="T_2b3dd_row0_col4" class="data row0 col4" >389000</td>
#     </tr>
#     <tr>
#       <td id="T_2b3dd_row1_col0" class="data row1 col0" >American Grill</td>
#       <td id="T_2b3dd_row1_col1" class="data row1 col1" >Roxy</td>
# ...

# %%
steak = sqldf("""SELECT restaurant_name, city, beef, chicken, seafood, other_poultry
FROM steak
WHERE (city = 'West Jakarta') AND specialized = 'Western'""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_58b8d_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >city</th>
#       <th class="col_heading level0 col2" >beef</th>
#       <th class="col_heading level0 col3" >chicken</th>
#       <th class="col_heading level0 col4" >seafood</th>
#       <th class="col_heading level0 col5" >other_poultry</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_58b8d_row0_col0" class="data row0 col0" >B'Steak Grill & Pancake</td>
#       <td id="T_58b8d_row0_col1" class="data row0 col1" >West Jakarta</td>
#       <td id="T_58b8d_row0_col2" class="data row0 col2" >brisket, tenderloin, striploin, rib eye, mignon, ribs, tomahawk, t-bone</td>
#       <td id="T_58b8d_row0_col3" class="data row0 col3" >grilled, schnitzel, cordon bleu, steak, florentine etc</td>
# ...

# %%
steak = sqldf("""SELECT restaurant_name, district, appetizer, other_dish, dessert
FROM steak
WHERE city = 'West Jakarta' AND specialized = 'Western'""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_d3575_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >district</th>
#       <th class="col_heading level0 col2" >appetizer</th>
#       <th class="col_heading level0 col3" >other_dish</th>
#       <th class="col_heading level0 col4" >dessert</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d3575_row0_col0" class="data row0 col0" >B'Steak Grill & Pancake</td>
#       <td id="T_d3575_row0_col1" class="data row0 col1" >Green Ville</td>
#       <td id="T_d3575_row0_col2" class="data row0 col2" >fries, soup, salad, taco, quesadilas</td>
#       <td id="T_d3575_row0_col3" class="data row0 col3" >sausage, omelette, burger, pasta, pie etc</td>
#       <td id="T_d3575_row0_col4" class="data row0 col4" >pancake, ice cream, banana, toast, sweet drinks</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# # North Jakarta
#
# North Jakarta's western are most located in Kelapa Gading and Pantai Indah Kapuk area. The most expensive is Tomahawk from **PAVVO (Pantai Indah Kapuk)** which priced IDR 1.850k. There also an all you can eat steak restaurant called **Steak 21 Buffet Kelapa Gading**. **Holy Smokes PIK** also has their wagyu brisket for IDR 160k each.
#
# **B'Steak Kelapa Gading** and Holy Smokes PIK has their most beef steak, BarBarRibs only has ribs and PAVVO only have tomahawk. The chicken are much served on **Street Steak (Kelapa Gading)**, B'Steak, and **Alter Five Beer & Restaurant (Mangga Dua)**, but steak are rare here. Pork is served on **BarBarRibs** at Kelapa Gading and least five bottom on beef section. Lamb is also available at three places.
#
# Salad and fries are the most vary appetizer, other than steak there are other various menu from rice, sausage, to burger etc. Holy Smokes and B'Steak has the most dessert from tart, pie, to ice cream, and PAVVO has their own croissant.

# %%
steak = sqldf("""SELECT restaurant_name, district, unique_menu, price
FROM steak
WHERE city = 'North Jakarta' AND specialized = 'Western'
ORDER BY price DESC""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_70028_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >district</th>
#       <th class="col_heading level0 col2" >unique_menu</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_70028_row0_col0" class="data row0 col0" >Steak 21 Buffet</td>
#       <td id="T_70028_row0_col1" class="data row0 col1" >Kelapa Gading</td>
#       <td id="T_70028_row0_col2" class="data row0 col2" >Paket C Supreme</td>
#       <td id="T_70028_row0_col3" class="data row0 col3" >368000</td>
#     </tr>
#     <tr>
#       <td id="T_70028_row1_col0" class="data row1 col0" >Alter Five Beer & Restaurant</td>
#       <td id="T_70028_row1_col1" class="data row1 col1" >Mangga Dua</td>
#       <td id="T_70028_row1_col2" class="data row1 col2" >Wagyu Rib Eye Steak</td>
# ...

# %%
steak = sqldf("""SELECT restaurant_name, beef, chicken, seafood, other_poultry
FROM steak
WHERE city = 'North Jakarta' AND specialized = 'Western'""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_ac0fd_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >beef</th>
#       <th class="col_heading level0 col2" >chicken</th>
#       <th class="col_heading level0 col3" >seafood</th>
#       <th class="col_heading level0 col4" >other_poultry</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ac0fd_row0_col0" class="data row0 col0" >Street Steak</td>
#       <td id="T_ac0fd_row0_col1" class="data row0 col1" >sirloin, tenderloin, rib eye, wagyu, tomahawk</td>
#       <td id="T_ac0fd_row0_col2" class="data row0 col2" >schnitzel, grilled, cordon bleu</td>
#       <td id="T_ac0fd_row0_col3" class="data row0 col3" >salon, dory, fish and chips</td>
#       <td id="T_ac0fd_row0_col4" class="data row0 col4" >seafood</td>
#     </tr>
#     <tr>
#       <td id="T_ac0fd_row1_col0" class="data row1 col0" >B'Steak Grill & Pancake</td>
# ...

# %%
steak = sqldf("""SELECT restaurant_name, appetizer, other_dish, dessert
FROM steak
WHERE city = 'North Jakarta' AND specialized = 'Western'""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_1ed8d_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >appetizer</th>
#       <th class="col_heading level0 col2" >other_dish</th>
#       <th class="col_heading level0 col3" >dessert</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1ed8d_row0_col0" class="data row0 col0" >Street Steak</td>
#       <td id="T_1ed8d_row0_col1" class="data row0 col1" >salad, fries, pasta</td>
#       <td id="T_1ed8d_row0_col2" class="data row0 col2" >no</td>
#       <td id="T_1ed8d_row0_col3" class="data row0 col3" >ice cream, banana</td>
#     </tr>
#     <tr>
#       <td id="T_1ed8d_row1_col0" class="data row1 col0" >B'Steak Grill & Pancake</td>
#       <td id="T_1ed8d_row1_col1" class="data row1 col1" >fries, soup, salad, taco, quesadilas</td>
# ...

# %% [markdown]
# # Facility
#
# They have many takeaway options but delivery are rare, very rare. Even they mostly don't have outdoor options but luckily smoking area are much available. Wine, cocktail, beer and liquor are most available alcohol options, almost all of them has wifi and can be reserved.
#
# There are Gandy Steak House which also turned up to bakery. Mucca Steak and BarBarRibs are claimed to be kids friendly. **J Steak (Blok M)** and **Holy Smokes (Senopati)** have their own valet parking, **SKYE** has their best city view. We can also costumize our order freely at **Super Steak (Blok M)**, meanwhile B'Steak and Street Steak both have payer room, private room are much more accessible here.

# %%
steak = sqldf("""SELECT restaurant_name, city, district, takeaway, delivery, outdoor, smoking_area,
alcohol_served, wifi, reservation, other
FROM steak 
WHERE specialized = 'Western'""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_dbdf7_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >city</th>
#       <th class="col_heading level0 col2" >district</th>
#       <th class="col_heading level0 col3" >takeaway</th>
#       <th class="col_heading level0 col4" >delivery</th>
#       <th class="col_heading level0 col5" >outdoor</th>
#       <th class="col_heading level0 col6" >smoking_area</th>
#       <th class="col_heading level0 col7" >alcohol_served</th>
#       <th class="col_heading level0 col8" >wifi</th>
#       <th class="col_heading level0 col9" >reservation</th>
#       <th class="col_heading level0 col10" >other</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_dbdf7_row0_col0" class="data row0 col0" >Tony Roma's</td>
#       <td id="T_dbdf7_row0_col1" class="data row0 col1" >Central Jakarta</td>
# ...
