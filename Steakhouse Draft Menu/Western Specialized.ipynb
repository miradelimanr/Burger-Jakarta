# %% [markdown]
# # Steakhouse Draft Menu List : Western Specialist
#
# Different from western, this project is specified other than english-speaking country. In this section I divide those into two section : Latina and Central Europe region. There are 13 restaurants through Jakarta area. The price range also the same with western one, above IDR 200k or nearby.
#
# Each section contained of glimpse menu and price, poultry, and courses. There are also facility at the bottom, providing options like takeaway, delivery, outdoor/smoking area, alcohol, wifi, reservation, and other special features.

# %%
import pandas as pd
from pandasql import sqldf
steak = pd.read_csv('../input/steakhouse-jakarta/Steakhouse.csv', sep = ";")

# %%
steak = sqldf("""SELECT COUNT(specialized) 
FROM steak 
WHERE specialized = 'Brazilian' OR specialized = 'Mexican' OR specialized = 'Argentinian' 
OR specialized = 'Italian' OR specialized = 'French'""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_c44af_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >COUNT(specialized)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c44af_row0_col0" class="data row0 col0" >13</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Latina Region
#
# Latina Region consist of all South American countries like Brazil, Mexico, and Argentina.
#
# The Most expensive one is Sirloin Strip from La Posta which priced IDR 395k.
#
# There is a all you can eat Brazilian food (including steak) called **Tucano's Churrascaria** based on two locations, Sudirman and Senayan. There are some distinct menu name right here which are Bifes Con Cebolla (grilled marinated steak) from **El Asador (Kemang)** and Chivito Plato (Churrasco tenderloin steak covered with mozarella cheese and others) from **El Machote (Menteng)**.
#
# El Machote and La Posta both have most beef steak choices, even got their flank and brisket. Not much chicken and seafood but they are there. Only El Machote is serving pork and lamb right now. **Carbon (Setiabudi)** has salmon, lobster, and duck.
#
# Most of appetizers are Mexican-style dishes, such as empanada (turnover pastry like pastel), quesadilas, along with soup and pasta. There are some fries food and ice cream also. Tucano's Churrascaria Senayan and Carbon has the most dessert available including churros, fruit salad, and others.

# %%
steak = sqldf("""SELECT restaurant_name, specialized, district, place, unique_menu, price
FROM steak
WHERE specialized = 'Brazilian' OR specialized = 'Mexican' OR specialized = 'Argentinian'
ORDER BY price DESC""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_0a154_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >specialized</th>
#       <th class="col_heading level0 col2" >district</th>
#       <th class="col_heading level0 col3" >place</th>
#       <th class="col_heading level0 col4" >unique_menu</th>
#       <th class="col_heading level0 col5" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0a154_row0_col0" class="data row0 col0" >La Posta</td>
#       <td id="T_0a154_row0_col1" class="data row0 col1" >Argentinian</td>
#       <td id="T_0a154_row0_col2" class="data row0 col2" >Sudirman</td>
#       <td id="T_0a154_row0_col3" class="data row0 col3" >Owned place</td>
#       <td id="T_0a154_row0_col4" class="data row0 col4" >Sirloin Strip</td>
#       <td id="T_0a154_row0_col5" class="data row0 col5" >395000</td>
#     </tr>
#     <tr>
#       <td id="T_0a154_row1_col0" class="data row1 col0" >Carbon</td>
#       <td id="T_0a154_row1_col1" class="data row1 col1" >Mexican</td>
#       <td id="T_0a154_row1_col2" class="data row1 col2" >Setiabudi</td>
#       <td id="T_0a154_row1_col3" class="data row1 col3" >MD Place Building</td>
#       <td id="T_0a154_row1_col4" class="data row1 col4" >Denver Steak 200gr</td>
#       <td id="T_0a154_row1_col5" class="data row1 col5" >295000</td>
#     </tr>
#     <tr>
#       <td id="T_0a154_row2_col0" class="data row2 col0" >Tucano's Churrascaria</td>
#       <td id="T_0a154_row2_col1" class="data row2 col1" >Brazilian</td>
#       <td id="T_0a154_row2_col2" class="data row2 col2" >Sudirman</td>
#       <td id="T_0a154_row2_col3" class="data row2 col3" >Senayan City</td>
#       <td id="T_0a154_row2_col4" class="data row2 col4" >Classic Beef 90 minutes</td>
#       <td id="T_0a154_row2_col5" class="data row2 col5" >268000</td>
#     </tr>
#     <tr>
#       <td id="T_0a154_row3_col0" class="data row3 col0" >Tucano's Churrascaria</td>
#       <td id="T_0a154_row3_col1" class="data row3 col1" >Brazilian</td>
#       <td id="T_0a154_row3_col2" class="data row3 col2" >Senayan</td>
#       <td id="T_0a154_row3_col3" class="data row3 col3" >Senayan City</td>
#       <td id="T_0a154_row3_col4" class="data row3 col4" >Classic Beef 90 minutes</td>
#       <td id="T_0a154_row3_col5" class="data row3 col5" >268000</td>
#     </tr>
#     <tr>
#       <td id="T_0a154_row4_col0" class="data row4 col0" >Chilis Grill & Bar</td>
#       <td id="T_0a154_row4_col1" class="data row4 col1" >Mexican</td>
#       <td id="T_0a154_row4_col2" class="data row4 col2" >Thamrin</td>
#       <td id="T_0a154_row4_col3" class="data row4 col3" >Sarinah Building</td>
#       <td id="T_0a154_row4_col4" class="data row4 col4" >Classic Ribeye</td>
#       <td id="T_0a154_row4_col5" class="data row4 col5" >215000</td>
#     </tr>
#     <tr>
#       <td id="T_0a154_row5_col0" class="data row5 col0" >El Asador</td>
#       <td id="T_0a154_row5_col1" class="data row5 col1" >Mexican</td>
#       <td id="T_0a154_row5_col2" class="data row5 col2" >Kemang</td>
#       <td id="T_0a154_row5_col3" class="data row5 col3" >Kemang Point Building</td>
#       <td id="T_0a154_row5_col4" class="data row5 col4" >Bifes Con Cebolla</td>
#       <td id="T_0a154_row5_col5" class="data row5 col5" >190000</td>
#     </tr>
#     <tr>
#       <td id="T_0a154_row6_col0" class="data row6 col0" >El Machote</td>
#       <td id="T_0a154_row6_col1" class="data row6 col1" >Mexican</td>
#       <td id="T_0a154_row6_col2" class="data row6 col2" >Menteng</td>
#       <td id="T_0a154_row6_col3" class="data row6 col3" >Owned place</td>
#       <td id="T_0a154_row6_col4" class="data row6 col4" >Chivito Plato</td>
#       <td id="T_0a154_row6_col5" class="data row6 col5" >150000</td>
#     </tr>
#   </tbody>
# </table>

# %%
steak = sqldf("""SELECT restaurant_name, specialized, district, beef, chicken, seafood, other_poultry
FROM steak
WHERE specialized = 'Brazilian' OR specialized = 'Mexican' OR specialized = 'Argentinian'""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_9a26a_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >specialized</th>
#       <th class="col_heading level0 col2" >district</th>
#       <th class="col_heading level0 col3" >beef</th>
#       <th class="col_heading level0 col4" >chicken</th>
#       <th class="col_heading level0 col5" >seafood</th>
#       <th class="col_heading level0 col6" >other_poultry</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9a26a_row0_col0" class="data row0 col0" >Tucano's Churrascaria</td>
#       <td id="T_9a26a_row0_col1" class="data row0 col1" >Brazilian</td>
#       <td id="T_9a26a_row0_col2" class="data row0 col2" >Sudirman</td>
#       <td id="T_9a26a_row0_col3" class="data row0 col3" >sirloin, wagyu</td>
#       <td id="T_9a26a_row0_col4" class="data row0 col4" >yes</td>
#       <td id="T_9a26a_row0_col5" class="data row0 col5" >no</td>
#       <td id="T_9a26a_row0_col6" class="data row0 col6" >no</td>
#     </tr>
#     <tr>
#       <td id="T_9a26a_row1_col0" class="data row1 col0" >El Machote</td>
#       <td id="T_9a26a_row1_col1" class="data row1 col1" >Mexican</td>
#       <td id="T_9a26a_row1_col2" class="data row1 col2" >Menteng</td>
#       <td id="T_9a26a_row1_col3" class="data row1 col3" >sirloin, rib eye, tenderloin, brisket etc</td>
#       <td id="T_9a26a_row1_col4" class="data row1 col4" >yes</td>
#       <td id="T_9a26a_row1_col5" class="data row1 col5" >salmon</td>
#       <td id="T_9a26a_row1_col6" class="data row1 col6" >pork, seafood, lamb</td>
#     </tr>
#     <tr>
#       <td id="T_9a26a_row2_col0" class="data row2 col0" >La Posta</td>
#       <td id="T_9a26a_row2_col1" class="data row2 col1" >Argentinian</td>
#       <td id="T_9a26a_row2_col2" class="data row2 col2" >Sudirman</td>
#       <td id="T_9a26a_row2_col3" class="data row2 col3" >sirloin, striploin, tenderloin, rib eye, flank etc</td>
#       <td id="T_9a26a_row2_col4" class="data row2 col4" >barbequed, fried</td>
#       <td id="T_9a26a_row2_col5" class="data row2 col5" >no</td>
#       <td id="T_9a26a_row2_col6" class="data row2 col6" >pork</td>
#     </tr>
#     <tr>
#       <td id="T_9a26a_row3_col0" class="data row3 col0" >Chilis Grill & Bar</td>
#       <td id="T_9a26a_row3_col1" class="data row3 col1" >Mexican</td>
#       <td id="T_9a26a_row3_col2" class="data row3 col2" >Thamrin</td>
#       <td id="T_9a26a_row3_col3" class="data row3 col3" >tenderloin, rib eye</td>
#       <td id="T_9a26a_row3_col4" class="data row3 col4" >crispy, grilled</td>
#       <td id="T_9a26a_row3_col5" class="data row3 col5" >fish and chips, salmon</td>
#       <td id="T_9a26a_row3_col6" class="data row3 col6" >seafood</td>
#     </tr>
#     <tr>
#       <td id="T_9a26a_row4_col0" class="data row4 col0" >Tucano's Churrascaria</td>
#       <td id="T_9a26a_row4_col1" class="data row4 col1" >Brazilian</td>
#       <td id="T_9a26a_row4_col2" class="data row4 col2" >Senayan</td>
#       <td id="T_9a26a_row4_col3" class="data row4 col3" >sirloin, wagyu</td>
#       <td id="T_9a26a_row4_col4" class="data row4 col4" >yes</td>
#       <td id="T_9a26a_row4_col5" class="data row4 col5" >no</td>
#       <td id="T_9a26a_row4_col6" class="data row4 col6" >no</td>
#     </tr>
#     <tr>
#       <td id="T_9a26a_row5_col0" class="data row5 col0" >El Asador</td>
#       <td id="T_9a26a_row5_col1" class="data row5 col1" >Mexican</td>
#       <td id="T_9a26a_row5_col2" class="data row5 col2" >Kemang</td>
#       <td id="T_9a26a_row5_col3" class="data row5 col3" >sirloin, tenderloin, rib eye</td>
#       <td id="T_9a26a_row5_col4" class="data row5 col4" >pan-fried, schnitzel</td>
#       <td id="T_9a26a_row5_col5" class="data row5 col5" >no</td>
#       <td id="T_9a26a_row5_col6" class="data row5 col6" >seafood</td>
#     </tr>
#     <tr>
#       <td id="T_9a26a_row6_col0" class="data row6 col0" >Carbon</td>
#       <td id="T_9a26a_row6_col1" class="data row6 col1" >Mexican</td>
#       <td id="T_9a26a_row6_col2" class="data row6 col2" >Setiabudi</td>
#       <td id="T_9a26a_row6_col3" class="data row6 col3" >sirloin, mignon, wagyu</td>
#       <td id="T_9a26a_row6_col4" class="data row6 col4" >roasted</td>
#       <td id="T_9a26a_row6_col5" class="data row6 col5" >salmon, lobster</td>
#       <td id="T_9a26a_row6_col6" class="data row6 col6" >seafood, duck, vegetables</td>
#     </tr>
#   </tbody>
# </table>

# %%
steak = sqldf("""SELECT restaurant_name, specialized, district, appetizer, other_dish, dessert
FROM steak
WHERE specialized = 'Brazilian' OR specialized = 'Mexican' OR specialized = 'Argentinian'""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_de88a_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >specialized</th>
#       <th class="col_heading level0 col2" >district</th>
#       <th class="col_heading level0 col3" >appetizer</th>
#       <th class="col_heading level0 col4" >other_dish</th>
#       <th class="col_heading level0 col5" >dessert</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_de88a_row0_col0" class="data row0 col0" >Tucano's Churrascaria</td>
#       <td id="T_de88a_row0_col1" class="data row0 col1" >Brazilian</td>
#       <td id="T_de88a_row0_col2" class="data row0 col2" >Sudirman</td>
#       <td id="T_de88a_row0_col3" class="data row0 col3" >soup, pasta</td>
#       <td id="T_de88a_row0_col4" class="data row0 col4" >churros, egg tart, fries</td>
#       <td id="T_de88a_row0_col5" class="data row0 col5" >ice cream</td>
#     </tr>
#     <tr>
#       <td id="T_de88a_row1_col0" class="data row1 col0" >El Machote</td>
#       <td id="T_de88a_row1_col1" class="data row1 col1" >Mexican</td>
#       <td id="T_de88a_row1_col2" class="data row1 col2" >Menteng</td>
#       <td id="T_de88a_row1_col3" class="data row1 col3" >soup, nachos, quesadilas, salad, pasta, empanada</td>
#       <td id="T_de88a_row1_col4" class="data row1 col4" >fries, burger, sandwich, wings etc</td>
#       <td id="T_de88a_row1_col5" class="data row1 col5" >crepe, ice cream</td>
#     </tr>
#     <tr>
#       <td id="T_de88a_row2_col0" class="data row2 col0" >La Posta</td>
#       <td id="T_de88a_row2_col1" class="data row2 col1" >Argentinian</td>
#       <td id="T_de88a_row2_col2" class="data row2 col2" >Sudirman</td>
#       <td id="T_de88a_row2_col3" class="data row2 col3" >eggs, mushrooms, empanada, salad, traditional</td>
#       <td id="T_de88a_row2_col4" class="data row2 col4" >fries</td>
#       <td id="T_de88a_row2_col5" class="data row2 col5" >cake, biscuit, ice cream</td>
#     </tr>
#     <tr>
#       <td id="T_de88a_row3_col0" class="data row3 col0" >Chilis Grill & Bar</td>
#       <td id="T_de88a_row3_col1" class="data row3 col1" >Mexican</td>
#       <td id="T_de88a_row3_col2" class="data row3 col2" >Thamrin</td>
#       <td id="T_de88a_row3_col3" class="data row3 col3" >taco, platter, guacamole, wings, nachos etc</td>
#       <td id="T_de88a_row3_col4" class="data row3 col4" >fajitas, burger, fries etc</td>
#       <td id="T_de88a_row3_col5" class="data row3 col5" >cake, ice cream</td>
#     </tr>
#     <tr>
#       <td id="T_de88a_row4_col0" class="data row4 col0" >Tucano's Churrascaria</td>
#       <td id="T_de88a_row4_col1" class="data row4 col1" >Brazilian</td>
#       <td id="T_de88a_row4_col2" class="data row4 col2" >Senayan</td>
#       <td id="T_de88a_row4_col3" class="data row4 col3" >soup, pasta, salad</td>
#       <td id="T_de88a_row4_col4" class="data row4 col4" >sushi, pizza, fries</td>
#       <td id="T_de88a_row4_col5" class="data row4 col5" >pudding, cheese cake, tart, churros, waffle</td>
#     </tr>
#     <tr>
#       <td id="T_de88a_row5_col0" class="data row5 col0" >El Asador</td>
#       <td id="T_de88a_row5_col1" class="data row5 col1" >Mexican</td>
#       <td id="T_de88a_row5_col2" class="data row5 col2" >Kemang</td>
#       <td id="T_de88a_row5_col3" class="data row5 col3" >nachos, quesadilas, empanada, fries, pasta, salad etc</td>
#       <td id="T_de88a_row5_col4" class="data row5 col4" >savory crepes</td>
#       <td id="T_de88a_row5_col5" class="data row5 col5" >ice cream, cake, waffle</td>
#     </tr>
#     <tr>
#       <td id="T_de88a_row6_col0" class="data row6 col0" >Carbon</td>
#       <td id="T_de88a_row6_col1" class="data row6 col1" >Mexican</td>
#       <td id="T_de88a_row6_col2" class="data row6 col2" >Setiabudi</td>
#       <td id="T_de88a_row6_col3" class="data row6 col3" >soup, seafood, quesadillas, taco</td>
#       <td id="T_de88a_row6_col4" class="data row6 col4" >fries, fried rice, pasta, chips, sashimi etc</td>
#       <td id="T_de88a_row6_col5" class="data row6 col5" >cake, churros, sorbet, fruit salad, tart, cream brulee</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Central Europe Region
#
# Central Europe are consist of two European countries, Italy and France. Most of them are located in South Jakarta except for **Caffe Milano (Thamrin)** and **Rosso (Sudirman)** which both located in Central Jakarta.
#
# Most expensive one is Filetto di Manzo in Salsa Al Gorgonzola (Australian beef tenderloin in Gorgonzola cheese sauce) for IDR 490k from Rosso. Other distinct menu is Filetto Al Pepe which are Seared prime beef tenderloin with Brandy sauce from **Alto Restaurant (Gatot Subroto) and Bar** and Steak fillet with peppercorn sauce and mustard from **Volare (Fatmawati)**.
#
# Within beef selection Volare and Liberte have most vary beef and seafood, chicken are mostly served in parmigiana layered with cheese and tomato sauce. There are some seafood available, mostly lobster and salmon. No pork available here, but foie gras and lamb.
#
# They are serving soup, pasta, pizza, and risotto as their appetizer, then there is pizza for other main menu options, and ice cream and pannacotta are the most available. But there are also have cream brulee, crepes, and sorbet, even traditional italian but specifically at Rosso.

# %%
steak = sqldf("""SELECT restaurant_name, specialized, district, place, unique_menu, price
FROM steak
WHERE specialized = 'Italian' OR specialized = 'French'
ORDER BY price DESC""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_4628e_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >specialized</th>
#       <th class="col_heading level0 col2" >district</th>
#       <th class="col_heading level0 col3" >place</th>
#       <th class="col_heading level0 col4" >unique_menu</th>
#       <th class="col_heading level0 col5" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4628e_row0_col0" class="data row0 col0" >Cafe de Paris</td>
#       <td id="T_4628e_row0_col1" class="data row0 col1" >French</td>
#       <td id="T_4628e_row0_col2" class="data row0 col2" >Kebayoran Lama</td>
#       <td id="T_4628e_row0_col3" class="data row0 col3" >Bellezza Shopping Arcade</td>
#       <td id="T_4628e_row0_col4" class="data row0 col4" >Steak aus Champignons</td>
#       <td id="T_4628e_row0_col5" class="data row0 col5" >98000</td>
#     </tr>
#     <tr>
#       <td id="T_4628e_row1_col0" class="data row1 col0" >Rosso</td>
#       <td id="T_4628e_row1_col1" class="data row1 col1" >Italian</td>
#       <td id="T_4628e_row1_col2" class="data row1 col2" >Sudirman</td>
#       <td id="T_4628e_row1_col3" class="data row1 col3" >Shangrila Hotel</td>
#       <td id="T_4628e_row1_col4" class="data row1 col4" >Filetto di Manzo in Salsa Al Gorgonzola</td>
#       <td id="T_4628e_row1_col5" class="data row1 col5" >490000</td>
#     </tr>
#     <tr>
#       <td id="T_4628e_row2_col0" class="data row2 col0" >Caffe Milano</td>
#       <td id="T_4628e_row2_col1" class="data row2 col1" >Italian</td>
#       <td id="T_4628e_row2_col2" class="data row2 col2" >Thamrin</td>
#       <td id="T_4628e_row2_col3" class="data row2 col3" >Grand Indonesia</td>
#       <td id="T_4628e_row2_col4" class="data row2 col4" >Wagyu Beef Tagliata</td>
#       <td id="T_4628e_row2_col5" class="data row2 col5" >380000</td>
#     </tr>
#     <tr>
#       <td id="T_4628e_row3_col0" class="data row3 col0" >Volare</td>
#       <td id="T_4628e_row3_col1" class="data row3 col1" >Italian</td>
#       <td id="T_4628e_row3_col2" class="data row3 col2" >Fatmawati</td>
#       <td id="T_4628e_row3_col3" class="data row3 col3" >Cilandak Town Square</td>
#       <td id="T_4628e_row3_col4" class="data row3 col4" >Filetto Al Pepe Verde</td>
#       <td id="T_4628e_row3_col5" class="data row3 col5" >295000</td>
#     </tr>
#     <tr>
#       <td id="T_4628e_row4_col0" class="data row4 col0" >Liberte</td>
#       <td id="T_4628e_row4_col1" class="data row4 col1" >Italian</td>
#       <td id="T_4628e_row4_col2" class="data row4 col2" >SCBD</td>
#       <td id="T_4628e_row4_col3" class="data row4 col3" >Pacific Place</td>
#       <td id="T_4628e_row4_col4" class="data row4 col4" >Premium T-Bone</td>
#       <td id="T_4628e_row4_col5" class="data row4 col5" >169000</td>
#     </tr>
#     <tr>
#       <td id="T_4628e_row5_col0" class="data row5 col0" >Alto Restaurant & Bar</td>
#       <td id="T_4628e_row5_col1" class="data row5 col1" >Italian</td>
#       <td id="T_4628e_row5_col2" class="data row5 col2" >Gatot Subroto</td>
#       <td id="T_4628e_row5_col3" class="data row5 col3" >Four Seasons Hotel</td>
#       <td id="T_4628e_row5_col4" class="data row5 col4" >Fileto Al Pepe 130gr</td>
#       <td id="T_4628e_row5_col5" class="data row5 col5" >None</td>
#     </tr>
#   </tbody>
# </table>

# %%
steak = sqldf("""SELECT restaurant_name, specialized, district, beef, chicken, seafood, other_poultry
FROM steak
WHERE specialized = 'Italian' OR specialized = 'French'""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_73ed0_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >specialized</th>
#       <th class="col_heading level0 col2" >district</th>
#       <th class="col_heading level0 col3" >beef</th>
#       <th class="col_heading level0 col4" >chicken</th>
#       <th class="col_heading level0 col5" >seafood</th>
#       <th class="col_heading level0 col6" >other_poultry</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_73ed0_row0_col0" class="data row0 col0" >Caffe Milano</td>
#       <td id="T_73ed0_row0_col1" class="data row0 col1" >Italian</td>
#       <td id="T_73ed0_row0_col2" class="data row0 col2" >Thamrin</td>
#       <td id="T_73ed0_row0_col3" class="data row0 col3" >sirloin, tenderloin, rib eye, wagyu</td>
#       <td id="T_73ed0_row0_col4" class="data row0 col4" >roasted, parmigiana</td>
#       <td id="T_73ed0_row0_col5" class="data row0 col5" >calamari, clam</td>
#       <td id="T_73ed0_row0_col6" class="data row0 col6" >seafood, vegetables</td>
#     </tr>
#     <tr>
#       <td id="T_73ed0_row1_col0" class="data row1 col0" >Rosso</td>
#       <td id="T_73ed0_row1_col1" class="data row1 col1" >Italian</td>
#       <td id="T_73ed0_row1_col2" class="data row1 col2" >Sudirman</td>
#       <td id="T_73ed0_row1_col3" class="data row1 col3" >sirloin, tenderloin, rib eye</td>
#       <td id="T_73ed0_row1_col4" class="data row1 col4" >roasted</td>
#       <td id="T_73ed0_row1_col5" class="data row1 col5" >platters, salmon, tuna, lobster</td>
#       <td id="T_73ed0_row1_col6" class="data row1 col6" >foie gras, seafood, vegetables</td>
#     </tr>
#     <tr>
#       <td id="T_73ed0_row2_col0" class="data row2 col0" >Alto Restaurant & Bar</td>
#       <td id="T_73ed0_row2_col1" class="data row2 col1" >Italian</td>
#       <td id="T_73ed0_row2_col2" class="data row2 col2" >Gatot Subroto</td>
#       <td id="T_73ed0_row2_col3" class="data row2 col3" >sirloin, tenderloin, t-bone</td>
#       <td id="T_73ed0_row2_col4" class="data row2 col4" >no</td>
#       <td id="T_73ed0_row2_col5" class="data row2 col5" >salmon, sea bass, lobster</td>
#       <td id="T_73ed0_row2_col6" class="data row2 col6" >seafood</td>
#     </tr>
#     <tr>
#       <td id="T_73ed0_row3_col0" class="data row3 col0" >Cafe de Paris</td>
#       <td id="T_73ed0_row3_col1" class="data row3 col1" >French</td>
#       <td id="T_73ed0_row3_col2" class="data row3 col2" >Kebayoran Lama</td>
#       <td id="T_73ed0_row3_col3" class="data row3 col3" >unspecific</td>
#       <td id="T_73ed0_row3_col4" class="data row3 col4" >parmigiana, cordon bleu</td>
#       <td id="T_73ed0_row3_col5" class="data row3 col5" >fish and chips, shrimp, squid, platter</td>
#       <td id="T_73ed0_row3_col6" class="data row3 col6" >seafood</td>
#     </tr>
#     <tr>
#       <td id="T_73ed0_row4_col0" class="data row4 col0" >Volare</td>
#       <td id="T_73ed0_row4_col1" class="data row4 col1" >Italian</td>
#       <td id="T_73ed0_row4_col2" class="data row4 col2" >Fatmawati</td>
#       <td id="T_73ed0_row4_col3" class="data row4 col3" >tomahawk, t-bone, sirloin, tenderloin, rib eye, wagyu etc</td>
#       <td id="T_73ed0_row4_col4" class="data row4 col4" >parmigiana, cordon bleu, fillet, roasted</td>
#       <td id="T_73ed0_row4_col5" class="data row4 col5" >barramundi, salmon, gindara, octopus</td>
#       <td id="T_73ed0_row4_col6" class="data row4 col6" >seafood</td>
#     </tr>
#     <tr>
#       <td id="T_73ed0_row5_col0" class="data row5 col0" >Liberte</td>
#       <td id="T_73ed0_row5_col1" class="data row5 col1" >Italian</td>
#       <td id="T_73ed0_row5_col2" class="data row5 col2" >SCBD</td>
#       <td id="T_73ed0_row5_col3" class="data row5 col3" >tenderloin, striploin, rib eye, tomahawk, t-bone</td>
#       <td id="T_73ed0_row5_col4" class="data row5 col4" >roasted, cordon bleu, parmigiana</td>
#       <td id="T_73ed0_row5_col5" class="data row5 col5" >lobster, fish and chips, salmon, baramundi, gindara, dory</td>
#       <td id="T_73ed0_row5_col6" class="data row5 col6" >seafood, lamb</td>
#     </tr>
#   </tbody>
# </table>

# %%
steak = sqldf("""SELECT restaurant_name, specialized, district, appetizer, other_dish, dessert
FROM steak
WHERE specialized = 'Italian' OR specialized = 'French'""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_9a114_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >specialized</th>
#       <th class="col_heading level0 col2" >district</th>
#       <th class="col_heading level0 col3" >appetizer</th>
#       <th class="col_heading level0 col4" >other_dish</th>
#       <th class="col_heading level0 col5" >dessert</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9a114_row0_col0" class="data row0 col0" >Caffe Milano</td>
#       <td id="T_9a114_row0_col1" class="data row0 col1" >Italian</td>
#       <td id="T_9a114_row0_col2" class="data row0 col2" >Thamrin</td>
#       <td id="T_9a114_row0_col3" class="data row0 col3" >salad, fries, pasta</td>
#       <td id="T_9a114_row0_col4" class="data row0 col4" >pizza etc</td>
#       <td id="T_9a114_row0_col5" class="data row0 col5" >gelato, cake, pannacotta, gelato parfait etc</td>
#     </tr>
#     <tr>
#       <td id="T_9a114_row1_col0" class="data row1 col0" >Rosso</td>
#       <td id="T_9a114_row1_col1" class="data row1 col1" >Italian</td>
#       <td id="T_9a114_row1_col2" class="data row1 col2" >Sudirman</td>
#       <td id="T_9a114_row1_col3" class="data row1 col3" >risotto, soup, pasta</td>
#       <td id="T_9a114_row1_col4" class="data row1 col4" >pizza</td>
#       <td id="T_9a114_row1_col5" class="data row1 col5" >sorbet, gelato, traditional italian</td>
#     </tr>
#     <tr>
#       <td id="T_9a114_row2_col0" class="data row2 col0" >Alto Restaurant & Bar</td>
#       <td id="T_9a114_row2_col1" class="data row2 col1" >Italian</td>
#       <td id="T_9a114_row2_col2" class="data row2 col2" >Gatot Subroto</td>
#       <td id="T_9a114_row2_col3" class="data row2 col3" >antipasti, soup, salad, pasta, risotto, bruschetta</td>
#       <td id="T_9a114_row2_col4" class="data row2 col4" >bruschetta, cheese puffs, fries, lasagna, risotto</td>
#       <td id="T_9a114_row2_col5" class="data row2 col5" >special</td>
#     </tr>
#     <tr>
#       <td id="T_9a114_row3_col0" class="data row3 col0" >Cafe de Paris</td>
#       <td id="T_9a114_row3_col1" class="data row3 col1" >French</td>
#       <td id="T_9a114_row3_col2" class="data row3 col2" >Kebayoran Lama</td>
#       <td id="T_9a114_row3_col3" class="data row3 col3" >soup, salad, pasta</td>
#       <td id="T_9a114_row3_col4" class="data row3 col4" >sandwich, fries</td>
#       <td id="T_9a114_row3_col5" class="data row3 col5" >banana, ice cream, crepes</td>
#     </tr>
#     <tr>
#       <td id="T_9a114_row4_col0" class="data row4 col0" >Volare</td>
#       <td id="T_9a114_row4_col1" class="data row4 col1" >Italian</td>
#       <td id="T_9a114_row4_col2" class="data row4 col2" >Fatmawati</td>
#       <td id="T_9a114_row4_col3" class="data row4 col3" >salad, soup, pasta, pizza, risotto, bruschetta etc</td>
#       <td id="T_9a114_row4_col4" class="data row4 col4" >fries</td>
#       <td id="T_9a114_row4_col5" class="data row4 col5" >nutella pizza, pannacotta, cream brulee, tiramisu etc</td>
#     </tr>
#     <tr>
#       <td id="T_9a114_row5_col0" class="data row5 col0" >Liberte</td>
#       <td id="T_9a114_row5_col1" class="data row5 col1" >Italian</td>
#       <td id="T_9a114_row5_col2" class="data row5 col2" >SCBD</td>
#       <td id="T_9a114_row5_col3" class="data row5 col3" >cheese, buratta, meatball, fries, soup, salad, pasta etc</td>
#       <td id="T_9a114_row5_col4" class="data row5 col4" >pizza, fries, croissant</td>
#       <td id="T_9a114_row5_col5" class="data row5 col5" >pizza, pannacotta, cake, cream brulee, calzone</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Facility
#
# Takeaway are the most available but delivery is quite rare, La Posta has their delivery menu. Outdoor room are ravely available along with smoking area. Wine and cocktail are the most for alcohol options. All restaurant providing wifi and reservation are suggested.
#
# **El Machote, La Posta, and Chilis Grill & Bar** can be turned up to a bar. Cafe de Paris has breakfast menu, Chilis Grill & Bar also has kids menu. For live entertainment or music options they're available both for Tucano's Churrascaria restaurants. Rosso has city view, **Volare (Fatmawati) and Liberte (SCBD)** both have corkage fee (charge for those whom bring their own wine).

# %%
steak = sqldf("""SELECT restaurant_name, city, district, takeaway, delivery, outdoor, smoking_area,
alcohol_served, wifi, reservation, other
FROM steak 
WHERE specialized = 'Brazilian' OR specialized = 'Mexican' OR specialized = 'Argentinian' 
OR specialized = 'Italian' OR specialized = 'French'""")
steak.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_927fd_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >restaurant_name</th>
#       <th class="col_heading level0 col1" >city</th>
#       <th class="col_heading level0 col2" >district</th>
#       <th class="col_heading level0 col3" >takeaway</th>
#       <th class="col_heading level0 col4" >delivery</th>
#       <th class="col_heading level0 col5" >outdoor</th>
#       <th class="col_heading level0 col6" >smoking_area</th>
#       <th class="col_heading level0 col7" >alcohol_served</th>
#       <th class="col_heading level0 col8" >wifi</th>
#       <th class="col_heading level0 col9" >reservation</th>
#       <th class="col_heading level0 col10" >other</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_927fd_row0_col0" class="data row0 col0" >Tucano's Churrascaria</td>
#       <td id="T_927fd_row0_col1" class="data row0 col1" >Central Jakarta</td>
#       <td id="T_927fd_row0_col2" class="data row0 col2" >Sudirman</td>
#       <td id="T_927fd_row0_col3" class="data row0 col3" >yes</td>
#       <td id="T_927fd_row0_col4" class="data row0 col4" >yes</td>
#       <td id="T_927fd_row0_col5" class="data row0 col5" >yes</td>
#       <td id="T_927fd_row0_col6" class="data row0 col6" >yes</td>
#       <td id="T_927fd_row0_col7" class="data row0 col7" >cocktail, wine, beer, highball</td>
#       <td id="T_927fd_row0_col8" class="data row0 col8" >yes</td>
#       <td id="T_927fd_row0_col9" class="data row0 col9" >yes</td>
#       <td id="T_927fd_row0_col10" class="data row0 col10" >buffet, bar, live entertainment, private dining</td>
#     </tr>
#     <tr>
#       <td id="T_927fd_row1_col0" class="data row1 col0" >El Machote</td>
#       <td id="T_927fd_row1_col1" class="data row1 col1" >Central Jakarta</td>
#       <td id="T_927fd_row1_col2" class="data row1 col2" >Menteng</td>
#       <td id="T_927fd_row1_col3" class="data row1 col3" >yes</td>
#       <td id="T_927fd_row1_col4" class="data row1 col4" >yes</td>
#       <td id="T_927fd_row1_col5" class="data row1 col5" >no</td>
#       <td id="T_927fd_row1_col6" class="data row1 col6" >yes</td>
#       <td id="T_927fd_row1_col7" class="data row1 col7" >beer, vodka, whiskey, tequila, wine etc</td>
#       <td id="T_927fd_row1_col8" class="data row1 col8" >yes</td>
#       <td id="T_927fd_row1_col9" class="data row1 col9" >yes</td>
#       <td id="T_927fd_row1_col10" class="data row1 col10" >all you can eat, bar</td>
#     </tr>
#     <tr>
#       <td id="T_927fd_row2_col0" class="data row2 col0" >La Posta</td>
#       <td id="T_927fd_row2_col1" class="data row2 col1" >Central Jakarta</td>
#       <td id="T_927fd_row2_col2" class="data row2 col2" >Sudirman</td>
#       <td id="T_927fd_row2_col3" class="data row2 col3" >yes</td>
#       <td id="T_927fd_row2_col4" class="data row2 col4" >yes</td>
#       <td id="T_927fd_row2_col5" class="data row2 col5" >no</td>
#       <td id="T_927fd_row2_col6" class="data row2 col6" >no</td>
#       <td id="T_927fd_row2_col7" class="data row2 col7" >wine, beer</td>
#       <td id="T_927fd_row2_col8" class="data row2 col8" >yes</td>
#       <td id="T_927fd_row2_col9" class="data row2 col9" >yes</td>
#       <td id="T_927fd_row2_col10" class="data row2 col10" >bar, delivery menu</td>
#     </tr>
#     <tr>
#       <td id="T_927fd_row3_col0" class="data row3 col0" >Caffe Milano</td>
#       <td id="T_927fd_row3_col1" class="data row3 col1" >Central Jakarta</td>
#       <td id="T_927fd_row3_col2" class="data row3 col2" >Thamrin</td>
#       <td id="T_927fd_row3_col3" class="data row3 col3" >yes</td>
#       <td id="T_927fd_row3_col4" class="data row3 col4" >no</td>
#       <td id="T_927fd_row3_col5" class="data row3 col5" >no</td>
#       <td id="T_927fd_row3_col6" class="data row3 col6" >yes</td>
#       <td id="T_927fd_row3_col7" class="data row3 col7" >cocktail, beer, liquor etc</td>
#       <td id="T_927fd_row3_col8" class="data row3 col8" >yes</td>
#       <td id="T_927fd_row3_col9" class="data row3 col9" >yes</td>
#       <td id="T_927fd_row3_col10" class="data row3 col10" >no</td>
#     </tr>
#     <tr>
#       <td id="T_927fd_row4_col0" class="data row4 col0" >Rosso</td>
#       <td id="T_927fd_row4_col1" class="data row4 col1" >Central Jakarta</td>
#       <td id="T_927fd_row4_col2" class="data row4 col2" >Sudirman</td>
#       <td id="T_927fd_row4_col3" class="data row4 col3" >no</td>
#       <td id="T_927fd_row4_col4" class="data row4 col4" >no</td>
#       <td id="T_927fd_row4_col5" class="data row4 col5" >no</td>
#       <td id="T_927fd_row4_col6" class="data row4 col6" >no</td>
#       <td id="T_927fd_row4_col7" class="data row4 col7" >wine, champagne, sparkling</td>
#       <td id="T_927fd_row4_col8" class="data row4 col8" >yes</td>
#       <td id="T_927fd_row4_col9" class="data row4 col9" >yes</td>
#       <td id="T_927fd_row4_col10" class="data row4 col10" >bar, city view</td>
#     </tr>
#     <tr>
#       <td id="T_927fd_row5_col0" class="data row5 col0" >Chilis Grill & Bar</td>
#       <td id="T_927fd_row5_col1" class="data row5 col1" >Central Jakarta</td>
#       <td id="T_927fd_row5_col2" class="data row5 col2" >Thamrin</td>
#       <td id="T_927fd_row5_col3" class="data row5 col3" >yes</td>
#       <td id="T_927fd_row5_col4" class="data row5 col4" >no</td>
#       <td id="T_927fd_row5_col5" class="data row5 col5" >no</td>
#       <td id="T_927fd_row5_col6" class="data row5 col6" >no</td>
#       <td id="T_927fd_row5_col7" class="data row5 col7" >margarita, beer, wine, mocktail</td>
#       <td id="T_927fd_row5_col8" class="data row5 col8" >yes</td>
#       <td id="T_927fd_row5_col9" class="data row5 col9" >yes</td>
#       <td id="T_927fd_row5_col10" class="data row5 col10" >kids menu, sports bar, bar</td>
#     </tr>
#     <tr>
#       <td id="T_927fd_row6_col0" class="data row6 col0" >Alto Restaurant & Bar</td>
#       <td id="T_927fd_row6_col1" class="data row6 col1" >Central Jakarta</td>
#       <td id="T_927fd_row6_col2" class="data row6 col2" >Gatot Subroto</td>
#       <td id="T_927fd_row6_col3" class="data row6 col3" >no</td>
#       <td id="T_927fd_row6_col4" class="data row6 col4" >no</td>
#       <td id="T_927fd_row6_col5" class="data row6 col5" >yes</td>
#       <td id="T_927fd_row6_col6" class="data row6 col6" >no</td>
#       <td id="T_927fd_row6_col7" class="data row6 col7" >sparkle, liquor, cocktail etc</td>
#       <td id="T_927fd_row6_col8" class="data row6 col8" >yes</td>
#       <td id="T_927fd_row6_col9" class="data row6 col9" >yes</td>
#       <td id="T_927fd_row6_col10" class="data row6 col10" >private room, luxury dining</td>
#     </tr>
#     <tr>
#       <td id="T_927fd_row7_col0" class="data row7 col0" >Cafe de Paris</td>
#       <td id="T_927fd_row7_col1" class="data row7 col1" >South Jakarta</td>
#       <td id="T_927fd_row7_col2" class="data row7 col2" >Kebayoran Lama</td>
#       <td id="T_927fd_row7_col3" class="data row7 col3" >yes</td>
#       <td id="T_927fd_row7_col4" class="data row7 col4" >no</td>
#       <td id="T_927fd_row7_col5" class="data row7 col5" >no</td>
#       <td id="T_927fd_row7_col6" class="data row7 col6" >no</td>
#       <td id="T_927fd_row7_col7" class="data row7 col7" >beer</td>
#       <td id="T_927fd_row7_col8" class="data row7 col8" >yes</td>
#       <td id="T_927fd_row7_col9" class="data row7 col9" >yes</td>
#       <td id="T_927fd_row7_col10" class="data row7 col10" >breakfast</td>
#     </tr>
#     <tr>
#       <td id="T_927fd_row8_col0" class="data row8 col0" >Tucano's Churrascaria</td>
#       <td id="T_927fd_row8_col1" class="data row8 col1" >South Jakarta</td>
#       <td id="T_927fd_row8_col2" class="data row8 col2" >Senayan</td>
#       <td id="T_927fd_row8_col3" class="data row8 col3" >yes</td>
#       <td id="T_927fd_row8_col4" class="data row8 col4" >yes</td>
#       <td id="T_927fd_row8_col5" class="data row8 col5" >yes</td>
#       <td id="T_927fd_row8_col6" class="data row8 col6" >yes</td>
#       <td id="T_927fd_row8_col7" class="data row8 col7" >highball, beer, wine, cocktail etc</td>
#       <td id="T_927fd_row8_col8" class="data row8 col8" >yes</td>
#       <td id="T_927fd_row8_col9" class="data row8 col9" >yes</td>
#       <td id="T_927fd_row8_col10"
